# %%
import sys
import os
from metient.metient import *
from metient.util import pairtree_data_extraction_util as ptutil

import matplotlib

matplotlib.rcParams['figure.figsize'] = [3, 3]

repo_dir = os.path.join(os.getcwd(),)
      
DATA_DIR = os.path.join(repo_dir, '/data/morrisq/divyak/data/gundem_neuroblastoma_2023/')
TREE_DIR = os.path.join(DATA_DIR, 'orchard_trees')    

print_config = PrintConfig(visualize=True, k_best_trees=1000)

# %% [markdown]
# ## Run Metient using orchard's eta estimation for U

# %%
# %%prun
OUTPUT_DIR = os.path.join(repo_dir, "metient", "data", "gundem_neuroblastoma_2023", "metient_outputs", "orchard_eta_solve_polys")

TSV_DIR = os.path.join(DATA_DIR, 'orchard_eta_clustered_tsvs')                 
patient_ids = [x.replace("_SNVs.tsv", "") for x in os.listdir(TSV_DIR)]
print(patient_ids)
len(patient_ids)

patient_ids = ['H103207']
mut_trees_fns = [os.path.join(TREE_DIR, f"{patient_id}.results.npz") for patient_id in patient_ids]
trees = [data[0] for data in ptutil.get_adj_matrices_from_pairtree_results(mut_trees_fns)]
ref_var_fns = [os.path.join(TSV_DIR, f"{patient_id}_SNVs.tsv") for patient_id in patient_ids]
run_names = [f"{pid}_calibrate" for pid in patient_ids]
calibrate_label_clone_tree(trees, ref_var_fns, print_config, OUTPUT_DIR, run_names, solve_polytomies=True,
                           sample_size=1024)
# Out:
# ['H116990', 'H116984', 'H132376', 'H134819', 'H132380', 'H132388', 'H112908', 'H132392', 'H134817', 'H132382', 'H116991', 'H112910', 'H133120', 'H118706', 'H112909', 'H116989', 'H103207', 'H132374', 'H134821', 'H134822', 'H132372', 'H132381', 'H132396', 'H116988', 'H132387', 'H132379', 'H132384']
# Saving results to /lila/data/morrisq/divyak/projects/metient/metient/data/gundem_neuroblastoma_2023/metient_outputs/orchard_eta_solve_polys/calibrate
# Overwriting existing directory at /lila/data/morrisq/divyak/projects/metient/metient/data/gundem_neuroblastoma_2023/metient_outputs/orchard_eta_solve_polys/calibrate
#
# *** Calibrating for patient: H103207_calibrate ***
# O: None
# Tumor samples: ['left lung lower lobe', 'liver', 'right lung lower lobe', 'brain, cerebellum', 'brain, right frontal', 'primary, left adrenal']
# 100%|██████████| 2800/2800 [02:58<00:00, 15.66it/s]
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:125: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/optim/lr_scheduler.py:136: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   warnings.warn("Detected call of `lr_scheduler.step()` before `optimizer.step()`. "
#   5%|▍         | 128/2800 [00:01<00:29, 91.22it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  10%|▉         | 276/2800 [00:02<00:19, 127.15it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  15%|█▌        | 426/2800 [00:03<00:18, 130.55it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  21%|██        | 575/2800 [00:04<00:17, 129.13it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  26%|██▌       | 725/2800 [00:05<00:16, 128.98it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  31%|███▏      | 875/2800 [00:06<00:14, 131.26it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  37%|███▋      | 1023/2800 [00:07<00:16, 108.88it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  42%|████▏     | 1166/2800 [00:09<00:14, 109.40it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  47%|████▋     | 1322/2800 [00:10<00:13, 109.69it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  52%|█████▏    | 1465/2800 [00:11<00:12, 110.61it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  58%|█████▊    | 1620/2800 [00:12<00:10, 110.88it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  63%|██████▎   | 1777/2800 [00:14<00:08, 121.77it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  69%|██████▉   | 1928/2800 [00:15<00:06, 131.32it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  74%|███████▍  | 2069/2800 [00:16<00:06, 111.38it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  79%|███████▉  | 2223/2800 [00:17<00:05, 107.50it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  84%|████████▍ | 2362/2800 [00:19<00:04, 106.29it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  90%|████████▉ | 2518/2800 [00:20<00:02, 105.23it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
#  96%|█████████▌| 2674/2800 [00:21<00:01, 110.45it/s]
# known_indices [37, 5, 8, 9, 38, 20, 23, 36, 11, 17, 21, 19, 22, 35, 16, 13, 6, 2, 1]
# 100%|█████████▉| 2789/2800 [00:22<00:00, 123.26it/s]
# Number of Pareto-optimal solutions: 7
# Calibrating to 1 patients
# Optimized thetas: tensor([0.38, 0.16, 0.46], grad_fn=<DivBackward0>)
# H103207_calibrate_primary, left adrenal
# 100%|██████████| 2800/2800 [00:38<00:00, 123.26it/s]
#          11516264 function calls (10409443 primitive calls) in 43.587 seconds
#
#    Ordered by: internal time
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#      3800    9.132    0.002    9.132    0.002 {method 'run_backward' of 'torch._C._EngineBase' objects}
#       112    2.722    0.024    2.728    0.024 {built-in method matplotlib._image.resample}
#      1763    2.581    0.001    2.581    0.001 {method 'acquire' of '_thread.lock' objects}
#      5638    2.317    0.000    2.317    0.000 {built-in method torch.rand}
#      1026    2.077    0.002    3.662    0.004 vertex_labeling_util.py:1410(path_matrix_dense)
#      1958    1.951    0.001    1.951    0.001 {method 'encode' of 'ImagingEncoder' objects}
#     96137    1.336    0.000    1.336    0.000 {built-in method torch.nonzero}
#        84    1.072    0.013    1.138    0.014 image.py:216(_rgb_to_rgba)
# 942781/1034    0.846    0.000    2.154    0.002 copy.py:128(deepcopy)
#      3813    0.577    0.000    1.337    0.000 vertex_labeling_util.py:382(genetic_distance_score)
#     25571    0.543    0.000    0.543    0.000 {built-in method torch.mul}
#     19760    0.503    0.000    0.503    0.000 {method 'repeat' of 'torch._C._TensorBase' objects}
#      3740    0.491    0.000    0.491    0.000 pydot.py:530(create_attribute_methods)
#      5600    0.485    0.000    0.485    0.000 {method 'sqrt' of 'torch._C._TensorBase' objects}
#      1000    0.449    0.000    0.549    0.001 eval_util.py:47(cross_ent)
#      2800    0.437    0.000   10.991    0.004 v_optimizer.py:404(compute_v_t_loss)
#      2800    0.425    0.000    4.053    0.001 v_optimizer.py:332(update_t_with_polytomy_resolver)
#     16801    0.415    0.000    0.415    0.000 {method 'max' of 'torch._C._TensorBase' objects}
#      2700    0.410    0.000    0.563    0.000 vertex_labeling_util.py:548(stack_fixed_labeling)
#      5600    0.382    0.000    2.952    0.001 v_optimizer.py:289(sample_gumbel)
#      5600    0.373    0.000    1.022    0.000 v_optimizer.py:293(softmax_shifted_3d)
#       271    0.357    0.001    0.357    0.001 {method 'decode' of 'ImagingDecoder' objects}
#      7601    0.350    0.000    0.350    0.000 {built-in method torch.exp}
#     31982    0.335    0.000    0.335    0.000 {built-in method torch.sum}
#      5278    0.321    0.000    0.390    0.000 vertex_labeling_util.py:502(clone_tree_labeling_loss_with_computed_metrics)
#     11534    0.313    0.000    0.313    0.000 {built-in method torch.rsub}
#     12466    0.300    0.000    0.473    0.000 vertex_labeling_util.py:1273(get_child_indices)
#     15013    0.299    0.000    0.299    0.000 {built-in method torch.log}
#      3813    0.278    0.000    0.278    0.000 {built-in method torch.bmm}
#      1600    0.268    0.000    0.268    0.000 {method 'split' of 're.Pattern' objects}
#      3813    0.256    0.000    6.711    0.002 vertex_labeling_util.py:431(ancestral_labeling_metrics)
#     16042    0.236    0.000    0.236    0.000 {method 'sum' of 'torch._C._TensorBase' objects}
#     60691    0.233    0.000    0.233    0.000 {built-in method torch.logical_or}
#      5600    0.230    0.000    4.206    0.001 v_optimizer.py:298(gumbel_softmax_sample)
#    119345    0.228    0.000    0.228    0.000 {method 'unsqueeze' of 'torch._C._TensorBase' objects}
#      2910    0.228    0.000    0.228    0.000 {built-in method torch.cat}
#      2800    0.226    0.000    1.149    0.000 adam.py:330(_single_tensor_adam)
#      5600    0.218    0.000    4.879    0.001 v_optimizer.py:302(gumbel_softmax)
#        19    0.211    0.011   22.266    1.172 v_optimizer.py:72(optimize_v_t)
# 64283/3516    0.198    0.000    2.151    0.001 copy.py:258(_reconstruct)
#      4596    0.186    0.000    0.186    0.000 {built-in method posix.stat}
# 62884/1032    0.185    0.000    2.131    0.002 copy.py:226(_deepcopy_dict)
#        14    0.183    0.013    0.183    0.013 {built-in method posix.read}
#     60823    0.174    0.000    0.270    0.000 copy.py:200(_deepcopy_list)
#     23731    0.160    0.000    0.160    0.000 {method 'unbind' of 'torch._C._TensorBase' objects}
#   2003287    0.159    0.000    0.159    0.000 {method 'get' of 'dict' objects}
#     18964    0.159    0.000    0.159    0.000 {built-in method torch.zeros}
#        14    0.156    0.011    0.156    0.011 {built-in method _posixsubprocess.fork_exec}
#      3813    0.147    0.000    0.313    0.000 vertex_labeling_util.py:247(comigration_number_approximation)
#      1006    0.145    0.000    0.264    0.000 polytomy_resolver.py:292(remove_nodes_from_adjacency_matrix)
#      7600    0.144    0.000    0.144    0.000 {built-in method torch._ops.profiler._record_function_enter_new}
#      5600    0.139    0.000    0.139    0.000 {method 'scatter_' of 'torch._C._TensorBase' objects}
#      7626    0.138    0.000    0.138    0.000 {built-in method torch.sigmoid}
#      5860    0.128    0.000    0.370    0.000 polytomy_resolver.py:172(should_remove_node)
#      3813    0.123    0.000    0.260    0.000 vertex_labeling_util.py:233(seeding_site_number)
#   1459732    0.123    0.000    0.123    0.000 {built-in method builtins.id}
#     30860    0.110    0.000    0.436    0.000 vertex_labeling_util.py:115(_nonzero_tuple)
#      1006    0.110    0.000    0.440    0.000 polytomy_resolver.py:326(remove_nodes)
#     14397    0.107    0.000    0.107    0.000 {built-in method torch.where}
#      2800    0.104    0.000    0.104    0.000 {built-in method torch.mm}
#    246364    0.101    0.000    0.143    0.000 copy.py:242(_keep_alive)
#      8023    0.100    0.000    0.100    0.000 {built-in method torch.eye}
#       144    0.096    0.001    0.096    0.001 vertex_labeling_util.py:1312(<listcomp>)
#      5600    0.096    0.000    0.096    0.000 {method 'mul_' of 'torch._C._TensorBase' objects}
#      5600    0.091    0.000    0.091    0.000 {method 'lerp_' of 'torch._C._TensorBase' objects}
#     23554    0.089    0.000    0.089    0.000 {method 'reshape' of 'torch._C._TensorBase' objects}
#      9311    0.087    0.000    0.087    0.000 {built-in method torch.tensor}
#     31455    0.083    0.000    0.083    0.000 {method 'tolist' of 'torch._C._TensorBase' objects}
#     17594    0.083    0.000    0.083    0.000 {built-in method torch.argmax}
#       678    0.080    0.000    0.080    0.000 {built-in method numpy.zeros}
#      5600    0.077    0.000    0.077    0.000 {method 'addcdiv_' of 'torch._C._TensorBase' objects}
#      5600    0.075    0.000    0.075    0.000 {method 'addcmul_' of 'torch._C._TensorBase' objects}
#     60767    0.074    0.000    1.251    0.000 copy.py:209(_deepcopy_tuple)
#      3813    0.074    0.000    0.205    0.000 vertex_labeling_util.py:465(calc_entropy)
#     11446    0.067    0.000    0.067    0.000 {method 'permute' of 'torch._C._TensorBase' objects}
#      3800    0.063    0.000    1.673    0.000 optimizer.py:356(wrapper)
#      6600    0.060    0.000    0.060    0.000 {method 'add_' of 'torch._C._TensorBase' objects}
#         1    0.058    0.058    1.417    1.417 eval_util.py:93(get_max_cross_ent_thetas)
#         4    0.057    0.014    0.057    0.014 backend_agg.py:78(__init__)
#      2814    0.056    0.000    0.056    0.000 {built-in method torch.mean}
#         1    0.056    0.056    7.534    7.534 migration_history_inference.py:70(get_best_final_solutions)
# 419267/419248    0.054    0.000    0.062    0.000 {built-in method builtins.isinstance}
#     12556    0.053    0.000    0.053    0.000 {method 'clone' of 'torch._C._TensorBase' objects}
#    696417    0.052    0.000    0.052    0.000 copy.py:182(_deepcopy_atomic)
#      1025    0.050    0.000    0.116    0.000 vertex_labeling_util.py:261(comigration_number_dense)
#      7197    0.049    0.000    0.049    0.000 {method 'reduce' of 'numpy.ufunc' objects}
#      4813    0.049    0.000    0.049    0.000 {built-in method torch.log2}
#      3839    0.048    0.000    0.331    0.000 eval_frame.py:267(__call__)
#        12    0.047    0.004    0.047    0.004 {method 'compress' of 'zlib.Compress' objects}
#     18727    0.047    0.000    0.601    0.000 vertex_labeling_util.py:1327(repeat_n)
#     49128    0.045    0.000    0.045    0.000 {method 'item' of 'torch._C._TensorBase' objects}
#    467549    0.044    0.000    0.044    0.000 {method 'append' of 'list' objects}
#       342    0.044    0.000    0.044    0.000 {method 'set_text' of 'matplotlib.ft2font.FT2Font' objects}
#         1    0.044    0.044    0.044    0.044 optimal_subtrees.py:50(<listcomp>)
#      7600    0.044    0.000    0.044    0.000 {built-in method torch._ops.profiler.}
#      7626    0.043    0.000    0.043    0.000 {built-in method torch.diagonal}
#         2    0.041    0.021    0.041    0.021 {method 'copy' of 'ImagingCore' objects}
#        18    0.041    0.002    0.041    0.002 optimal_subtrees.py:204(_apply_poly_fixes)
#      3800    0.040    0.000    0.176    0.000 optimizer.py:776(zero_grad)
#    213824    0.039    0.000    0.041    0.000 {built-in method builtins.getattr}
#     64283    0.039    0.000    0.039    0.000 {method '__reduce_ex__' of 'object' objects}
#         5    0.039    0.008    0.040    0.008 {method 'read_low_memory' of 'pandas._libs.parsers.TextReader' objects}
#     60767    0.037    0.000    1.172    0.000 copy.py:210(<listcomp>)
#         1    0.036    0.036    0.210    0.210 optimal_subtrees.py:78(find_optimal_subtree_nodes)
#      3800    0.035    0.000    1.431    0.000 optimizer.py:58(_use_grad)
#      3813    0.035    0.000    7.278    0.002 vertex_labeling_util.py:518(clone_tree_labeling_objective)
#      3813    0.034    0.000    0.140    0.000 vertex_labeling_util.py:221(migration_number)
#         1    0.033    0.033    6.818    6.818 polytomy_resolver.py:344(remove_extra_resolver_nodes)
#         4    0.033    0.008    0.033    0.008 {method 'clear' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      5551    0.032    0.000    0.082    0.000 optimal_subtrees.py:58(get_descendants)
#      7600    0.032    0.000    0.082    0.000 profiler.py:636(__exit__)
#       655    0.031    0.000    0.031    0.000 socket.py:621(send)
#    271137    0.031    0.000    0.034    0.000 {built-in method builtins.setattr}
#         2    0.031    0.015    0.031    0.015 {method 'draw_path' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      3839    0.030    0.000    0.244    0.000 eval_frame.py:307(_fn)
#      2800    0.029    0.000    0.038    0.000 adam.py:80(_init_group)
#      5600    0.029    0.000    0.029    0.000 {built-in method torch.unsqueeze}
#        14    0.028    0.002    0.038    0.003 core.py:2332(masked_invalid)
#      7600    0.028    0.000    0.054    0.000 profiler.py:619(__init__)
#      7600    0.027    0.000    0.027    0.000 optimizer.py:122(<genexpr>)
#     23731    0.027    0.000    0.210    0.000 _tensor.py:980(__iter__)
#    123596    0.026    0.000    0.095    0.000 copy.py:263(<genexpr>)
#      6904    0.026    0.000    0.026    0.000 {method 'detach' of 'torch._C._TensorBase' objects}
#      2819    0.026    0.000    0.045    0.000 lr_scheduler.py:124(step)
#        28    0.025    0.001    0.025    0.001 {method 'draw_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#      3839    0.025    0.000    0.238    0.000 inspect.py:692(getsourcefile)
#      2800    0.025    0.000    0.964    0.000 vertex_labeling_util.py:592(stack_vertex_labeling)
#      3800    0.024    0.000    9.219    0.002 __init__.py:149(backward)
#      6992    0.024    0.000    0.053    0.000 vertex_labeling_util.py:858(tree_iterator)
#        14    0.024    0.002    0.987    0.070 plotting_util.py:604(migration_history_tree_dot)
#      3800    0.024    0.000    0.051    0.000 __init__.py:56(_make_grads)
#      4839    0.024    0.000    0.024    0.000 {built-in method torch.transpose}
# 56524/45816    0.024    0.000    0.039    0.000 artist.py:319(stale)
#        19    0.023    0.001    0.141    0.007 v_optimizer.py:463(x_weight_initialization)
#      9050    0.023    0.000    0.292    0.000 vertex_labeling_util.py:124(__hash__)
#      3200    0.023    0.000    0.294    0.000 plotting_util.py:478(pruned_mut_label)
#      3800    0.023    0.000    0.023    0.000 {built-in method torch.ones_like}
# 158237/156747    0.022    0.000    0.026    0.000 {built-in method builtins.len}
#      6143    0.022    0.000    0.022    0.000 {built-in method numpy.array}
#     64283    0.022    0.000    0.030    0.000 copyreg.py:90(__newobj__)
#    205212    0.022    0.000    0.022    0.000 {method 'items' of 'dict' objects}
#      7600    0.021    0.000    0.173    0.000 profiler.py:630(__enter__)
# 19786/14102    0.021    0.000    0.111    0.000 {built-in method numpy.core._multiarray_umath.implement_array_function}
#        72    0.021    0.000    0.021    0.000 {method 'join' of 'bytes' objects}
#      3190    0.021    0.000    0.197    0.000 vertex_labeling_util.py:128(__eq__)
#        14    0.021    0.001    0.021    0.001 {built-in method PIL._imaging.new}
#      4801    0.020    0.000    0.093    0.000 artist.py:1180(_update_props)
#     18346    0.020    0.000    0.029    0.000 pydot.py:233(<listcomp>)
#      2001    0.020    0.000    0.051    0.000 eval_util.py:41(stable_softmax)
#      2800    0.020    0.000    0.020    0.000 {method 't' of 'torch._C._TensorBase' objects}
#      3800    0.019    0.000    0.062    0.000 optimizer.py:109(_default_to_fused_or_foreach)
#      3839    0.018    0.000    0.035    0.000 inspect.py:654(getfile)
#      2800    0.018    0.000    1.341    0.000 adam.py:130(step)
#     57441    0.018    0.000    0.018    0.000 {method 'match' of 're.Pattern' objects}
#     11534    0.017    0.000    0.348    0.000 _tensor.py:34(wrapped)
#      2800    0.017    0.000    1.224    0.000 adam.py:254(adam)
#     18374    0.017    0.000    0.060    0.000 pydot.py:214(needs_quotes)
#       646    0.016    0.000    0.016    0.000 {built-in method torch.rand_like}
#      1006    0.016    0.000    0.020    0.000 vertex_labeling_util.py:81(remove_indices_and_reindex)
#      3839    0.016    0.000    0.634    0.000 _compile.py:20(inner)
#       117    0.015    0.000    0.029    0.000 vertex_labeling_util.py:1297(get_parent_idx_sparse_t)
#     87711    0.015    0.000    0.015    0.000 {built-in method builtins.hasattr}
#      9814    0.015    0.000    0.017    0.000 contextlib.py:82(__init__)
#      3839    0.015    0.000    0.374    0.000 decorators.py:33(disable)
# 27477/24649    0.015    0.000    0.023    0.000 {built-in method builtins.hash}
#        14    0.015    0.001    0.019    0.001 plotting_util.py:673(<dictcomp>)
#      7600    0.015    0.000    0.025    0.000 typing.py:255(inner)
#      2700    0.014    0.000    0.014    0.000 {method 'squeeze' of 'torch._C._TensorBase' objects}
#      3800    0.014    0.000    9.235    0.002 _tensor.py:433(backward)
#     20276    0.014    0.000    0.080    0.000 pydot.py:250(quote_if_necessary)
#       594    0.014    0.000    0.057    0.000 vertex_labeling_util.py:1126(get_resolver_sites_of_node_and_children)
#        14    0.014    0.001    0.026    0.002 plotting_util.py:610(<dictcomp>)
#      4253    0.014    0.000    0.023    0.000 __init__.py:1736(normalize_kwargs)
#      3860    0.014    0.000    0.027    0.000 functools.py:34(update_wrapper)
#         1    0.014    0.014   30.938   30.938 migration_history_inference.py:527(infer_migration_history)
#     25609    0.014    0.000    0.014    0.000 {built-in method torch._C._get_tracing_state}
# 16681/15221    0.013    0.000    0.044    0.000 {built-in method builtins.any}
#      2015    0.013    0.000    0.013    0.000 {built-in method torch.max}
#     41748    0.013    0.000    0.030    0.000 __init__.py:729(__getitem__)
#       240    0.013    0.000    0.106    0.000 threading.py:540(wait)
#     11534    0.013    0.000    0.326    0.000 _tensor.py:907(__rsub__)
#     15358    0.013    0.000    0.013    0.000 {method 'size' of 'torch._C._TensorBase' objects}
# 14740/4122    0.013    0.000    0.017    0.000 transforms.py:167(_invalidate_internal)
#     11814    0.012    0.000    0.020    0.000 __init__.py:2004(_setattr_cm)
# 9517/9489    0.012    0.000    0.019    0.000 __init__.py:301(process)
#      2051    0.012    0.000    0.012    0.000 {method 'int' of 'torch._C._TensorBase' objects}
#      3839    0.012    0.000    0.013    0.000 eval_frame.py:221(__init__)
#      7720    0.012    0.000    0.022    0.000 grad_mode.py:182(__init__)
#      2971    0.012    0.000    0.012    0.000 {method 'nonzero' of 'torch._C._TensorBase' objects}
#      2800    0.012    0.000    0.058    0.000 optimizer.py:309(_cuda_graph_capture_health_check)
#        56    0.012    0.000    3.919    0.070 image.py:328(_make_image)
#      1524    0.011    0.000    0.029    0.000 arraysetops.py:323(_unique1d)
#        18    0.011    0.001    0.014    0.001 optimal_subtrees.py:180(_apply_node_fixes)
#      2835    0.011    0.000    0.017    0.000 os.py:670(__getitem__)
#      5156    0.011    0.000    0.050    0.000 vertex_labeling_util.py:476(get_repeating_weight_vector)
#      1025    0.010    0.000    0.010    0.000 {built-in method torch.logical_xor}
#     41748    0.010    0.000    0.017    0.000 __init__.py:678(_get)
#      4388    0.010    0.000    0.012    0.000 transforms.py:194(set_children)
#    214399    0.010    0.000    0.010    0.000 {built-in method builtins.ord}
#      1804    0.010    0.000    0.011    0.000 function_base.py:1320(diff)
#     22824    0.010    0.000    0.012    0.000 __init__.py:101(check_in_list)
#      3839    0.010    0.000    0.023    0.000 eval_frame.py:442(__init__)
#      1592    0.010    0.000    0.014    0.000 inspect.py:2901(_bind)
#      4402    0.009    0.000    0.014    0.000 font_manager.py:633(__hash__)
#       182    0.009    0.000    0.009    0.000 {method 'draw_glyphs_to_bitmap' of 'matplotlib.ft2font.FT2Font' objects}
# 29813/29573    0.009    0.000    0.040    0.000 {built-in method builtins.next}
# 9814/9754    0.009    0.000    0.023    0.000 contextlib.py:117(__exit__)
#         5    0.009    0.002    0.009    0.002 c_parser_wrapper.py:49(__init__)
#       594    0.009    0.000    0.027    0.000 optimal_subtrees.py:129(_collect_node_fixes)
#      2800    0.009    0.000    1.604    0.001 grad_scaler.py:318(step)
#      3839    0.009    0.000    0.009    0.000 skipfiles.py:205(check)
#      7626    0.009    0.000    0.016    0.000 vertex_labeling_util.py:795(add_batch_dim)
#     66605    0.009    0.000    0.009    0.000 {built-in method __new__ of type object at 0x5584f2af4620}
# 9814/9754    0.009    0.000    0.030    0.000 contextlib.py:108(__enter__)
#      5600    0.008    0.000    0.013    0.000 optimizer.py:97(_dispatch_sqrt)
# 3212/1662    0.008    0.000    0.031    0.000 transforms.py:2444(get_affine)
#      1032    0.008    0.000    3.811    0.004 vertex_labeling_util.py:287(comigration_number)
#      3820    0.008    0.000    0.008    0.000 {method 'to_dense' of 'torch._C._TensorBase' objects}
#      3813    0.008    0.000    0.031    0.000 vertex_labeling_util.py:406(organotropism_score)
#        18    0.008    0.000    0.197    0.011 optimal_subtrees.py:257(init_optimal_x_polyres)
#       206    0.008    0.000    0.017    0.000 std.py:464(format_meter)
#       182    0.008    0.000    0.009    0.000 {method 'draw_text_image' of 'matplotlib.backends._backend_agg.RendererAgg' objects}
#       240    0.008    0.000    0.008    0.000 threading.py:222(__init__)
#      2800    0.008    0.000    0.201    0.000 std.py:1198(update)
# 9334/9332    0.008    0.000    0.438    0.000 {built-in method numpy.asarray}
#      7720    0.008    0.000    0.008    0.000 {built-in method torch._C._set_grad_enabled}
#      3929    0.008    0.000    0.166    0.000 genericpath.py:16(exists)
#      5600    0.008    0.000    0.022    0.000 optimizer.py:84(_get_value)
#      1461    0.008    0.000    0.014    0.000 artist.py:180(__init__)
#      3914    0.008    0.000    0.018    0.000 transforms.py:754(__init__)
#      7434    0.008    0.000    0.018    0.000 vertex_labeling_util.py:157(convert_metric_to_int)
#       504    0.008    0.000    0.061    0.000 lines.py:274(__init__)
#     66240    0.008    0.000    0.008    0.000 {built-in method builtins.issubclass}
#      5010    0.008    0.000    0.021    0.000 copy.py:66(copy)
#       926    0.008    0.000    0.053    0.000 pydot.py:656(to_string)
#      9614    0.008    0.000    0.008    0.000 {method 'copy' of 'numpy.ndarray' objects}
#      7600    0.008    0.000    0.011    0.000 typing.py:329(__hash__)
#     19583    0.008    0.000    0.008    0.000 {method 'endswith' of 'str' objects}
#       930    0.007    0.000    0.039    0.000 pydot.py:834(to_string)
#      7600    0.007    0.000    0.151    0.000 _ops.py:687(__call__)
#         7    0.007    0.001    0.014    0.002 vertex_labeling_util.py:1377(purdom_transitive_closure)
#        28    0.007    0.000    0.253    0.009 nx_pydot.py:202(to_pydot)
# 10111/10106    0.007    0.000    0.042    0.000 {built-in method builtins.all}
#     18672    0.007    0.000    0.007    0.000 {method 'numel' of 'torch._C._TensorBase' objects}
#      9814    0.007    0.000    0.024    0.000 contextlib.py:238(helper)
#      3839    0.007    0.000    0.045    0.000 package_importer.py:692(_patched_getfile)
#     25635    0.007    0.000    0.007    0.000 {method 'dim' of 'torch._C._TensorBase' objects}
#      2820    0.007    0.000    0.044    0.000 __init__.py:125(is_available)
#     56636    0.007    0.000    0.007    0.000 artist.py:851(get_animated)
#      3651    0.007    0.000    0.010    0.000 __init__.py:65(check_isinstance)
#      2800    0.007    0.000    0.007    0.000 lr_scheduler.py:562(<listcomp>)
#        14    0.007    0.000    0.007    0.000 {built-in method pygraphviz._graphviz.agread}
#      5752    0.007    0.000    0.022    0.000 fromnumeric.py:69(_wrapreduction)
#       217    0.007    0.000    0.007    0.000 {method 'coalesce' of 'torch._C._TensorBase' objects}
#       140    0.007    0.000    0.067    0.000 text.py:363(_get_layout)
#         7    0.006    0.001    0.081    0.012 plotting_util.py:306(phyleticity)
#      2819    0.006    0.000    0.013    0.000 lr_scheduler.py:551(get_lr)
#      2478    0.006    0.000    0.037    0.000 vertex_labeling_util.py:173(__init__)
#        19    0.006    0.000    0.006    0.000 {built-in method posix.unlink}
#      4253    0.006    0.000    0.006    0.000 __init__.py:1775(<dictcomp>)
#      7434    0.006    0.000    0.013    0.000 vertex_labeling_util.py:164(convert_metric_to_float)
#       224    0.006    0.000    0.104    0.000 _base.py:2937(_update_title_position)
#      3138    0.006    0.000    0.007    0.000 {built-in method builtins.sorted}
#     41804    0.006    0.000    0.006    0.000 {function RcParams.__getitem__ at 0x2aafa845baf0}
#     12960    0.006    0.000    0.006    0.000 {method 'update' of 'dict' objects}
#     15724    0.006    0.000    0.006    0.000 transforms.py:110(__init__)
#      1092    0.006    0.000    0.085    0.000 text.py:918(get_window_extent)
# 36458/36457    0.006    0.000    0.006    0.000 {built-in method builtins.iter}
#      2820    0.006    0.000    0.023    0.000 _collections_abc.py:657(get)
#      1219    0.006    0.000    0.067    0.000 text.py:185(_reset_visual_defaults)
#      7619    0.006    0.000    0.006    0.000 {built-in method torch._C._get_privateuse1_backend_name}
#      3800    0.006    0.000    0.006    0.000 {built-in method torch._C._are_functorch_transforms_active}
#      2820    0.006    0.000    0.032    0.000 __init__.py:121(_nvml_based_avail)
#     11517    0.005    0.000    0.011    0.000 inspect.py:699(<genexpr>)
#       947    0.005    0.000    0.005    0.000 {method 'append' of 'collections.deque' objects}
#      5156    0.005    0.000    0.005    0.000 vertex_labeling_util.py:483(<listcomp>)
#        14    0.005    0.000    0.352    0.025 subprocess.py:1552(_execute_child)
#      4525    0.005    0.000    0.005    0.000 vertex_labeling_util.py:106(__init__)
#      8464    0.005    0.000    0.009    0.000 transforms.py:1772(__init__)
#         1    0.005    0.005    0.005    0.005 {method 'flush' of '_io.BufferedRandom' objects}
#      7600    0.005    0.000    0.049    0.000 _ops.py:447(__call__)
#     11534    0.005    0.000    0.005    0.000 {built-in method torch._C._has_torch_function}
#      7238    0.005    0.000    0.014    0.000 artist.py:103(_stale_axes_callback)
#        72    0.005    0.000    0.005    0.000 {built-in method io.open}
#      4510    0.005    0.000    0.013    0.000 transforms.py:1889(__init__)
#        20    0.005    0.000    0.064    0.003 vertex_labeling_util.py:1156(get_k_or_more_children_nodes)
#       168    0.005    0.000    0.012    0.000 arraysetops.py:524(in1d)
#     11580    0.005    0.000    0.005    0.000 {built-in method torch.is_grad_enabled}
#      5600    0.005    0.000    0.005    0.000 {built-in method torch.is_complex}
#      3860    0.005    0.000    0.005    0.000 functools.py:64(wraps)
#        16    0.005    0.000    0.005    0.000 {method 'close' of '_io.BufferedWriter' objects}
#       594    0.005    0.000    0.038    0.000 vertex_labeling_util.py:1093(top_k_integers_by_count)
#        14    0.004    0.000    0.050    0.004 plotting_util.py:562(migration_graph_dot)
#       168    0.004    0.000    0.132    0.001 axis.py:58(__init__)
#  1614/816    0.004    0.000    0.085    0.000 deprecation.py:379(wrapper)
#     15356    0.004    0.000    0.006    0.000 inspect.py:702(<genexpr>)
#      1555    0.004    0.000    0.020    0.000 font_manager.py:590(__init__)
#      9315    0.004    0.000    0.022    0.000 artist.py:417(pchanged)
#      7698    0.004    0.000    0.016    0.000 colors.py:213(_is_nth_color)
#      1006    0.004    0.000    0.004    0.000 polytomy_resolver.py:318(<listcomp>)
#      1007    0.004    0.000    0.004    0.000 {method 'any' of 'torch._C._TensorBase' objects}
#      8565    0.004    0.000    0.006    0.000 re.py:289(_compile)
#       592    0.004    0.000    0.033    0.000 patches.py:742(get_patch_transform)
#      2820    0.004    0.000    0.027    0.000 os.py:766(getenv)
#      5247    0.004    0.000    0.018    0.000 colors.py:265(to_rgba)
#      2690    0.004    0.000    0.006    0.000 font_manager.py:809(set_size)
#        28    0.004    0.000    0.392    0.014 pydot.py:1482(to_string)
#      1000    0.004    0.000    0.004    0.000 {built-in method torch.isnan}
#        14    0.004    0.000    0.004    0.000 {built-in method pygraphviz._graphviz.agwrite}
#       112    0.004    0.000    2.753    0.025 image.py:160(_resample)
#      1860    0.004    0.000    0.317    0.000 pydot.py:721(__init__)
#      2835    0.004    0.000    0.006    0.000 os.py:748(encode)
#      1000    0.004    0.000    0.005    0.000 sgd.py:36(_init_group)
#     26460    0.004    0.000    0.004    0.000 _jit_internal.py:1109(is_scripting)
#      7473    0.004    0.000    0.247    0.000 {method 'add' of 'set' objects}
#      8400    0.004    0.000    0.004    0.000 adam.py:296(<genexpr>)
#      1750    0.004    0.000    0.006    0.000 transforms.py:2054(scale)
#      7678    0.004    0.000    0.005    0.000 eval_frame.py:192(innermost_fn)
#      8767    0.004    0.000    0.006    0.000 {method 'join' of 'str' objects}
#        14    0.004    0.000    0.043    0.003 plotting_util.py:664(collect_top_tree_info)
#      1006    0.004    0.000    0.004    0.000 polytomy_resolver.py:334(<listcomp>)
#      4651    0.004    0.000    0.004    0.000 {method 'reshape' of 'numpy.ndarray' objects}
#       547    0.004    0.000    0.007    0.000 pathlib.py:64(parse_parts)
#      3800    0.004    0.000    0.008    0.000 _foreach_utils.py:14(_get_fused_kernels_supported_devices)
#      5600    0.004    0.000    0.004    0.000 {method 'conj' of 'torch._C._TensorBase' objects}
# 6608/4088    0.004    0.000    0.010    0.000 transforms.py:2384(_invalidate_internal)
#         1    0.003    0.003    0.003    0.003 {built-in method posix.listdir}
#      1006    0.003    0.000    0.003    0.000 polytomy_resolver.py:337(<listcomp>)
#      6878    0.003    0.000    0.011    0.000 re.py:188(match)
#        50    0.003    0.000    0.003    0.000 {method 'decompress' of 'zlib.Decompress' objects}
#        42    0.003    0.000    0.003    0.000 plotting_util.py:42(dfs)
#      7468    0.003    0.000    0.003    0.000 {built-in method numpy.asanyarray}
#      4178    0.003    0.000    0.005    0.000 {method 'format' of 'str' objects}
#      3706    0.003    0.000    0.092    0.000 artist.py:1227(set)
#      1852    0.003    0.000    0.190    0.000 pydot.py:581(__init__)
#      2185    0.003    0.000    0.003    0.000 {built-in method matplotlib._path.affine_transform}
#      1000    0.003    0.000    0.029    0.000 sgd.py:55(step)
#      7702    0.003    0.000    0.004    0.000 inspect.py:72(isclass)
#      7755    0.003    0.000    0.005    0.000 _tensor.py:1002(__hash__)
#       734    0.003    0.000    0.016    0.000 font_manager.py:1201(findfont)
#      1006    0.003    0.000    0.003    0.000 polytomy_resolver.py:338(<listcomp>)
#      1882    0.003    0.000    0.007    0.000 fromnumeric.py:38(_wrapit)
#     23252    0.003    0.000    0.003    0.000 {built-in method builtins.callable}
#     11142    0.003    0.000    0.005    0.000 nx_pydot.py:257(<genexpr>)
#        18    0.003    0.000   21.518    1.195 v_optimizer.py:207(second_v_optimization)
#      3682    0.003    0.000    0.013    0.000 fromnumeric.py:51(_wrapfunc)
# 2814/2799    0.003    0.000    0.011    0.000 transforms.py:1109(get_points)
#       217    0.003    0.000    0.003    0.000 threading.py:258(_acquire_restore)
#       336    0.003    0.000    0.148    0.000 axis.py:867(clear)
#       212    0.003    0.000    0.145    0.001 iostream.py:547(flush)
#       392    0.003    0.000    0.012    0.000 ticker.py:2010(_validate_steps)
#     15239    0.003    0.000    0.003    0.000 {method 'values' of 'collections.OrderedDict' objects}
#      7478    0.003    0.000    0.004    0.000 {built-in method _abc._abc_instancecheck}
#      1378    0.003    0.000    0.035    0.000 transforms.py:1475(transform)
#      3839    0.003    0.000    0.003    0.000 inspect.py:63(ismodule)
#       392    0.003    0.000    0.028    0.000 axis.py:351(_apply_params)
#     24384    0.003    0.000    0.003    0.000 artist.py:295(axes)
#     10826    0.003    0.000    0.005    0.000 utils.py:375(<genexpr>)
#     31836    0.003    0.000    0.003    0.000 nx_pydot.py:195(_check_colon_quotes)
#      1915    0.003    0.000    0.003    0.000 __init__.py:197(__init__)
#        42    0.003    0.000    0.004    0.000 plotting_util.py:542(migration_graph)
#       392    0.003    0.000    0.113    0.000 text.py:738(draw)
#      7678    0.003    0.000    0.003    0.000 {built-in method torch._C._dynamo.eval_frame.set_eval_frame}
#       594    0.003    0.000    0.105    0.000 optimal_subtrees.py:153(_collect_poly_fixes)
#      1884    0.003    0.000    0.010    0.000 transforms.py:2355(__init__)
#      6538    0.003    0.000    0.004    0.000 function_base.py:346(iterable)
#        28    0.003    0.000    0.315    0.011 plotting_util.py:508(full_tree_node_idx_to_label)
#      1820    0.003    0.000    0.005    0.000 __init__.py:890(get_siblings)
#      5551    0.003    0.000    0.008    0.000 optimal_subtrees.py:69(<listcomp>)
#      1947    0.003    0.000    0.017    0.000 text.py:985(set_color)
#      1033    0.003    0.000    3.679    0.004 vertex_labeling_util.py:1439(path_matrix)
#         2    0.003    0.001   10.444    5.222 plotting_util.py:898(save_outputs)
#       912    0.003    0.000    0.003    0.000 nx_pydot.py:253(<dictcomp>)
#         1    0.003    0.003    0.104    0.104 migration_history_inference.py:23(prune_histories)
#      4694    0.003    0.000    0.003    0.000 {method 'cpu' of 'torch._C._TensorBase' objects}
#      5600    0.003    0.000    0.003    0.000 {built-in method math.sqrt}
#      7678    0.003    0.000    0.003    0.000 eval_frame.py:205(enable_dynamic)
#       840    0.003    0.000    0.011    0.000 markers.py:327(_set_marker)
#      3706    0.003    0.000    0.095    0.000 artist.py:147(<lambda>)
#      3800    0.002    0.000    0.004    0.000 _foreach_utils.py:8(_get_foreach_kernels_supported_devices)
#       784    0.002    0.000    0.007    0.000 axis.py:1870(_set_formatter)
# 1325/1179    0.002    0.000    0.172    0.000 deprecation.py:443(wrapper)
#      5394    0.002    0.000    0.003    0.000 {built-in method builtins.max}
#      3800    0.002    0.000    0.002    0.000 __init__.py:139(_tensor_or_tensors_to_tuple)
# 2185/2184    0.002    0.000    0.007    0.000 transforms.py:1851(transform_affine)
#       168    0.002    0.000    0.010    0.000 lines.py:656(recache)
#      1000    0.002    0.000    0.021    0.000 sgd.py:185(sgd)
#     16800    0.002    0.000    0.002    0.000 _utils.py:841(is_compiling)
#       112    0.002    0.000    4.142    0.037 _base.py:2999(draw)
#      4122    0.002    0.000    0.020    0.000 transforms.py:157(invalidate)
#       895    0.002    0.000    2.499    0.003 threading.py:1017(_wait_for_tstate_lock)
#       655    0.002    0.000    0.039    0.000 iostream.py:243(schedule)
#      2016    0.002    0.000    0.003    0.000 axis.py:2206(<genexpr>)
#       240    0.002    0.000    0.011    0.000 threading.py:505(__init__)
#      3839    0.002    0.000    0.003    0.000 inspect.py:80(ismethod)
#      2820    0.002    0.000    0.002    0.000 {built-in method torch._C._cuda_getDeviceCount}
#       392    0.002    0.000    0.029    0.000 ticker.py:533(set_useMathText)
#       240    0.002    0.000    0.002    0.000 threading.py:249(__exit__)
#      2353    0.002    0.000    0.005    0.000 text.py:1249(set_verticalalignment)
#       392    0.002    0.000    0.007    0.000 _base.py:4273(get_children)
#      1798    0.002    0.000    0.022    0.000 transforms.py:809(from_extents)
#       168    0.002    0.000    0.031    0.000 path.py:603(get_extents)
#      3373    0.002    0.000    0.004    0.000 vertex_labeling_util.py:1506(<genexpr>)
#       217    0.002    0.000    0.090    0.000 threading.py:270(wait)
#      1991    0.002    0.000    0.009    0.000 artist.py:438(set_transform)
#      3472    0.002    0.000    0.003    0.000 spines.py:558(__getitem__)
#      2578    0.002    0.000    0.034    0.000 vertex_labeling_util.py:496(get_mig_weight_vector)
#       732    0.002    0.000    0.004    0.000 transforms.py:1986(rotate)
#       218    0.002    0.000    0.002    0.000 {built-in method zlib.crc32}
#       312    0.002    0.000    0.016    0.000 iostream.py:610(write)
#      5752    0.002    0.000    0.002    0.000 fromnumeric.py:70(<dictcomp>)
#       610    0.002    0.000    0.003    0.000 transforms.py:379(bounds)
#      7478    0.002    0.000    0.006    0.000 abc.py:96(__instancecheck__)
#      2548    0.002    0.000    0.007    0.000 units.py:56(_is_natively_supported)
#      2820    0.002    0.000    0.003    0.000 __init__.py:116(_is_compiled)
#       420    0.002    0.000    0.039    0.000 artist.py:778(set_clip_path)
#      2448    0.002    0.000    0.011    0.000 fromnumeric.py:2829(amin)
#         9    0.002    0.000    0.002    0.000 encoder.py:204(iterencode)
#      1878    0.002    0.000    0.003    0.000 _tensor.py:964(__len__)
#       930    0.002    0.000    0.003    0.000 pydot.py:1249(add_edge)
#      1680    0.002    0.000    0.007    0.000 markers.py:277(_recache)
#      3849    0.002    0.000    0.002    0.000 inspect.py:158(isfunction)
#      3212    0.002    0.000    0.007    0.000 <__array_function__ internals>:177(dot)
#   784/672    0.002    0.000    0.004    0.000 spines.py:332(get_spine_transform)
#         2    0.002    0.001   11.643    5.821 plotting_util.py:812(save_best_trees)
#     568/4    0.002    0.000    4.182    1.046 artist.py:54(draw_wrapper)
#       926    0.002    0.000    0.004    0.000 pydot.py:1137(add_node)
#      2448    0.002    0.000    0.010    0.000 fromnumeric.py:2703(amax)
#      2462    0.002    0.000    0.002    0.000 {method 'flatten' of 'numpy.ndarray' objects}
# 3712/1808    0.002    0.000    0.002    0.000 transforms.py:2413(<lambda>)
#        56    0.002    0.000    0.045    0.001 axis.py:655(__init__)
#      4404    0.002    0.000    0.004    0.000 font_manager.py:1257(<genexpr>)
#       280    0.002    0.000    0.003    0.000 cycler.py:364(by_key)
#      1524    0.002    0.000    0.033    0.000 arraysetops.py:138(unique)
#       280    0.002    0.000    0.027    0.000 _base.py:1876(apply_aspect)
#      4254    0.002    0.000    0.082    0.000 artist.py:1216(_internal_update)
#       840    0.002    0.000    0.048    0.000 text.py:93(_get_text_metrics_with_cache)
#      3839    0.002    0.000    0.003    0.000 inspect.py:236(istraceback)
#       411    0.002    0.000    0.002    0.000 std.py:400(format_interval)
#      3839    0.002    0.000    0.002    0.000 inspect.py:246(isframe)
#      1219    0.002    0.000    0.029    0.000 text.py:1307(set_fontproperties)
#      2353    0.002    0.000    0.004    0.000 text.py:1000(set_horizontalalignment)
#      8387    0.002    0.000    0.002    0.000 transforms.py:1039(get_points)
#      2819    0.002    0.000    0.002    0.000 lr_scheduler.py:172(__init__)
#        28    0.002    0.000    0.006    0.000 pydot.py:1708(__init__)
#       112    0.002    0.000    0.143    0.001 _base.py:4331(get_tightbbox)
#      1000    0.002    0.000    0.006    0.000 sgd.py:231(_single_tensor_sgd)
#       392    0.002    0.000    0.018    0.000 ticker.py:2031(set_params)
#        19    0.002    0.000    0.026    0.001 traceback.py:321(extract)
#      3843    0.002    0.000    0.002    0.000 contextlib.py:697(__init__)
#      2887    0.002    0.000    0.002    0.000 {method 'encode' of 'str' objects}
#      1884    0.002    0.000    0.012    0.000 transforms.py:2511(composite_transform_factory)
#      2451    0.002    0.000    0.016    0.000 colors.py:237(_check_color_like)
#        21    0.002    0.000    0.002    0.000 {built-in method posix.lstat}
#       812    0.002    0.000    0.006    0.000 transforms.py:2289(__init__)
#      2451    0.002    0.000    0.014    0.000 colors.py:218(is_color_like)
#       285    0.002    0.000    0.011    0.000 <frozen importlib._bootstrap_external>:1498(find_spec)
#        28    0.002    0.000    0.339    0.012 _base.py:1262(__clear)
#      5773    0.002    0.000    0.002    0.000 {built-in method torch._C._has_torch_function_unary}
#      1278    0.002    0.000    0.013    0.000 transforms.py:328(ymax)
#       504    0.002    0.000    0.003    0.000 lines.py:1136(set_linestyle)
#      3502    0.002    0.000    0.004    0.000 _collections_abc.py:760(__iter__)
#      2588    0.002    0.000    0.008    0.000 artist.py:271(convert_xunits)
#       814    0.002    0.000    0.002    0.000 nx_pydot.py:296(<dictcomp>)
#       392    0.002    0.000    0.068    0.000 scale.py:103(set_default_locators_and_formatters)
#       392    0.002    0.000    0.003    0.000 ticker.py:2025(_staircase)
#     10620    0.002    0.000    0.002    0.000 {built-in method unicodedata.east_asian_width}
#      6622    0.002    0.000    0.002    0.000 pydot.py:481(get_parent_graph)
#      1415    0.002    0.000    0.003    0.000 text.py:329(set_rotation_mode)
#       335    0.002    0.000    0.008    0.000 {built-in method builtins.sum}
#      1106    0.002    0.000    0.007    0.000 series.py:966(__getitem__)
#      1512    0.002    0.000    0.004    0.000 lines.py:1195(_set_markercolor)
#   278/268    0.002    0.000    0.015    0.000 series.py:342(__init__)
#      1225    0.002    0.000    0.002    0.000 std.py:231(__call__)
#      3839    0.002    0.000    0.002    0.000 inspect.py:260(iscode)
#      1778    0.002    0.000    0.002    0.000 __init__.py:1324(is_math_text)
#        28    0.002    0.000    0.497    0.018 _base.py:574(__init__)
#      2457    0.002    0.000    0.020    0.000 font_manager.py:894(copy)
#       114    0.002    0.000    0.002    0.000 {built-in method torch.zeros_like}
#      1274    0.002    0.000    0.004    0.000 text.py:1283(_preprocess_math)
#      1352    0.002    0.000    0.003    0.000 transforms.py:2041(translate)
#       412    0.002    0.000    0.002    0.000 utils.py:273(_is_ascii)
#      2578    0.002    0.000    0.020    0.000 vertex_labeling_util.py:499(get_seed_site_weight_vector)
#      2819    0.002    0.000    0.002    0.000 lr_scheduler.py:175(__enter__)
#      1008    0.002    0.000    0.031    0.000 text.py:270(_get_xy_display)
#      1260    0.002    0.000    0.004    0.000 lines.py:1268(set_xdata)
#      1278    0.002    0.000    0.009    0.000 transforms.py:318(ymin)
#      2800    0.002    0.000    0.002    0.000 __init__.py:29(is_built)
#        89    0.002    0.000    0.020    0.000 vertex_labeling_util.py:945(get_root_index)
#      3470    0.002    0.000    0.003    0.000 figure.py:68(_stale_figure_callback)
#      1555    0.002    0.000    0.003    0.000 font_manager.py:731(set_style)
#     14055    0.001    0.000    0.001    0.000 {method 'replace' of 'str' objects}
#      4884    0.001    0.000    0.002    0.000 nx_pydot.py:302(<genexpr>)
#      1415    0.001    0.000    0.004    0.000 text.py:1217(set_rotation)
#       532    0.001    0.000    0.006    0.000 _base.py:844(<dictcomp>)
#       206    0.001    0.000    0.002    0.000 std.py:1446(format_dict)
#      2057    0.001    0.000    0.007    0.000 <__array_function__ internals>:177(concatenate)
#       462    0.001    0.000    0.006    0.000 path.py:99(__init__)
#      8509    0.001    0.000    0.001    0.000 {method 'pop' of 'dict' objects}
#        19    0.001    0.000    0.003    0.000 traceback.py:388(format)
#        84    0.001    0.000    0.012    0.000 axis.py:1174(_set_lim)
#       392    0.001    0.000    0.004    0.000 axis.py:1896(set_major_locator)
#      3658    0.001    0.000    0.001    0.000 {built-in method builtins.round}
#      2663    0.001    0.000    0.002    0.000 enum.py:313(__call__)
#       547    0.001    0.000    0.056    0.000 text.py:132(__init__)
#      2800    0.001    0.000    0.001    0.000 grad_scaler.py:166(scale)
#      1555    0.001    0.000    0.003    0.000 font_manager.py:744(set_variant)
#      2448    0.001    0.000    0.013    0.000 <__array_function__ internals>:177(amax)
#      7600    0.001    0.000    0.001    0.000 decorators.py:141(graph_break)
#      2448    0.001    0.000    0.014    0.000 <__array_function__ internals>:177(amin)
#       547    0.001    0.000    0.008    0.000 pathlib.py:658(_parse_args)
#      1698    0.001    0.000    0.002    0.000 digraph.py:420(add_node)
#      2800    0.001    0.000    0.001    0.000 grad_scaler.py:422(update)
#       538    0.001    0.000    0.006    0.000 transforms.py:1087(__init__)
#         1    0.001    0.001    0.055    0.055 optimal_subtrees.py:36(get_optimal_subtree_indices)
#      1260    0.001    0.000    0.003    0.000 lines.py:1289(set_ydata)
#       867    0.001    0.000    0.004    0.000 threading.py:1071(is_alive)
#      1378    0.001    0.000    0.027    0.000 transforms.py:2421(transform_affine)
#        14    0.001    0.000    0.001    0.000 {built-in method pygraphviz._graphviz.agclose}
#      2588    0.001    0.000    0.005    0.000 artist.py:283(convert_yunits)
#      1876    0.001    0.000    0.002    0.000 __init__.py:841(clean)
#      2632    0.001    0.000    0.007    0.000 text.py:1195(set_x)
#       224    0.001    0.000    0.151    0.001 axis.py:930(set_tick_params)
#       994    0.001    0.000    0.001    0.000 {built-in method builtins.min}
#      1798    0.001    0.000    0.013    0.000 <__array_function__ internals>:177(reshape)
#      1860    0.001    0.000    0.002    0.000 pydot.py:804(parse_node_ref)
#      1328    0.001    0.000    0.001    0.000 {method 'nonzero' of 'numpy.ndarray' objects}
#      1804    0.001    0.000    0.014    0.000 <__array_function__ internals>:177(diff)
#        56    0.001    0.000    3.951    0.071 image.py:617(draw)
#      1897    0.001    0.000    0.002    0.000 font_manager.py:717(set_family)
#       392    0.001    0.000    0.032    0.000 ticker.py:427(__init__)
#      1158    0.001    0.000    0.015    0.000 transforms.py:800(from_bounds)
#       142    0.001    0.000    0.014    0.000 patches.py:48(__init__)
#      1092    0.001    0.000    0.011    0.000 text.py:893(get_unitless_position)
#      1219    0.001    0.000    0.006    0.000 text.py:1030(set_linespacing)
# ...
#        10    0.000    0.000    0.000    0.000 common.py:196(<genexpr>)
#         2    0.000    0.000    0.000    0.000 series.py:846(__array__)
#         4    0.000    0.000    0.000    0.000 {method 'readline' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 <string>:11(<listcomp>)
#         2    0.000    0.000    0.000    0.000 figure.py:2695(_repr_html_)
#        14    0.000    0.000    0.000    0.000 {built-in method posix.WIFEXITED}
#         7    0.000    0.000    0.000    0.000 numeric.py:181(_validate_dtype)
#         1    0.000    0.000    0.000    0.000 {function Tensor.__format__ at 0x2aaf99471af0}
#         3    0.000    0.000    0.000    0.000 grouper.py:840(is_in_axis)
#         7    0.000    0.000    0.000    0.000 fromnumeric.py:1149(_argmax_dispatcher)
#         8    0.000    0.000    0.000    0.000 pyplot.py:198(_get_backend_mod)
#         1    0.000    0.000    0.013    0.013 pairtree_data_extraction_util.py:211(get_adj_matrices_from_pairtree_results)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._functorch.is_functorch_wrapped_tensor}
#         3    0.000    0.000    0.000    0.000 ops.py:1311(slabels)
#         4    0.000    0.000    0.000    0.000 linalg.py:117(isComplexType)
#         3    0.000    0.000    0.000    0.000 ops.py:1281(_is_indexed_like)
#         2    0.000    0.000    0.000    0.000 pretty.py:417(_in_deferred_types)
#         1    0.000    0.000    0.000    0.000 _tensor_str.py:265(_tensor_str_with_formatter)
#         2    0.000    0.000    0.000    0.000 generic.py:4114(_set_is_copy)
#         2    0.000    0.000    0.000    0.000 {method 'hexdigest' of '_hashlib.HASH' objects}
#         2    0.000    0.000    0.000    0.000 displaypub.py:43(_validate_data)
#         7    0.000    0.000    0.000    0.000 index_tricks.py:782(_fill_diagonal_dispatcher)
#         1    0.000    0.000    0.000    0.000 graph.py:374(adj)
#         5    0.000    0.000    0.000    0.000 base_parser.py:209(<setcomp>)
#         2    0.000    0.000    0.000    0.000 linalg.py:130(_realType)
#         1    0.000    0.000    0.000    0.000 frame.py:12012(_reindex_for_setitem)
#         1    0.000    0.000    0.000    0.000 font_manager.py:172(get_fontext_synonyms)
#        12    0.000    0.000    0.000    0.000 zipfile.py:1527(<lambda>)
#         1    0.000    0.000    0.000    0.000 base.py:210(interleaved_dtype)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(sum)
#         1    0.000    0.000    0.000    0.000 _validators.py:449(validate_ascending)
#         2    0.000    0.000    0.000    0.000 gzip.py:405(_read_exact)
#         6    0.000    0.000    0.000    0.000 grouper.py:805(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {built-in method pandas._libs.missing.checknull}
#         3    0.000    0.000    0.000    0.000 frame.py:600(_constructor)
#         6    0.000    0.000    0.000    0.000 pretty.py:118(_safe_getattr)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.internals.get_blkno_placements}
#         4    0.000    0.000    0.000    0.000 backend_bases.py:933(set_dashes)
#         5    0.000    0.000    0.000    0.000 base_parser.py:924(_validate_usecols_arg)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:77(json_clean)
#         2    0.000    0.000    0.000    0.000 {method 'get' of 'mappingproxy' objects}
#         3    0.000    0.000    0.000    0.000 _tensor_str.py:231(_val_formatter)
#         2    0.000    0.000    0.000    0.000 figure.py:469(set_facecolor)
#         2    0.000    0.000    0.000    0.000 configurable.py:565(initialized)
#         3    0.000    0.000    0.000    0.000 algorithms.py:855(resolve_na_sentinel)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:106(remove)
#         3    0.000    0.000    0.000    0.000 grouper.py:927(_is_label_like)
#         2    0.000    0.000    0.000    0.000 figure.py:427(get_edgecolor)
#         4    0.000    0.000    0.000    0.000 range.py:293(step)
#        10    0.000    0.000    0.000    0.000 parse.py:102(_noop)
#         2    0.000    0.000    0.000    0.000 linalg.py:186(_assert_stacked_square)
#         4    0.000    0.000    0.000    0.000 range.py:270(stop)
#         1    0.000    0.000    0.000    0.000 utils.py:266(_supports_unicode)
#         1    0.000    0.000    0.000    0.000 {method 'delete' of 'pandas._libs.internals.BlockPlacement' objects}
#         1    0.000    0.000    0.000    0.000 generic.py:11921(max)
#         3    0.000    0.000    0.000    0.000 ops.py:901(<listcomp>)
#         3    0.000    0.000    0.000    0.000 std.py:226(__init__)
#         4    0.000    0.000    0.000    0.000 range.py:189(_constructor)
#         1    0.000    0.000    0.000    0.000 _monitor.py:94(report)
#         2    0.000    0.000    0.000    0.000 figure.py:82(__init__)
#         1    0.000    0.000    0.000    0.000 frame.py:4271(_clear_item_cache)
#         3    0.000    0.000    0.000    0.000 algorithms.py:905(_re_wrap_factorize)
#         4    0.000    0.000    0.000    0.000 __init__.py:119(__eq__)
#         1    0.000    0.000    0.000    0.000 iostream.py:348(fileno)
#        14    0.000    0.000    0.000    0.000 {built-in method posix.WEXITSTATUS}
#         1    0.000    0.000    0.000    0.000 graph.py:1481(degree)
#         4    0.000    0.000    0.000    0.000 figure.py:2925(set_canvas)
#         1    0.000    0.000    0.000    0.000 nanops.py:1453(_maybe_null_out)
#         1    0.000    0.000    0.000    0.000 inference.py:363(is_sequence)
#         2    0.000    0.000    0.000    0.000 numeric.py:192(_ensure_dtype)
#         1    0.000    0.000    0.000    0.000 migration_history_inference.py:442(<listcomp>)
#         1    0.000    0.000    0.000    0.000 <string>:9(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:20(__enter__)
#         5    0.000    0.000    0.000    0.000 format.py:645(<genexpr>)
#         2    0.000    0.000    0.000    0.000 blocks.py:1912(get_values)
#         2    0.000    0.000    0.000    0.000 dispatch.py:13(should_extension_dispatch)
#         4    0.000    0.000    0.000    0.000 artist.py:671(get_sketch_params)
#         6    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISLNK}
#         1    0.000    0.000    0.000    0.000 {built-in method posix.fstat}
#         2    0.000    0.000    0.000    0.000 {method 'endswith' of 'bytes' objects}
#         2    0.000    0.000    0.000    0.000 {method 'cleanup' of 'ImagingEncoder' objects}
#         5    0.000    0.000    0.000    0.000 {built-in method sys.getrecursionlimit}
#         1    0.000    0.000    0.000    0.000 std.py:1147(__del__)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:26(__exit__)
#         3    0.000    0.000    0.000    0.000 ops.py:905(<listcomp>)
#         2    0.000    0.000    0.000    0.000 cast.py:1630(<genexpr>)
#         2    0.000    0.000    0.000    0.000 linalg.py:180(_assert_stacked_2d)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:1585(Done)
#         1    0.000    0.000    0.000    0.000 contextlib.py:388(pop_all)
#         5    0.000    0.000    0.000    0.000 series.py:1274(_clear_item_cache)
#         1    0.000    0.000    0.000    0.000 misc.py:143(arbitrary_element)
#         1    0.000    0.000    0.000    0.000 <__array_function__ internals>:177(prod)
#         2    0.000    0.000    0.000    0.000 cast.py:1628(<genexpr>)
#         3    0.000    0.000    0.000    0.000 grouper.py:857(is_in_obj)
#         4    0.000    0.000    0.000    0.000 backend_bases.py:1006(set_snap)
#         4    0.000    0.000    0.000    0.000 widgets.py:38(__init__)
#         2    0.000    0.000    0.000    0.000 _pylab_helpers.py:33(get_fig_manager)
#         2    0.000    0.000    0.000    0.000 transforms.py:293(p0)
#         2    0.000    0.000    0.000    0.000 std.py:1153(_comparable)
#         4    0.000    0.000    0.000    0.000 generic.py:1775(<genexpr>)
#         2    0.000    0.000    0.000    0.000 std.py:1157(__hash__)
#         2    0.000    0.000    0.000    0.000 pyplot.py:914(get_fignums)
#         1    0.000    0.000    0.000    0.000 utils.py:156(__init__)
#         2    0.000    0.000    0.000    0.000 __init__.py:146(_DType_reduce)
#         2    0.000    0.000    0.000    0.000 tokenize.py:164(__init__)
#         1    0.000    0.000    0.000    0.000 utils.py:125(__eq__)
#         3    0.000    0.000    0.000    0.000 {built-in method _weakref.proxy}
#         1    0.000    0.000    0.000    0.000 genericpath.py:87(samestat)
#         5    0.000    0.000    0.000    0.000 readers.py:1812(__enter__)
#         1    0.000    0.000    0.000    0.000 {method 'total_seconds' of 'datetime.timedelta' objects}
#         1    0.000    0.000    0.000    0.000 utils.py:282(_screen_shape_wrapper)
#         3    0.000    0.000    0.000    0.000 groupby.py:1092(_reset_group_selection)
#         5    0.000    0.000    0.000    0.000 base_parser.py:221(<listcomp>)
#         3    0.000    0.000    0.000    0.000 cast.py:1619(<genexpr>)
#         5    0.000    0.000    0.000    0.000 readers.py:547(_validate_names)
#         2    0.000    0.000    0.000    0.000 transforms.py:1776(__array__)
#         2    0.000    0.000    0.000    0.000 {method 'splitlines' of 'str' objects}
#         1    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 tokenize.py:612(generate_tokens)
#         4    0.000    0.000    0.000    0.000 patches.py:292(get_facecolor)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1408(<listcomp>)
#         1    0.000    0.000    0.000    0.000 _tensor_str.py:258(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {built-in method _stat.S_ISDIR}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._get_default_device}
#         2    0.000    0.000    0.000    0.000 utils.py:222(__eq__)
#         4    0.000    0.000    0.000    0.000 backend_bases.py:1646(<lambda>)
#         5    0.000    0.000    0.000    0.000 base.py:148(is_consolidated)
#         1    0.000    0.000    0.000    0.000 {built-in method fromkeys}
#         1    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.BytesIO' objects}
#         3    0.000    0.000    0.000    0.000 cast.py:1635(<genexpr>)
#         1    0.000    0.000    0.000    0.000 npyio.py:222(__del__)
#         2    0.000    0.000    0.000    0.000 __init__.py:1273(is_interactive)
#         1    0.000    0.000    0.000    0.000 graph.py:37(__set__)
#         3    0.000    0.000    0.000    0.000 grouper.py:587(_ilevel)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:649(<listcomp>)
#         2    0.000    0.000    0.000    0.000 utils.py:139(__getattr__)
#         1    0.000    0.000    0.000    0.000 frame.py:4234(_ensure_valid_index)
#         2    0.000    0.000    0.000    0.000 tz.py:74(utcoffset)
#         2    0.000    0.000    0.000    0.000 _compression.py:150(tell)
#         2    0.000    0.000    0.000    0.000 {method 'getvalue' of '_io.StringIO' objects}
#         1    0.000    0.000    0.000    0.000 {method '__enter__' of '_io._IOBase' objects}
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:16(__init__)
#         4    0.000    0.000    0.000    0.000 __init__.py:836(<dictcomp>)
#         2    0.000    0.000    0.000    0.000 {built-in method _struct.calcsize}
#         1    0.000    0.000    0.000    0.000 {built-in method torch._is_functional_tensor}
#         4    0.000    0.000    0.000    0.000 {method 'seekable' of '_io.BufferedReader' objects}
#         2    0.000    0.000    0.000    0.000 formatters.py:830(_check_return)
#         1    0.000    0.000    0.000    0.000 {pandas._libs.lib.dtypes_all_equal}
#         1    0.000    0.000    0.000    0.000 _tensor_str.py:255(<listcomp>)
#         1    0.000    0.000    0.000    0.000 threading.py:81(RLock)
#         1    0.000    0.000    0.000    0.000 utils.py:252(_is_utf)
#         2    0.000    0.000    0.000    0.000 figure.py:2603(_check_layout_engines_compat)
#         1    0.000    0.000    0.000    0.000 _weakrefset.py:52(_commit_removals)
#         1    0.000    0.000    0.000    0.000 zipfile.py:1819(__del__)
#         2    0.000    0.000    0.000    0.000 jsonutil.py:52(encode_images)
#         2    0.000    0.000    0.000    0.000 {method '__array_prepare__' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 managers.py:1240(value_getitem)
#         1    0.000    0.000    0.000    0.000 std.py:708(<lambda>)
#         1    0.000    0.000    0.000    0.000 managers.py:262(_clear_reference_block)
#         2    0.000    0.000    0.000    0.000 format.py:197(_check_version)
#         1    0.000    0.000    0.000    0.000 polytomy_resolver.py:132(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {built-in method torch.get_default_dtype}
#         2    0.000    0.000    0.000    0.000 {method 'clear' of 'collections.deque' objects}
#         1    0.000    0.000    0.000    0.000 frame.py:1498(__len__)
#         2    0.000    0.000    0.000    0.000 patches.py:288(get_edgecolor)
#         1    0.000    0.000    0.000    0.000 vertex_labeling_util.py:1514(<listcomp>)
#         1    0.000    0.000    0.000    0.000 std.py:760(get_lock)
#         2    0.000    0.000    0.000    0.000 artist.py:1080(set_in_layout)
#         1    0.000    0.000    0.000    0.000 data_extraction_util.py:368(initialize_organotropism_vector)
#         1    0.000    0.000    0.000    0.000 blocks.py:275(__len__)
#         1    0.000    0.000    0.000    0.000 <string>:10(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'move_to_end' of 'collections.OrderedDict' objects}
#         2    0.000    0.000    0.000    0.000 linalg.py:465(_unary_dispatcher)
#         1    0.000    0.000    0.000    0.000 vertex_labeling_util.py:1515(<listcomp>)
#         2    0.000    0.000    0.000    0.000 {method 'item' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 managers.py:233(is_single_block)
#         1    0.000    0.000    0.000    0.000 generic.py:1835(<listcomp>)
#         2    0.000    0.000    0.000    0.000 generic.py:1721(<genexpr>)
#         2    0.000    0.000    0.000    0.000 {method 'has_names' of 'torch._C._TensorBase' objects}
#         2    0.000    0.000    0.000    0.000 backend_bases.py:2057(draw)
#         1    0.000    0.000    0.000    0.000 {built-in method torch._C._len_torch_dispatch_stack}
#         1    0.000    0.000    0.000    0.000 {method '_is_zerotensor' of 'torch._C._TensorBase' objects}
#         1    0.000    0.000    0.000    0.000 {method 'transpose' of 'numpy.ndarray' objects}
#         1    0.000    0.000    0.000    0.000 {method 'disable' of '_lsprof.Profiler' objects}
#         1    0.000    0.000    0.000    0.000 {method 'startswith' of 'bytes' objects}
#         1    0.000    0.000    0.000    0.000 coreviews.py:46(__len__)
#         2    0.000    0.000    0.000    0.000 _compression.py:36(readable)
#         1    0.000    0.000    0.000    0.000 <string>:12(<listcomp>)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:2925(destroy)
#         1    0.000    0.000    0.000    0.000 _tensor_str.py:189(width)
#         2    0.000    0.000    0.000    0.000 backend_bases.py:2941(set_window_title)
#         1    0.000    0.000    0.000    0.000 {method 'append' of 'pandas._libs.internals.BlockPlacement' objects}
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2183(_sum_dispatcher)
#         2    0.000    0.000    0.000    0.000 graph.py:1557(is_directed)
#         1    0.000    0.000    0.000    0.000 {method 'flush' of '_io.BytesIO' objects}
#         1    0.000    0.000    0.000    0.000 {function _ParameterMeta.__instancecheck__ at 0x2aaf997e5670}
#         1    0.000    0.000    0.000    0.000 _python_dispatch.py:110(<listcomp>)
#         1    0.000    0.000    0.000    0.000 fromnumeric.py:2950(_prod_dispatcher)
#         1    0.000    0.000    0.000    0.000 std.py:1301(<lambda>)
#         2    0.000    0.000    0.000    0.000 inspect.py:2543(default)
#         1    0.000    0.000    0.000    0.000 numerictypes.py:650(<listcomp>)

# %% [markdown]
# ## Run Metient using metient's U estimation

# %%
OUTPUT_DIR = os.path.join(repo_dir, "data", "gundem_neuroblastoma_2023", "metient_outputs", "solve_polys")
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    
TSV_DIR = os.path.join(DATA_DIR, 'clustered_tsvs')  
patient_ids = [x.replace("_SNVs.tsv", "") for x in os.listdir(TSV_DIR)]

print(patient_ids)
len(patient_ids)

mut_trees_fns = [os.path.join(TREE_DIR, f"{patient_id}.results.npz") for patient_id in patient_ids]
trees = [data[0] for data in ptutil.get_adj_matrices_from_pairtree_results(mut_trees_fns)]
ref_var_fns = [os.path.join(TSV_DIR, f"{patient_id}_SNVs.tsv") for patient_id in patient_ids]
run_names = [f"{pid}_calibrate" for pid in patient_ids]
calibrate(trees, ref_var_fns, print_config, OUTPUT_DIR, run_names, solve_polytomies=True, batch_size=4096)
