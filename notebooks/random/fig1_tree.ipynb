# %%
import json
import os
from metient import *

notebook_dir = os.path.join(os.getcwd(), "metient/jupyter_notebooks/random")
output_dir = os.path.join(notebook_dir, "outputs")

tree_fn = os.path.join(notebook_dir, "fig1_tree.txt")
tsv_fn = os.path.join(notebook_dir, "fig1_tree.tsv")
# import pandas as pd
# df = pd.read_csv(tsv_fn, sep="\t")
# df
evaluate_label_clone_tree(tree_fn, tsv_fn, Weights(), PrintConfig(visualize=True), output_dir, "fig1")
# Out:
# /lila/data/morrisq/divyak/projects/metient/metient/jupyter_notebooks/random/fig1_tree.tsv
# O: None
# Tumor samples: ['colon', 'liver', 'lung', 'lymph']
# Input tree has 7 nodes, calculated sample size: 1136
# input_T.shape torch.Size([7, 7])
# Using sparse T: False
#   0%|          | 0/1900 [00:00<?, ?it/s]/lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/cuda/amp/grad_scaler.py:125: UserWarning: torch.cuda.amp.GradScaler is enabled, but CUDA is not available.  Disabling.
#   warnings.warn(
#  99%|█████████▉| 1883/1900 [00:07<00:00, 327.29it/s]
# Fitch-hartigan result: (tensor([5.]), tensor([4.]), tensor([3.]), tensor([0.]), tensor([0.]))
# Number of Pareto-optimal solutions: 4
# fig1_colon
# 100%|██████████| 1900/1900 [00:19<00:00, 327.29it/s]
