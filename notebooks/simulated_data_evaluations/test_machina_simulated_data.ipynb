# %%
# Test migration history reconstruction on simulated data

import sys
import os

REPO_DIR = os.path.join(os.getcwd(), "../../../")
from metient.metient import *
import metient.util.vertex_labeling_util as vutil
import metient.util.data_extraction_util as dutil

import matplotlib
import torch
MACHINA_DATA_DIR = os.path.join(REPO_DIR, 'metient/data/machina_sims')
OUT_DIR = os.path.join(REPO_DIR, "metient/test/output_plots")
# Out:
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/__init__.py:614: UserWarning: torch.set_default_tensor_type() is deprecated as of PyTorch 2.1, please use torch.set_default_dtype() and torch.set_default_device() as alternatives. (Triggered internally at ../torch/csrc/tensor/python_tensor.cpp:451.)
#   _C._set_default_tensor_type(t)
# CUDA GPU: True
# Using cuda
# Using cuda

# %%
import pydot
from IPython.display import Image, display

def visualize_ground_truth(tree_fn, graph_fn):
    def view_pydot(pdot):
        plt = Image(pdot.create_png())
        display(plt)
    
    (graph,) = pydot.graph_from_dot_file(tree_fn)
    view_pydot(graph)

    (graph,) = pydot.graph_from_dot_file(graph_fn)
    view_pydot(graph)

# %%
num_sites = "m8"
mig_type = "S"
seed = 12

og_sims_dir = "/data/morrisq/divyak/projects/machina/data/sims"
SIM_DATA_DIR = os.path.join(og_sims_dir, num_sites, mig_type)
print("Ground truth")
visualize_ground_truth(os.path.join(SIM_DATA_DIR, f"T_seed{seed}.dot"), os.path.join(SIM_DATA_DIR, f"G_seed{seed}.dot"))
# Out:
# Ground truth

# %%
import fnmatch
custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'cornflowerblue', 'hotpink', 'grey', 'saddlebrown', 'darkorange', 'purple', 'red', 'black', 'black', 'black', 'black']]
def find_labelings_all_mutation_trees(site, cluster_fn, all_mut_trees_fn, ref_var_fn):
    #weights = Weights(mig=0.563*50, comig=0.246*50, seed_site=0.197*50,gen_dist=0.1, reg=0.5, data_fit=15.0)
    
    trees = fnmatch.filter(os.listdir(os.path.join(MACHINA_DATA_DIR, f"{site}_clustered_input_corrected")), f"cluster_{mig_type}_seed{seed}_tree*.tsv")

    idx_to_cluster_label = dutil.get_idx_to_cluster_label(cluster_fn)
    data = dutil.get_adj_matrices_from_spruce_mutation_trees(all_mut_trees_fn, idx_to_cluster_label, is_sim_data=True)
    custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'royalblue', 'hotpink', 'grey', 'saddlebrown', 'darkorange', 'purple', 'red', 'black', 'black', 'black', 'black']]
    perf_stats = []
    trees = trees[:3]

    print("Number of trees:", len(trees))
    for tree_num in range(len(trees)):

        ref_var_fn = os.path.join(MACHINA_DATA_DIR, f"{site}_clustered_input_corrected", f"cluster_{mig_type}_seed{seed}_tree{tree_num}.tsv")
        data = dutil.get_adj_matrices_from_spruce_mutation_trees(all_mut_trees_fn, idx_to_cluster_label, is_sim_data=True)
        T = torch.tensor(data[tree_num][0], dtype = torch.float32)
        print(T.shape)
        print_config = PrintConfig(visualize=True, verbose=True, k_best_trees=10, save_outputs=True)
#         vert.evaluate(T, ref_var_fn, weights, print_config, "../output_plots/", f"tree{tree_num}_seed{seed}", 
#                       None, sample_size=1024, custom_colors=custom_colors, bias_weights=True, solve_polytomies=True)
        calibrate([T], [ref_var_fn], print_config, "../output_plots/", [f"tree{tree_num}_seed{seed}"], 
                   None, sample_size=1024, custom_colors=custom_colors, solve_polytomies=True)

# %%
# %%prun -D prof_output.prof
find_labelings_all_mutation_trees(num_sites, os.path.join(MACHINA_DATA_DIR, f"{num_sites}_clustered_input", f"cluster_{mig_type}_seed{seed}.txt"),
                                  os.path.join(MACHINA_DATA_DIR, f"{num_sites}_mut_trees", f"mut_trees_{mig_type}_seed{seed}.txt"),
                                  os.path.join(MACHINA_DATA_DIR, f"{num_sites}_clustered_input", f"cluster_{mig_type}_seed{seed}.tsv"))
# Out:
# Number of trees: 3
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 get_ipython().run_cell_magic('prun', '-D prof_output.prof', 'find_labelings_all_mutation_trees(num_sites, os.path.join(MACHINA_DATA_DIR, f"{num_sites}_clustered_input", f"cluster_{mig_type}_seed{seed}.txt"),\n                                  os.path.join(MACHINA_DATA_DIR, f"{num_sites}_mut_trees", f"mut_trees_{mig_type}_seed{seed}.txt"),\n                                  os.path.join(MACHINA_DATA_DIR, f"{num_sites}_clustered_input", f"cluster_{mig_type}_seed{seed}.tsv"))\n')
#
# File /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/magics/execution.py:298, in ExecutionMagics.prun(self, parameter_s, cell)
#     296     arg_str += '\n' + cell
#     297 arg_str = self.shell.transform_cell(arg_str)
# --> 298 return self._run_with_profiler(arg_str, opts, self.shell.user_ns)
#
# File /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/magics/execution.py:320, in ExecutionMagics._run_with_profiler(self, code, opts, namespace)
#     318 prof = profile.Profile()
#     319 try:
# --> 320     prof = prof.runctx(code, namespace, namespace)
#     321     sys_exit = ''
#     322 except SystemExit:
#
# File /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/cProfile.py:100, in Profile.runctx(self, cmd, globals, locals)
#      98 self.enable()
#      99 try:
# --> 100     exec(cmd, globals, locals)
#     101 finally:
#     102     self.disable()
#
# File <string>:1
#
# Cell In[4], line 19, in find_labelings_all_mutation_trees(site, cluster_fn, all_mut_trees_fn, ref_var_fn)
#      17 ref_var_fn = os.path.join(MACHINA_DATA_DIR, f"{site}_clustered_input_corrected", f"cluster_{mig_type}_seed{seed}_tree{tree_num}.tsv")
#      18 data = dutil.get_adj_matrices_from_spruce_mutation_trees(all_mut_trees_fn, idx_to_cluster_label, is_sim_data=True)
# ---> 19 T = torch.tensor(data[tree_num][0], dtype = torch.float32)
#      20 print(T.shape)
#      21 print_config = PrintConfig(visualize=True, verbose=True, k_best_trees=10, save_outputs=True)
#
# RuntimeError: CUDA error: CUDA-capable device(s) is/are busy or unavailable
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
import pstats

# Load the profiling data
p = pstats.Stats('prof_output.prof')

# Sort by cumulative time and print the top 20 functions
p.sort_stats('cumtime').print_stats(50)
# Out:
# Mon Aug 12 15:50:33 2024    prof_output.prof
#
#          7341385 function calls (7152456 primitive calls) in 138.878 seconds
#
#    Ordered by: cumulative time
#    List reduced from 4758 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     645/1    0.045    0.000  138.879  138.879 {built-in method builtins.exec}
#         1    0.000    0.000  138.879  138.879 /scratch/lsftmp/8595108.tmpdir/ipykernel_72674/1828735359.py:3(find_labelings_all_mutation_trees)
#         3    0.001    0.000  138.855   46.285 /lila/data/morrisq/divyak/projects/metient/metient/metient.py:59(calibrate)
#         3    0.002    0.001  138.854   46.285 /lila/data/morrisq/divyak/projects/metient/metient/lib/migration_history_inference.py:205(calibrate)
#         3    0.003    0.001  112.497   37.499 /lila/data/morrisq/divyak/projects/metient/metient/lib/migration_history_inference.py:320(infer_migration_history)
#         3    0.000    0.000  101.518   33.839 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:33(run)
#         3    0.000    0.000  101.517   33.839 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:158(run_multiple_optimizations)
#        15    0.118    0.008  101.298    6.753 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:36(optimize_v)
#        12    0.000    0.000   88.102    7.342 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:170(second_optimization_task)
#        12    0.001    0.000   88.007    7.334 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:131(second_v_optimization)
#      1350    3.228    0.002   53.020    0.039 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:262(compute_v_loss)
#      4228    0.024    0.000   46.716    0.011 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/_tensor.py:433(backward)
#      4228    0.031    0.000   46.689    0.011 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/autograd/__init__.py:149(backward)
#      4228   46.560    0.011   46.560    0.011 {method 'run_backward' of 'torch._C._EngineBase' objects}
#      2250    0.126    0.000   26.423    0.012 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:204(gumbel_softmax)
#         6    0.003    0.001   26.181    4.363 /lila/data/morrisq/divyak/projects/metient/metient/util/plotting_util.py:654(save_best_trees)
#         6    0.019    0.003   24.927    4.154 /lila/data/morrisq/divyak/projects/metient/metient/util/plotting_util.py:735(save_outputs)
#      1410    0.017    0.000   23.154    0.016 /lila/data/morrisq/divyak/projects/metient/metient/util/vertex_labeling_util.py:404(clone_tree_labeling_objective)
#      1430   15.157    0.011   22.854    0.016 /lila/data/morrisq/divyak/projects/metient/metient/util/vertex_labeling_util.py:318(ancestral_labeling_metrics)
#        12    0.001    0.000   21.146    1.762 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/backend_bases.py:2241(print_figure)
#      2250    0.146    0.000   17.724    0.008 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:200(gumbel_softmax_sample)
#      4503   16.290    0.004   16.290    0.004 {method 'max' of 'torch._C._TensorBase' objects}
#         3    0.001    0.000   15.573    5.191 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/figure.py:3255(savefig)
#        24    0.000    0.000   14.875    0.620 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/artist.py:93(draw_wrapper)
#   1764/24    0.008    0.000   14.875    0.620 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/artist.py:54(draw_wrapper)
#        24    0.001    0.000   14.875    0.620 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/figure.py:3155(draw)
#    156/24    0.002    0.000   14.805    0.617 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:113(_draw_list_compositing_images)
#       132    0.004    0.000   14.804    0.112 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/axes/_base.py:2999(draw)
#         3    0.000    0.000   13.410    4.470 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:95(first_v_optimization)
#        24    0.000    0.000   12.942    0.539 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/backend_bases.py:2232(<lambda>)
#        24    0.000    0.000   12.942    0.539 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:462(print_png)
#        24    0.007    0.000   12.942    0.539 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:452(_print_pil)
#        80    0.002    0.000   12.757    0.159 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:617(draw)
#        80    0.001    0.000   12.646    0.158 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:940(make_image)
#        80    0.040    0.000   12.642    0.158 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:328(_make_image)
#      2250    0.157    0.000   11.151    0.005 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:195(softmax_shifted_3d)
#       160    0.007    0.000   10.765    0.067 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:160(_resample)
#       160   10.679    0.067   10.695    0.067 {built-in method matplotlib._image.resample}
#         3    0.008    0.003    9.423    3.141 /lila/data/morrisq/divyak/projects/metient/metient/lib/u_optimizer.py:26(run)
#         3    0.268    0.089    9.415    3.138 /lila/data/morrisq/divyak/projects/metient/metient/lib/u_optimizer.py:35(find_umap)
#        24    0.001    0.000    7.869    0.328 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:392(draw)
#      1430    5.201    0.004    6.804    0.005 /lila/data/morrisq/divyak/projects/metient/metient/util/vertex_labeling_util.py:235(comigration_number)
#      2250    0.172    0.000    6.423    0.003 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:191(sample_gumbel)
#      8808    6.242    0.001    6.242    0.001 {built-in method torch.log}
#         9    0.000    0.000    5.618    0.624 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/pyplot.py:401(show)
#         9    0.000    0.000    5.618    0.624 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:72(show)
#        12    0.000    0.000    5.617    0.468 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/display_functions.py:105(display)
#        12    0.001    0.000    5.591    0.466 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/formatters.py:90(format)
#       144    0.000    0.000    5.590    0.039 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/decorator.py:229(fun)
#       144    0.000    0.000    5.585    0.039 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/formatters.py:219(catch_format_error)

# %%
f = '/data/morrisq/divyak/data/metient_prediction_results/'

tree = 0

for run in range(5):
    base_fn = os.path.join(f, f"predictions_batch_exp_bs1024_calibrate_wip_solvepoly_r{run+1}_06202024", num_sites, mig_type)
    visualize_ground_truth(os.path.join(base_fn, f"tree{tree}_seed{seed}_calibrate.tree.dot"), os.path.join(base_fn, f"tree{tree}_seed{seed}_calibrate.mig_graph.dot"))
# Out:
# 100%|██████████| 450/450 [00:47<00:00, 84.82it/s]
