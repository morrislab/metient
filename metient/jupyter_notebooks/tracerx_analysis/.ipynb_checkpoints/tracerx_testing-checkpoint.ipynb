# %%
import sys
import os
from metient.metient import *
from metient.util import data_extraction_util as dutil

REPO_DIR = os.path.join(os.getcwd(), "../../")
TRACERX_DATA_DIR = os.path.join(REPO_DIR, 'data/tracerx_nsclc/')
PYCLONE_CLUSTERED_TSVS_DIR = os.path.join(TRACERX_DATA_DIR, 'patient_data', 'conipher_pyclone_clustered_phyloccf_presence')
CONIPHER_TREES_DIR = os.path.join(TRACERX_DATA_DIR, 'conipher_outputs', 'TreeBuilding')
OUTPUT_DIR = os.path.join(TRACERX_DATA_DIR, "metient_outputs", "test")

def run_conipher_patient(patient, weights):
    space = "x"*44
    tsv_fn = os.path.join(PYCLONE_CLUSTERED_TSVS_DIR, f"{patient}_SNVs.tsv")
    print(tsv_fn)
    print(f"{space} PATIENT {patient} {space}")
    tree_fn = os.path.join(CONIPHER_TREES_DIR, f"{patient}_conipher_SNVsallTrees_cleaned.txt")
    trees = dutil.get_adj_matrices_from_all_conipher_trees(tree_fn)
    print_config = PrintConfig(visualize=True, verbose=False, k_best_trees=30)
    calibrate_label_clone_tree(trees[0], tsv_fn, weights, print_config, OUTPUT_DIR, patient, O=None,
                               bias_weights=True, solve_polytomies=True)

# %%
# %%prun
weights = Weights(mig=10, comig=5, seed_site=1, reg=2, gen_dist=0.1, organotrop=0.0)

run_conipher_patient("CRUK0762", weights)
# Out:
# /lila/data/morrisq/divyak/projects/metient/metient/jupyter_notebooks/tracerx_analysis/../../data/tracerx_nsclc/patient_data/conipher_pyclone_clustered/CRUK0762_SNVs.tsv
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0762 xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# WARNING: dropping extra columns without aggregation rules: {'original_anatomical_site_label', 'sample_label'}
# ordered_sites ['LN_SU_FLN1', 'LN_SU_FLN2', 'LN_SU_FLN3', 'LN_SU_LN1', 'LN_SU_LN2', 'primary_SU_T1']
# calculate_batch_size 2116
#   0%|          | 0/200 [00:00<?, ?it/s]
# nll 13.248
# U
#                   GL  0;RP11-314C16.1;FAT2  1;PCDHGA8;SPATA33  2;GPR31;TMEM234  \
# LN_SU_FLN1    0.268                 0.363              0.000            0.000
# LN_SU_FLN2    0.284                 0.353              0.000            0.000
# LN_SU_FLN3    0.252                 0.348              0.000            0.000
# LN_SU_LN1     0.229                 0.390              0.000            0.000
# LN_SU_LN2     0.247                 0.353              0.000            0.000
# primary_SU_T1 0.242                 0.279              0.029            0.040
#
#                3;LTA4H;NRG3  4;OR5B12;GRIA2  5;SECISBP2L;ZNF264  6;SEMA6D;LPA  \
# LN_SU_FLN1            0.000           0.206               0.000         0.000
# LN_SU_FLN2            0.000           0.000               0.000         0.000
# LN_SU_FLN3            0.000           0.000               0.000         0.000
# LN_SU_LN1             0.000           0.380               0.000         0.000
# LN_SU_LN2             0.000           0.000               0.000         0.000
# primary_SU_T1         0.041           0.001               0.001         0.000
#
#                7;FYCO1;DSEL  8;COL5A1;FRMD6  9;WTAPP1;PLA1A  10;EXOSC2;PRG3  \
# LN_SU_FLN1            0.000           0.000           0.003           0.000
# LN_SU_FLN2            0.000           0.000           0.363           0.000
# LN_SU_FLN3            0.000           0.000           0.000           0.000
# LN_SU_LN1             0.000           0.000           0.000           0.000
# LN_SU_LN2             0.000           0.215           0.000           0.000
# primary_SU_T1         0.002           0.000           0.000           0.066
#
#                11;TYMP;OR10A4  12;TSPYL1;STK32B  13;KLRD1;ANXA11  \
# LN_SU_FLN1              0.000             0.000            0.000
# LN_SU_FLN2              0.000             0.000            0.001
# LN_SU_FLN3              0.000             0.000            0.000
# LN_SU_LN1               0.000             0.000            0.000
# LN_SU_LN2               0.184             0.000            0.000
# primary_SU_T1           0.000             0.073            0.068
#
#                14;ATP10A;WDR96  15;LRRFIP2;CLCN6  16;ADAM19;ATP10B  \
# LN_SU_FLN1               0.000             0.000             0.000
# LN_SU_FLN2               0.000             0.000             0.000
# LN_SU_FLN3               0.000             0.399             0.000
# LN_SU_LN1                0.000             0.000             0.000
# LN_SU_LN2                0.000             0.000             0.000
# primary_SU_T1            0.000             0.000             0.113
#
#                17;POFUT2;CLSTN2  18;CDH23;NTM  19;CDKL4;MSH2  20;TLR4;MYF6  \
# LN_SU_FLN1                0.000         0.160          0.000         0.000
# LN_SU_FLN2                0.000         0.000          0.000         0.000
# LN_SU_FLN3                0.000         0.000          0.000         0.000
# LN_SU_LN1                 0.000         0.000          0.000         0.000
# LN_SU_LN2                 0.000         0.000          0.000         0.000
# primary_SU_T1             0.030         0.001          0.012         0.000
#
#                21;TDRD12;SMARCA5
# LN_SU_FLN1                 0.000
# LN_SU_FLN2                 0.000
# LN_SU_FLN3                 0.000
# LN_SU_LN1                  0.000
# LN_SU_LN2                  0.000
# primary_SU_T1              0.000
# F
#                 0;RP11-314C16.1;FAT2  1;PCDHGA8;SPATA33  2;GPR31;TMEM234  \
# LN_SU_FLN1                    0.363              0.001            0.002
# LN_SU_FLN2                    0.354              0.002            0.001
# LN_SU_FLN3                    0.371              0.002            0.002
# LN_SU_LN1                     0.379              0.001            0.000
# LN_SU_LN2                     0.373              0.001            0.001
# primary_SU_T1                 0.379              0.042            0.021
#
#                3;LTA4H;NRG3  4;OR5B12;GRIA2  5;SECISBP2L;ZNF264  6;SEMA6D;LPA  \
# LN_SU_FLN1            0.001           0.177               0.178         0.204
# LN_SU_FLN2            0.000           0.000               0.157         0.216
# LN_SU_FLN3            0.003           0.003               0.002         0.213
# LN_SU_LN1             0.001           0.171               0.195         0.196
# LN_SU_LN2             0.001           0.001               0.001         0.211
# primary_SU_T1         0.020           0.000               0.016         0.083
#
#                7;FYCO1;DSEL  8;COL5A1;FRMD6  9;WTAPP1;PLA1A  10;EXOSC2;PRG3  \
# LN_SU_FLN1            0.172           0.001           0.006           0.001
# LN_SU_FLN2            0.143           0.003           0.220           0.000
# LN_SU_FLN3            0.181           0.204           0.004           0.004
# LN_SU_LN1             0.187           0.001           0.002           0.000
# LN_SU_LN2             0.188           0.197           0.001           0.001
# primary_SU_T1         0.083           0.000           0.000           0.072
#
#                11;TYMP;OR10A4  12;TSPYL1;STK32B  13;KLRD1;ANXA11  \
# LN_SU_FLN1              0.001             0.000            0.213
# LN_SU_FLN2              0.003             0.000            0.247
# LN_SU_FLN3              0.007             0.001            0.250
# LN_SU_LN1               0.001             0.000            0.230
# LN_SU_LN2               0.101             0.002            0.231
# primary_SU_T1           0.000             0.135            0.124
#
#                14;ATP10A;WDR96  15;LRRFIP2;CLCN6  16;ADAM19;ATP10B  \
# LN_SU_FLN1               0.228             0.001             0.001
# LN_SU_FLN2               0.238             0.004             0.004
# LN_SU_FLN3               0.002             0.192             0.001
# LN_SU_LN1                0.233             0.000             0.001
# LN_SU_LN2                0.001             0.009             0.002
# primary_SU_T1            0.083             0.000             0.037
#
#                17;POFUT2;CLSTN2  18;CDH23;NTM  19;CDKL4;MSH2  20;TLR4;MYF6  \
# LN_SU_FLN1                0.000         0.089          0.000         0.002
# LN_SU_FLN2                0.000         0.000          0.000         0.009
# LN_SU_FLN3                0.000         0.001          0.000         0.008
# LN_SU_LN1                 0.000         0.005          0.000         0.000
# LN_SU_LN2                 0.000         0.000          0.000         0.000
# primary_SU_T1             0.097         0.000          0.026         0.062
#
#                21;TDRD12;SMARCA5
# LN_SU_FLN1                 0.177
# LN_SU_FLN2                 0.135
# LN_SU_FLN3                 0.000
# LN_SU_LN1                  0.159
# LN_SU_LN2                  0.001
# primary_SU_T1              0.001
# F hat
#                 0;RP11-314C16.1;FAT2  1;PCDHGA8;SPATA33  2;GPR31;TMEM234  \
# LN_SU_FLN1                    0.732              0.000            0.000
# LN_SU_FLN2                    0.716              0.000            0.000
# LN_SU_FLN3                    0.748              0.000            0.000
# LN_SU_LN1                     0.771              0.000            0.000
# LN_SU_LN2                     0.753              0.000            0.000
# primary_SU_T1                 0.758              0.083            0.040
#
#                3;LTA4H;NRG3  4;OR5B12;GRIA2  5;SECISBP2L;ZNF264  6;SEMA6D;LPA  \
# LN_SU_FLN1            0.000           0.366               0.369         0.369
# LN_SU_FLN2            0.000           0.000               0.363         0.363
# LN_SU_FLN3            0.000           0.000               0.000         0.399
# LN_SU_LN1             0.000           0.381               0.381         0.381
# LN_SU_LN2             0.000           0.000               0.000         0.399
# primary_SU_T1         0.041           0.001               0.043         0.157
#
#                7;FYCO1;DSEL  8;COL5A1;FRMD6  9;WTAPP1;PLA1A  10;EXOSC2;PRG3  \
# LN_SU_FLN1            0.369           0.000           0.003           0.000
# LN_SU_FLN2            0.363           0.000           0.363           0.000
# LN_SU_FLN3            0.399           0.399           0.000           0.000
# LN_SU_LN1             0.381           0.000           0.000           0.000
# LN_SU_LN2             0.399           0.399           0.000           0.000
# primary_SU_T1         0.160           0.001           0.000           0.149
#
#                11;TYMP;OR10A4  12;TSPYL1;STK32B  13;KLRD1;ANXA11  \
# LN_SU_FLN1              0.000             0.000            0.369
# LN_SU_FLN2              0.000             0.000            0.363
# LN_SU_FLN3              0.000             0.001            0.400
# LN_SU_LN1               0.000             0.000            0.381
# LN_SU_LN2               0.184             0.000            0.399
# primary_SU_T1           0.000             0.251            0.228
#
#                14;ATP10A;WDR96  15;LRRFIP2;CLCN6  16;ADAM19;ATP10B  \
# LN_SU_FLN1               0.369             0.000             0.000
# LN_SU_FLN2               0.363             0.000             0.000
# LN_SU_FLN3               0.000             0.399             0.000
# LN_SU_LN1                0.381             0.000             0.000
# LN_SU_LN2                0.000             0.000             0.000
# primary_SU_T1            0.156             0.000             0.113
#
#                17;POFUT2;CLSTN2  18;CDH23;NTM  19;CDKL4;MSH2  20;TLR4;MYF6  \
# LN_SU_FLN1                0.000         0.160          0.000         0.000
# LN_SU_FLN2                0.000         0.000          0.000         0.000
# LN_SU_FLN3                0.001         0.000          0.000         0.000
# LN_SU_LN1                 0.000         0.000          0.000         0.000
# LN_SU_LN2                 0.000         0.000          0.000         0.000
# primary_SU_T1             0.179         0.001          0.053         0.113
#
#                21;TDRD12;SMARCA5
# LN_SU_FLN1                 0.369
# LN_SU_FLN2                 0.363
# LN_SU_FLN3                 0.000
# LN_SU_LN1                  0.381
# LN_SU_LN2                  0.000
# primary_SU_T1              0.002
# 100%|██████████| 200/200 [00:18<00:00, 10.57it/s]
# pareto_metrics [(11, 5, 1), (10, 7, 3)]
# # final solutions: 2
# CRUK0762_primary_SU_T1
# 30 unique trees were not found (2 were found). Retry with a higher sample size if you want to get more trees.

# %%
tracerx_reported_counts = {
    "Brain":6, "Chest wall":1, "Bronchus":4,"Pleura":2,"Rib":2,
    "Liver":6,"Flank":1,"Femur":1,"Neck LN":2,"Primary LN":148,
    "Recurrence LN":20,"Scapula":1,"Axillary LN":1,"Recurrence lung":13,
    "Primary surgery satellite lesion lung":3, "Adrenal gland":1,
    "Subphrenic mass":1, "Skin":3, "Paravertebral":1, "Peritoneum":1,
    "Lung":0
}

total = sum([tracerx_reported_counts[key] for key in tracerx_reported_counts])
tracerx_reported_freqs = {key:float(tracerx_reported_counts[key]/total) for key in tracerx_reported_counts}
print(tracerx_reported_freqs)
def get_organotropism_matrix_from_tracerx(unique_sites, tracerx_map):
    mapped_sites = [tracerx_map[site] for site in unique_sites]
    organotrop_arr = np.zeros(len(mapped_sites))
    for i, metastatic_site in enumerate(mapped_sites):
        organotrop_arr[i] = tracerx_reported_freqs[metastatic_site]
    return torch.tensor(organotrop_arr, dtype = torch.float32)
# Out:
# {'Brain': 0.027522935779816515, 'Chest wall': 0.0045871559633027525, 'Bronchus': 0.01834862385321101, 'Pleura': 0.009174311926605505, 'Rib': 0.009174311926605505, 'Liver': 0.027522935779816515, 'Flank': 0.0045871559633027525, 'Femur': 0.0045871559633027525, 'Neck LN': 0.009174311926605505, 'Primary LN': 0.6788990825688074, 'Recurrence LN': 0.09174311926605505, 'Scapula': 0.0045871559633027525, 'Axillary LN': 0.0045871559633027525, 'Recurrence lung': 0.05963302752293578, 'Primary surgery satellite lesion lung': 0.013761467889908258, 'Adrenal gland': 0.0045871559633027525, 'Subphrenic mass': 0.0045871559633027525, 'Skin': 0.013761467889908258, 'Paravertebral': 0.0045871559633027525, 'Peritoneum': 0.0045871559633027525, 'Lung': 0.0}

# %%
import pandas as pd
no_cna_dir = os.path.join(TRACERX_DATA_DIR, "CRUK0762_no_cna_testing")
dutil.pool_input_tsv(os.path.join(no_cna_dir, "CRUK0762_SNVs.tsv"), no_cna_dir, f"tmp_CRUK0762")
df = pd.read_csv(os.path.join(no_cna_dir,"tmp_CRUK0762_clustered_SNVs.tsv"),sep="\t")
df['implied F no CNA'] = df.apply(lambda row: row['var']/(0.5*row['ref']+row['var']), axis=1)
df = df[['anatomical_site_label', 'cluster_index', 'implied F no CNA']]
matrix_df = df.pivot(index='cluster_index', columns='anatomical_site_label', values='implied F no CNA')
matrix_df.to_csv(os.path.join(no_cna_dir,"CRUK0762_clustered_SNVs_no_cnas.tsv"), sep="\t")
# Out:
# WARNING: dropping extra columns without aggregation rules: {'original_anatomical_site_label', 'sample_label'}

# %%
df
# Out:
#    anatomical_site_label  cluster_index  implied F no CNA
# 0             LN_SU_FLN1              0             0.201
# 1             LN_SU_FLN2              0             0.128
# 2             LN_SU_FLN3              0             0.149
# 3              LN_SU_LN1              0             0.138
# 4              LN_SU_LN2              0             0.153
# ..                   ...            ...               ...
# 83            LN_SU_FLN2             20             0.000
# 84            LN_SU_FLN3             20             0.000
# 85             LN_SU_LN1             20             0.000
# 86             LN_SU_LN2             20             0.000
# 87         primary_SU_T1             20             0.060
#
# [88 rows x 3 columns]
