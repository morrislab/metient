# %%
# Test migration history reconstruction on simulated data

import sys
import os

REPO_DIR = os.path.join(os.getcwd(), "../../../")
from metient.metient import *
import metient.lib.vertex_labeling as vert
import metient.util.vertex_labeling_util as vutil
import metient.util.data_extraction_util as dutil

import matplotlib
import torch
MACHINA_DATA_DIR = os.path.join(REPO_DIR, 'metient/data/machina_sims')
OUT_DIR = os.path.join(REPO_DIR, "metient/test/output_plots")
# Out:
# CUDA GPU: False

# %%
import pydot
from IPython.display import Image, display

def visualize_ground_truth(tree_fn, graph_fn):
    def view_pydot(pdot):
        plt = Image(pdot.create_png())
        display(plt)
    
    (graph,) = pydot.graph_from_dot_file(tree_fn)
    view_pydot(graph)

    (graph,) = pydot.graph_from_dot_file(graph_fn)
    view_pydot(graph)

# %%
num_sites = "m5"
mig_type = "mS"
seed = 0

og_sims_dir = "/data/morrisq/divyak/projects/machina/data/sims"
SIM_DATA_DIR = os.path.join(og_sims_dir, num_sites, mig_type)
print("Ground truth")
visualize_ground_truth(os.path.join(SIM_DATA_DIR, f"T_seed{seed}.dot"), os.path.join(SIM_DATA_DIR, f"G_seed{seed}.dot"))
# Out:
# Ground truth

# %%
import fnmatch
custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'cornflowerblue', 'hotpink', 'grey', 'saddlebrown', 'darkorange', 'purple', 'red', 'black', 'black', 'black', 'black']]
def find_labelings_all_mutation_trees(site, cluster_fn, all_mut_trees_fn, ref_var_fn):
    weights = Weights(mig=0.563*50, comig=0.246*50, seed_site=0.197*50,gen_dist=0.1, reg=0.5, data_fit=15.0)
    
    trees = fnmatch.filter(os.listdir(os.path.join(MACHINA_DATA_DIR, f"{site}_clustered_input_corrected")), f"cluster_{mig_type}_seed{seed}_tree*.tsv")

    idx_to_cluster_label = dutil.get_idx_to_cluster_label(cluster_fn)
    data = dutil.get_adj_matrices_from_spruce_mutation_trees(all_mut_trees_fn, idx_to_cluster_label, is_sim_data=True)
    custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'royalblue', 'hotpink', 'grey', 'saddlebrown', 'darkorange', 'purple', 'red', 'black', 'black', 'black', 'black']]
    perf_stats = []
    trees = [trees[0]]

    print("Number of trees:", len(trees))
    for tree_num in range(len(trees)):

        ref_var_fn = os.path.join(MACHINA_DATA_DIR, f"{site}_clustered_input_corrected", f"cluster_{mig_type}_seed{seed}_tree{tree_num}.tsv")
        data = dutil.get_adj_matrices_from_spruce_mutation_trees(all_mut_trees_fn, idx_to_cluster_label, is_sim_data=True)
        T = torch.tensor(data[tree_num][0], dtype = torch.float32)
        print(T.shape)
        print_config = PrintConfig(visualize=True, verbose=False, k_best_trees=10, save_outputs=True)
#         vert.evaluate(T, ref_var_fn, weights, print_config, "../output_plots/", f"tree{tree_num}_seed{seed}", 
#                       None, batch_size=1024, custom_colors=custom_colors, bias_weights=True, solve_polytomies=True)
        vert.calibrate([T], [ref_var_fn], print_config, "../output_plots/", [f"tree{tree_num}_seed{seed}"], 
                      None, batch_size=1024, custom_colors=custom_colors, bias_weights=True, solve_polytomies=True)

# %%
# %%prun -D prof_output.prof
find_labelings_all_mutation_trees(num_sites, os.path.join(MACHINA_DATA_DIR, f"{num_sites}_clustered_input", f"cluster_{mig_type}_seed{seed}.txt"),
                                  os.path.join(MACHINA_DATA_DIR, f"{num_sites}_mut_trees", f"mut_trees_{mig_type}_seed{seed}.txt"),
                                  os.path.join(MACHINA_DATA_DIR, f"{num_sites}_clustered_input", f"cluster_{mig_type}_seed{seed}.tsv"))
# Out:
# Number of trees: 1
# torch.Size([13, 13])
# Saving results to ../output_plots/calibrate
# Overwriting existing directory at ../output_plots/calibrate
#
# *** Calibrating for patient: tree0_seed0 ***
# ordered_sites ['P', 'M1', 'M2', 'M3', 'M4']
# internal_node_idx_to_sites {2: [1], 3: [1], 4: [0], 5: [0], 6: [3], 7: [0], 8: [4], 9: [2], 10: [3], 11: [2], 12: [4]}
# node indices not well estimated []
# idx_to_observed_sites {2: [1], 3: [1], 4: [0], 5: [0], 6: [3], 7: [0], 8: [4], 9: [2], 10: [3], 11: [2], 12: [4]}
# nodes_w_polys [0, 4, 5] resolver_sites [[1], [0], [0]]
#  46%|████▌     | 46/100 [00:04<00:03, 15.37it/s]/lila/data/morrisq/divyak/projects/metient/metient/lib/vertex_labeling.py:615: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3614.)
#   known_labelings.append(torch.eye(num_sites)[optimal_site].T)
# 100%|██████████| 100/100 [00:06<00:00, 15.57it/s]
# soln set size 412
# has_pss_solution True
# soln set size after expansion 412
# pareto_metrics {(4, 4, 1)}
# # final solutions: 4
# WARNING: Unable to calibrate since no patients have multiple Pareto optimal trees. Using default weighting, wm > wc > ws
# tree0_seed0_P
# 10 unique trees were not found (4 were found). Retry with a higher sample size if you want to get more trees.
#
# *** Profile stats marshalled to file 'prof_output.prof'.

# %%
import pstats

# Load the profiling data
p = pstats.Stats('prof_output.prof')

# Sort by cumulative time and print the top 20 functions
p.sort_stats('cumtime').print_stats(50)
# Out:
# Wed Jul  3 08:38:44 2024    prof_output.prof
#
#          2522218 function calls (2496927 primitive calls) in 23.906 seconds
#
#    Ordered by: cumulative time
#    List reduced from 4416 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#     644/1    0.087    0.000   23.909   23.909 {built-in method builtins.exec}
#         1    0.001    0.001   23.908   23.908 /scratch/lsftmp/7549758.tmpdir/ipykernel_145503/463821087.py:3(find_labelings_all_mutation_trees)
#         1    0.001    0.001   23.892   23.892 /lila/data/morrisq/divyak/projects/metient/metient/lib/vertex_labeling.py:421(calibrate)
#         2    0.002    0.001   13.315    6.658 /lila/data/morrisq/divyak/projects/metient/metient/util/plotting_util.py:618(save_best_trees)
#         2    0.004    0.002   12.939    6.469 /lila/data/morrisq/divyak/projects/metient/metient/util/plotting_util.py:698(save_outputs)
#         1    0.006    0.006   10.463   10.463 /lila/data/morrisq/divyak/projects/metient/metient/lib/vertex_labeling.py:799(get_migration_history)
#         2    0.000    0.000   10.411    5.205 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/backend_bases.py:2241(print_figure)
#         1    0.001    0.001    8.026    8.026 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/figure.py:3255(savefig)
#         4    0.000    0.000    7.498    1.875 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/artist.py:93(draw_wrapper)
#     248/4    0.003    0.000    7.498    1.875 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/artist.py:54(draw_wrapper)
#         4    0.000    0.000    7.498    1.875 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/figure.py:3155(draw)
#      52/4    0.001    0.000    7.469    1.867 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:113(_draw_list_compositing_images)
#        48    0.003    0.000    7.468    0.156 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/axes/_base.py:2999(draw)
#         4    0.000    0.000    7.014    1.754 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/backend_bases.py:2232(<lambda>)
#         4    0.000    0.000    7.014    1.754 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:462(print_png)
#         4    0.005    0.001    7.014    1.754 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:452(_print_pil)
#        32    0.002    0.000    6.901    0.216 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:617(draw)
#        32    0.001    0.000    6.831    0.213 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:940(make_image)
#        32    0.031    0.001    6.829    0.213 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:328(_make_image)
#         2    0.016    0.008    5.400    2.700 /lila/data/morrisq/divyak/projects/metient/metient/lib/vertex_labeling.py:747(optimize_V)
#        64    0.006    0.000    5.269    0.082 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:160(_resample)
#        64    5.217    0.082    5.226    0.082 {built-in method matplotlib._image.resample}
#         4    0.000    0.000    4.423    1.106 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py:392(draw)
#       100    0.075    0.001    3.758    0.038 /lila/data/morrisq/divyak/projects/metient/metient/lib/vertex_labeling.py:169(compute_v_loss)
#         1    0.021    0.021    2.801    2.801 /lila/data/morrisq/divyak/projects/metient/metient/lib/vertex_labeling.py:698(optimize_umap)
#       316    0.005    0.000    2.615    0.008 /lila/data/morrisq/divyak/projects/metient/metient/util/vertex_labeling_util.py:304(clone_tree_labeling_objective)
#         2    0.000    0.000    2.587    1.293 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/image.py:1569(imsave)
#         2    0.000    0.000    2.586    1.293 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/PIL/Image.py:2353(save)
#     203/9    0.003    0.000    2.566    0.285 <frozen importlib._bootstrap>:986(_find_and_load)
#     202/9    0.003    0.000    2.565    0.285 <frozen importlib._bootstrap>:956(_find_and_load_unlocked)
#     194/9    0.003    0.000    2.551    0.283 <frozen importlib._bootstrap>:650(_load_unlocked)
#     193/9    0.002    0.000    2.550    0.283 <frozen importlib._bootstrap_external>:777(exec_module)
#       888    2.542    0.003    2.542    0.003 {method 'encode' of 'ImagingEncoder' objects}
#         2    0.000    0.000    2.531    1.265 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/PIL/PngImagePlugin.py:1221(_save)
#         2    0.000    0.000    2.529    1.265 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/PIL/ImageFile.py:496(_save)
#         2    0.001    0.000    2.529    1.264 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/PIL/ImageFile.py:524(_encode_tile)
#     320/9    0.001    0.000    2.516    0.280 <frozen importlib._bootstrap>:211(_call_with_frames_removed)
#       324    0.124    0.000    2.438    0.008 /lila/data/morrisq/divyak/projects/metient/metient/util/vertex_labeling_util.py:218(ancestral_labeling_metrics)
#         1    0.000    0.000    2.398    2.398 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib/pyplot.py:401(show)
#         1    0.000    0.000    2.398    2.398 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/matplotlib_inline/backend_inline.py:72(show)
#         2    0.000    0.000    2.397    1.199 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/display_functions.py:105(display)
#         2    0.000    0.000    2.388    1.194 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/formatters.py:90(format)
#        24    0.000    0.000    2.388    0.100 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/decorator.py:229(fun)
#        24    0.000    0.000    2.387    0.099 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/formatters.py:219(catch_format_error)
#        18    0.000    0.000    2.387    0.133 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/formatters.py:330(__call__)
#         2    0.000    0.000    2.386    1.193 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/IPython/core/pylabtools.py:111(print_figure)
#       421    0.003    0.000    2.351    0.006 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/_compile.py:20(inner)
#         4    0.000    0.000    2.273    0.568 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/optim/adam.py:15(__init__)
#         4    0.000    0.000    2.273    0.568 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/optim/optimizer.py:239(__init__)
#         1    0.000    0.000    2.265    2.265 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/_dynamo/__init__.py:1(<module>)

# %%
f = '/data/morrisq/divyak/data/metient_prediction_results/'

tree = 0

for run in range(5):
    base_fn = os.path.join(f, f"predictions_batch_exp_bs1024_calibrate_wip_solvepoly_r{run+1}_06202024", num_sites, mig_type)
    visualize_ground_truth(os.path.join(base_fn, f"tree{tree}_seed{seed}_calibrate.tree.dot"), os.path.join(base_fn, f"tree{tree}_seed{seed}_calibrate.mig_graph.dot"))
