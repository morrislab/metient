# %%
# Test migration history reconstruction on simulated data

import sys
import os

REPO_DIR = os.path.join(os.getcwd(), "../../../")
from metient.metient import *
import metient.util.vertex_labeling_util as vutil
import metient.util.data_extraction_util as dutil

import matplotlib
import torch
MACHINA_DATA_DIR = os.path.join(REPO_DIR, 'metient/data/machina_sims')
OUT_DIR = os.path.join(REPO_DIR, "metient/test/output_plots")
# Out:
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11070). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# CUDA GPU: False

# %%
import pydot
from IPython.display import Image, display

def visualize_ground_truth(tree_fn, graph_fn):
    def view_pydot(pdot):
        plt = Image(pdot.create_png())
        display(plt)
    
    (graph,) = pydot.graph_from_dot_file(tree_fn)
    view_pydot(graph)

    (graph,) = pydot.graph_from_dot_file(graph_fn)
    view_pydot(graph)

# %%
num_sites = "m8"
mig_type = "R"
seed = 157

og_sims_dir = "/data/morrisq/divyak/projects/machina/data/sims"
SIM_DATA_DIR = os.path.join(og_sims_dir, num_sites, mig_type)
print("Ground truth")
visualize_ground_truth(os.path.join(SIM_DATA_DIR, f"T_seed{seed}.dot"), os.path.join(SIM_DATA_DIR, f"G_seed{seed}.dot"))
# Out:
# Ground truth

# %%
import fnmatch
custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'cornflowerblue', 'hotpink', 'grey', 'saddlebrown', 'darkorange', 'purple', 'red', 'black', 'black', 'black', 'black']]
def find_labelings_all_mutation_trees(site, cluster_fn, all_mut_trees_fn, ref_var_fn):
    weights = Weights(mig=0.563*50, comig=0.246*50, seed_site=0.197*50,gen_dist=0.1, reg=0.5, data_fit=15.0)
    
    trees = fnmatch.filter(os.listdir(os.path.join(MACHINA_DATA_DIR, f"{site}_clustered_input_corrected")), f"cluster_{mig_type}_seed{seed}_tree*.tsv")

    idx_to_cluster_label = dutil.get_idx_to_cluster_label(cluster_fn)
    data = dutil.get_adj_matrices_from_spruce_mutation_trees(all_mut_trees_fn, idx_to_cluster_label, is_sim_data=True)
    custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'royalblue', 'hotpink', 'grey', 'saddlebrown', 'darkorange', 'purple', 'red', 'black', 'black', 'black', 'black']]
    perf_stats = []
    trees = trees[:3]

    print("Number of trees:", len(trees))
    for tree_num in range(len(trees)):

        ref_var_fn = os.path.join(MACHINA_DATA_DIR, f"{site}_clustered_input_corrected", f"cluster_{mig_type}_seed{seed}_tree{tree_num}.tsv")
        data = dutil.get_adj_matrices_from_spruce_mutation_trees(all_mut_trees_fn, idx_to_cluster_label, is_sim_data=True)
        T = torch.tensor(data[tree_num][0], dtype = torch.float32)
        print(T.shape)
        print_config = PrintConfig(visualize=False, verbose=False, k_best_trees=10, save_outputs=True)
#         vert.evaluate(T, ref_var_fn, weights, print_config, "../output_plots/", f"tree{tree_num}_seed{seed}", 
#                       None, batch_size=1024, custom_colors=custom_colors, bias_weights=True, solve_polytomies=True)
        calibrate([T], [ref_var_fn], print_config, "../output_plots/", [f"tree{tree_num}_seed{seed}"], 
                   None, batch_size=64, custom_colors=custom_colors, solve_polytomies=True)

# %%
# %%prun -D prof_output.prof
find_labelings_all_mutation_trees(num_sites, os.path.join(MACHINA_DATA_DIR, f"{num_sites}_clustered_input", f"cluster_{mig_type}_seed{seed}.txt"),
                                  os.path.join(MACHINA_DATA_DIR, f"{num_sites}_mut_trees", f"mut_trees_{mig_type}_seed{seed}.txt"),
                                  os.path.join(MACHINA_DATA_DIR, f"{num_sites}_clustered_input", f"cluster_{mig_type}_seed{seed}.tsv"))
# Out:
# Number of trees: 3
# torch.Size([21, 21])
# Saving results to ../output_plots/calibrate
# Overwriting existing directory at ../output_plots/calibrate
#
# *** Calibrating for patient: tree0_seed157 ***
# ordered_sites ['P', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10']
# 100%|██████████| 450/450 [00:06<00:00, 80.10it/s]
# full solution set size: 320
# pareto_metrics {(13, 10, 1), (12, 11, 2)}
# # final solutions: 3
# Calibrating to 1 patients
# Early stopping after 785 epochs.
# Optimized thetas: tensor([0.67, 0.16, 0.16], grad_fn=<DivBackward0>)
# torch.Size([21, 21])
# Saving results to ../output_plots/calibrate
# Overwriting existing directory at ../output_plots/calibrate
#
# *** Calibrating for patient: tree1_seed157 ***
# ordered_sites ['P', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10']
# 100%|██████████| 450/450 [00:18<00:00, 80.10it/s]
# full solution set size: 320
# pareto_metrics {(13, 10, 1), (12, 11, 2)}
# # final solutions: 2
# Calibrating to 1 patients
# Early stopping after 621 epochs.
# Optimized thetas: tensor([0.58, 0.21, 0.21], grad_fn=<DivBackward0>)
# torch.Size([21, 21])
# Saving results to ../output_plots/calibrate
# Overwriting existing directory at ../output_plots/calibrate
#
# *** Calibrating for patient: tree2_seed157 ***
# ordered_sites ['P', 'M1', 'M2', 'M3', 'M4', 'M5', 'M6', 'M7', 'M8', 'M9', 'M10']
# 100%|██████████| 450/450 [00:17<00:00, 80.80it/s]
# full solution set size: 320
# pareto_metrics {(13, 10, 1), (12, 11, 2)}
# # final solutions: 4
# Calibrating to 1 patients
# Early stopping after 838 epochs.
# Optimized thetas: tensor([0.61, 0.20, 0.20], grad_fn=<DivBackward0>)
#
# *** Profile stats marshalled to file 'prof_output.prof'.
# 100%|██████████| 450/450 [00:16<00:00, 74.60it/s]

# %%
import pstats

# Load the profiling data
p = pstats.Stats('prof_output.prof')

# Sort by cumulative time and print the top 20 functions
p.sort_stats('cumtime').print_stats(50)
# Out:
# Sat Jul  6 14:00:01 2024    prof_output.prof
#
#          4487586 function calls (4457895 primitive calls) in 42.864 seconds
#
#    Ordered by: cumulative time
#    List reduced from 1927 to 50 due to restriction <50>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000   42.865   42.865 {built-in method builtins.exec}
#         1    0.000    0.000   42.864   42.864 <string>:1(<module>)
#         1    0.000    0.000   42.864   42.864 /scratch/lsftmp/8006622.tmpdir/ipykernel_70382/2635462196.py:3(find_labelings_all_mutation_trees)
#         3    0.001    0.000   42.783   14.261 /lila/data/morrisq/divyak/projects/metient/metient/metient.py:59(calibrate)
#         3    0.003    0.001   42.783   14.261 /lila/data/morrisq/divyak/projects/metient/metient/lib/migration_history_inference.py:196(calibrate)
#         3    0.006    0.002   37.663   12.554 /lila/data/morrisq/divyak/projects/metient/metient/lib/migration_history_inference.py:308(infer_migration_history)
#         3    0.000    0.000   27.989    9.330 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:33(run)
#         3    0.000    0.000   27.989    9.330 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:147(run_multiple_optimizations)
#        15    0.128    0.009   27.391    1.826 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:36(optimize_v)
#        12    0.000    0.000   23.697    1.975 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:159(second_optimization_task)
#        12    0.001    0.000   23.575    1.965 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:131(second_v_optimization)
#      1350    0.405    0.000   19.434    0.014 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:251(compute_v_loss)
#      2527    0.035    0.000   17.371    0.007 /lila/data/morrisq/divyak/projects/metient/metient/util/vertex_labeling_util.py:306(clone_tree_labeling_objective)
#      2553    0.650    0.000   16.823    0.007 /lila/data/morrisq/divyak/projects/metient/metient/util/vertex_labeling_util.py:220(ancestral_labeling_metrics)
#      2553    0.567    0.000   14.374    0.006 /lila/data/morrisq/divyak/projects/metient/metient/util/vertex_labeling_util.py:137(comigration_number)
#      1671    9.950    0.006   12.696    0.008 /lila/data/morrisq/divyak/projects/metient/metient/util/vertex_labeling_util.py:921(path_matrix)
#      4034    0.021    0.000    8.315    0.002 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/_tensor.py:433(backward)
#      4034    0.027    0.000    8.292    0.002 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/autograd/__init__.py:149(backward)
#      4034    8.185    0.002    8.185    0.002 {method 'run_backward' of 'torch._C._EngineBase' objects}
#         3    0.003    0.001    6.533    2.178 /lila/data/morrisq/divyak/projects/metient/metient/lib/migration_history_inference.py:78(get_best_final_solutions)
#        12    0.039    0.003    5.217    0.435 /lila/data/morrisq/divyak/projects/metient/metient/lib/polytomy_resolver.py:202(remove_extra_resolver_nodes)
#      2700    0.318    0.000    4.832    0.002 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:193(gumbel_softmax)
#         3    0.000    0.000    4.288    1.429 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:95(first_v_optimization)
#      2700    0.365    0.000    3.971    0.001 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:189(gumbel_softmax_sample)
#         3    0.163    0.054    3.052    1.017 /lila/data/morrisq/divyak/projects/metient/metient/util/eval_util.py:98(get_max_cross_ent_thetas)
#      2700    0.678    0.000    2.448    0.001 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:180(sample_gumbel)
#         6    0.004    0.001    2.180    0.363 /lila/data/morrisq/divyak/projects/metient/metient/util/plotting_util.py:618(save_best_trees)
#     81651    1.956    0.000    1.956    0.000 {built-in method torch.logical_or}
#         3    0.001    0.000    1.706    0.569 /lila/data/morrisq/divyak/projects/metient/metient/lib/u_optimizer.py:23(run)
#         3    0.067    0.022    1.706    0.569 /lila/data/morrisq/divyak/projects/metient/metient/lib/u_optimizer.py:31(find_umap)
#        26    0.098    0.004    1.637    0.063 /lila/data/morrisq/divyak/projects/metient/metient/util/plotting_util.py:522(plot_tree)
#      2700    0.414    0.000    1.156    0.000 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:184(softmax_shifted_3d)
#      1784    0.862    0.000    1.148    0.001 /lila/data/morrisq/divyak/projects/metient/metient/util/eval_util.py:47(cross_ent)
#      2553    0.272    0.000    1.140    0.000 /lila/data/morrisq/divyak/projects/metient/metient/util/vertex_labeling_util.py:174(genetic_distance_score)
#      2715    1.099    0.000    1.099    0.000 {built-in method torch.rand}
#      8853    1.085    0.000    1.085    0.000 {built-in method torch.log}
#      4034    0.076    0.000    1.083    0.000 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/optim/optimizer.py:356(wrapper)
#      6136    1.023    0.000    1.023    0.000 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pydot.py:530(create_attribute_methods)
#      1350    0.411    0.000    0.990    0.001 /lila/data/morrisq/divyak/projects/metient/metient/lib/v_optimizer.py:223(stack_vertex_labeling)
#        52    0.010    0.000    0.965    0.019 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pydot.py:1482(to_string)
#         3    0.042    0.014    0.964    0.321 /lila/data/morrisq/divyak/projects/metient/metient/lib/migration_history_inference.py:113(recover_prim_ss_solutions)
#         3    0.000    0.000    0.884    0.295 /lila/data/morrisq/divyak/projects/metient/metient/lib/migration_history_inference.py:136(prep_inputs)
#         3    0.000    0.000    0.884    0.295 /lila/data/morrisq/divyak/projects/metient/metient/util/data_extraction_util.py:83(pool_input_tsv)
#     26110    0.834    0.000    0.834    0.000 {built-in method torch.mul}
#      3056    0.011    0.000    0.831    0.000 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pydot.py:721(__init__)
#      4034    0.045    0.000    0.791    0.000 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/optim/optimizer.py:58(_use_grad)
#       960    0.267    0.000    0.787    0.001 /lila/data/morrisq/divyak/projects/metient/metient/lib/polytomy_resolver.py:173(remove_nodes)
#      4517    0.028    0.000    0.754    0.000 /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/_compile.py:20(inner)
#       900    0.048    0.000    0.713    0.001 /lila/data/morrisq/divyak/projects/metient/metient/lib/u_optimizer.py:101(compute_u_loss)
#         3    0.005    0.002    0.704    0.235 /lila/data/morrisq/divyak/projects/metient/metient/util/data_extraction_util.py:101(write_pooled_tsv_from_clusters)
# 100%|██████████| 450/450 [00:25<00:00, 81.40it/s]

# %%
f = '/data/morrisq/divyak/data/metient_prediction_results/'

tree = 0

for run in range(5):
    base_fn = os.path.join(f, f"predictions_batch_exp_bs1024_calibrate_wip_solvepoly_r{run+1}_06202024", num_sites, mig_type)
    visualize_ground_truth(os.path.join(base_fn, f"tree{tree}_seed{seed}_calibrate.tree.dot"), os.path.join(base_fn, f"tree{tree}_seed{seed}_calibrate.mig_graph.dot"))
# Out:
# 100%|██████████| 450/450 [00:20<00:00, 102.91it/s]
