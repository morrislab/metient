# %%
import os
from metient.util import plotting_util as putil
from metient.util import eval_util as eutil

import pandas as pd
import fnmatch
import seaborn as sns

REPO_DIR = os.path.join(os.getcwd(), "../")
# Out:
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11070). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# CUDA GPU: False

# %%
SITES = ["m5", "m8"]
MIG_TYPES = ["mS", "M", "S", "R"]
CUTOFF = 1.0
k = float("inf")
LOSS_THRES=0.0
SUFFIX='_calibrate'

DATE = "05162024"
PARAMS = "calibrate_wip_solvepoly_gen0.1"

# %%
# Get number of clusters (tree vertices to label) per site/mig_type/seed combo
def get_num_mut_trees(mut_tree_fn):
    with open(mut_tree_fn, 'r') as f:
        # look for line w/ "3 #trees" as an example
        for line in f:
            if  "#trees" in line:
                return int(line.strip().split()[0])
sims_dir = os.path.join(REPO_DIR, "data/machina_sims")
og_sims_dir = "/data/morrisq/divyak/projects/machina/data/sims"

data = []
tot = 0
for site in SITES:
    for mig_type in MIG_TYPES:
        site_mig_type_dir = os.path.join(sims_dir, site, mig_type)
        seeds = fnmatch.filter(os.listdir(site_mig_type_dir), 'clustering_observed_seed*.txt')
        seeds = [s.replace(".txt", "").replace("clustering_observed_seed", "") for s in seeds]
        for seed in seeds:
            fn = os.path.join(site_mig_type_dir, f"clustering_observed_seed{seed}.txt")
            num_lines = sum(1 for _ in open(fn))
            fn = os.path.join(og_sims_dir, site, mig_type,f"T_seed{seed}.labeling")
            sites = set()
            with open(fn) as f:
                for line in f:
                    sites.add(line.strip().split()[1])
            n = get_num_mut_trees(os.path.join(sims_dir, f"{site}_mut_trees", f"mut_trees_{mig_type}_seed{seed}.txt"))
            #print(n)
            tot+=n
            for i in range(n):
                data.append([seed, site, mig_type, num_lines, len(sites), i])
print("tot",tot)
cols = ["seed", "site", "mig_type", "clusters", "sites", "tree_num"]
cluster_num_df = pd.DataFrame(data, columns=cols)
cluster_num_df["seed"] = cluster_num_df["seed"].astype(int)
print(cluster_num_df['clusters'].max())

cluster_num_df['cluster_bins'] = pd.qcut(cluster_num_df['clusters'], 3, labels=False, duplicates='drop')
denom=10000
def calc_prob_size(num_sites, num_nodes):
    return (num_sites**(num_nodes-1))
cluster_num_df['prob_size'] = cluster_num_df.apply(lambda row: calc_prob_size(row["sites"], row['clusters'])/denom, axis=1)
cluster_num_df['prob_size_bins'] = pd.qcut(cluster_num_df['prob_size'], 3, labels=False, duplicates='drop')

sns.histplot(cluster_num_df['clusters'], kde=True, color='skyblue')
# Out:
# tot 1647
# 29
# <Axes: xlabel='clusters', ylabel='Count'>

# %%
cluster_num_df
# Out:
#       seed site mig_type  clusters  sites  tree_num  cluster_bins  \
# 0        0   m5       mS        19      5         0             0
# 1        0   m5       mS        19      5         1             0
# 2        7   m5       mS        14      5         0             0
# 3        7   m5       mS        14      5         1             0
# 4        4   m5       mS        12      5         0             0
# ...    ...  ...      ...       ...    ...       ...           ...
# 1642   157   m8        R        29     11        43             2
# 1643   157   m8        R        29     11        44             2
# 1644   157   m8        R        29     11        45             2
# 1645   157   m8        R        29     11        46             2
# 1646   157   m8        R        29     11        47             2
#
#                                   prob_size  prob_size_bins
# 0                           381,469,726.562               0
# 1                           381,469,726.562               0
# 2                               122,070.312               0
# 3                               122,070.312               0
# 4                                 4,882.812               0
# ...                                     ...             ...
# 1642 14,420,993,610,649,923,169,026,048.000               2
# 1643 14,420,993,610,649,923,169,026,048.000               2
# 1644 14,420,993,610,649,923,169,026,048.000               2
# 1645 14,420,993,610,649,923,169,026,048.000               2
# 1646 14,420,993,610,649,923,169,026,048.000               2
#
# [1647 rows x 9 columns]

# %% [markdown]
# ### Evaluate Metient's best trees based on batch size, tree size and number of anatomical sites

# %%
from tqdm import tqdm
import re

batch_sizes = ['64', '256', '1024', ]
num_runs = 5

metient_results_dir = '/data/morrisq/divyak/data/metient_prediction_results/'


bs_to_num_nodes_to_ground_truth_slns = {bs:{} for bs in batch_sizes}
bs_to_num_sites_to_ground_truth_slns = {bs:{} for bs in batch_sizes}
bs_to_prob_size_bin_to_ground_truth_slns = {bs:{} for bs in batch_sizes}
bs_to_prob_size_to_ground_truth_slns = {bs:{} for bs in batch_sizes}

for bs in batch_sizes:
    for run in range(1,num_runs+1):
        prediction_dir = os.path.join(metient_results_dir, f'predictions_batch_exp_bs{bs}_{PARAMS}_r{run}_{DATE}')

        print(prediction_dir)
        grad_m5_f1_scores = []
        grad_m8_f1_scores = []
        ct = 0
        tot = 0
        for site in SITES:
            for mig_type in tqdm(MIG_TYPES):
                true_site_mig_type_data_dir = os.path.join(og_sims_dir, site, mig_type)
                seeds = fnmatch.filter(os.listdir(true_site_mig_type_data_dir), 'clustering_observed_seed*.txt')
                seeds = [s.replace(".txt", "").replace("clustering_observed_seed", "") for s in seeds]
                predicted_site_mig_type_data_dir = os.path.join(prediction_dir, site, mig_type)
                print(seeds)
                print(predicted_site_mig_type_data_dir)
                for seed in seeds:
                    tree_info = eutil.get_metient_min_loss_trees(predicted_site_mig_type_data_dir, seed, k, loss_thres=LOSS_THRES, suffix=SUFFIX)
                    ground_truth_clones_found = False
                    ground_truth_mig_graph_found = False
                    Fs, F_G2s = [], []

                    for i, (loss, met_results_dict, met_tree_num) in enumerate(tree_info):
                        recall, precision, F, has_resolved_polytomy = eutil.evaluate_seeding_clones(os.path.join(true_site_mig_type_data_dir, f"T_seed{seed}.tree"),
                                                                      os.path.join(true_site_mig_type_data_dir, f"T_seed{seed}.vertex.labeling"),
                                                                      met_results_dict, met_tree_num)

                        if F >= CUTOFF:
                            ground_truth_clones_found = True

                        recall_G2, precision_G2, F_G2 = eutil.evaluate_migration_multigraph(os.path.join(true_site_mig_type_data_dir, f"G_seed{seed}.tree"),
                                                                                            met_results_dict, met_tree_num)
                        if F_G2 >= CUTOFF:
                            ground_truth_mig_graph_found = True   
                        Fs.append(F)
                        F_G2s.append(F_G2)
                    subset_df = cluster_num_df[(cluster_num_df['seed']==int(seed))&(cluster_num_df['site']==site)&(cluster_num_df['mig_type']==mig_type)]
                    num_nodes = subset_df.iloc[0]['clusters']
                    rng = subset_df['cluster_bins'].unique().item()
                    if rng not in bs_to_num_nodes_to_ground_truth_slns[bs]:
                        bs_to_num_nodes_to_ground_truth_slns[bs][rng] = []
                    if sum(Fs)/len(Fs) < min(Fs):
                        ct += 1
                    tot+= 1
                    info = (ground_truth_clones_found, ground_truth_mig_graph_found, sum(Fs)/len(Fs), sum(F_G2s)/len(F_G2s))
                    bs_to_num_nodes_to_ground_truth_slns[bs][rng].append(info)

                    num_sites = subset_df.iloc[0]['sites']
                    if num_sites not in bs_to_num_sites_to_ground_truth_slns[bs]:
                        bs_to_num_sites_to_ground_truth_slns[bs][num_sites] = []
                    bs_to_num_sites_to_ground_truth_slns[bs][num_sites].append(info)
                    
                    prob_size_bin = subset_df['prob_size_bins'].unique().item()
                    if prob_size_bin not in bs_to_prob_size_bin_to_ground_truth_slns[bs]:
                        bs_to_prob_size_bin_to_ground_truth_slns[bs][prob_size_bin] = []
                    bs_to_prob_size_bin_to_ground_truth_slns[bs][prob_size_bin].append(info)
                    
                    prob_size = subset_df['prob_size'].unique().item()
                    if prob_size not in bs_to_prob_size_to_ground_truth_slns[bs]:
                        bs_to_prob_size_to_ground_truth_slns[bs][prob_size] = []
                    bs_to_prob_size_to_ground_truth_slns[bs][prob_size].append(info)

bs_to_prob_size_bin_to_ground_truth_slns
# Out:
#   0%|          | 0/4 [00:00<?, ?it/s]
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r1_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r1_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:01,  1.58it/s]
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r1_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:10<00:06,  3.37s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r1_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:13<00:03,  3.34s/it]
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r1_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:29<00:00,  7.34s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r1_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:10<00:30, 10.18s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r1_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:22<00:21, 10.73s/it]
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r1_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:48<00:15, 15.30s/it]
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r1_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:56<00:00, 14.21s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r2_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r2_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:00,  3.77it/s]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r2_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:02<00:01,  1.10it/s]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r2_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:03<00:00,  1.08it/s]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r2_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:08<00:00,  2.09s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r2_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:04<00:12,  4.06s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r2_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:08<00:08,  4.28s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r2_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:32<00:10, 10.13s/it]
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r2_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:36<00:00,  9.01s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r3_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r3_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:02,  1.45it/s]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r3_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:04<00:03,  1.63s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r3_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:05<00:01,  1.49s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r3_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:09<00:00,  2.49s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r3_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:03<00:09,  3.20s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r3_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:08<00:07,  3.78s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r3_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:28<00:08,  8.63s/it]
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r3_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:30<00:00,  7.65s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r4_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r4_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:01,  2.31it/s]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r4_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:05<00:03,  1.90s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r4_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:07<00:01,  1.87s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r4_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:13<00:00,  3.29s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r4_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:03<00:09,  3.17s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r4_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:08<00:07,  3.91s/it]
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r4_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:16<00:05,  5.02s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r4_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:18<00:00,  4.68s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r5_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r5_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:01,  1.79it/s]
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r5_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:03<00:02,  1.30s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r5_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:05<00:01,  1.50s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r5_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:13<00:00,  3.44s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r5_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:04<00:14,  4.86s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r5_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:16<00:13,  6.97s/it]
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r5_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:31<00:09,  9.27s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs64_calibrate_wip_more_calibrate_iters_r5_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:33<00:00,  8.33s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r1_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r1_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:01,  2.78it/s]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r1_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:04<00:02,  1.49s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r1_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:08<00:02,  2.13s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r1_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:28<00:00,  7.24s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r1_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:11<00:35, 11.92s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r1_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:26<00:25, 12.83s/it]
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r1_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [01:00<00:19, 19.17s/it]
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r1_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [01:11<00:00, 17.89s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r2_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r2_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:02,  1.09it/s]
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r2_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:07<00:05,  2.70s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r2_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:08<00:02,  2.23s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r2_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:13<00:00,  3.49s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r2_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:03<00:10,  3.46s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r2_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:09<00:08,  4.21s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r2_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:40<00:12, 12.25s/it]
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r2_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:43<00:00, 10.87s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r3_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r3_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:01,  1.70it/s]
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r3_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:09<00:06,  3.07s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r3_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:11<00:02,  2.63s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r3_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:20<00:00,  5.03s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r3_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:04<00:13,  4.42s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r3_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:12<00:11,  5.50s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r3_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:28<00:08,  8.64s/it]
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r3_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:31<00:00,  7.93s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r4_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r4_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:02,  1.06it/s]
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r4_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:11<00:07,  3.70s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r4_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:13<00:03,  3.38s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r4_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:25<00:00,  6.41s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r4_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:05<00:17,  5.86s/it]
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r4_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:18<00:15,  7.93s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r4_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:26<00:07,  7.85s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r4_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:30<00:00,  7.55s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r5_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r5_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:01,  2.15it/s]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r5_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:06<00:04,  2.09s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r5_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:09<00:02,  2.42s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r5_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:17<00:00,  4.49s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r5_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:10<00:31, 10.57s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r5_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:32<00:27, 13.84s/it]
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r5_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:57<00:17, 17.21s/it]
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs256_calibrate_wip_more_calibrate_iters_r5_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [01:05<00:00, 16.39s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r1_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r1_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:01,  1.51it/s]
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r1_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:09<00:06,  3.14s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r1_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:11<00:02,  2.84s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r1_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:30<00:00,  7.59s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r1_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:13<00:39, 13.06s/it]
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r1_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:22<00:23, 11.83s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r1_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:57<00:19, 19.06s/it]
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r1_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [01:10<00:00, 17.53s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r2_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r2_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:01<00:03,  1.28s/it]
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r2_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:14<00:09,  4.90s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r2_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:16<00:03,  3.96s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r2_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:26<00:00,  6.57s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r2_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:06<00:19,  6.45s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r2_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:15<00:14,  7.13s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r2_03282024/m8/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:53<00:16, 16.49s/it]
# # min loss trees: 1
# ['10157', '1070', '9', '905', '10046', '394', '981', '383', '30342', '157']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r2_03282024/m8/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:59<00:00, 14.85s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r3_03282024
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r3_03282024/m5/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:01<00:03,  1.12s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['209', '534', '694', '512', '545', '865', '907', '76', '565', '473']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r3_03282024/m5/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:13<00:09,  4.61s/it]
# # min loss trees: 1
# ['49', '35', '25', '31', '81', '40', '32', '23', '62', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r3_03282024/m5/S
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  75%|███████▌  | 3/4 [00:17<00:04,  4.18s/it]
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# ['571', '1140', '538', '981', '2155', '950', '247', '955', '518', '17']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r3_03282024/m5/R
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# 100%|██████████| 4/4 [00:31<00:00,  7.87s/it]
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 1
# ['0', '7', '4', '9', '8', '3', '12', '10', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r3_03282024/m8/mS
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:07<00:22,  7.48s/it]
# # min loss trees: 1
# ['45', '7', '35', '243', '216', '239', '19', '76', '172', '241']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r3_03282024/m8/M
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 1
#  50%|█████     | 2/4 [00:17<00:16,  8.26s/it]
# # min loss trees: 1
# # min loss trees: 1
# ['0', '35', '37', '31', '69', '54', '12', '23', '2', '5']
# /data/morrisq/divyak/data/metient_prediction_results/predictions_batch_exp_bs1024_calibrate_wip_more_calibrate_iters_r3_03282024/m8/S
# # min loss trees: 1
# ...
#    (True, False, 1.0, 0.9333333333333333),
#    (True, False, 1.0, 0.47058823529411764),
#    (True, False, 1.0, 0.42105263157894735),
#    (False, False, 0.9230769230769229, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8571428571428572, 0.8571428571428572),
#    (False, False, 0.8, 0.7619047619047619),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.75),
#    (True, False, 1.0, 0.75),
#    (True, False, 1.0, 0.8),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.6000000000000001),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.75, 0.46153846153846145),
#    (False, False, 0.5714285714285714, 0.6666666666666666),
#    (True, False, 1.0, 0.9230769230769229),
#    (True, False, 1.0, 0.6153846153846154),
#    (True, False, 1.0, 0.9230769230769229),
#    (False, False, 0.8888888888888888, 0.8571428571428571),
#    (True, False, 1.0, 0.8571428571428571),
#    (False, False, 0.8888888888888888, 0.6666666666666666),
#    (False, False, 0.8571428571428572, 0.5454545454545454),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, False, 1.0, 0.9090909090909091),
#    (False, False, 0.8571428571428572, 0.7692307692307694),
#    (True, False, 1.0, 0.5),
#    (False, False, 0.5714285714285714, 0.8333333333333334),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, False, 1.0, 0.8235294117647058),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.7272727272727273),
#    (True, False, 1.0, 0.7692307692307694),
#    (True, False, 1.0, 0.9090909090909091),
#    (False, False, 0.6666666666666666, 0.875),
#    (False, False, 0.6666666666666666, 0.2),
#    (False, False, 0.8888888888888888, 0.1111111111111111),
#    (False, False, 0.8888888888888888, 0.4),
#    (False, False, 0.8571428571428572, 0.7692307692307694),
#    (True, False, 1.0, 0.9230769230769229),
#    (False, False, 0.6666666666666666, 0.5),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.6666666666666666),
#    (True, False, 1.0, 0.9333333333333333),
#    (True, False, 1.0, 0.47058823529411764),
#    (False, False, 0.6153846153846154, 0.6666666666666666),
#    (False, False, 0.9230769230769229, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8571428571428572, 0.8571428571428572),
#    (False, False, 0.8, 0.7619047619047619),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.75),
#    (True, False, 1.0, 0.75),
#    (True, False, 1.0, 0.8),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.6000000000000001),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.75, 0.46153846153846145),
#    (False, False, 0.5714285714285714, 0.7272727272727273),
#    (True, False, 1.0, 0.9230769230769229),
#    (True, False, 1.0, 0.6153846153846154),
#    (True, False, 1.0, 0.9230769230769229),
#    (False, False, 0.8, 0.8571428571428571),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8888888888888888, 0.6666666666666666),
#    (False, False, 0.8571428571428572, 0.5454545454545454),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, False, 1.0, 0.9090909090909091),
#    (False, False, 0.8571428571428572, 0.7692307692307694),
#    (True, False, 1.0, 0.5),
#    (False, False, 0.5714285714285714, 0.8333333333333334),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.8571428571428572, 0.8),
#    (False, False, 0.8571428571428572, 0.8235294117647058),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.7272727272727273),
#    (True, False, 1.0, 0.7692307692307694),
#    (True, False, 1.0, 0.9090909090909091),
#    (False, False, 0.8571428571428572, 0.875),
#    (False, False, 0.6666666666666666, 0.2),
#    (False, False, 0.8888888888888888, 0.1111111111111111),
#    (False, False, 0.8888888888888888, 0.4),
#    (False, False, 0.8571428571428572, 0.7692307692307694),
#    (True, False, 1.0, 0.9230769230769229),
#    (False, False, 0.6666666666666666, 0.5),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.6666666666666666),
#    (True, False, 1.0, 0.9333333333333333),
#    (True, False, 1.0, 0.47058823529411764),
#    (True, False, 1.0, 0.3),
#    (False, False, 0.9230769230769229, 0.5555555555555556),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8571428571428572, 0.8571428571428572),
#    (False, False, 0.8, 0.7619047619047619),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.75),
#    (True, False, 1.0, 0.75),
#    (True, False, 1.0, 0.8),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.6000000000000001),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.75, 0.46153846153846145),
#    (False, False, 0.5714285714285714, 0.6666666666666666),
#    (True, False, 1.0, 0.9230769230769229),
#    (True, False, 1.0, 0.6153846153846154),
#    (True, False, 1.0, 0.9230769230769229),
#    (False, False, 0.8888888888888888, 0.8571428571428571),
#    (True, False, 1.0, 0.7142857142857143),
#    (False, False, 0.8888888888888888, 0.6666666666666666),
#    (False, False, 0.8571428571428572, 0.5454545454545454),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, False, 1.0, 0.9090909090909091),
#    (False, False, 0.8571428571428572, 0.7692307692307694),
#    (True, False, 1.0, 0.5),
#    (False, False, 0.5714285714285714, 0.8333333333333334),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.75, 0.8),
#    (True, False, 1.0, 0.8235294117647058),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.7272727272727273),
#    (True, False, 1.0, 0.7692307692307694),
#    (True, False, 1.0, 0.9090909090909091),
#    (False, False, 0.75, 0.875),
#    (False, False, 0.6666666666666666, 0.2),
#    (False, False, 0.8888888888888888, 0.1111111111111111),
#    (False, False, 0.8888888888888888, 0.4),
#    (False, False, 0.8571428571428572, 0.7692307692307694),
#    (True, False, 1.0, 0.9230769230769229),
#    (False, False, 0.75, 0.5),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.6666666666666666),
#    (True, False, 1.0, 0.9333333333333333),
#    (True, False, 1.0, 0.47058823529411764),
#    (True, False, 1.0, 0.42105263157894735),
#    (False, False, 0.9230769230769229, 0.5555555555555556),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8571428571428572, 0.8571428571428572),
#    (False, False, 0.8, 0.7619047619047619),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.75),
#    (True, False, 1.0, 0.75),
#    (True, False, 1.0, 0.8),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.6000000000000001),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.75, 0.46153846153846145),
#    (False, False, 0.5714285714285714, 0.6666666666666666),
#    (True, False, 1.0, 0.9230769230769229),
#    (True, False, 1.0, 0.6153846153846154),
#    (True, False, 1.0, 0.9230769230769229),
#    (False, False, 0.8888888888888888, 0.8571428571428571),
#    (True, False, 1.0, 0.7142857142857143),
#    (False, False, 0.8888888888888888, 0.6666666666666666),
#    (False, False, 0.8571428571428572, 0.5454545454545454),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, False, 1.0, 0.9090909090909091),
#    (False, False, 0.8571428571428572, 0.7692307692307694),
#    (True, False, 1.0, 0.5),
#    (False, False, 0.5714285714285714, 0.8333333333333334),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, False, 1.0, 0.8235294117647058),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.7272727272727273),
#    (True, False, 1.0, 0.7692307692307694),
#    (True, False, 1.0, 0.9090909090909091),
#    (False, False, 0.75, 0.875),
#    (False, False, 0.6666666666666666, 0.2),
#    (False, False, 0.8888888888888888, 0.1111111111111111),
#    (False, False, 0.8888888888888888, 0.4),
#    (False, False, 0.8571428571428572, 0.7692307692307694),
#    (True, False, 1.0, 0.9230769230769229),
#    (False, False, 0.75, 0.5),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.6666666666666666),
#    (True, False, 1.0, 0.9333333333333333),
#    (True, False, 1.0, 0.47058823529411764),
#    (False, False, 0.9090909090909091, 0.8421052631578947),
#    (False, False, 0.9230769230769229, 0.5555555555555556),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8571428571428572, 0.8571428571428572),
#    (False, False, 0.8, 0.7619047619047619)],
#   1: [(True, False, 1.0, 0.9090909090909091),
#    (True, False, 1.0, 0.8571428571428572),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.6666666666666666, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.875),
#    (True, False, 1.0, 0.34782608695652173),
#    (False, False, 0.8571428571428572, 0.8571428571428572),
#    (False, False, 0.8888888888888888, 0.8999999999999999),
#    (True, False, 1.0, 0.631578947368421),
#    (False, False, 0.8571428571428571, 0.5714285714285714),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.875),
#    (False, False, 0.8888888888888888, 0.8),
#    (False, False, 0.8888888888888888, 0.13333333333333333),
#    (True, False, 1.0, 0.7777777777777779),
#    (True, False, 1.0, 0.9565217391304348),
#    (False, False, 0.9090909090909091, 0.7499999999999999),
#    (False, False, 0.6666666666666666, 0.8888888888888888),
#    (True, False, 1.0, 0.9473684210526315),
#    (True, False, 1.0, 0.47619047619047616),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.7142857142857143, 0.8571428571428572),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.5454545454545454, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.875),
#    (True, False, 1.0, 0.34782608695652173),
#    (False, False, 0.8571428571428572, 0.8571428571428572),
#    (False, False, 0.8888888888888888, 0.8999999999999999),
#    (True, False, 1.0, 0.5263157894736842),
#    (False, False, 0.8571428571428571, 0.5714285714285714),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.875),
#    (False, False, 0.8888888888888888, 0.8),
#    (False, False, 0.8888888888888888, 0.13333333333333333),
#    (True, False, 1.0, 0.7777777777777779),
#    (True, False, 1.0, 0.9565217391304348),
#    (False, False, 0.9090909090909091, 0.625),
#    (False, False, 0.6666666666666666, 0.8888888888888888),
#    (True, False, 1.0, 0.9473684210526315),
#    (True, False, 1.0, 0.47619047619047616),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.8571428571428571, 0.5714285714285714),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.6666666666666666, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.875),
#    (True, False, 1.0, 0.34782608695652173),
#    (False, False, 0.8571428571428572, 0.8571428571428572),
#    (False, False, 0.8888888888888888, 0.8999999999999999),
#    (True, False, 1.0, 0.5263157894736842),
#    (False, False, 0.8571428571428571, 0.5714285714285714),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.875),
#    (False, False, 0.8888888888888888, 0.8),
#    (False, False, 0.8888888888888888, 0.13333333333333333),
#    (False, False, 0.8, 0.7777777777777779),
#    (True, False, 1.0, 0.6086956521739131),
#    (False, False, 0.9090909090909091, 0.823529411764706),
#    (False, False, 0.6666666666666666, 0.8888888888888888),
#    (True, False, 1.0, 0.9473684210526315),
#    (True, False, 1.0, 0.47619047619047616),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.8, 0.8571428571428572),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.6666666666666666, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.875),
#    (True, False, 1.0, 0.34782608695652173),
#    (False, False, 0.8571428571428572, 0.8571428571428572),
#    (False, False, 0.8888888888888888, 0.8999999999999999),
#    (True, False, 1.0, 0.5263157894736842),
#    (False, False, 0.5714285714285714, 0.6666666666666666),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.875),
#    (False, False, 0.8888888888888888, 0.8),
#    (False, False, 0.8888888888888888, 0.13333333333333333),
#    (True, False, 1.0, 0.7777777777777779),
#    (True, False, 1.0, 0.9565217391304348),
#    (False, False, 0.9090909090909091, 0.7499999999999999),
#    (False, False, 0.6666666666666666, 0.8888888888888888),
#    (True, False, 1.0, 0.8421052631578947),
#    (True, False, 1.0, 0.6666666666666666),
#    (True, False, 1.0, 0.9090909090909091),
#    (False, False, 0.7142857142857143, 0.8571428571428572),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.6666666666666666, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.875),
#    (True, False, 1.0, 0.34782608695652173),
#    (False, False, 0.8571428571428572, 0.8571428571428572),
#    (False, False, 0.8888888888888888, 0.8999999999999999),
#    (True, False, 1.0, 0.5263157894736842),
#    (False, False, 0.8571428571428571, 0.5714285714285714),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.875),
#    (False, False, 0.8888888888888888, 0.8),
#    (False, False, 0.8888888888888888, 0.13333333333333333),
#    (True, False, 1.0, 0.7777777777777779),
#    (True, False, 1.0, 0.9565217391304348),
#    (False, False, 0.9090909090909091, 0.7499999999999999),
#    (False, False, 0.6666666666666666, 0.8888888888888888),
#    (True, False, 1.0, 0.8421052631578947),
#    (True, False, 1.0, 0.6666666666666666)],
#   2: [(False, False, 0.6153846153846154, 0.8421052631578947),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.823529411764706),
#    (False, False, 0.6666666666666666, 0.8148148148148148),
#    (True, False, 1.0, 0.2),
#    (False, False, 0.875, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8, 0.9473684210526315),
#    (True, False, 1.0, 0.5),
#    (False, False, 0.9090909090909091, 0.6363636363636364),
#    (False, False, 0.7142857142857143, 0.38095238095238093),
#    (False, False, 0.8571428571428572, 0.5263157894736842),
#    (True, False, 1.0, 0.9600000000000002),
#    (True, False, 1.0, 0.823529411764706),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.823529411764706),
#    (False, False, 0.6666666666666666, 0.8148148148148148),
#    (True, False, 1.0, 0.2),
#    (False, False, 0.875, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8, 0.9473684210526315),
#    (True, False, 1.0, 0.5),
#    (False, False, 0.9090909090909091, 0.6363636363636364),
#    (False, False, 0.7142857142857143, 0.38095238095238093),
#    (False, False, 0.8571428571428572, 0.5263157894736842),
#    (True, False, 1.0, 0.9600000000000002),
#    (True, False, 1.0, 0.823529411764706),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.823529411764706),
#    (False, False, 0.588235294117647, 0.8148148148148148),
#    (True, False, 1.0, 0.2),
#    (False, False, 0.875, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8, 0.9473684210526315),
#    (True, False, 1.0, 0.5),
#    (False, False, 0.9090909090909091, 0.6363636363636364),
#    (False, False, 0.7142857142857143, 0.38095238095238093),
#    (False, False, 0.8571428571428572, 0.5263157894736842),
#    (True, False, 1.0, 0.9600000000000002),
#    (True, False, 1.0, 0.3333333333333333),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.823529411764706),
#    (False, False, 0.9090909090909091, 0.8888888888888888),
#    (True, False, 1.0, 0.2),
#    (False, False, 0.875, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.9090909090909091, 0.9473684210526315),
#    (True, False, 1.0, 0.5),
#    (False, False, 0.9090909090909091, 0.6363636363636364),
#    (False, False, 0.7142857142857143, 0.38095238095238093),
#    (False, False, 0.8571428571428572, 0.5263157894736842),
#    (True, False, 1.0, 0.9600000000000002),
#    (True, False, 1.0, 0.823529411764706),
#    (True, False, 1.0, 0.8888888888888888),
#    (True, False, 1.0, 0.823529411764706),
#    (False, False, 0.8, 0.7857142857142856),
#    (True, False, 1.0, 0.2),
#    (False, False, 0.875, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8, 0.9473684210526315),
#    (True, False, 1.0, 0.5),
#    (False, False, 0.9090909090909091, 0.6363636363636364),
#    (False, False, 0.7142857142857143, 0.38095238095238093),
#    (False, False, 0.8571428571428572, 0.5263157894736842),
#    (True, False, 1.0, 0.9600000000000002)]}}

# %% [markdown]
# ### Load machina results for comparison

# %%
mach_node_size_to_ground_truth_slns = {}
mach_num_sites_to_ground_truth_slns = {}
mach_prob_size_bin_to_ground_truth_slns = {}
mach_prob_size_to_ground_truth_slns = {}

machina_m5_df, machina_m8_df = eutil.load_machina_results(os.path.join(REPO_DIR, 'test/machina_simulated_data'))
col_mapping = {"FscoreT": "migrating clones F1 score", "FscoreMultiG": "migration graph F1 score", "pattern": "seeding pattern", "seed":"seed"}
machina_m5_df = machina_m5_df.rename(columns=col_mapping)
machina_m8_df = machina_m8_df.rename(columns=col_mapping)
for site, df in zip(['m5', 'm8'],[machina_m5_df, machina_m8_df]):
    for i, row in df.iterrows():
        pattern = row['seeding pattern'].replace("p", "")
        subset_df = cluster_num_df[(cluster_num_df['seed']==int(row['seed']))&(cluster_num_df['site']==site)&(cluster_num_df['mig_type']==pattern)]
        num_nodes = subset_df.iloc[0]['clusters']
        rng = subset_df['cluster_bins'].unique().item()
        num_sites = subset_df.iloc[0]['sites']
        if rng not in mach_node_size_to_ground_truth_slns:
            mach_node_size_to_ground_truth_slns[rng] = []
        if num_sites not in mach_num_sites_to_ground_truth_slns:
            mach_num_sites_to_ground_truth_slns[num_sites] = []
            
        prob_size_bin = subset_df['prob_size_bins'].unique().item()
        if prob_size_bin not in mach_prob_size_bin_to_ground_truth_slns:
            mach_prob_size_bin_to_ground_truth_slns[prob_size_bin] = []
        
        prob_size = subset_df['prob_size'].unique().item()
        if prob_size not in mach_prob_size_to_ground_truth_slns:
            mach_prob_size_to_ground_truth_slns[prob_size] = []
        
        ground_truth_clones_found = False
        ground_truth_mig_graph_found = False
        if float(row['migrating clones F1 score']) >= CUTOFF:
            ground_truth_clones_found = True
        if float(row['migration graph F1 score']) >= CUTOFF:
            ground_truth_mig_graph_found = True
        info = (ground_truth_clones_found, ground_truth_mig_graph_found, row['migrating clones F1 score'], row['migration graph F1 score'])
        mach_node_size_to_ground_truth_slns[rng].append(info)
        mach_num_sites_to_ground_truth_slns[num_sites].append(info)
        mach_prob_size_bin_to_ground_truth_slns[prob_size_bin].append(info)
        mach_prob_size_to_ground_truth_slns[prob_size].append(info)

mach_prob_size_to_ground_truth_slns
# Out:
# {3051757.8125: [(False, False, 0.666666666667, 0.5),
#   (False, False, 0.666666666667, 0.5),
#   (False, False, 0.75, 0.5),
#   (False, False, 0.75, 0.5),
#   (False, False, 0.75, 0.5),
#   (False, False, 0.75, 0.5),
#   (False, False, 0.75, 0.5),
#   (False, False, 0.75, 0.5),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.8, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.888888888889, 0.571428571429),
#   (False, False, 0.8, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.888888888889, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.888888888889, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.666666666667, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.888888888889, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.666666666667, 0.142857142857),
#   (False, False, 0.888888888889, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.6, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.888888888889, 0.571428571429),
#   (False, False, 0.888888888889, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.888888888889, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (False, False, 0.8, 0.888888888889)],
#  390982104858298.8: [(False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.666666666667, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.615384615385, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.857142857143, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.615384615385, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.857142857143, 0.8),
#   (False, False, 0.857142857143, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.533333333333, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.8, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.615384615385, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.615384615385, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.923076923077, 0.8)],
#  15258789.0625: [(True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273)],
#  24414.0625: [(False, False, 0.5, 0.727272727273),
#   (False, False, 0.571428571429, 0.727272727273),
#   (False, False, 0.444444444444, 0.727272727273),
#   (False, False, 0.571428571429, 0.727272727273),
#   (False, False, 0.571428571429, 0.727272727273),
#   (False, False, 0.5, 0.727272727273),
#   (False, False, 0.444444444444, 0.727272727273),
#   (False, False, 0.5, 0.727272727273),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.8, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (False, False, 0.8, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (False, False, 0.8, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (False, False, 0.5, 0.545454545455),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (False, False, 0.75, 0.833333333333),
#   (False, False, 0.857142857143, 0.8),
#   (False, False, 0.75, 0.8)],
#  1692665944.4736: [(True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.615384615385),
#   (True, False, 1.0, 0.615384615385)],
#  610351.5625: [(True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5)],
#  76293945.3125: [(True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (False, False, 0.75, 0.571428571429),
#   (False, False, 0.666666666667, 0.571428571429),
#   (False, False, 0.75, 0.571428571429),
#   (False, False, 0.75, 0.571428571429),
#   (False, False, 0.888888888889, 0.2),
#   (False, False, 0.888888888889, 0.2),
#   (False, False, 0.888888888889, 0.2),
#   (False, False, 0.888888888889, 0.2),
#   (False, False, 0.571428571429, 0.909090909091),
#   (False, False, 0.571428571429, 0.909090909091),
#   (False, False, 0.571428571429, 0.909090909091),
#   (False, False, 0.571428571429, 0.909090909091)],
#  381469726.5625: [(False, False, 0.8, 0.666666666667),
#   (False, False, 0.888888888889, 0.666666666667),
#   (False, False, 0.8, 0.666666666667),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0)],
#  4882.8125: [(True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75),
#   (False, False, 0.666666666667, 0.8),
#   (False, False, 0.75, 0.8),
#   (False, False, 0.75, 0.8),
#   (False, False, 0.666666666667, 0.8)],
#  976.5625: [(True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.857142857143, 0.8)],
#  195.3125: [(True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75)],
#  13162170384226.713: [(True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0)],
#  122070.3125: [(True, True, 1.0, 1.0),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.833333333333),
#   (False, False, 0.857142857143, 0.833333333333),
#   (False, False, 0.857142857143, 0.833333333333),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.666666666667),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.888888888889),
#   (True, False, 1.0, 0.888888888889)],
#  1.5625: [(False, False, 0.8, 0.75)],
#  7836416.4096: [(True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.75, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.545454545455, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.666666666667, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.6, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.6, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.75, 0.333333333333),
#   (False, False, 0.75, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.75, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (False, False, 0.6, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.75, 0.769230769231),
#   (False, False, 0.75, 0.769230769231)],
#  23263051398.7207: [(True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.235294117647),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571)],
#  47018498.4576: [(True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333)],
#  1e+24: [(True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.909090909091, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.8, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.909090909091, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.8, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.909090909091, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.909090909091, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.8, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.8, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.823529411765, 0.521739130435),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.25, 0.521739130435),
#   (False, False, 0.235294117647, 0.608695652174),
#   (False, False, 0.375, 0.521739130435),
#   (False, False, 0.235294117647, 0.521739130435),
#   (False, False, 0.75, 0.608695652174),
#   (False, False, 0.235294117647, 0.608695652174),
#   (False, False, 0.235294117647, 0.608695652174),
#   (False, False, 0.75, 0.608695652174),
#   (False, False, 0.235294117647, 0.608695652174),
#   (False, False, 0.875, 0.695652173913),
#   (False, False, 0.75, 0.695652173913),
#   (False, False, 0.375, 0.695652173913),
#   (False, False, 0.823529411765, 0.608695652174),
#   (False, False, 0.875, 0.521739130435),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.666666666667, 0.695652173913),
#   (False, False, 0.823529411765, 0.608695652174),
#   (False, False, 0.333333333333, 0.608695652174),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.666666666667, 0.608695652174),
#   (False, False, 0.823529411765, 0.608695652174),
#   (False, False, 0.352941176471, 0.521739130435),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.875, 0.695652173913),
#   (False, False, 0.75, 0.521739130435),
#   (False, False, 0.235294117647, 0.695652173913),
#   (False, False, 0.235294117647, 0.521739130435),
#   (False, False, 0.666666666667, 0.608695652174),
#   (False, False, 0.75, 0.608695652174),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.875, 0.695652173913),
#   (False, False, 0.75, 0.695652173913),
#   (False, False, 0.875, 0.695652173913),
#   (False, False, 0.333333333333, 0.608695652174),
#   (False, False, 0.875, 0.608695652174),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.666666666667, 0.608695652174),
#   (False, False, 0.875, 0.608695652174),
#   (False, False, 0.823529411765, 0.695652173913),
#   (False, False, 0.352941176471, 0.608695652174),
#   (False, False, 0.823529411765, 0.608695652174),
#   (False, False, 0.352941176471, 0.608695652174),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.875, 0.695652173913)],
#  1801439850948.1985: [(False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.666666666667),
#   (True, False, 1.0, 0.823529411765),
#   (True, False, 1.0, 0.823529411765),
#   (False, False, 0.8, 0.777777777778),
#   (False, False, 0.8, 0.777777777778),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.666666666667)],
#  4.7223664828696454e+17: [(True, False, 1.0, 0.352941176471),
#   (True, False, 1.0, 0.588235294118),
#   (True, False, 1.0, 0.588235294118)],
#  7378697629483821.0: [(False, False, 0.8, 0.823529411765),
#   (True, False, 1.0, 0.823529411765),
#   (True, False, 1.0, 0.823529411765),
#   (True, False, 1.0, 0.823529411765),
#   (False, True, 0.666666666667, 1.0),
#   (False, True, 0.615384615385, 1.0),
#   (False, False, 0.666666666667, 0.666666666667),
#   (False, False, 0.666666666667, 0.888888888889),
#   (False, False, 0.666666666667, 0.666666666667),
#   (False, True, 0.666666666667, 1.0),
#   (False, False, 0.666666666667, 0.888888888889),
#   (False, True, 0.615384615385, 1.0),
#   (False, True, 0.666666666667, 1.0),
#   (False, True, 0.666666666667, 1.0),
#   (False, True, 0.615384615385, 1.0),
#   (False, True, 0.666666666667, 1.0),
#   (False, False, 0.666666666667, 0.777777777778),
#   (False, True, 0.666666666667, 1.0),
#   (False, False, 0.666666666667, 0.888888888889),
#   (False, False, 0.666666666667, 0.888888888889)],
#  5.814973700304006e+21: [(True, False, 1.0, 0.846153846154),
#   (True, False, 1.0, 0.846153846154),
#   (True, False, 1.0, 0.846153846154),
#   (False, False, 0.923076923077, 0.846153846154),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (False, False, 0.588235294118, 0.380952380952),
#   (False, False, 0.625, 0.380952380952)],
#  8.8629381196525e+17: [(False, False, 0.727272727273, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.727272727273, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.727272727273, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.727272727273, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952)],
#  922337203685477.6: [(False, False, 0.888888888889, 0.857142857143),
#   (False, False, 0.909090909091, 0.375),
#   (False, False, 0.727272727273, 0.375),
#   (False, False, 0.909090909091, 0.375),
#   (False, False, 0.909090909091, 0.375),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.857142857143, 0.761904761905),
#   (False, False, 0.857142857143, 0.571428571429),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.47619047619),
#   (False, False, 0.933333333333, 0.857142857143),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.47619047619),
#   (False, False, 0.857142857143, 0.857142857143),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.933333333333, 0.571428571429),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.47619047619),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.857142857143, 0.857142857143),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.8, 0.666666666667),
#   (False, False, 0.933333333333, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.285714285714),
#   (False, False, 0.857142857143, 0.571428571429),
#   (False, False, 0.933333333333, 0.571428571429),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.933333333333, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.857142857143, 0.47619047619),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.933333333333, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.571428571429),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.933333333333, 0.857142857143),
#   (True, False, 1.0, 0.47619047619),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.933333333333, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.857142857143, 0.761904761905),
#   (False, False, 0.857142857143, 0.380952380952),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.8, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.857142857143, 0.571428571429),
#   (True, False, 1.0, 0.47619047619),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.933333333333, 0.761904761905),
#   (False, False, 0.933333333333, 0.857142857143),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.761904761905),
#   (False, False, 0.933333333333, 0.761904761905),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.857142857143, 0.380952380952),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.857142857143, 0.857142857143),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.47619047619),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.933333333333, 0.761904761905),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.285714285714),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.857142857143, 0.571428571429),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.933333333333, 0.857142857143),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.857142857143),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.857142857143),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.933333333333, 0.761904761905),
#   (False, False, 0.857142857143, 0.571428571429)],
#  9.847709021836112e+16: [(False, False, 0.533333333333, 0.9),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.8, 0.9)],
#  5.902958103587057e+16: [(False, False, 0.857142857143, 0.333333333333),
#   (False, False, 0.857142857143, 0.333333333333),
#   (False, False, 0.857142857143, 0.333333333333),
#   (False, False, 0.857142857143, 0.222222222222)],
#  5.233476330273605e+22: [(True, False, 1.0, 0.875), (True, False, 1.0, 0.875)],
#  225179981368.5248: [(True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0)],
#  135085171767299.2: [(True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.625),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.625),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.625),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0)],
#  2287679245.4961: [(True, False, 1.0, 0.625), (True, False, 1.0, 0.25)],
#  14411518807585.588: [(False, False, 0.666666666667, 0.714285714286),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, True, 0.666666666667, 1.0),
#   (False, False, 0.923076923077, 0.444444444444),
#   (True, False, 1.0, 0.444444444444),
#   (False, False, 0.857142857143, 0.444444444444),
#   (False, False, 0.923076923077, 0.444444444444),
#   (False, False, 0.714285714286, 0.444444444444),
#   (True, False, 1.0, 0.444444444444),
#   (False, False, 0.8, 0.5),
#   (False, True, 0.8, 1.0),
#   (False, True, 0.545454545455, 1.0),
#   (False, True, 0.727272727273, 1.0),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (False, False, 0.909090909091, 0.5),
#   (False, True, 0.8, 1.0),
#   (True, False, 1.0, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.8, 0.5),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.5),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.5),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.5),
#   (False, True, 0.8, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.8, 0.5),
#   (False, False, 0.909090909091, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, True, 0.909090909091, 1.0),
#   (False, True, 0.727272727273, 1.0),
#   (False, True, 0.8, 1.0),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.8, 0.5),
#   (False, True, 0.727272727273, 1.0),
#   (False, True, 0.8, 1.0),
#   (False, True, 0.8, 1.0),
#   (False, False, 0.8, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, True, 0.8, 1.0),
#   (False, True, 0.545454545455, 1.0),
#   (False, False, 0.727272727273, 0.5),
#   (False, True, 0.909090909091, 1.0),
#   (False, True, 0.545454545455, 1.0),
#   (False, False, 0.8, 0.5),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.5),
#   (False, True, 0.8, 1.0),
#   (False, False, 0.8, 0.5),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.727272727273, 1.0),
#   (False, False, 0.8, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.727272727273, 1.0),
#   (True, False, 1.0, 0.5),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.8, 1.0),
#   (False, False, 0.8, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.8, 0.5),
#   (False, False, 0.888888888889, 0.133333333333)],
#  115292150460684.7: [(True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.933333333333),
#   (True, False, 1.0, 0.933333333333),
#   (True, False, 1.0, 0.933333333333),
#   (True, False, 1.0, 0.933333333333),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.888888888889, 0.533333333333),
#   (False, False, 0.888888888889, 0.4),
#   (True, False, 1.0, 0.666666666667)],
#  6.461081889226673e+20: [(True, True, 1.0, 1.0),
#   (False, True, 0.888888888889, 1.0)],
#  1667718169966.657: [(True, False, 1.0, 0.75)],
#  3.7778931862957164e+18: [(False, False, 0.727272727273, 0.526315789474),
#   (False, False, 0.727272727273, 0.526315789474),
#   (False, False, 0.909090909091, 0.941176470588),
#   (False, False, 0.909090909091, 0.941176470588),
#   (False, False, 0.909090909091, 0.941176470588),
#   (False, False, 0.909090909091, 0.941176470588)],
#  1.9342813113834068e+21: [(False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.727272727273, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.727272727273, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.625, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.875, 0.526315789474)],
#  1.4420993610649923e+25: [(False, False, 0.727272727273, 0.416666666667),
#   (False, False, 0.909090909091, 0.416666666667),
#   (False, False, 0.666666666667, 0.416666666667),
#   (False, False, 0.909090909091, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.727272727273, 0.583333333333),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.666666666667, 0.416666666667),
#   (False, False, 0.727272727273, 0.416666666667),
#   (False, False, 0.909090909091, 0.583333333333),
#   (False, False, 0.909090909091, 0.416666666667),
#   (False, False, 0.727272727273, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.833333333333, 0.5),
#   (False, False, 0.727272727273, 0.416666666667),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.909090909091, 0.583333333333),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.666666666667, 0.416666666667),
#   (False, False, 0.727272727273, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.909090909091, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.909090909091, 0.416666666667),
#   (False, False, 0.666666666667, 0.416666666667),
#   (False, False, 0.727272727273, 0.5)],
#  1.0941898913151236e+16: [(True, False, 1.0, 0.526315789474),
#   (False, False, 0.909090909091, 0.736842105263),
#   (False, False, 0.909090909091, 0.736842105263),
#   (False, False, 0.909090909091, 0.631578947368),
#   (True, False, 1.0, 0.526315789474),
#   (True, False, 1.0, 0.736842105263),
#   (False, False, 0.909090909091, 0.526315789474),
#   (True, False, 1.0, 0.631578947368)],
#  28147497671.0656: [(False, False, 0.857142857143, 0.947368421053),
#   (False, False, 0.857142857143, 0.947368421053),
#   (False, False, 0.857142857143, 0.947368421053),
#   (False, False, 0.857142857143, 0.947368421053)],
#  3.022314549036573e+19: [(False, True, 0.888888888889, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.727272727273, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.8, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.888888888889, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.888888888889, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0)]}

# %%
def get_merged_results_df(met_dict, mach_dict, x, methods):
    data = []
    for bs in met_dict:
        for key in met_dict[bs]:
            gt_list = met_dict[bs][key]
            percent_true_clones = sum(1 for item in gt_list if item[0]) / len(gt_list) * 100
            percent_true_mig_graph = sum(1 for item in gt_list if item[1]) / len(gt_list) * 100
            avg_clones_f1 = sum(item[2] for item in gt_list) / len(gt_list) * 100
            avg_mig_graph_f1 = sum(item[3] for item in gt_list) / len(gt_list) * 100
            data.append([f"Metient-{bs}", key, avg_clones_f1, avg_mig_graph_f1, percent_true_clones, percent_true_mig_graph])
    
    for key in mach_dict:
        gt_list = mach_dict[key]
        percent_true_clones = sum(1 for item in gt_list if item[0]) / len(gt_list) * 100
        percent_true_mig_graph = sum(1 for item in gt_list if item[1]) / len(gt_list) * 100
        avg_clones_f1 = sum(item[2] for item in gt_list) / len(gt_list) * 100
        avg_mig_graph_f1 = sum(item[3] for item in gt_list) / len(gt_list) * 100
        data.append(["MACHINA", key, avg_clones_f1, avg_mig_graph_f1, percent_true_clones, percent_true_mig_graph])
    results = pd.DataFrame(data, columns=["Method", x, "Migrating clones F1-score", "Migration graph F1-score", "% time that migrating clone ground truth found", "% time that migration graph ground truth found"])
    return results

methods = ["Metient-64", "Metient-256", "Metient-1024",]

results1 = get_merged_results_df(bs_to_num_nodes_to_ground_truth_slns, mach_node_size_to_ground_truth_slns, "Number of tree nodes", methods)
results2 = get_merged_results_df(bs_to_num_sites_to_ground_truth_slns, mach_num_sites_to_ground_truth_slns, "Number of anatomical sites", methods)
results3 = get_merged_results_df(bs_to_prob_size_bin_to_ground_truth_slns, mach_prob_size_bin_to_ground_truth_slns, "Size of search space binned", methods)
# results4 = get_merged_results_df(bs_to_prob_size_to_ground_truth_slns, mach_prob_size_to_ground_truth_slns, "Size of Search Space", methods)

results1
# Out:
#           Method  Number of tree nodes  Migrating clones F1-score  \
# 0     Metient-64                     0                     91.481
# 1     Metient-64                     1                     91.714
# 2     Metient-64                     2                     91.559
# 3    Metient-256                     0                     91.594
# 4    Metient-256                     1                     91.752
# 5    Metient-256                     2                     92.183
# 6   Metient-1024                     0                     91.825
# 7   Metient-1024                     1                     91.596
# 8   Metient-1024                     2                     91.618
# 9        MACHINA                     0                     90.419
# 10       MACHINA                     1                     88.689
# 11       MACHINA                     2                     84.658
#
#     Migration graph F1-score  % time that migrating clone ground truth found  \
# 0                     76.284                                          62.174
# 1                     78.442                                          57.000
# 2                     67.984                                          48.571
# 3                     75.005                                          59.565
# 4                     77.279                                          54.000
# 5                     67.491                                          51.429
# 6                     74.916                                          59.565
# 7                     77.011                                          55.000
# 8                     68.789                                          55.714
# 9                     58.344                                          52.754
# 10                    70.657                                          44.675
# 11                    50.726                                          43.933
#
#     % time that migration graph ground truth found
# 0                                           19.130
# 1                                           10.000
# 2                                            7.143
# 3                                           14.348
# 4                                           10.000
# 5                                            7.143
# 6                                           13.478
# 7                                           10.000
# 8                                            7.143
# 9                                            7.536
# 10                                          16.104
# 11                                           7.531

# %% [markdown]
# ### Make plots for performance as a function of tree size, # anatomical sites, and size of search space

# %%
import seaborn as sns
import matplotlib.pyplot as plt
colors = sns.color_palette("crest")
colors = colors[:len(methods)]
colors.append((0.99609375, 0.56640625, 0.37109375))
print(colors)
sns.set_palette(sns.color_palette(colors))

ys = ["Migrating clones F1-score", "Migration graph F1-score", "% time that migrating clone ground truth found", "% time that migration graph ground truth found"]
y_labels = ["Migrating clones F1-score", "Migration graph F1-score", "Ground truth migrating\n clones found (%)", "Ground truth migration\n graph found (%)"]
out_names = ["Migrating clones F1-score", "Migration graph F1-score", "Ground truth migrating clones found", "Ground truth migration graph found"]

def get_tree_node_bins():
    bin_numbers = sorted(list(cluster_num_df['cluster_bins'].unique()))
    bin_ranges = []
    for bin_num in bin_numbers:
        bin_min = cluster_num_df[cluster_num_df['cluster_bins']==bin_num]['clusters'].min()
        bin_max = cluster_num_df[cluster_num_df['cluster_bins']==bin_num]['clusters'].max()
        size = len(cluster_num_df[cluster_num_df['cluster_bins']==bin_num])
        bin_ranges.append(f"{bin_min}-{bin_max}")
        print(bin_num, bin_min, bin_max, size)
    return bin_numbers, bin_ranges

def get_prob_size_bins():
    bin_numbers = sorted(list(cluster_num_df['prob_size_bins'].unique()))
    bin_ranges = []
    for bin_num in bin_numbers:
        bin_min = cluster_num_df[cluster_num_df['prob_size_bins']==bin_num]['prob_size'].min()*denom
        bin_minf = "{:.1e}".format(bin_min)
        bin_max = cluster_num_df[cluster_num_df['prob_size_bins']==bin_num]['prob_size'].max()*denom
        bin_maxf = "{:.1e}".format(bin_max)
        size = len(cluster_num_df[cluster_num_df['prob_size_bins']==bin_num])
        bin_ranges.append(f"{bin_minf}-{bin_maxf}")
        print(bin_num, bin_minf, bin_maxf, size)
    return bin_numbers, bin_ranges

for x, df in zip(["Number of tree nodes", "Number of anatomical sites", "Size of search space binned"], [results1, results2, results3]):
    for i,y in enumerate(ys):
        with sns.plotting_context("notebook", font_scale=1.6):
            g = sns.lineplot(
                data=df, x=x, y=y, linewidth=2.5,
                hue="Method", legend=False,  
            )
            if x == "Number of tree nodes":
                bin_numbers, bin_ranges = get_tree_node_bins()
                plt.xticks(ticks=bin_numbers,labels=bin_ranges)
            if x == "Size of search space binned":
                bin_numbers, bin_ranges = get_prob_size_bins()
                plt.xticks(ticks=bin_numbers,labels=bin_ranges)
                plt.xticks(rotation=45)
            if x == "Size of search space":
                plt.xscale('log')
            
            if y == "% time that migration graph ground truth found":
                plt.ylim(0, 70)
            elif y == "Migrating clones F1-score":
                plt.ylim(80, 100)
            elif y == "Migration graph F1-score":
                plt.ylim(40, 100)
            else:
                plt.ylim(0, 100)
                
            legend = g.legend(prop={'size': 8})  # Set the desired font size here
            g.spines['top'].set_visible(False)
            g.spines['right'].set_visible(False)
            
            plt.ylabel(y_labels[i])
            out_name = ("_").join(out_names[i].split(" ") + x.split(" "))

            plt.savefig(os.path.join(REPO_DIR, "test/output_plots", f"{out_name}_10runs_lossthres{LOSS_THRES}_k{k}_{PARAMS}_{DATE}.png"), dpi=600, bbox_inches="tight", pad_inches=0.3) 

            plt.show()
# Out:
# 20:43:37 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [(0.48942421, 0.72854938, 0.56751036), (0.34892097, 0.64828676, 0.56513633), (0.24929311, 0.56486397, 0.5586654), (0.99609375, 0.56640625, 0.37109375)]
# 0 7 19 567
# 1 20 24 542
# 2 25 29 538
# 20:43:38 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 7 19 567
# 1 20 24 542
# 2 25 29 538
# 20:43:39 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 7 19 567
# 1 20 24 542
# 2 25 29 538
# 20:43:40 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 7 19 567
# 1 20 24 542
# 2 25 29 538
# 20:43:41 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 20:43:42 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 20:43:43 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 20:43:44 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 20:43:46 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 1.6e+04 1.8e+16 567
# 1 1.3e+17 8.9e+21 548
# 2 3.8e+22 1.4e+29 532
# 20:43:47 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 1.6e+04 1.8e+16 567
# 1 1.3e+17 8.9e+21 548
# 2 3.8e+22 1.4e+29 532
# 20:43:48 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 1.6e+04 1.8e+16 567
# 1 1.3e+17 8.9e+21 548
# 2 3.8e+22 1.4e+29 532
# 20:43:50 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 1.6e+04 1.8e+16 567
# 1 1.3e+17 8.9e+21 548
# 2 3.8e+22 1.4e+29 532

# %%
import pandas as pd
data = []
for bs in bs_to_prob_size_to_ground_truth_slns:
    for search_size in bs_to_prob_size_to_ground_truth_slns[bs]:
        bs_ss_data = bs_to_prob_size_to_ground_truth_slns[bs][search_size]
        for item in bs_ss_data:
            data.append([bs, search_size, item[2], item[3]])
ss_df = pd.DataFrame(data, columns=["Batch size", "Search space size", "Migrating clones F1", "Migration graph F1"])
ss_df.to_csv("sample_size_exp_search_space_size.csv")

# %%
mach_data = []
for search_size in mach_prob_size_to_ground_truth_slns:
    items = mach_prob_size_to_ground_truth_slns[search_size]
    for item in items:
        mach_data.append({"Method": "MACHINA", "Search space size":search_size, "Migrating clones F1":item[2], "Migration graph F1":item[3]})

# %%
import pandas as pd
import numpy as np

ss_df = pd.read_csv("sample_size_exp_search_space_size.csv")
ss_df['Method'] = ss_df.apply(lambda row: f"Metient-{int(row['Batch size'])}", axis=1)
ss_df = ss_df.loc[:, ~ss_df.columns.str.contains('^Unnamed')]
ss_df = ss_df.loc[:, ~ss_df.columns.str.contains('Batch size')]
ss_df = ss_df.append(mach_data, ignore_index=True)
ss_df['log(Search space size)'] = ss_df.apply(lambda row: np.log(row['Search space size']), axis=1)
ss_df
# Out:
#                   Search space size  Migrating clones F1  Migration graph F1  \
# 0                   381,469,726.562                1.000               1.000
# 1                   381,469,726.562                0.889               0.667
# 2                   381,469,726.562                1.000               1.000
# 3                   381,469,726.562                0.889               0.667
# 4                   381,469,726.562                1.000               1.000
# ...                             ...                  ...                 ...
# 2164 30,223,145,490,365,730,816.000                0.889               1.000
# 2165 30,223,145,490,365,730,816.000                1.000               1.000
# 2166 30,223,145,490,365,730,816.000                0.889               1.000
# 2167 30,223,145,490,365,730,816.000                1.000               1.000
# 2168 30,223,145,490,365,730,816.000                1.000               1.000
#
#           Method  log(Search space size)
# 0     Metient-64                  19.760
# 1     Metient-64                  19.760
# 2     Metient-64                  19.760
# 3     Metient-64                  19.760
# 4     Metient-64                  19.760
# ...          ...                     ...
# 2164     MACHINA                  44.855
# 2165     MACHINA                  44.855
# 2166     MACHINA                  44.855
# 2167     MACHINA                  44.855
# 2168     MACHINA                  44.855
#
# [2169 rows x 5 columns]

# %%
import seaborn as sns
import matplotlib.pyplot as plt

def contour_plot(y):
    subset_df = ss_df[ss_df['Method'].isin(["MACHINA", "Metient-1024"])]
    colors = sns.color_palette("crest")
    colors = [colors[2]]
    colors.append((0.99609375, 0.56640625, 0.37109375))
    colors.reverse()
    print(colors)
    with sns.plotting_context("notebook", font_scale=1.2):
        # Plot using seaborn
        sns.set_palette(sns.color_palette(colors))
        
        fig, axs = plt.subplots(1, 2, figsize=(10, 5))

        # Plot KDE plots
        sns.kdeplot(data=subset_df[subset_df['Method']=="MACHINA"], x='log(Search space size)', 
                    y=y, ax=axs[0], color=colors[0], fill=True, alpha=0.6,)
        sns.kdeplot(data=subset_df[subset_df['Method']=="Metient-1024"], x='log(Search space size)', 
                    y=y, ax=axs[1], color=colors[1], fill=True, alpha=0.6,)

        # Add a grid to each subplot
        axs[0].grid(True)
        axs[1].grid(True)

        # Optionally, set titles for each subplot
        axs[0].set_title('KDE of Data1')
        axs[1].set_title('KDE of Data2')
        axs[0].set_ylim(-0.2,1.2)
        axs[1].set_ylim(-0.2,1.2)

#         plt.figure(figsize=(2, 2), dpi=300) 
#         g = sns.kdeplot(data=subset_df, x='log(Search space size)', 
#                             y=y,hue='Method',legend=True,hue_order=["MACHINA", "Metient-1024"],
#                             palette=colors,fill=True, alpha=0.6,linewidths=1.8)

    #     g = sns.scatterplot(data=ss_df, x='log(Search space size)', 
    #                         y='Migrating clones F1',hue='Method',
    #                         palette=colors, s=100, )  # s is the marker size
        #legend = g.legend(prop={'size': 8})  # Set the desired font size here

        g.spines['top'].set_visible(False)
        g.spines['right'].set_visible(False)
        plt.legend(loc='center left',frameon=False)


        # Optional: additional plot styling
        plt.title(y)
        plt.xticks(rotation=45)  # Rotates x-axis labels to avoid overlap
        #plt.subplots_adjust(right=0.75)  # Adjust this value as needed to make space for the legend

        # Show the plot
        plt.show()
    
contour_plot('Migration graph F1')
contour_plot('Migrating clones F1')
# Out:
# [(0.99609375, 0.56640625, 0.37109375), (0.24929311, 0.56486397, 0.5586654)]
# 20:43:53 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [(0.99609375, 0.56640625, 0.37109375), (0.24929311, 0.56486397, 0.5586654)]
# 20:43:55 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
