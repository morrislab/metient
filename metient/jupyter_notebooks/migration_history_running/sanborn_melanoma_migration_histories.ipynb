# %% [markdown]
# ## Test migration history reconstruction on Sanborn et. al. Melanoma data

# %%
import sys
import os

repo_dir = os.path.join(os.getcwd(), "../../")

from metient.metient import *
from metient.util import pairtree_data_extraction_util as ptutil

import matplotlib
import torch

matplotlib.rcParams['figure.figsize'] = [3, 3]
SANBORN_DATA_DIR = os.path.join(repo_dir, 'data', 'sanborn_melanoma_2015', 'cn_neutral_data')
TREE_DIR = os.path.join(SANBORN_DATA_DIR, 'pyclone_vi_orchard_trees')    
TSV_DIR = os.path.join(SANBORN_DATA_DIR, 'pyclone_vi_clustered_tsvs')                 

OUTPUT_DIR = os.path.join(repo_dir, 'data', 'sanborn_melanoma_2015', "metient_outputs_solve_polys_no_cna_pyclone_vi_orchard")

PATIENT_IDS = ['A', 'B', 'C', 'D', 'E', 'F', 'G']

print_config = PrintConfig(visualize=True)
# Out:
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11070). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# CUDA GPU: False

# %% [markdown]
# ### Run all patients in calibrate mode

# %%
#%%prun
mut_trees_fns = [os.path.join(TREE_DIR, f"{patient_id}.results.npz") for patient_id in PATIENT_IDS]
trees = [data[0] for data in ptutil.get_adj_matrices_from_pairtree_results(mut_trees_fns)]
ref_var_fns = [os.path.join(TSV_DIR, f"{patient_id}_SNVs.tsv") for patient_id in PATIENT_IDS]
run_names = [f"{pid}_calibrate" for pid in PATIENT_IDS]

calibrate(trees, ref_var_fns, print_config, OUTPUT_DIR, run_names, bias_weights=True,solve_polytomies=True)
# Out:
# Saving results to /lila/data/morrisq/divyak/projects/metient/metient/jupyter_notebooks/migration_history_running/../../data/sanborn_melanoma_2015/metient_outputs_solve_polys_no_cna_pyclone_vi_orchard/calibrate
# Overwriting existing directory at /lila/data/morrisq/divyak/projects/metient/metient/jupyter_notebooks/migration_history_running/../../data/sanborn_melanoma_2015/metient_outputs_solve_polys_no_cna_pyclone_vi_orchard/calibrate
#
# *** Calibrating for patient: A_calibrate ***
# ordered_sites ['Primary, forehead', 'Parotid metastasis', 'Locoregional skin metastasis 1, forehead', 'Locoregional skin metastasis 2, angle jaw']
# calculate_batch_size 1504
#   0%|          | 0/166 [00:00<?, ?it/s]
# nll 8.153
# internal_node_idx_to_sites {0: [1], 1: [0], 2: [0, 2], 3: [1, 3], 4: [2], 5: [0, 2]}
# nodes_w_children [0, 1, 2, 3, 4, 5] biased_sites [[0, 1, 2], [0, 1, 2, 3], [0, 2], [1, 3], [2], [0, 2]]
#  40%|███▉      | 66/166 [00:01<00:02, 40.97it/s]
# poly_res.children_of_polys [3, 5, 10, 1, 11, 12, 4, 16, 17]
# poly_res.resolver_indices [6, 7, 8]
# poly_res.resolver_index_to_parent_idx {6: 1, 7: 2, 8: 5}
# /lila/data/morrisq/divyak/projects/metient/metient/lib/vertex_labeling.py:710: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3614.)
#   known_labelings.append(torch.eye(num_sites)[optimal_site].T)
#  43%|████▎     | 71/166 [00:03<00:08, 11.22it/s]
# nodes_w_children [0, 1, 2, 3, 4, 5] biased_sites [[0, 1, 2], [0, 1, 2, 3], [0, 2], [1, 3], [2], [0, 2]]
# optimal subtree sets [[4, 8, 15, 17]]
# poly_resolver_to_optimal_children {8: [4, 17]}
# tensor([[3.00, 3.00, 1.50, 3.00],
#         [3.00, 0.78, 3.00, 0.47],
#         [3.00, 3.00, 0.81, 3.00],
#         [3.00, 0.49, 3.00, 0.83]])
# known_indices [3]
# unknown_indices [0, 1, 2, 4]
#  99%|█████████▉| 165/166 [00:05<00:00, 51.67it/s]
# 100%|██████████| 166/166 [00:05<00:00, 31.87it/s]
# pareto_metrics {(5, 3, 1)}
# batch nums [1]
# # final solutions: 1
#
# *** Calibrating for patient: B_calibrate ***
# ordered_sites ['Primary, mid-left back', 'Lymph node metastasis, left axilla', 'Locoregional skin metastasis 1, left back', 'Locoregional skin metastasis 2, left axilla']
# calculate_batch_size 1424
#   1%|          | 1/166 [00:00<00:20,  8.11it/s]
# nll 4.607
# internal_node_idx_to_sites {0: [0, 2, 3], 1: [0], 2: [1, 3], 3: [2, 3], 4: [2]}
# nodes_w_children [0, 1, 2, 3, 4] biased_sites [[0, 2, 3], [0, 1, 3], [1, 3], [0, 2, 3], [2]]
#  38%|███▊      | 63/166 [00:01<00:02, 44.91it/s]
# poly_res.children_of_polys [3, 8, 9, 10, 1, 4, 14, 15]
# poly_res.resolver_indices [5, 6, 7]
# poly_res.resolver_index_to_parent_idx {5: 0, 6: 0, 7: 3}
#  44%|████▍     | 73/166 [00:02<00:05, 17.59it/s]
# nodes_w_children [0, 1, 2, 3, 4] biased_sites [[0, 2, 3], [0, 1, 3], [1, 3], [0, 2, 3], [2]]
# optimal subtree sets [[4, 7, 14, 16]]
# poly_resolver_to_optimal_children {7: [4, 14]}
# tensor([[3.00, 1.50, 3.00],
#         [3.00, 3.00, 0.74],
#         [0.40, 0.57, 3.00],
#         [3.00, 3.00, 3.00]])
# known_indices [3]
# unknown_indices [0, 1, 2]
#  97%|█████████▋| 161/166 [00:04<00:00, 59.19it/s]
# 100%|██████████| 166/166 [00:04<00:00, 37.27it/s]
# pareto_metrics {(6, 3, 1), (5, 4, 2)}
# batch nums [1, 469]
# # final solutions: 2
#
# *** Calibrating for patient: C_calibrate ***
# ordered_sites ['Primary, right lower calf', 'Locoregional skin metastasis 1, right calf', 'Locoregional skin metastasis 2, right mid-calf']
# calculate_batch_size 1384
#   4%|▎         | 6/166 [00:00<00:03, 53.23it/s]
# nll 12.7
# internal_node_idx_to_sites {0: [0], 2: [1], 3: [0, 2], 4: [2], 5: [0, 1, 2]}
# nodes_w_children [0, 1, 2, 3, 4, 5] biased_sites [[0, 2], [0, 1, 2], [1], [0, 2], [0, 2], [0, 1, 2]]
#  39%|███▊      | 64/166 [00:01<00:02, 50.79it/s]
# poly_res.children_of_polys [1, 3, 11]
# poly_res.resolver_indices [6]
# poly_res.resolver_index_to_parent_idx {6: 4}
#  46%|████▌     | 76/166 [00:02<00:05, 16.50it/s]
# nodes_w_children [0, 1, 2, 3, 4, 5] biased_sites [[0, 2], [0, 1, 2], [1], [0, 2], [0, 2], [0, 1, 2]]
# optimal subtree sets []
# poly_resolver_to_optimal_children {}
#  97%|█████████▋| 161/166 [00:07<00:00, 36.25it/s]
# 100%|██████████| 166/166 [00:08<00:00, 20.52it/s]
# pareto_metrics {(5, 2, 1)}
# batch nums [1, 3]
# # final solutions: 2
#
# *** Calibrating for patient: D_calibrate ***
# ordered_sites ['Primary, right ankle', 'Lymph node metastasis, right groin', 'Locoregional skin metastasis 1, right ankle', 'Locoregional skin metastasis 2, right leg']
# calculate_batch_size 1264
#   5%|▌         | 9/166 [00:00<00:01, 85.90it/s]
# nll 3.641
# internal_node_idx_to_sites {1: [1, 2, 3], 2: [0]}
# No potential polytomies to solve, not resolving polytomies.
# nodes_w_children [0, 1, 2] biased_sites [[0, 1, 2, 3], [1, 2, 3], [0]]
#  39%|███▉      | 65/166 [00:02<00:06, 15.16it/s]
#  45%|████▌     | 75/166 [00:03<00:06, 13.99it/s]
# nodes_w_children [0, 1, 2] biased_sites [[0, 1, 2, 3], [1, 2, 3], [0]]
# optimal subtree sets []
# poly_resolver_to_optimal_children {}
#  96%|█████████▌| 159/166 [00:03<00:00, 73.09it/s]
# 100%|██████████| 166/166 [00:04<00:00, 40.46it/s]
# pareto_metrics {(3, 3, 1)}
# batch nums [1]
# # final solutions: 1
#
# *** Calibrating for patient: E_calibrate ***
# ordered_sites ['Primary, left heel', 'Locoregional skin metastasis 1, left heel', 'Locoregional skin metastasis 2, left heel', 'Lymph node metastasis, left groin', 'Locoregional skin metastasis 3, left heel']
# calculate_batch_size 1624
#   2%|▏         | 3/166 [00:00<00:05, 27.30it/s]
# nll 5.899
# internal_node_idx_to_sites {0: [0], 1: [2], 2: [0, 1, 2, 3, 4], 3: [3, 4], 4: [0], 5: [1, 2, 3, 4]}
# nodes_w_children [0, 1, 2, 3, 4, 5] biased_sites [[0, 1, 2, 3, 4], [2], [0, 1, 2, 3, 4], [3, 4], [0], [0, 1, 2, 3, 4]]
#  39%|███▊      | 64/166 [00:01<00:02, 36.71it/s]
# poly_res.children_of_polys [4, 5, 10, 1, 2, 3, 20, 21, 22, 23]
# poly_res.resolver_indices [6, 7, 8, 9]
# poly_res.resolver_index_to_parent_idx {6: 0, 7: 5, 8: 5, 9: 5}
#  43%|████▎     | 72/166 [00:03<00:10,  9.20it/s]
# nodes_w_children [0, 1, 2, 3, 4, 5] biased_sites [[0, 1, 2, 3, 4], [2], [0, 1, 2, 3, 4], [3, 4], [0], [0, 1, 2, 3, 4]]
# optimal subtree sets [[4, 6, 10, 19], [1, 9, 11, 21]]
# poly_resolver_to_optimal_children {6: [4, 10], 9: [1, 21]}
# tensor([[3.00, 1.50, 3.00],
#         [3.00, 0.57, 3.00],
#         [3.00, 0.21, 3.00],
#         [3.00, 3.00, 3.00],
#         [3.00, 3.00, 3.00]])
# known_indices [3, 0]
# unknown_indices [1, 2, 4]
# 100%|██████████| 166/166 [00:07<00:00, 22.96it/s]
# 100%|██████████| 166/166 [00:08<00:00, 20.42it/s]
# pareto_metrics {(10, 4, 1), (9, 5, 2)}
# batch nums [1, 634, 585]
# # final solutions: 3
#
# *** Calibrating for patient: F_calibrate ***
# ordered_sites ['Primary, left ear', 'Lymph node metastasis, left cervical node', 'Locoregional skin metastasis, left ear', 'Distant skin metastasis, back']
# calculate_batch_size 1424
#   1%|          | 2/166 [00:00<00:08, 18.88it/s]
# nll 18.552
# internal_node_idx_to_sites {0: [0, 1, 2, 3], 1: [0, 1, 2, 3], 2: [0, 3], 3: [0, 1, 3], 4: [0, 1, 2, 3]}
# nodes_w_children [0, 1, 2, 3, 4] biased_sites [[0, 1, 2, 3], [0, 1, 2, 3], [0, 3], [0, 1, 2, 3], [0, 1, 2, 3]]
#  40%|███▉      | 66/166 [00:02<00:03, 29.79it/s]
# poly_res.children_of_polys [3, 11, 12, 13, 14, 1, 4, 21, 22, 23, 2, 24, 25, 26, 27]
# poly_res.resolver_indices [5, 6, 7, 8, 9, 10]
# poly_res.resolver_index_to_parent_idx {5: 0, 6: 0, 7: 3, 8: 3, 9: 4, 10: 4}
# nodes_w_children [0, 1, 2, 3, 4] biased_sites [[0, 1, 2, 3], [0, 1, 2, 3], [0, 3], [0, 1, 2, 3], [0, 1, 2, 3]]
# optimal subtree sets []
# poly_resolver_to_optimal_children {}
#  99%|█████████▉| 165/166 [00:10<00:00, 34.32it/s]
# 100%|██████████| 166/166 [00:10<00:00, 15.63it/s]
# pareto_metrics {(12, 3, 1)}
# batch nums [1]
# # final solutions: 1
#
# *** Calibrating for patient: G_calibrate ***
# ordered_sites ['Primary, right forearm', 'Lung metastasis', 'Locoregional skin metastasis, axilla']
# calculate_batch_size 1264
#   1%|          | 1/166 [00:00<00:19,  8.29it/s]
# nll 5.389
# internal_node_idx_to_sites {0: [0, 1, 2], 1: [0], 2: [2], 3: [1]}
# nodes_w_children [0, 1, 2, 3] biased_sites [[0, 1, 2], [0, 1, 2], [2], [1]]
#  38%|███▊      | 63/166 [00:01<00:02, 49.95it/s]
# poly_res.children_of_polys [1, 5, 6, 7]
# poly_res.resolver_indices [4]
# poly_res.resolver_index_to_parent_idx {4: 0}
#  45%|████▍     | 74/166 [00:02<00:05, 18.32it/s]
# nodes_w_children [0, 1, 2, 3] biased_sites [[0, 1, 2], [0, 1, 2], [2], [1]]
# optimal subtree sets []
# poly_resolver_to_optimal_children {}
#  97%|█████████▋| 161/166 [00:03<00:00, 72.28it/s]
# 100%|██████████| 166/166 [00:03<00:00, 42.88it/s]
# pareto_metrics {(4, 2, 1)}
# batch nums [9, 3, 7, 0]
# # final solutions: 4
# Calibrating to 7 patients
# Optimized thetas: tensor([0.48, 0.26, 0.26], grad_fn=<DivBackward0>)
# batch nums [0]
# A_calibrate_Primary, forehead
# 1000 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# batch nums [0, 1]
# B_calibrate_Primary, mid-left back
# 1000 unique trees were not found (2 were found). Retry with a higher sample size if you want to get more trees.
# batch nums [0, 1]
# C_calibrate_Primary, right lower calf
# 1000 unique trees were not found (2 were found). Retry with a higher sample size if you want to get more trees.
# batch nums [0]
# D_calibrate_Primary, right ankle
# 1000 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# batch nums [0, 1, 2]
# E_calibrate_Primary, left heel
# 1000 unique trees were not found (3 were found). Retry with a higher sample size if you want to get more trees.
# batch nums [0]
# F_calibrate_Primary, left ear
# 1000 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# batch nums [3, 2, 1, 0]
# G_calibrate_Primary, right forearm
# 1000 unique trees were not found (4 were found). Retry with a higher sample size if you want to get more trees.
# [0.4844200909137726, 0.2577899098396301, 0.2577899098396301]
