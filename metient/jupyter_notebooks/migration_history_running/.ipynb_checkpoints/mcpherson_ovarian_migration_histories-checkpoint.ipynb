# %% [markdown]
# ### Test migration history reconstruction on ovarian cancer data

# %%
import sys
import os
from metient.util.globals import *
from metient.metient import *
import matplotlib

matplotlib.rcParams['figure.figsize'] = [3, 3]
repo_dir = os.path.join(os.getcwd(), "../../")
MSK_MET_FN = os.path.join(repo_dir, 'data/msk_met/msk_met_freq_by_cancer_type.csv')
      
MCPHERSON_DATA_DIR = os.path.join(repo_dir, 'data', 'mcpherson_ovarian_2016')               

OUTPUT_DIR = os.path.join(MCPHERSON_DATA_DIR, "metient_outputs", "solve_polys")
if not os.path.exists(OUTPUT_DIR):
    os.makedirs(OUTPUT_DIR)
    
PATIENT_IDS = [1,2,3,4,7,9,10]

print_config = PrintConfig(visualize=True, k_best_trees=20)
# Out:
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11070). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0
# CUDA GPU: False

# %% [markdown]
# ### Run all patients in calibrate mode

# %%
mut_trees_fns = [os.path.join(MCPHERSON_DATA_DIR, f"patient{patient_id}_tree.txt") for patient_id in PATIENT_IDS]
ref_var_fns = [os.path.join(MCPHERSON_DATA_DIR, f"patient{patient_id}_SNVs.tsv") for patient_id in PATIENT_IDS]
run_names = [f"{pid}_calibrate" for pid in PATIENT_IDS]
calibrate_label_clone_tree(mut_trees_fns, ref_var_fns, print_config, OUTPUT_DIR, run_names,
                           bias_weights=True, solve_polytomies=True)
# Out:
# Saving results to /lila/data/morrisq/divyak/projects/metient/metient/jupyter_notebooks/migration_history_running/../../data/mcpherson_ovarian_2016/metient_outputs/solve_polys/calibrate
# Overwriting existing directory at /lila/data/morrisq/divyak/projects/metient/metient/jupyter_notebooks/migration_history_running/../../data/mcpherson_ovarian_2016/metient_outputs/solve_polys/calibrate
#
# *** Calibrating for patient: 1_calibrate ***
# Multiple primaries given. Running each as primary
# ordered_sites ['Left Ovary', 'Right Ovary', 'Appendix', 'Left Fallopian Tube', 'Omentum', 'Right Fallopian Tube', 'Small Bowel']
# calculate_batch_size 2060
#  50%|█████     | 100/200 [01:50<02:23,  1.44s/it]/lila/data/morrisq/divyak/projects/metient/metient/lib/vertex_labeling.py:712: UserWarning: The use of `x.T` on tensors of dimension other than 2 to reverse their shape is deprecated and it will throw an error in a future release. Consider `x.mT` to transpose batches of matrices or `x.permute(*torch.arange(x.ndim - 1, -1, -1))` to reverse the dimensions of a tensor. (Triggered internally at ../aten/src/ATen/native/TensorShape.cpp:3614.)
#   known_labelings.append(torch.eye(num_sites)[optimal_site].T)
# 100%|██████████| 200/200 [03:16<00:00,  1.02it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
# pareto_metrics [(9, 6, 1), (9, 6, 1), (9, 6, 1), (9, 6, 1), (9, 6, 1)]
# # final solutions: 1
# ordered_sites ['Left Ovary', 'Right Ovary', 'Appendix', 'Left Fallopian Tube', 'Omentum', 'Right Fallopian Tube', 'Small Bowel']
# calculate_batch_size 2060
# 100%|██████████| 200/200 [03:04<00:00,  1.08it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
# pareto_metrics [(9, 6, 1), (9, 6, 1)]
# # final solutions: 2
#
# *** Calibrating for patient: 2_calibrate ***
# ordered_sites ['Right Ovary', 'Omentum']
# calculate_batch_size 2048
# No potential polytomies to solve, not resolving polytomies.
# 100%|██████████| 200/200 [00:37<00:00,  5.30it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
# pareto_metrics [(1, 1, 1)]
# # final solutions: 1
#
# *** Calibrating for patient: 3_calibrate ***
# Multiple primaries given. Running each as primary
# ordered_sites ['Left Ovary', 'Right Ovary', 'Adnexa', 'Cul de Sac', 'Left Fallopian Tube Fimbriae', 'Omentum', 'Right Fallopian Tube', 'Sigmoid Colon Deposit']
# calculate_batch_size 2064
# 100%|██████████| 200/200 [03:33<00:00,  1.07s/it]
#   0%|          | 0/200 [00:00<?, ?it/s]
# pareto_metrics [(14, 7, 1), (14, 7, 1)]
# # final solutions: 1
# ordered_sites ['Left Ovary', 'Right Ovary', 'Adnexa', 'Cul de Sac', 'Left Fallopian Tube Fimbriae', 'Omentum', 'Right Fallopian Tube', 'Sigmoid Colon Deposit']
# calculate_batch_size 2064
# 100%|██████████| 200/200 [03:48<00:00,  1.14s/it]
# pareto_metrics [(17, 7, 1), (16, 11, 3), (16, 11, 3), (16, 12, 2), (16, 11, 3)]
# # final solutions: 5
#   0%|          | 0/200 [00:00<?, ?it/s]
# *** Calibrating for patient: 4_calibrate ***
# Multiple primaries given. Running each as primary
# ordered_sites ['Left Ovary Surface', 'Right Ovary', 'Left Pelvic Sidewall', 'Right Pelvic Sidewall']
# calculate_batch_size 2048
# 100%|██████████| 200/200 [02:35<00:00,  1.28it/s]
# pareto_metrics [(4, 3, 1)]
# # final solutions: 1
#   0%|          | 0/200 [00:00<?, ?it/s]
# ordered_sites ['Left Ovary Surface', 'Right Ovary', 'Left Pelvic Sidewall', 'Right Pelvic Sidewall']
# calculate_batch_size 2048
# 100%|██████████| 200/200 [02:48<00:00,  1.19it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
# pareto_metrics [(3, 3, 1)]
# # final solutions: 1
#
# *** Calibrating for patient: 7_calibrate ***
# Multiple primaries given. Running each as primary
# ordered_sites ['Left Ovary', 'Right Ovary', 'Right Uterosacral', 'Bowel Implant', 'Brain Metastasis', 'Righ Pelvic Mass']
# calculate_batch_size 2060
# 100%|██████████| 200/200 [03:17<00:00,  1.01it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
# pareto_metrics [(8, 5, 1), (7, 6, 2)]
# # final solutions: 2
# ordered_sites ['Left Ovary', 'Right Ovary', 'Right Uterosacral', 'Bowel Implant', 'Brain Metastasis', 'Righ Pelvic Mass']
# calculate_batch_size 2060
# 100%|██████████| 200/200 [03:20<00:00,  1.00s/it]
# pareto_metrics [(7, 5, 1), (6, 6, 2)]
# # final solutions: 2
#   0%|          | 0/200 [00:00<?, ?it/s]
# ordered_sites ['Left Ovary', 'Right Ovary', 'Right Uterosacral', 'Bowel Implant', 'Brain Metastasis', 'Righ Pelvic Mass']
# calculate_batch_size 2060
# 100%|██████████| 200/200 [03:27<00:00,  1.04s/it]
#   0%|          | 0/200 [00:00<?, ?it/s]
# pareto_metrics [(6, 5, 1), (6, 5, 1), (6, 5, 1), (6, 5, 1), (6, 5, 1), (6, 5, 1), (6, 5, 1), (6, 5, 1), (6, 5, 1)]
# # final solutions: 1
#
# *** Calibrating for patient: 9_calibrate ***
# Multiple primaries given. Running each as primary
# ordered_sites ['Left Ovary', 'Right Ovary', 'Omentum']
# calculate_batch_size 2048
# No potential polytomies to solve, not resolving polytomies.
# 100%|██████████| 200/200 [00:52<00:00,  3.79it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
# pareto_metrics [(2, 2, 1)]
# # final solutions: 1
# ordered_sites ['Left Ovary', 'Right Ovary', 'Omentum']
# calculate_batch_size 2048
# No potential polytomies to solve, not resolving polytomies.
# 100%|██████████| 200/200 [00:49<00:00,  4.02it/s]
#   0%|          | 0/200 [00:00<?, ?it/s]
# pareto_metrics [(3, 2, 1), (3, 2, 1)]
# # final solutions: 1
#
# *** Calibrating for patient: 10_calibrate ***
# ordered_sites ['Right Ovary', 'Left Fallopian Tube', 'Omentum']
# calculate_batch_size 2048
# 100%|██████████| 200/200 [02:06<00:00,  1.58it/s]
# pareto_metrics [(5, 2, 1)]
# # final solutions: 1
# Calibrating to 13 patients
# Optimized thetas: tensor([0.52, 0.19, 0.28], grad_fn=<DivBackward0>)
# 1_calibrate_Left Ovary
# 20 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# 1_calibrate_Right Ovary
# 20 unique trees were not found (2 were found). Retry with a higher sample size if you want to get more trees.
# 2_calibrate_Right Ovary
# 20 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# 3_calibrate_Left Ovary
# 20 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# 3_calibrate_Right Ovary
# 20 unique trees were not found (5 were found). Retry with a higher sample size if you want to get more trees.
# 4_calibrate_Left Ovary Surface
# 20 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# 4_calibrate_Right Ovary
# 20 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# 7_calibrate_Left Ovary
# 20 unique trees were not found (2 were found). Retry with a higher sample size if you want to get more trees.
# 7_calibrate_Right Ovary
# 20 unique trees were not found (2 were found). Retry with a higher sample size if you want to get more trees.
# 7_calibrate_Right Uterosacral
# 20 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# 9_calibrate_Left Ovary
# 20 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# 9_calibrate_Right Ovary
# 20 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# 10_calibrate_Right Ovary
# 20 unique trees were not found (1 was found). Retry with a higher sample size if you want to get more trees.
# [0.5232510566711426, 0.1918308287858963, 0.28491806983947754]

# %%
OUTPUT_DIR = os.path.join(MCPHERSON_DATA_DIR, "metient_outputs", "evaluate_testing")
patient_id = 1
mut_trees_fn = os.path.join(MCPHERSON_DATA_DIR, f"patient{patient_id}_tree.txt")
ref_var_fns = os.path.join(MCPHERSON_DATA_DIR, f"patient{patient_id}_SNVs.tsv")
run_names = [f"{pid}_calibrate" for pid in PATIENT_IDS]
evaluate(mut_trees_fns, ref_var_fns, print_config, OUTPUT_DIR, run_names,
         bias_weights=True, solve_polytomies=False)
