# %%
import gzip
import pickle
import glob
import pandas as pd
import numpy as np
import os
from metient.util import eval_util as eutil
from metient.util.globals import *
import seaborn as sns
import matplotlib.pyplot as plt
from statannot import add_stat_annotation
import itertools

REPO_DIR = os.path.join(os.getcwd(), "../")

METRICS = ["Migration", "Comigration", "Seeding site"]
DATASET_NAMES = [ "HGSOC", "Melanoma", "HR-NB", "NSCLC"]
CALIBRATE_DIRS = [os.path.join(REPO_DIR,"data/mcpherson_ovarian_2016/metient_outputs/solve_polys", "calibrate"),
                  os.path.join(REPO_DIR,"data/sanborn_melanoma_2015/metient_outputs_solve_polys_no_cna_pyclone_vi_orchard", "calibrate"),
                  os.path.join(REPO_DIR,"data/gundem_neuroblastoma_2023/metient_outputs/solve_polys", "calibrate"),
                  os.path.join(REPO_DIR,"data/tracerx_nsclc/metient_outputs/tracerx_trees_06062024/calibrate",)]

num_bootstrap_samples = 100

num_mets = []
dataset_to_pickle_files = {dataset:[] for dataset in DATASET_NAMES}
for dataset_name, calibrate_dir in zip(DATASET_NAMES, CALIBRATE_DIRS):
    matching_files = glob.glob(f'{calibrate_dir}/*pkl.gz')
    print(calibrate_dir)
    for fn in matching_files:
        with gzip.open(fn, 'rb') as f:
            pkl = pickle.load(f)
            num_sites = len(pkl[OUT_SITES_KEY])
            loss_dicts = pkl[OUT_LOSS_DICT_KEY]
            #if num_sites > 2:
            dataset_to_pickle_files[dataset_name].append((fn, num_sites))
            num_mets.append(num_sites)

def convert_thetas_to_alt_metrics(thetas):
    wtot = thetas[0] + thetas[1]
    delta = thetas[1]/wtot
    return wtot, delta, thetas[2]
    
sizes = {k:len(v) for k,v in dataset_to_pickle_files.items()}
sizes
# Out:
# /lila/data/morrisq/divyak/projects/metient/metient/jupyter_notebooks/../data/mcpherson_ovarian_2016/metient_outputs/solve_polys/calibrate
# /lila/data/morrisq/divyak/projects/metient/metient/jupyter_notebooks/../data/sanborn_melanoma_2015/metient_outputs_solve_polys_no_cna_pyclone_vi_orchard/calibrate
# /lila/data/morrisq/divyak/projects/metient/metient/jupyter_notebooks/../data/gundem_neuroblastoma_2023/metient_outputs/solve_polys/calibrate
# /lila/data/morrisq/divyak/projects/metient/metient/jupyter_notebooks/../data/tracerx_nsclc/metient_outputs/tracerx_trees_06062024/calibrate
# {'HGSOC': 13, 'Melanoma': 7, 'HR-NB': 30, 'NSCLC': 128}

# %% [markdown]
# ### How consistent are the thetas when calibrated on random samples within the same cancer type cohort?

# %%
data = []


# Bootstrap sampling
for i in range(num_bootstrap_samples):
    print(f"\n**** RUN {i+1} ***")
    for dataset in dataset_to_pickle_files:
        matching_files = [x[0] for x in dataset_to_pickle_files[dataset]]
        if len(matching_files) == 0:
            continue
        # Create a bootstrap sample by sampling with replacement
        bootstrap_sample = list(np.random.choice(matching_files, size=len(matching_files), replace=True))
        thetas = eutil.get_max_cross_ent_thetas(pickle_file_list=bootstrap_sample)
        #thetas = convert_thetas_to_alt_metrics(thetas)
        for midx, metric in enumerate(METRICS):
            data.append([dataset, metric, thetas[midx]])

thetas_split_on_same_cohort = pd.DataFrame(data, columns=["dataset", "Parsimony metric", "Fit theta"])
thetas_split_on_same_cohort.to_csv('thetas_split_on_same_cohort.csv') 
thetas_split_on_same_cohort
# Out:
# **** RUN 1 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4787, 0.2618, 0.2595], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4481, 0.2759, 0.2759], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6327, 0.1676, 0.1997], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4205, 0.3099, 0.2696], grad_fn=<DivBackward0>)
#
# **** RUN 2 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5744, 0.1833, 0.2422], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6837, 0.1616, 0.1547], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4380, 0.3195, 0.2425], grad_fn=<DivBackward0>)
#
# **** RUN 3 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4883, 0.2579, 0.2538], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5198, 0.2401, 0.2401], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5277, 0.2161, 0.2562], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4647, 0.2989, 0.2364], grad_fn=<DivBackward0>)
#
# **** RUN 4 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4787, 0.2618, 0.2595], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3872, 0.3018, 0.3110], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4216, 0.3149, 0.2635], grad_fn=<DivBackward0>)
#
# **** RUN 5 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5538, 0.2268, 0.2194], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3902, 0.3197, 0.2902], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3974, 0.3373, 0.2653], grad_fn=<DivBackward0>)
#
# **** RUN 6 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4433, 0.2769, 0.2797], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5266, 0.2123, 0.2611], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4339, 0.3043, 0.2618], grad_fn=<DivBackward0>)
#
# **** RUN 7 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5744, 0.1833, 0.2422], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5035, 0.2493, 0.2472], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4387, 0.3210, 0.2403], grad_fn=<DivBackward0>)
#
# **** RUN 8 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5823, 0.1836, 0.2341], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4960, 0.2520, 0.2520], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5675, 0.1965, 0.2359], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4124, 0.3120, 0.2756], grad_fn=<DivBackward0>)
#
# **** RUN 9 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5204, 0.2425, 0.2372], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 875 epochs.
# Optimized thetas: tensor([0.4969, 0.2515, 0.2515], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5275, 0.2340, 0.2385], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4515, 0.2951, 0.2533], grad_fn=<DivBackward0>)
#
# **** RUN 10 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4883, 0.2579, 0.2538], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5312, 0.2412, 0.2276], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4737, 0.2958, 0.2305], grad_fn=<DivBackward0>)
#
# **** RUN 11 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4305, 0.3247, 0.2449], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4980, 0.2510, 0.2510], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6809, 0.1664, 0.1527], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4712, 0.2954, 0.2334], grad_fn=<DivBackward0>)
#
# **** RUN 12 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5832, 0.1835, 0.2333], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4171, 0.2838, 0.2991], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3987, 0.3273, 0.2740], grad_fn=<DivBackward0>)
#
# **** RUN 13 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5643, 0.1839, 0.2518], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4980, 0.2510, 0.2510], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.2863, 0.3494, 0.3643], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4068, 0.3137, 0.2795], grad_fn=<DivBackward0>)
#
# **** RUN 14 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4883, 0.2579, 0.2538], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4481, 0.2759, 0.2759], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6059, 0.1961, 0.1980], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4582, 0.3015, 0.2402], grad_fn=<DivBackward0>)
#
# **** RUN 15 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4163, 0.3269, 0.2568], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4998, 0.2323, 0.2679], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4209, 0.3132, 0.2659], grad_fn=<DivBackward0>)
#
# **** RUN 16 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5672, 0.1803, 0.2525], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5747, 0.1940, 0.2313], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4761, 0.2998, 0.2242], grad_fn=<DivBackward0>)
#
# **** RUN 17 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5204, 0.2425, 0.2372], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5198, 0.2401, 0.2401], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6822, 0.1593, 0.1585], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4805, 0.2725, 0.2470], grad_fn=<DivBackward0>)
#
# **** RUN 18 ***
# Calibrating to 13 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6152, 0.1894, 0.1953], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4390, 0.3021, 0.2589], grad_fn=<DivBackward0>)
#
# **** RUN 19 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4329, 0.2806, 0.2865], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5361, 0.2104, 0.2535], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4545, 0.2942, 0.2513], grad_fn=<DivBackward0>)
#
# **** RUN 20 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.3822, 0.3310, 0.2867], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6138, 0.2153, 0.1709], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4236, 0.3122, 0.2642], grad_fn=<DivBackward0>)
#
# **** RUN 21 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5468, 0.1759, 0.2773], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.2288, 0.3769, 0.3942], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4234, 0.3157, 0.2609], grad_fn=<DivBackward0>)
#
# **** RUN 22 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4442, 0.3222, 0.2337], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3419, 0.3482, 0.3100], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4621, 0.2937, 0.2442], grad_fn=<DivBackward0>)
#
# **** RUN 23 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4483, 0.3213, 0.2303], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4481, 0.2759, 0.2759], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4325, 0.2818, 0.2858], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4256, 0.3053, 0.2691], grad_fn=<DivBackward0>)
#
# **** RUN 24 ***
# Calibrating to 13 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5731, 0.1791, 0.2478], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4527, 0.3166, 0.2307], grad_fn=<DivBackward0>)
#
# **** RUN 25 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5672, 0.1803, 0.2525], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4941, 0.1975, 0.3084], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4215, 0.3133, 0.2652], grad_fn=<DivBackward0>)
#
# **** RUN 26 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5583, 0.1841, 0.2576], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 825 epochs.
# Optimized thetas: tensor([0.4958, 0.2521, 0.2521], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3573, 0.2856, 0.3572], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4481, 0.3027, 0.2491], grad_fn=<DivBackward0>)
#
# **** RUN 27 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4883, 0.2579, 0.2538], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5198, 0.2401, 0.2401], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6378, 0.1886, 0.1737], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3991, 0.3249, 0.2761], grad_fn=<DivBackward0>)
#
# **** RUN 28 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4352, 0.3238, 0.2409], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5071, 0.2464, 0.2464], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5583, 0.2223, 0.2194], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4481, 0.3086, 0.2434], grad_fn=<DivBackward0>)
#
# **** RUN 29 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5787, 0.1832, 0.2381], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 875 epochs.
# Optimized thetas: tensor([0.4969, 0.2515, 0.2515], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3640, 0.2981, 0.3378], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4481, 0.3099, 0.2420], grad_fn=<DivBackward0>)
#
# **** RUN 30 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5283, 0.2391, 0.2326], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6419, 0.1892, 0.1689], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3940, 0.3486, 0.2574], grad_fn=<DivBackward0>)
#
# **** RUN 31 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5860, 0.1837, 0.2303], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5198, 0.2401, 0.2401], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4379, 0.2436, 0.3185], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.5102, 0.2812, 0.2086], grad_fn=<DivBackward0>)
#
# **** RUN 32 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4442, 0.3222, 0.2337], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3218, 0.2841, 0.3941], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4311, 0.2945, 0.2745], grad_fn=<DivBackward0>)
#
# **** RUN 33 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4305, 0.3247, 0.2449], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3973, 0.3201, 0.2826], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4732, 0.2817, 0.2452], grad_fn=<DivBackward0>)
#
# **** RUN 34 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5122, 0.2459, 0.2419], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3902, 0.3197, 0.2902], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4891, 0.2835, 0.2274], grad_fn=<DivBackward0>)
#
# **** RUN 35 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5283, 0.2391, 0.2326], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4049, 0.3022, 0.2929], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3909, 0.3300, 0.2791], grad_fn=<DivBackward0>)
#
# **** RUN 36 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5538, 0.2268, 0.2194], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 747 epochs.
# Optimized thetas: tensor([0.5032, 0.2484, 0.2484], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5893, 0.2016, 0.2090], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4277, 0.3229, 0.2494], grad_fn=<DivBackward0>)
#
# **** RUN 37 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4108, 0.3277, 0.2615], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5071, 0.2464, 0.2464], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3333, 0.3097, 0.3570], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4568, 0.2957, 0.2475], grad_fn=<DivBackward0>)
#
# **** RUN 38 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.3822, 0.3310, 0.2867], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4960, 0.2520, 0.2520], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5313, 0.2481, 0.2206], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4762, 0.2871, 0.2367], grad_fn=<DivBackward0>)
#
# **** RUN 39 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4352, 0.3238, 0.2409], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6072, 0.2049, 0.1879], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4836, 0.2828, 0.2337], grad_fn=<DivBackward0>)
#
# **** RUN 40 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5893, 0.1842, 0.2266], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6058, 0.2038, 0.1904], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4490, 0.2887, 0.2623], grad_fn=<DivBackward0>)
#
# **** RUN 41 ***
# Calibrating to 13 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 810 epochs.
# Optimized thetas: tensor([0.4878, 0.2561, 0.2561], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4391, 0.2737, 0.2872], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3758, 0.3218, 0.3024], grad_fn=<DivBackward0>)
#
# **** RUN 42 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4979, 0.2538, 0.2482], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5198, 0.2401, 0.2401], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5517, 0.1985, 0.2498], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4408, 0.3044, 0.2549], grad_fn=<DivBackward0>)
#
# **** RUN 43 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4433, 0.2769, 0.2797], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5198, 0.2401, 0.2401], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3786, 0.3299, 0.2915], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4620, 0.2972, 0.2408], grad_fn=<DivBackward0>)
#
# **** RUN 44 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5122, 0.2459, 0.2419], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6163, 0.1785, 0.2052], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4126, 0.3101, 0.2772], grad_fn=<DivBackward0>)
#
# **** RUN 45 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5468, 0.1759, 0.2773], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5071, 0.2464, 0.2464], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5037, 0.2485, 0.2478], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4066, 0.3174, 0.2760], grad_fn=<DivBackward0>)
#
# **** RUN 46 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5538, 0.2268, 0.2194], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 747 epochs.
# Optimized thetas: tensor([0.5032, 0.2484, 0.2484], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5651, 0.1748, 0.2600], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4527, 0.2948, 0.2525], grad_fn=<DivBackward0>)
#
# **** RUN 47 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5203, 0.1907, 0.2891], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4980, 0.2510, 0.2510], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4072, 0.3236, 0.2692], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4761, 0.2990, 0.2249], grad_fn=<DivBackward0>)
#
# **** RUN 48 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5203, 0.1907, 0.2891], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 875 epochs.
# Optimized thetas: tensor([0.4969, 0.2515, 0.2515], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4905, 0.2668, 0.2427], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4270, 0.3099, 0.2631], grad_fn=<DivBackward0>)
#
# **** RUN 49 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5787, 0.1832, 0.2381], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4960, 0.2520, 0.2520], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5529, 0.2366, 0.2105], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4835, 0.2936, 0.2229], grad_fn=<DivBackward0>)
#
# **** RUN 50 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5477, 0.2292, 0.2231], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6011, 0.1992, 0.1997], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4680, 0.3079, 0.2241], grad_fn=<DivBackward0>)
#
# **** RUN 51 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4979, 0.2538, 0.2482], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5552, 0.2073, 0.2375], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4351, 0.3026, 0.2623], grad_fn=<DivBackward0>)
#
# **** RUN 52 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.3745, 0.2979, 0.3276], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 870 epochs.
# Optimized thetas: tensor([0.5053, 0.2473, 0.2473], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5964, 0.1991, 0.2045], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4227, 0.3273, 0.2500], grad_fn=<DivBackward0>)
#
# **** RUN 53 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4433, 0.2769, 0.2797], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4960, 0.2520, 0.2520], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6495, 0.1641, 0.1863], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.5000, 0.2883, 0.2116], grad_fn=<DivBackward0>)
#
# **** RUN 54 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4163, 0.3269, 0.2568], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3607, 0.3320, 0.3073], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3798, 0.3290, 0.2911], grad_fn=<DivBackward0>)
#
# **** RUN 55 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4567, 0.3196, 0.2237], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4445, 0.2387, 0.3168], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3824, 0.3264, 0.2912], grad_fn=<DivBackward0>)
#
# **** RUN 56 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4163, 0.3269, 0.2568], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5198, 0.2401, 0.2401], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.2551, 0.3562, 0.3887], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4581, 0.2985, 0.2434], grad_fn=<DivBackward0>)
#
# **** RUN 57 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4329, 0.2806, 0.2865], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5483, 0.2043, 0.2474], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4465, 0.2950, 0.2585], grad_fn=<DivBackward0>)
#
# **** RUN 58 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4163, 0.3269, 0.2568], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5948, 0.2024, 0.2028], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4881, 0.2780, 0.2339], grad_fn=<DivBackward0>)
#
# **** RUN 59 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5468, 0.1759, 0.2773], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5071, 0.2464, 0.2464], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3340, 0.3328, 0.3332], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4788, 0.3032, 0.2180], grad_fn=<DivBackward0>)
#
# **** RUN 60 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4108, 0.3277, 0.2615], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.2457, 0.3773, 0.3770], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.5201, 0.2723, 0.2076], grad_fn=<DivBackward0>)
#
# **** RUN 61 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5203, 0.1907, 0.2891], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6462, 0.1827, 0.1711], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4225, 0.3123, 0.2652], grad_fn=<DivBackward0>)
#
# **** RUN 62 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4052, 0.3285, 0.2663], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6061, 0.1839, 0.2099], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4399, 0.3154, 0.2448], grad_fn=<DivBackward0>)
#
# **** RUN 63 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5709, 0.1820, 0.2471], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4980, 0.2510, 0.2510], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.2103, 0.3580, 0.4317], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4793, 0.3015, 0.2192], grad_fn=<DivBackward0>)
#
# **** RUN 64 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5789, 0.1834, 0.2377], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5627, 0.2037, 0.2335], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4747, 0.3044, 0.2209], grad_fn=<DivBackward0>)
#
# **** RUN 65 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.3757, 0.3316, 0.2927], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5148, 0.2444, 0.2408], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4423, 0.3029, 0.2548], grad_fn=<DivBackward0>)
#
# **** RUN 66 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5788, 0.1842, 0.2371], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6367, 0.1479, 0.2154], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4100, 0.3251, 0.2649], grad_fn=<DivBackward0>)
#
# **** RUN 67 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5748, 0.1826, 0.2426], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4960, 0.2520, 0.2520], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6471, 0.1595, 0.1933], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4864, 0.2904, 0.2233], grad_fn=<DivBackward0>)
#
# **** RUN 68 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5895, 0.1839, 0.2266], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6258, 0.1787, 0.1955], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4018, 0.3368, 0.2615], grad_fn=<DivBackward0>)
#
# **** RUN 69 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4052, 0.3285, 0.2663], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 872 epochs.
# Optimized thetas: tensor([0.5054, 0.2473, 0.2473], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3911, 0.3032, 0.3057], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4969, 0.2986, 0.2045], grad_fn=<DivBackward0>)
#
# **** RUN 70 ***
# Calibrating to 13 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4405, 0.2591, 0.3004], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4364, 0.3140, 0.2496], grad_fn=<DivBackward0>)
#
# **** RUN 71 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4883, 0.2579, 0.2538], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6515, 0.1571, 0.1915], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4240, 0.3101, 0.2660], grad_fn=<DivBackward0>)
#
# **** RUN 72 ***
# Calibrating to 13 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 875 epochs.
# Optimized thetas: tensor([0.4969, 0.2515, 0.2515], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.2086, 0.3561, 0.4352], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4216, 0.3002, 0.2781], grad_fn=<DivBackward0>)
#
# **** RUN 73 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4329, 0.2806, 0.2865], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4481, 0.2759, 0.2759], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3834, 0.2294, 0.3872], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4893, 0.2693, 0.2414], grad_fn=<DivBackward0>)
#
# **** RUN 74 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5895, 0.1839, 0.2266], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4481, 0.2759, 0.2759], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4011, 0.2924, 0.3064], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.5177, 0.2852, 0.1971], grad_fn=<DivBackward0>)
#
# **** RUN 75 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4352, 0.3238, 0.2409], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.2819, 0.3068, 0.4113], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4169, 0.3115, 0.2716], grad_fn=<DivBackward0>)
#
# **** RUN 76 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5203, 0.1907, 0.2891], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5071, 0.2464, 0.2464], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6698, 0.1726, 0.1576], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4123, 0.3289, 0.2588], grad_fn=<DivBackward0>)
#
# **** RUN 77 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5361, 0.2359, 0.2280], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5071, 0.2464, 0.2464], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4769, 0.2775, 0.2456], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4487, 0.2984, 0.2529], grad_fn=<DivBackward0>)
#
# **** RUN 78 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4979, 0.2538, 0.2482], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6258, 0.2071, 0.1671], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4750, 0.2970, 0.2281], grad_fn=<DivBackward0>)
#
# **** RUN 79 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5625, 0.1795, 0.2580], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 875 epochs.
# Optimized thetas: tensor([0.4969, 0.2515, 0.2515], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6123, 0.1922, 0.1955], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3727, 0.3214, 0.3059], grad_fn=<DivBackward0>)
#
# **** RUN 80 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5823, 0.1836, 0.2341], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6014, 0.1987, 0.1998], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4358, 0.3086, 0.2556], grad_fn=<DivBackward0>)
#
# **** RUN 81 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.3757, 0.3316, 0.2927], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4980, 0.2510, 0.2510], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6660, 0.1768, 0.1571], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4437, 0.3012, 0.2552], grad_fn=<DivBackward0>)
#
# **** RUN 82 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4108, 0.3277, 0.2615], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5071, 0.2464, 0.2464], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6671, 0.1568, 0.1761], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4633, 0.2911, 0.2457], grad_fn=<DivBackward0>)
#
# **** RUN 83 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4979, 0.2538, 0.2482], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6344, 0.1723, 0.1933], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4294, 0.3207, 0.2499], grad_fn=<DivBackward0>)
#
# **** RUN 84 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.3745, 0.2979, 0.3276], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6741, 0.1750, 0.1509], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4265, 0.3104, 0.2631], grad_fn=<DivBackward0>)
#
# **** RUN 85 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5712, 0.1912, 0.2376], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5676, 0.2107, 0.2217], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4613, 0.2969, 0.2418], grad_fn=<DivBackward0>)
#
# **** RUN 86 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4108, 0.3277, 0.2615], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.1975, 0.3650, 0.4375], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4109, 0.3008, 0.2883], grad_fn=<DivBackward0>)
#
# **** RUN 87 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5744, 0.1833, 0.2422], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3381, 0.3108, 0.3511], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4358, 0.3004, 0.2638], grad_fn=<DivBackward0>)
#
# **** RUN 88 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4163, 0.3269, 0.2568], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5850, 0.1955, 0.2194], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4432, 0.3083, 0.2486], grad_fn=<DivBackward0>)
#
# **** RUN 89 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.3757, 0.3316, 0.2927], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4481, 0.2759, 0.2759], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3024, 0.3315, 0.3660], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4552, 0.2950, 0.2498], grad_fn=<DivBackward0>)
#
# **** RUN 90 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4433, 0.2769, 0.2797], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4481, 0.2759, 0.2759], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5552, 0.2272, 0.2176], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4438, 0.3124, 0.2438], grad_fn=<DivBackward0>)
#
# **** RUN 91 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5643, 0.1839, 0.2518], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4481, 0.2759, 0.2759], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4613, 0.2401, 0.2985], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3887, 0.3322, 0.2791], grad_fn=<DivBackward0>)
#
# **** RUN 92 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5955, 0.1846, 0.2200], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.4062, 0.3057, 0.2881], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4285, 0.3072, 0.2644], grad_fn=<DivBackward0>)
#
# **** RUN 93 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5860, 0.1837, 0.2303], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Early stopping after 51 epochs.
# Optimized thetas: tensor([0.3333, 0.3333, 0.3333], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Early stopping after 830 epochs.
# Optimized thetas: tensor([0.6667, 0.1599, 0.1735], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4438, 0.2994, 0.2568], grad_fn=<DivBackward0>)
#
# **** RUN 94 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5283, 0.2391, 0.2326], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4844, 0.2578, 0.2578], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5314, 0.2732, 0.1954], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4219, 0.3225, 0.2556], grad_fn=<DivBackward0>)
#
# **** RUN 95 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4163, 0.3269, 0.2568], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5919, 0.2078, 0.2003], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4519, 0.3054, 0.2427], grad_fn=<DivBackward0>)
#
# **** RUN 96 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4575, 0.3195, 0.2231], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5299, 0.2350, 0.2350], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6922, 0.1602, 0.1476], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4412, 0.3069, 0.2519], grad_fn=<DivBackward0>)
#
# **** RUN 97 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4163, 0.3269, 0.2568], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4723, 0.2638, 0.2638], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.7038, 0.1534, 0.1428], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.3964, 0.3048, 0.2989], grad_fn=<DivBackward0>)
#
# **** RUN 98 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4979, 0.2538, 0.2482], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.5071, 0.2464, 0.2464], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.3927, 0.3206, 0.2867], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4695, 0.2880, 0.2425], grad_fn=<DivBackward0>)
#
# **** RUN 99 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.4108, 0.3277, 0.2615], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4960, 0.2520, 0.2520], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.5962, 0.1841, 0.2197], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4247, 0.3033, 0.2720], grad_fn=<DivBackward0>)
#
# **** RUN 100 ***
# Calibrating to 13 patients
# Optimized thetas: tensor([0.5832, 0.1835, 0.2333], grad_fn=<DivBackward0>)
# Calibrating to 7 patients
# Optimized thetas: tensor([0.4326, 0.2837, 0.2837], grad_fn=<DivBackward0>)
# Calibrating to 30 patients
# Optimized thetas: tensor([0.6506, 0.1688, 0.1806], grad_fn=<DivBackward0>)
# Calibrating to 128 patients
# Optimized thetas: tensor([0.4536, 0.3050, 0.2414], grad_fn=<DivBackward0>)
#        dataset Parsimony metric  Fit theta
# 0        HGSOC        Migration      0.479
# 1        HGSOC      Comigration      0.262
# 2        HGSOC     Seeding site      0.259
# 3     Melanoma        Migration      0.448
# 4     Melanoma      Comigration      0.276
# ...        ...              ...        ...
# 1195     HR-NB      Comigration      0.169
# 1196     HR-NB     Seeding site      0.181
# 1197     NSCLC        Migration      0.454
# 1198     NSCLC      Comigration      0.305
# 1199     NSCLC     Seeding site      0.241
#
# [1200 rows x 3 columns]

# %% [markdown]
# ### How consistent are thetas when calibrating on random samples amongst all cancer type cohorts?

# %%
data = []
dataset_sizes = []
all_matching_files = []
for dataset in dataset_to_pickle_files:
    files = dataset_to_pickle_files[dataset]
    dataset_sizes.append(len(files))
    all_matching_files.extend(files)
print(dataset_sizes, len(all_matching_files))

for i in range(num_bootstrap_samples):
    print(f"\n**** RUN {i+1} ***")
    matching_files = [x[0] for x in all_matching_files]
    if len(matching_files) == 0:
        continue
    # Create a bootstrap sample by sampling with replacement
    bootstrap_sample = list(np.random.choice(matching_files, size=len(matching_files), replace=True))
    thetas = eutil.get_max_cross_ent_thetas(pickle_file_list=bootstrap_sample)
    for midx, metric in enumerate(METRICS):
        data.append([metric, thetas[midx]])

thetas_split_on_random_cohort = pd.DataFrame(data, columns=["Parsimony metric", "Fit theta"])
thetas_split_on_random_cohort.to_csv('thetas_split_on_random_cohort.csv') 

thetas_split_on_random_cohort
# Out:
# [13, 7, 30, 128] 178
#
# **** RUN 1 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4084, 0.3115, 0.2801], grad_fn=<DivBackward0>)
#
# **** RUN 2 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5677, 0.2337, 0.1987], grad_fn=<DivBackward0>)
#
# **** RUN 3 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5014, 0.2920, 0.2066], grad_fn=<DivBackward0>)
#
# **** RUN 4 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4369, 0.3050, 0.2581], grad_fn=<DivBackward0>)
#
# **** RUN 5 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4832, 0.2790, 0.2378], grad_fn=<DivBackward0>)
#
# **** RUN 6 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5223, 0.2387, 0.2390], grad_fn=<DivBackward0>)
#
# **** RUN 7 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4484, 0.2827, 0.2689], grad_fn=<DivBackward0>)
#
# **** RUN 8 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4789, 0.2744, 0.2467], grad_fn=<DivBackward0>)
#
# **** RUN 9 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4615, 0.2946, 0.2438], grad_fn=<DivBackward0>)
#
# **** RUN 10 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4221, 0.3049, 0.2730], grad_fn=<DivBackward0>)
#
# **** RUN 11 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4444, 0.2947, 0.2609], grad_fn=<DivBackward0>)
#
# **** RUN 12 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4019, 0.3219, 0.2762], grad_fn=<DivBackward0>)
#
# **** RUN 13 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4013, 0.3027, 0.2959], grad_fn=<DivBackward0>)
#
# **** RUN 14 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4722, 0.2897, 0.2381], grad_fn=<DivBackward0>)
#
# **** RUN 15 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4369, 0.2942, 0.2689], grad_fn=<DivBackward0>)
#
# **** RUN 16 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5210, 0.2477, 0.2313], grad_fn=<DivBackward0>)
#
# **** RUN 17 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4582, 0.2806, 0.2612], grad_fn=<DivBackward0>)
#
# **** RUN 18 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4516, 0.2871, 0.2613], grad_fn=<DivBackward0>)
#
# **** RUN 19 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4590, 0.2887, 0.2523], grad_fn=<DivBackward0>)
#
# **** RUN 20 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4739, 0.2726, 0.2534], grad_fn=<DivBackward0>)
#
# **** RUN 21 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4249, 0.3054, 0.2696], grad_fn=<DivBackward0>)
#
# **** RUN 22 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4267, 0.3122, 0.2611], grad_fn=<DivBackward0>)
#
# **** RUN 23 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4764, 0.2790, 0.2447], grad_fn=<DivBackward0>)
#
# **** RUN 24 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4906, 0.2688, 0.2407], grad_fn=<DivBackward0>)
#
# **** RUN 25 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4410, 0.3044, 0.2546], grad_fn=<DivBackward0>)
#
# **** RUN 26 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4276, 0.3077, 0.2647], grad_fn=<DivBackward0>)
#
# **** RUN 27 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5044, 0.2722, 0.2235], grad_fn=<DivBackward0>)
#
# **** RUN 28 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4744, 0.2819, 0.2438], grad_fn=<DivBackward0>)
#
# **** RUN 29 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4427, 0.2851, 0.2722], grad_fn=<DivBackward0>)
#
# **** RUN 30 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5036, 0.2669, 0.2295], grad_fn=<DivBackward0>)
#
# **** RUN 31 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5052, 0.2668, 0.2280], grad_fn=<DivBackward0>)
#
# **** RUN 32 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4323, 0.2964, 0.2712], grad_fn=<DivBackward0>)
#
# **** RUN 33 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4618, 0.2818, 0.2564], grad_fn=<DivBackward0>)
#
# **** RUN 34 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4323, 0.3016, 0.2661], grad_fn=<DivBackward0>)
#
# **** RUN 35 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4809, 0.2863, 0.2328], grad_fn=<DivBackward0>)
#
# **** RUN 36 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4896, 0.2760, 0.2343], grad_fn=<DivBackward0>)
#
# **** RUN 37 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4304, 0.3026, 0.2670], grad_fn=<DivBackward0>)
#
# **** RUN 38 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4555, 0.2940, 0.2504], grad_fn=<DivBackward0>)
#
# **** RUN 39 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4622, 0.2820, 0.2558], grad_fn=<DivBackward0>)
#
# **** RUN 40 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4428, 0.2917, 0.2654], grad_fn=<DivBackward0>)
#
# **** RUN 41 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4884, 0.2803, 0.2314], grad_fn=<DivBackward0>)
#
# **** RUN 42 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4864, 0.2806, 0.2330], grad_fn=<DivBackward0>)
#
# **** RUN 43 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.3914, 0.3084, 0.3002], grad_fn=<DivBackward0>)
#
# **** RUN 44 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4740, 0.2857, 0.2403], grad_fn=<DivBackward0>)
#
# **** RUN 45 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4726, 0.2703, 0.2570], grad_fn=<DivBackward0>)
#
# **** RUN 46 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4610, 0.2824, 0.2566], grad_fn=<DivBackward0>)
#
# **** RUN 47 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4704, 0.2861, 0.2436], grad_fn=<DivBackward0>)
#
# **** RUN 48 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4753, 0.2667, 0.2580], grad_fn=<DivBackward0>)
#
# **** RUN 49 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5073, 0.2750, 0.2177], grad_fn=<DivBackward0>)
#
# **** RUN 50 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4271, 0.2940, 0.2789], grad_fn=<DivBackward0>)
#
# **** RUN 51 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4881, 0.2826, 0.2293], grad_fn=<DivBackward0>)
#
# **** RUN 52 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4080, 0.3147, 0.2773], grad_fn=<DivBackward0>)
#
# **** RUN 53 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.3876, 0.3346, 0.2778], grad_fn=<DivBackward0>)
#
# **** RUN 54 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4424, 0.2893, 0.2683], grad_fn=<DivBackward0>)
#
# **** RUN 55 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4408, 0.2780, 0.2812], grad_fn=<DivBackward0>)
#
# **** RUN 56 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4295, 0.3114, 0.2591], grad_fn=<DivBackward0>)
#
# **** RUN 57 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5669, 0.2273, 0.2058], grad_fn=<DivBackward0>)
#
# **** RUN 58 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.3840, 0.3200, 0.2960], grad_fn=<DivBackward0>)
#
# **** RUN 59 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4839, 0.2743, 0.2418], grad_fn=<DivBackward0>)
#
# **** RUN 60 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4769, 0.2678, 0.2554], grad_fn=<DivBackward0>)
#
# **** RUN 61 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4269, 0.3002, 0.2729], grad_fn=<DivBackward0>)
#
# **** RUN 62 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4658, 0.2752, 0.2590], grad_fn=<DivBackward0>)
#
# **** RUN 63 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4829, 0.2738, 0.2432], grad_fn=<DivBackward0>)
#
# **** RUN 64 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5427, 0.2402, 0.2170], grad_fn=<DivBackward0>)
#
# **** RUN 65 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4914, 0.2837, 0.2250], grad_fn=<DivBackward0>)
#
# **** RUN 66 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4734, 0.2819, 0.2447], grad_fn=<DivBackward0>)
#
# **** RUN 67 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4381, 0.2952, 0.2667], grad_fn=<DivBackward0>)
#
# **** RUN 68 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4693, 0.2917, 0.2391], grad_fn=<DivBackward0>)
#
# **** RUN 69 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4296, 0.2944, 0.2760], grad_fn=<DivBackward0>)
#
# **** RUN 70 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4341, 0.3066, 0.2593], grad_fn=<DivBackward0>)
#
# **** RUN 71 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4376, 0.2908, 0.2716], grad_fn=<DivBackward0>)
#
# **** RUN 72 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4246, 0.3024, 0.2731], grad_fn=<DivBackward0>)
#
# **** RUN 73 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5065, 0.2591, 0.2345], grad_fn=<DivBackward0>)
#
# **** RUN 74 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4863, 0.2865, 0.2272], grad_fn=<DivBackward0>)
#
# **** RUN 75 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4973, 0.2760, 0.2267], grad_fn=<DivBackward0>)
#
# **** RUN 76 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4993, 0.2729, 0.2278], grad_fn=<DivBackward0>)
#
# **** RUN 77 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4164, 0.2978, 0.2858], grad_fn=<DivBackward0>)
#
# **** RUN 78 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5165, 0.2486, 0.2349], grad_fn=<DivBackward0>)
#
# **** RUN 79 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4467, 0.2942, 0.2591], grad_fn=<DivBackward0>)
#
# **** RUN 80 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4815, 0.2816, 0.2369], grad_fn=<DivBackward0>)
#
# **** RUN 81 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4943, 0.2687, 0.2370], grad_fn=<DivBackward0>)
#
# **** RUN 82 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4384, 0.2933, 0.2683], grad_fn=<DivBackward0>)
#
# **** RUN 83 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4576, 0.2790, 0.2634], grad_fn=<DivBackward0>)
#
# **** RUN 84 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5422, 0.2451, 0.2128], grad_fn=<DivBackward0>)
#
# **** RUN 85 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4380, 0.3007, 0.2613], grad_fn=<DivBackward0>)
#
# **** RUN 86 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4880, 0.2777, 0.2343], grad_fn=<DivBackward0>)
#
# **** RUN 87 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.3881, 0.3314, 0.2805], grad_fn=<DivBackward0>)
#
# **** RUN 88 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4090, 0.3143, 0.2767], grad_fn=<DivBackward0>)
#
# **** RUN 89 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4512, 0.2956, 0.2532], grad_fn=<DivBackward0>)
#
# **** RUN 90 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4433, 0.3031, 0.2537], grad_fn=<DivBackward0>)
#
# **** RUN 91 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4810, 0.2738, 0.2452], grad_fn=<DivBackward0>)
#
# **** RUN 92 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.3866, 0.3179, 0.2955], grad_fn=<DivBackward0>)
#
# **** RUN 93 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4919, 0.2719, 0.2362], grad_fn=<DivBackward0>)
#
# **** RUN 94 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5646, 0.2246, 0.2107], grad_fn=<DivBackward0>)
#
# **** RUN 95 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4430, 0.2935, 0.2636], grad_fn=<DivBackward0>)
#
# **** RUN 96 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4436, 0.2937, 0.2627], grad_fn=<DivBackward0>)
#
# **** RUN 97 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5515, 0.2405, 0.2079], grad_fn=<DivBackward0>)
#
# **** RUN 98 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4464, 0.2798, 0.2737], grad_fn=<DivBackward0>)
#
# **** RUN 99 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.4779, 0.2717, 0.2504], grad_fn=<DivBackward0>)
#
# **** RUN 100 ***
# Calibrating to 178 patients
# Optimized thetas: tensor([0.5036, 0.2620, 0.2344], grad_fn=<DivBackward0>)
#     Parsimony metric  Fit theta
# 0          Migration      0.408
# 1        Comigration      0.311
# 2       Seeding site      0.280
# 3          Migration      0.568
# 4        Comigration      0.234
# ..               ...        ...
# 295      Comigration      0.272
# 296     Seeding site      0.250
# 297        Migration      0.504
# 298      Comigration      0.262
# 299     Seeding site      0.234
#
# [300 rows x 2 columns]

# %%
# Load data
thetas_split_on_same_cohort = pd.read_csv('thetas_split_on_same_cohort.csv', index_col=False).drop(columns=['Unnamed: 0']) 
thetas_split_on_random_cohort = pd.read_csv('thetas_split_on_random_cohort.csv', index_col=False).drop(columns=['Unnamed: 0']) 

colors = sns.color_palette("flare")[2:]

def point_plot(df, color, name, with_stats):
   
    sns.set(style='ticks', rc={'axes.labelsize': 6, 'xtick.labelsize': 6, 'ytick.labelsize': 6, })

    fig = plt.figure(figsize=(2, 2.5), dpi=200)
    snsfig = sns.pointplot(data=df, x='Parsimony metric', y='Fit theta', markersize=0.5, errwidth=1.7,capsize=0.1, 
                           dodge=True, markers='.', errorbar='sd', palette='viridis')

#     snsfig = sns.violinplot(x='Parsimony metric', y='Fit theta', data=df, 
#                          linewidth=0.7, color=color, alpha=0.5, inner=None)
    
    if with_stats:
        add_stat_annotation(snsfig, data=df, x='Parsimony metric', y="Fit theta",
                            box_pairs=itertools.combinations(METRICS, 2),
                            line_offset=0.2,test='t-test_welch', text_format='star', loc='outside', line_offset_to_box=0.1, 
                            text_offset=0.00001, verbose=2,  fontsize=7, comparisons_correction=None,linewidth=1.0,
                            )
    if with_stats:
        plt.ylim(0, 0.9) 
    else:
        plt.ylim(0, 0.7)
    plt.ylabel("Penalty")
    snsfig.spines['top'].set_visible(False)
    snsfig.spines['right'].set_visible(False)
    saved_name = "_".join(name.split(" "))
    plt.setp(snsfig.collections, alpha=0.8)
    plt.tight_layout(pad=1.8) 
    plt.xticks(rotation=45)  
    plt.savefig(f"output_plots/{saved_name}_theta_distribution.png", dpi=500)
    plt.title(name, fontsize=8)
    plt.show()
    plt.close()

with_stats = True
for i,dataset in enumerate(dataset_to_pickle_files):
    subset = thetas_split_on_same_cohort[thetas_split_on_same_cohort['dataset']==dataset]
    point_plot(subset, colors[i], dataset, with_stats)

point_plot(thetas_split_on_random_cohort, 'lightseagreen', 'random', with_stats)
# Out:
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Migration v.s. Comigration: Welch's t-test independent samples, P_val=4.299e-58 stat=2.359e+01
# Comigration v.s. Seeding site: Welch's t-test independent samples, P_val=8.897e-01 stat=-1.389e-01
# Migration v.s. Seeding site: Welch's t-test independent samples, P_val=4.439e-56 stat=2.806e+01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Migration v.s. Comigration: Welch's t-test independent samples, P_val=1.571e-75 stat=3.674e+01
# Comigration v.s. Seeding site: Welch's t-test independent samples, P_val=1.000e+00 stat=2.563e-06
# Migration v.s. Seeding site: Welch's t-test independent samples, P_val=1.571e-75 stat=3.674e+01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Migration v.s. Comigration: Welch's t-test independent samples, P_val=1.646e-39 stat=1.841e+01
# Comigration v.s. Seeding site: Welch's t-test independent samples, P_val=1.271e-01 stat=-1.532e+00
# Migration v.s. Seeding site: Welch's t-test independent samples, P_val=6.809e-37 stat=1.685e+01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Migration v.s. Comigration: Welch's t-test independent samples, P_val=5.890e-77 stat=3.892e+01
# Comigration v.s. Seeding site: Welch's t-test independent samples, P_val=1.452e-48 stat=2.051e+01
# Migration v.s. Seeding site: Welch's t-test independent samples, P_val=3.388e-104 stat=4.956e+01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Migration v.s. Comigration: Welch's t-test independent samples, P_val=6.964e-81 stat=3.934e+01
# Comigration v.s. Seeding site: Welch's t-test independent samples, P_val=9.628e-22 stat=1.082e+01
# Migration v.s. Seeding site: Welch's t-test independent samples, P_val=1.041e-91 stat=4.626e+01

# %% [markdown]
# ### Make one plot per metric with datasets side by side

# %%
from matplotlib.colors import to_rgb
from statannot import add_stat_annotation
dataset_colors = ["#b84988","#06879e","#5a9e09","#d4892a", "#939598"]

dataset_order = ["Melanoma", "HGSOC", "HR-NB", "NSCLC", "Combined"]
def plot_all_metrics(df, metric, with_stats, ylim, shape=(2,2), colors=None):

    sns.set(style='ticks', rc={'axes.labelsize': 6, 'xtick.labelsize': 8, 'ytick.labelsize': 8,  "axes.linewidth":1.0, })
    subset = df[df['Parsimony metric']==metric]
    if with_stats:
        shape = (shape[0], shape[1]+0.3)
    fig = plt.figure(figsize=(shape[0], shape[1]), dpi=200)

    snsfig = sns.pointplot(data=subset, x='dataset', y='Fit theta', s=5, errwidth=1.7, order=dataset_order,
                           dodge=True, markers='.', errorbar='se', palette=dataset_colors, capsize=0.2)

#     snsfig = sns.violinplot(x='dataset', y='Fit theta', data=subset, palette=colors,
#                          linewidth=0.7, alpha=0.5, inner=None )

    groups = list(subset['dataset'].unique())
    
    # Plot the medians
#     medians = [np.median(subset[subset['dataset']==dataset]['Fit theta']) for dataset in set(groups)]
#     plt.setp(snsfig.collections, alpha=.3)
#     plt.scatter(x=range(len(medians)),y=medians,c="k",s=5.0, )
    
    if with_stats:
        if "Combined" in groups: groups.remove("Combined")

        line_offset = 0.17 if metric == 'Comigration' else 0.07
        add_stat_annotation(snsfig, data=subset, x='dataset', y="Fit theta",
                            box_pairs=itertools.combinations(groups, 2),order=dataset_order, line_offset=line_offset,
                            test='t-test_welch', text_format='star', loc='outside', line_offset_to_box=0.05, 
                            text_offset=0.00001, verbose=2,  fontsize=7, comparisons_correction=None,linewidth=1.0,
                            )
        plt.ylim(ylim[0], ylim[1]) 
    else:
        plt.ylim(ylim[0], ylim[1]) 
            
    snsfig.set_xticklabels(snsfig.get_xticklabels(), rotation=45, horizontalalignment='right')
    
    plt.xlabel("Dataset", fontsize=8)
    ylabel = f"{metric} penalty" if "index" not in metric else metric
    plt.ylabel(f"{ylabel} (a.u.)", fontsize=8)
    snsfig.spines['top'].set_visible(False)
    snsfig.spines['right'].set_visible(False)
    saved_name = "_".join(metric.split(" "))
    plt.setp(snsfig.collections, alpha=0.7)
    #plt.tight_layout() 
    plt.savefig(f"output_plots/{saved_name}_theta_distribution_stat.png", dpi=500,  bbox_inches='tight', pad_inches=0.05)
    plt.show()
    plt.close()
    
thetas_split_on_random_cohort['dataset'] = "Combined"
print(thetas_split_on_random_cohort)
print(thetas_split_on_same_cohort)
combined_df = pd.concat([thetas_split_on_same_cohort, thetas_split_on_random_cohort], axis=0)
combined_df = combined_df[combined_df['dataset']!='Breast Cancer'].reset_index(drop=True)

# This is to plot the alternative metrics (Effective migration #, polyclonality index)
import math
group_size = 3
tolerance = 1e-4
rows_to_add = []
for _, group in combined_df.groupby(combined_df.index // group_size):
    assert(math.isclose(group['Fit theta'].sum(),1.0, rel_tol=tolerance, abs_tol=tolerance))
    dataset = group['dataset'].unique().item()

    mig = float(group[group['Parsimony metric']=="Migration"]["Fit theta"].item())
    comig = float(group[group['Parsimony metric']=="Comigration"]["Fit theta"].item())
    ss = float(group[group['Parsimony metric']=="Seeding site"]["Fit theta"].item())
    rows_to_add.append([dataset,  "Migration # index", 1-(mig)])
    rows_to_add.append([dataset,  "Polyclonality index", 1-(comig/(mig+comig))])
    rows_to_add.append([dataset,  "Comigration # index", 1-(comig)])
    rows_to_add.append([dataset,  "Seeding site index", 1-ss])

combined_df = pd.concat([combined_df, pd.DataFrame(rows_to_add, columns=combined_df.columns)], axis=0)

with_stats = True
plot_all_metrics(combined_df, 'Migration', with_stats, (0.4,0.6))
plot_all_metrics(combined_df, 'Comigration', with_stats,(0.15,0.4))
plot_all_metrics(combined_df, "Seeding site", with_stats, (0.23,0.3))
plot_all_metrics(combined_df, 'Polyclonality index', with_stats, (0.55,0.8))
# Out:
#     Parsimony metric  Fit theta   dataset
# 0          Migration      0.408  Combined
# 1        Comigration      0.311  Combined
# 2       Seeding site      0.280  Combined
# 3          Migration      0.568  Combined
# 4        Comigration      0.234  Combined
# ..               ...        ...       ...
# 295      Comigration      0.272  Combined
# 296     Seeding site      0.250  Combined
# 297        Migration      0.504  Combined
# 298      Comigration      0.262  Combined
# 299     Seeding site      0.234  Combined
#
# [300 rows x 3 columns]
#        dataset Parsimony metric  Fit theta
# 0        HGSOC        Migration      0.479
# 1        HGSOC      Comigration      0.262
# 2        HGSOC     Seeding site      0.259
# 3     Melanoma        Migration      0.448
# 4     Melanoma      Comigration      0.276
# ...        ...              ...        ...
# 1195     HR-NB      Comigration      0.169
# 1196     HR-NB     Seeding site      0.181
# 1197     NSCLC        Migration      0.454
# 1198     NSCLC      Comigration      0.305
# 1199     NSCLC     Seeding site      0.241
#
# [1200 rows x 3 columns]
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Melanoma v.s. HGSOC: Welch's t-test independent samples, P_val=5.689e-02 stat=-1.917e+00
# HGSOC v.s. HR-NB: Welch's t-test independent samples, P_val=1.476e-01 stat=-1.455e+00
# HR-NB v.s. NSCLC: Welch's t-test independent samples, P_val=4.378e-06 stat=4.832e+00
# HGSOC v.s. NSCLC: Welch's t-test independent samples, P_val=5.811e-07 stat=5.253e+00
# Melanoma v.s. HR-NB: Welch's t-test independent samples, P_val=5.735e-03 stat=-2.811e+00
# Melanoma v.s. NSCLC: Welch's t-test independent samples, P_val=1.727e-05 stat=4.424e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Melanoma v.s. HGSOC: Welch's t-test independent samples, P_val=1.616e-01 stat=1.408e+00
# HGSOC v.s. HR-NB: Welch's t-test independent samples, P_val=4.040e-02 stat=2.063e+00
# HR-NB v.s. NSCLC: Welch's t-test independent samples, P_val=1.056e-17 stat=-1.025e+01
# HGSOC v.s. NSCLC: Welch's t-test independent samples, P_val=2.501e-12 stat=-7.874e+00
# Melanoma v.s. HR-NB: Welch's t-test independent samples, P_val=1.090e-04 stat=3.994e+00
# Melanoma v.s. NSCLC: Welch's t-test independent samples, P_val=3.849e-29 stat=-1.379e+01
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Melanoma v.s. HGSOC: Welch's t-test independent samples, P_val=3.002e-02 stat=2.186e+00
# HGSOC v.s. HR-NB: Welch's t-test independent samples, P_val=6.057e-01 stat=5.175e-01
# HR-NB v.s. NSCLC: Welch's t-test independent samples, P_val=8.568e-01 stat=1.809e-01
# HGSOC v.s. NSCLC: Welch's t-test independent samples, P_val=1.262e-01 stat=1.536e+00
# Melanoma v.s. HR-NB: Welch's t-test independent samples, P_val=1.153e-01 stat=1.586e+00
# Melanoma v.s. NSCLC: Welch's t-test independent samples, P_val=4.068e-05 stat=4.200e+00
# p-value annotation legend:
# ns: 5.00e-02 < p <= 1.00e+00
# *: 1.00e-02 < p <= 5.00e-02
# **: 1.00e-03 < p <= 1.00e-02
# ***: 1.00e-04 < p <= 1.00e-03
# ****: p <= 1.00e-04
#
# Melanoma v.s. HGSOC: Welch's t-test independent samples, P_val=1.111e-01 stat=-1.602e+00
# HGSOC v.s. HR-NB: Welch's t-test independent samples, P_val=2.645e-01 stat=-1.119e+00
# HR-NB v.s. NSCLC: Welch's t-test independent samples, P_val=8.017e-09 stat=6.253e+00
# HGSOC v.s. NSCLC: Welch's t-test independent samples, P_val=9.391e-10 stat=6.652e+00
# Melanoma v.s. HR-NB: Welch's t-test independent samples, P_val=1.334e-02 stat=-2.509e+00
# Melanoma v.s. NSCLC: Welch's t-test independent samples, P_val=1.450e-13 stat=8.096e+00

# %% [markdown]
# ### How concordant is the top solution when using the bootstrapped weights?

# %%
import torch
data = []

for calibrate_dir,dataset in zip(CALIBRATE_DIRS, DATASET_NAMES):
    # Use glob to get the list of matching files
    matching_files = glob.glob(f'{calibrate_dir}/*pkl.gz')
    patients = [m.split("/")[-1].split("_")[0] for m in matching_files]
    print(dataset, len(patients))
    for fn in matching_files:
        with gzip.open(fn, 'rb') as f:
            
            pid = fn.split("/")[-1].split("_")[0]
            pkl = pickle.load(f)
            # For each patient, how would their Pareto optimal trees get reordered
            # with different bootstrapped weights?
            
            loss_dicts = pkl[OUT_LOSS_DICT_KEY]
            pars_metrics = []
            for l in loss_dicts:
                pars_metrics.append((int(l[MIG_KEY]), int(l[COMIG_KEY]), int(l[SEEDING_KEY])))
            
            dataset_thetas = list(thetas_split_on_same_cohort[thetas_split_on_same_cohort['dataset']==dataset]['Fit theta'])
            for i in range(0, len(dataset_thetas), 3):
                one_samp_thetas = dataset_thetas[i:i+3]
                
                
                best_soln_loss, best_soln_idx = float("inf"), -1
                for x,pars in enumerate(pars_metrics):
                    loss = one_samp_thetas[0]*pars[0]+one_samp_thetas[1]*pars[1] + one_samp_thetas[2]*pars[2]
                    if loss < best_soln_loss:
                        best_soln_idx = x
                        best_soln_loss = loss
                
                data.append([dataset, pid, best_soln_idx])

consistency_df = pd.DataFrame(data, columns=['dataset', 'pid', 'best_soln_idx'])
consistency_df
# Out:
# HGSOC 13
# Melanoma 7
# HR-NB 30
# NSCLC 128
#       dataset       pid  best_soln_idx
# 0       HGSOC         7              0
# 1       HGSOC         7              0
# 2       HGSOC         7              0
# 3       HGSOC         7              0
# 4       HGSOC         7              0
# ...       ...       ...            ...
# 17795   NSCLC  CRUK0022              0
# 17796   NSCLC  CRUK0022              0
# 17797   NSCLC  CRUK0022              0
# 17798   NSCLC  CRUK0022              0
# 17799   NSCLC  CRUK0022              0
#
# [17800 rows x 3 columns]

# %%
import statistics

dataset_to_avg_concurrency = {d:[] for d in consistency_df['dataset'].unique()}
overall_avg_concurrency = []
for pid in consistency_df['pid'].unique():
    best_solutions = list(consistency_df[consistency_df['pid']==pid]['best_soln_idx'])
    mode = statistics.mode(best_solutions)
    # What percent of the boostrapped weights returns the same mode
    mode_count = best_solutions.count(mode)
    percent_mode = (mode_count / len(best_solutions)) * 100
    dataset = consistency_df[consistency_df['pid']==pid]['dataset'].unique().item()
    dataset_to_avg_concurrency[dataset].append(percent_mode)
    overall_avg_concurrency.append(percent_mode)
    
dataset_to_avg_concurrency = {k:sum(v)/len(v) for k,v in dataset_to_avg_concurrency.items()}
print(dataset_to_avg_concurrency)
print(sum(overall_avg_concurrency)/len(overall_avg_concurrency))
# Out:
# {'HGSOC': 100.0, 'Melanoma': 94.28571428571429, 'HR-NB': 94.92592592592592, 'NSCLC': 99.82539682539682}
# 98.80838323353294
