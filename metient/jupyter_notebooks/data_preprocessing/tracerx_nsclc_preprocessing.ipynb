# %% [markdown]
# ### Load paths

# %%
import pyreadr
import os
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

REPO_DIR = os.path.join(os.getcwd(), "../../")

TRACERX_DATA_DIR = os.path.join(REPO_DIR, "data/tracerx_nsclc/")
OUTPUT_DIR = os.path.join(REPO_DIR, "data/tracerx_nsclc/patient_data")
CONIPHER_DIR = os.path.join(REPO_DIR, "data/tracerx_nsclc/conipher_inputs")

# %% [markdown]
# ### Load sample overview information (from TRACERx publicly available data)

# %%
sample_info_df= pd.read_csv(os.path.join(TRACERX_DATA_DIR,"sample_overview_original.txt"), sep="\t")
print(sample_info_df['sampleType'].value_counts())
print(sample_info_df['sampleTypeDetail'].value_counts())
sample_info_df
# Out:
# primary       476
# metastasis    218
# Name: sampleType, dtype: int64
# primary            476
# LN                 148
# metachronousMet     67
# synchronousMet       3
# Name: sampleTypeDetail, dtype: int64
#     patient_id tumour_id             region  sampleType sampleTypeDetail
# 0     CRUK0010  CRUK0010  CRUK0010_SU_T1.R1     primary          primary
# 1     CRUK0010  CRUK0010  CRUK0010_SU_T1.R2     primary          primary
# 2     CRUK0010  CRUK0010   CRUK0010_SU_FLN1  metastasis               LN
# 3     CRUK0010  CRUK0010    CRUK0010_BR_LN1  metastasis  metachronousMet
# 4     CRUK0010  CRUK0010    CRUK0010_BR_LN2  metastasis  metachronousMet
# ..         ...       ...                ...         ...              ...
# 689   CRUK0872  CRUK0872  CRUK0872_SU_T1.R1     primary          primary
# 690   CRUK0872  CRUK0872  CRUK0872_SU_T1.R2     primary          primary
# 691   CRUK0872  CRUK0872  CRUK0872_SU_T1.R3     primary          primary
# 692   CRUK0872  CRUK0872  CRUK0872_SU_T1.R4     primary          primary
# 693   CRUK0872  CRUK0872   CRUK0872_SU_FLN1  metastasis               LN
#
# [694 rows x 5 columns]

# %% [markdown]
# ### Load purity and ploidy information (from TRACERx publicly available data)

# %%
purity_ploidy_df = pd.read_csv(os.path.join(TRACERX_DATA_DIR, "20220808_purityandploidy.txt"), sep="\t")
purity_ploidy_df
# Out:
#       Patient             Sample  final.purity  final.ploidy
# 0    CRUK0090  CRUK0090_SU_T1.R2          0.54          3.15
# 1    CRUK0090  CRUK0090_BP_T1.R1          0.74          3.25
# 2    CRUK0090  CRUK0090_BR_T1.R1          0.20          3.30
# 3    CRUK0090  CRUK0090_SU_T1.R1          0.58          3.20
# 4    CRUK0090  CRUK0090_BP_T2.R1          0.23          3.40
# ..        ...                ...           ...           ...
# 689  CRUK0810  CRUK0810_SU_T1.R4          0.49          3.85
# 690  CRUK0810  CRUK0810_SU_T1.R1          0.25          3.70
# 691  CRUK0810  CRUK0810_SU_T1.R8          0.20          3.95
# 692  CRUK0810  CRUK0810_SU_T1.R6          0.39          3.65
# 693  CRUK0810  CRUK0810_SU_T1.R5          0.51          3.75
#
# [694 rows x 4 columns]

# %% [markdown]
# ### Load all patient mutation data (from TRACERx publicly available data)

# %%
# NOTE: not including this rda file in the repo because its big, but it can be downloaded here: https://zenodo.org/records/7649257
patient_data_all = pyreadr.read_r(os.path.join('/data/morrisq/divyak/data/tracerx_nsclc_2023/mutTableAll.cloneInfo.20220726.rda'))
patient_data_all_df = patient_data_all['mutTableAll']
print("Patient data columns:\n ", patient_data_all_df.columns)
print(patient_data_all_df[:10]['RegionSum'])

patient_data_all_df = patient_data_all_df[['mutation_id', 'patient_id', 'Hugo_Symbol','exonic.func','NucleotideChange', 'RegionSum' , 'MajorCPN_SC', 'MinorCPN_SC', 'chr', 'start', 'stop', 'ref', 'var']]
unique_patients = patient_data_all_df['patient_id'].unique()
print("Number of unique patients:", len(unique_patients))
patient_data_all_df.to_csv("raw_tracerx_data.csv")
patient_data_all_df
# Out:
# Patient data columns:
#   Index(['mutation_id', 'patient_id', 'tumour_id', 'chr', 'start', 'stop', 'ref',
#        'var', 'Hugo_Symbol', 'func', 'exonic.func', 'NucleotideChange',
#        'AAChange', 'GL_VAF', 'GL_nAlt', 'GL_depth', 'ITHState', 'RegionSum',
#        'Is.present', 'PyCloneClonal_SC', 'PyCloneCluster_SC',
#        'cleanCluster_SC', 'PhyloCCF_SC', 'combTiming_SC', 'MutCPN_SC',
#        'MajorCPN_SC', 'MinorCPN_SC', 'DriverMut', 'treeClones',
#        'seedingClones', 'clonalClones', 'sharedClones', 'primaryClones',
#        'metClones'],
#       dtype='object')
# 0              BR_LN1:40/168;BR_LN2:64/276;BR_LN3:47/235;SU_FLN1:96/518;SU_T1.R1:236/317;SU_T1.R2:80/227
# 1               BR_LN1:14/106;BR_LN2:18/155;BR_LN3:18/138;SU_FLN1:12/102;SU_T1.R1:94/153;SU_T1.R2:27/175
# 2              BR_LN1:44/191;BR_LN2:55/233;BR_LN3:75/260;SU_FLN1:86/288;SU_T1.R1:148/245;SU_T1.R2:92/270
# 3             BR_LN1:71/525;BR_LN2:61/694;BR_LN3:60/675;SU_FLN1:57/485;SU_T1.R1:385/647;SU_T1.R2:103/654
# 4               BR_LN1:16/116;BR_LN2:21/141;BR_LN3:27/180;SU_FLN1:49/281;SU_T1.R1:76/152;SU_T1.R2:31/139
# 5            BR_LN1:55/456;BR_LN2:54/702;BR_LN3:84/653;SU_FLN1:131/863;SU_T1.R1:278/559;SU_T1.R2:152/626
# 6    BR_LN1:136/815;BR_LN2:190/1083;BR_LN3:222/1104;SU_FLN1:161/1095;SU_T1.R1:669/1375;SU_T1.R2:291/1096
# 7           BR_LN1:63/368;BR_LN2:86/542;BR_LN3:103/571;SU_FLN1:112/585;SU_T1.R1:312/677;SU_T1.R2:127/528
# 8              BR_LN1:39/333;BR_LN2:43/454;BR_LN3:65/486;SU_FLN1:41/435;SU_T1.R1:270/604;SU_T1.R2:66/431
# 9              BR_LN1:39/291;BR_LN2:45/420;BR_LN3:56/445;SU_FLN1:76/570;SU_T1.R1:225/534;SU_T1.R2:99/437
# Name: RegionSum, dtype: object
# Number of unique patients: 126
#                    mutation_id patient_id Hugo_Symbol        exonic.func  \
# 0        CRUK0010:3:47103798:G   CRUK0010       SETD2       stopgain SNV
# 1        CRUK0010:6:45459895:C   CRUK0010       RUNX2                NaN
# 2       CRUK0010:1:156105064:C   CRUK0010        LMNA     synonymous SNV
# 3        CRUK0010:6:25850091:C   CRUK0010     SLC17A3       stopgain SNV
# 4        CRUK0010:8:16001109:G   CRUK0010        MSR1  nonsynonymous SNV
# ...                        ...        ...         ...                ...
# 136310  CRUK0872:22:40080280:C   CRUK0872     CACNA1I                NaN
# 136311  CRUK0872:14:99872776:T   CRUK0872       SETD3                NaN
# 136312  CRUK0872:8:110131566:C   CRUK0872        TRHR       stopgain SNV
# 136313   CRUK0872:1:51032853:G   CRUK0872        FAF1  nonsynonymous SNV
# 136314  CRUK0872:20:24524120:G   CRUK0872     SYNDIG1     synonymous SNV
#
#        NucleotideChange  \
# 0              c.C6148T
# 1                   NaN
# 2               c.C561T
# 3               c.G979T
# 4               c.C991G
# ...                 ...
# 136310              NaN
# 136311              NaN
# 136312         c.C1079A
# 136313         c.C1164G
# 136314          c.G387A
#
#                                                                                          RegionSum  \
# 0        BR_LN1:40/168;BR_LN2:64/276;BR_LN3:47/235;SU_FLN1:96/518;SU_T1.R1:236/317;SU_T1.R2:80/227
# 1         BR_LN1:14/106;BR_LN2:18/155;BR_LN3:18/138;SU_FLN1:12/102;SU_T1.R1:94/153;SU_T1.R2:27/175
# 2        BR_LN1:44/191;BR_LN2:55/233;BR_LN3:75/260;SU_FLN1:86/288;SU_T1.R1:148/245;SU_T1.R2:92/270
# 3       BR_LN1:71/525;BR_LN2:61/694;BR_LN3:60/675;SU_FLN1:57/485;SU_T1.R1:385/647;SU_T1.R2:103/654
# 4         BR_LN1:16/116;BR_LN2:21/141;BR_LN3:27/180;SU_FLN1:49/281;SU_T1.R1:76/152;SU_T1.R2:31/139
# ...                                                                                            ...
# 136310     SU_FLN1:18/668;SU_LN1:1/446;SU_T1.R1:0/602;SU_T1.R2:0/501;SU_T1.R3:0/443;SU_T1.R4:0/463
# 136311     SU_FLN1:0/573;SU_LN1:0/518;SU_T1.R1:0/609;SU_T1.R2:0/625;SU_T1.R3:0/581;SU_T1.R4:13/510
# 136312     SU_FLN1:0/562;SU_LN1:3/616;SU_T1.R1:2/716;SU_T1.R2:0/763;SU_T1.R3:0/722;SU_T1.R4:16/650
# 136313     SU_FLN1:0/389;SU_LN1:0/394;SU_T1.R1:0/464;SU_T1.R2:0/484;SU_T1.R3:11/449;SU_T1.R4:0/428
# 136314   SU_FLN1:10/1295;SU_LN1:15/612;SU_T1.R1:0/745;SU_T1.R2:1/716;SU_T1.R3:0/740;SU_T1.R4:0/621
#
#                                                        MajorCPN_SC  \
# 0       SU_T1.R1:3;SU_T1.R2:2;SU_FLN1:2;BR_LN1:2;BR_LN2:2;BR_LN3:2
# 1       SU_T1.R1:2;SU_T1.R2:1;SU_FLN1:1;BR_LN1:1;BR_LN2:1;BR_LN3:1
# 2       SU_T1.R1:2;SU_T1.R2:2;SU_FLN1:3;BR_LN1:2;BR_LN2:2;BR_LN3:3
# 3       SU_T1.R1:2;SU_T1.R2:1;SU_FLN1:2;BR_LN1:1;BR_LN2:1;BR_LN3:1
# 4       SU_T1.R1:1;SU_T1.R2:1;SU_FLN1:1;BR_LN1:1;BR_LN2:1;BR_LN3:1
# ...                                                            ...
# 136310       SU_T1.R1:3;SU_T1.R2:3;SU_T1.R3:2;SU_T1.R4:3;SU_FLN1:3
# 136311       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:2
# 136312       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:2
# 136313       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:2
# 136314                                                         NaN
#
#                                                        MinorCPN_SC    chr  \
# 0       SU_T1.R1:0;SU_T1.R2:0;SU_FLN1:0;BR_LN1:0;BR_LN2:0;BR_LN3:0   chr3
# 1       SU_T1.R1:0;SU_T1.R2:1;SU_FLN1:1;BR_LN1:1;BR_LN2:1;BR_LN3:1   chr6
# 2       SU_T1.R1:0;SU_T1.R2:0;SU_FLN1:0;BR_LN1:0;BR_LN2:0;BR_LN3:0   chr1
# 3       SU_T1.R1:0;SU_T1.R2:1;SU_FLN1:1;BR_LN1:1;BR_LN2:1;BR_LN3:1   chr6
# 4       SU_T1.R1:0;SU_T1.R2:0;SU_FLN1:0;BR_LN1:0;BR_LN2:0;BR_LN3:0   chr8
# ...                                                            ...    ...
# 136310       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:3;SU_FLN1:2  chr22
# 136311       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:2  chr14
# 136312       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:2   chr8
# 136313       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:1   chr1
# 136314                                                         NaN  chr20
#
#             start       stop ref var
# 0        47103798   47103798   G   A
# 1        45459895   45459895   C   G
# 2       156105064  156105064   C   T
# 3        25850091   25850091   C   A
# 4        16001109   16001109   G   C
# ...           ...        ...  ..  ..
# 136310   40080280   40080280   C   T
# 136311   99872776   99872776   T   C
# 136312  110131566  110131566   C   A
# 136313   51032853   51032853   G   C
# 136314   24524120   24524120   G   A
#
# [136315 rows x 13 columns]

# %%
print(purity_ploidy_df[purity_ploidy_df['Patient']=='CRUK0762'])
cruk_0762 = patient_data_all_df[patient_data_all_df['patient_id']=="CRUK0762"]
cruk_0762[cruk_0762['Hugo_Symbol']=='FAT2']
# Out:
#       Patient             Sample  final.purity  final.ploidy
# 586  CRUK0762    CRUK0762_SU_LN1          0.14          3.60
# 587  CRUK0762   CRUK0762_SU_FLN1          0.23          3.20
# 588  CRUK0762  CRUK0762_SU_T1.R1          0.55          3.10
# 589  CRUK0762  CRUK0762_SU_T1.R2          0.49          3.45
# 590  CRUK0762   CRUK0762_SU_FLN2          0.13          3.55
# 591  CRUK0762    CRUK0762_SU_LN2          0.16          3.10
# 592  CRUK0762   CRUK0762_SU_FLN3          0.16          3.40
#                    mutation_id patient_id Hugo_Symbol        exonic.func  \
# 125708  CRUK0762:5:150911604:G   CRUK0762        FAT2                NaN
# 126337  CRUK0762:5:150924665:C   CRUK0762        FAT2  nonsynonymous SNV
#
#        NucleotideChange  \
# 125708              NaN
# 126337         c.G6023A
#
#                                                                                                       RegionSum  \
# 125708  SU_FLN1:28/77;SU_FLN2:36/117;SU_FLN3:25/91;SU_LN1:43/143;SU_LN2:52/182;SU_T1.R1:140/240;SU_T1.R2:97/200
# 126337      SU_FLN1:0/507;SU_FLN2:0/567;SU_FLN3:18/549;SU_LN1:0/703;SU_LN2:9/795;SU_T1.R1:0/1023;SU_T1.R2:0/854
#
#                                                                   MajorCPN_SC  \
# 125708  SU_LN1:7;SU_LN2:7;SU_T1.R1:6;SU_T1.R2:5;SU_FLN3:6;SU_FLN1:5;SU_FLN2:6
# 126337  SU_LN1:7;SU_LN2:7;SU_T1.R1:6;SU_T1.R2:5;SU_FLN3:6;SU_FLN1:5;SU_FLN2:6
#
#                                                                   MinorCPN_SC  \
# 125708  SU_LN1:3;SU_LN2:2;SU_T1.R1:2;SU_T1.R2:2;SU_FLN3:2;SU_FLN1:2;SU_FLN2:2
# 126337  SU_LN1:3;SU_LN2:2;SU_T1.R1:2;SU_T1.R2:2;SU_FLN3:2;SU_FLN1:2;SU_FLN2:2
#
#          chr      start       stop ref var
# 125708  chr5  150911604  150911604   G   A
# 126337  chr5  150924665  150924665   C   T

# %% [markdown]
# ### Prep data for input into tree building methods (CONIPHER, PairTree, Orchard) and migration history methods (Metient and MACHINA)

# %%
'''
For Matient/MACHINA, need a tsv with minimum columns: ['#sample_index', 'sample_label', 'anatomical_site_index',
'anatomical_site_label', 'character_index', 'character_label','ref', 'var']

For CONIPHER, need a tsv with minimum columns: ['CASE_ID', 'SAMPLE', 'CHR', 'POS', 'REF', 'ALT', 
'REF_COUNT', 'VAR_COUNT', 'DEPTH', 'COPY_NUMBER_A', 'COPY_NUMBER_B', 'ACF', 'PLOIDY']
'''

import re
from metient.util import pairtree_data_extraction_util as pt_util
import numpy as np

def remove_region_suffix(input_string):
    pattern = r'\.R\d+$'
    modified_string = re.sub(pattern, '', input_string)
    return modified_string

def generate_sample_and_mut_info(row):
    '''
    Given a row in the patient_data_all_df dataframe, yields three objects:
        (1) the first for MACHINA/Matient input, 
        with columns: [sample_name, mutation_name, sample_type_detailed, ref_count,var_count, sample_type, purity, ploidy, major_cn, minor_cn]
        e.g. ["SETD3:2:14:99872776:T", "BR_LN1", "LN_SU_FLN1", 43,270, "metastasis", 0.54, 3.19]
        
        (2) the second for CONIPHER input,
        with columns: [patient_id, sample_name, chr, pos, ref, alt, ref_count, var_count, depth,
        copy_number_a, copy_number_b, purity, ploidy]
        
    '''
    mut_id = ":".join(row['mutation_id'].split(":")[1:])
    mut_name = f"{row['Hugo_Symbol']}:{mut_id}"
        
    # RegionSum  column values need to be split by sample 
    # (e.g. "SU_FLN1:0/562;SU_LN1:3/616")    
    sample_name_to_mut_counts = {x.split(":")[0]:x.split(":")[1] for x in row['RegionSum'].split(";")}
    # Don't include mutations without copy number information
    if isinstance(row['MajorCPN_SC'], float) or isinstance(row['MinorCPN_SC'], float):
        yield None
        return
    sample_name_to_major_cn = {x.split(":")[0]:x.split(":")[1] for x in row['MajorCPN_SC'].split(";")}
    sample_name_to_minor_cn = {x.split(":")[0]:x.split(":")[1] for x in row['MinorCPN_SC'].split(";")}

    for sample_name in sample_name_to_mut_counts.keys():
        mut_count = sample_name_to_mut_counts[sample_name]
        # Lookup sample info in sample_overview dataframe
        patient_sample_name = row['patient_id']+"_"+sample_name
        sample_info = sample_info_df[sample_info_df['region']==patient_sample_name]
        # Low purity samples
        if len(sample_info) == 0:
            yield None
            continue
        
        sample_type = sample_info['sampleType'].item()
        sample_type_detailed = sample_info['sampleTypeDetail'].item()+"_"+sample_name
        
        # Lookup purity and ploidy info
        purity_ploidy_info = purity_ploidy_df[purity_ploidy_df["Sample"]==patient_sample_name]
        if len(purity_ploidy_info) == 0:
            yield None
            continue
        purity = purity_ploidy_info["final.purity"].item()
        ploidy =  purity_ploidy_info["final.ploidy"].item()
        
        if purity <= 0.1:
            yield None
            continue
            
        # Get ref and var counts
        var = int(mut_count.split("/")[0])
        total = int(mut_count.split("/")[1])
        ref = total - var
        
        # According to TRACERx: muts w/o copy number calls in this dataset are muts that either do not overlap with 
        # copy number  values – (e.g. on sex chromosomes or mutations from regions with low purity), and therefore 
        # not included in clustering and phylogenetic tree building.  
        if (sample_name not in sample_name_to_major_cn) or (sample_name not in sample_name_to_minor_cn):
            yield None
            continue
        cn_a_count = sample_name_to_major_cn[sample_name]
        cn_b_count = sample_name_to_minor_cn[sample_name]

        # remove_region_suffix(sample_type_detailed) means samples from multiple regions
        # of the same primary get mapped to the same anatomical site label, e.g. primary.T1.R1 
        # and primary.T1.R2 get mapped to primary.T1. This means they get pooled together below as well.
        mig_hist_input = [mut_name, patient_sample_name, remove_region_suffix(sample_type_detailed), 
                          ref, var,  sample_type_detailed, sample_type, purity, ploidy, cn_a_count, cn_b_count]
            
        conipher_input = [ row['patient_id'], patient_sample_name, row['chr'].replace('chr', ''), row['start'], 
                          row['ref'], row['var'], ref, var, total,cn_a_count, cn_b_count, purity, ploidy ]
        
        yield mig_hist_input, conipher_input

        
def format_mig_hist_df(data):
    sample_mut_df = pd.DataFrame(data)
    sample_mut_df.columns = ["character_label", "sample_label", "anatomical_site_label", "ref",
                            "var", "original_anatomical_site_label", "sample_type", "purity", "ploidy", "major_cn", "minor_cn"]
    
    # Add indices for mutations, samples and anatomical sites as needed for input format
    sample_mut_df['sample_index'] = sample_mut_df.apply(lambda row: list(sample_mut_df['sample_label'].unique()).index(row["sample_label"]), axis=1)    
    sample_mut_df['character_index'] = sample_mut_df.apply(lambda row: list(sample_mut_df['character_label'].unique()).index(row["character_label"]), axis=1)
    sample_mut_df['anatomical_site_index'] = sample_mut_df.apply(lambda row: list(sample_mut_df['anatomical_site_label'].unique()).index(row["anatomical_site_label"]), axis=1)
    
    sample_mut_df = sample_mut_df[['sample_index', "sample_label", "anatomical_site_index", "anatomical_site_label", 
                                 'character_index', "character_label", "ref","var", "original_anatomical_site_label", 
                                   "sample_type","purity", "ploidy", "major_cn", "minor_cn"]]

    return sample_mut_df

def format_conipher_df(data):
    sample_mut_df = pd.DataFrame(data)
    sample_mut_df.columns = ['CASE_ID', 'SAMPLE', 'CHR', 'POS', 'REF', 'ALT', 'REF_COUNT', 'VAR_COUNT', 
                             'DEPTH', 'COPY_NUMBER_A', 'COPY_NUMBER_B', 'ACF', 'PLOIDY']
    sample_mut_df = sample_mut_df.dropna()
    return sample_mut_df

def write_pyclone_dfs(data, patient_id, output_dir):
    '''
    Return a dictionary of dfs, one for each sample, each with columns: 
        [mutation_id, ref_counts, var_counts, normal_cn, minor_cn, major_cn]
    '''
    patient_pyclone_dir = os.path.join(output_dir, "pyclone_analysis", patient_id)
    if not os.path.exists(patient_pyclone_dir):
        os.makedirs(patient_pyclone_dir)
    
    mig_hist_df = format_mig_hist_df(data)
    for sample in mig_hist_df['sample_label'].unique():
        sample_subset = mig_hist_df[mig_hist_df['sample_label']==sample]
        sample_subset['normal_cn'] = 2
        sample_subset.rename(columns={'character_label': 'mutation_id', 'ref': 'ref_counts', 'var': 'var_counts'}, inplace=True)
        sample_subset = sample_subset[["mutation_id", "ref_counts","var_counts","normal_cn","minor_cn","major_cn"]]
        sample_subset['major_cn'] = sample_subset['major_cn'].astype(int)
        sample_subset['minor_cn'] = sample_subset['minor_cn'].astype(int)
        sample_subset = sample_subset[sample_subset["major_cn"]!=0]
        sample_subset.to_csv(os.path.join(patient_pyclone_dir, f"{patient_id}_{sample}.tsv"), sep="\t")        
    
    # Setup PyClone command to run 
    cmd = [f"bsub -n 8 -W 100:00 -R rusage[mem=8] -o output_{patient_id}.log -e error_{patient_id}.log", "PyClone run_analysis_pipeline", "--in_files"]
    
    for sample in mig_hist_df['sample_label'].unique():
        cmd.append(os.path.join(patient_pyclone_dir,  f"{patient_id}_{sample}.tsv"))
    cmd += ["--working_dir", patient_pyclone_dir, "--tumour_contents"]
    
    # Add tumour cell proportions for each sample
    for sample in mig_hist_df['sample_label'].unique():
        purity = float(purity_ploidy_df[(purity_ploidy_df['Patient']==patient_id) &(purity_ploidy_df['Sample']==sample)]['final.purity'].item())
        cmd.append(str(purity))
    # Add sample names
    cmd.append("--samples")
    for sample in mig_hist_df['sample_label'].unique():
        cmd.append(sample)
    cmd += ["--max_clusters", "30", "--num_iters", "10000", "--burnin", "5000"]
    return " ".join(cmd)

# %% [markdown]
# ### Write all tsvs/json/ssm files

# %%
pyclone_cmds = []
for patient_id in unique_patients:
    print(patient_id)
    output_rows = []
    subset = patient_data_all_df[patient_data_all_df['patient_id'] == patient_id]
    print(len(subset))
    
    mig_hist_data = []
    conipher_data = []
    for _, row in subset.iterrows(): # each row is one mutation
        generator = generate_sample_and_mut_info(row)
        for data in generator:
            if data == None:
                continue
            mig_hist_input, conipher_input = data
            mig_hist_data.append(mig_hist_input)
            conipher_data.append(conipher_input)
    mig_hist_df = format_mig_hist_df(mig_hist_data)
    conipher_df = format_conipher_df(conipher_data)
    # Write migration history inputs
    mig_hist_df.to_csv(os.path.join(OUTPUT_DIR, f"{patient_id}_SNVs.tsv"), sep="\t")
    # Write conipher inputs
    conipher_df.to_csv(os.path.join(CONIPHER_DIR, f"{patient_id}_conipher_SNVs.tsv"), sep="\t")
    # Write pairtree inputs
    pt_util.write_pairtree_inputs(mig_hist_df, patient_id, OUTPUT_DIR)
    # Write pyclone inputs
    pyclone_cmd = write_pyclone_dfs(mig_hist_data, patient_id, os.path.join(OUTPUT_DIR, "../"))
    pyclone_cmds.append(pyclone_cmd)
# Out:
# CRUK0010
# 242
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0013
# 246
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0284
# 1331
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0361
# 1484
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0497
# 1654
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0452
# 525
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0472
# 988
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0484
# 1333
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0418
# 11308
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0721
# 2856
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0702
# 646
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0794
# ...
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0476
# 612
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0528
# 1075
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0666
# 603
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# CRUK0872
# 474
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(
# /scratch/lsftmp/6206206.tmpdir/ipykernel_9314/1654277213.py:129: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sample_subset['normal_cn'] = 2
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pandas/core/frame.py:4438: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().rename(

# %%
for cmd in pyclone_cmds:
    print(cmd)

# %%
# Assemble conipher clustering and tree building commands
with open(os.path.join(TRACERX_DATA_DIR, 'conipher_outputs', 'TreeBuilding', "run_all_clustering_tree_building_test.sh"), "w") as f:
    f.write("#!/bin/bash")
    f.write("\n")
    for patient_id in unique_patients:
        f.write(f"bsub -J \"conipher_job_$p\" -n 8 -W 100:00 -o output%I.log -e error_%I.log ./run_single_clustering_tree_building.sh ../../conipher_inputs/ /data/morrisq/divyak/projects/CONIPHER-wrapper/ ./ {patient_id}_conipher_SNVs")
        f.write("\n")

# %% [markdown]
# ### Above is all on individual mutations. **After clustering mutations using PyClone**, we have to prep clustered inputs for Metient

# %%
tracerx_patient_info = pyreadr.read_r(os.path.join('/data/morrisq/divyak/data/tracerx_nsclc_2023/20221109_TRACERx421_all_patient_df.rds'))[None]
tracerx_patient_info
# Out:
#       cruk_id tumour_id_muttable_cruk              tumour_id_per_patient  age  \
# 0    CRUK0034                CRUK0034                           CRUK0034   68
# 1    CRUK0150                CRUK0150                           CRUK0150   81
# 2    CRUK0159                CRUK0159                           CRUK0159   60
# 3    CRUK0090                CRUK0090                           CRUK0090   65
# 4    CRUK0045                CRUK0045                           CRUK0045   85
# ..        ...                     ...                                ...  ...
# 416  CRUK0872                CRUK0872                           CRUK0872   66
# 417  CRUK0817                CRUK0817                           CRUK0817   64
# 418  CRUK0864                CRUK0864                           CRUK0864   78
# 419  CRUK0810                CRUK0810                           CRUK0810   59
# 420  CRUK0881        CRUK0881_Tumour1  CRUK0881_Tumour1;CRUK0881_Tumour2   84
#
#         sex       ethnicity  cigs_perday  years_smoking  packyears  \
# 0    Female    White- Irish       20.000             35     35.000
# 1      Male  White- British       44.500             49    109.025
# 2      Male  White- British       20.000             38     38.000
# 3      Male  White- British       10.000             35     17.500
# 4      Male  White- British       10.000             25     12.500
# ..      ...             ...          ...            ...        ...
# 416    Male  White- British       20.000             54     54.000
# 417    Male  White- British       12.000             27     16.200
# 418  Female  White- British       10.000             30     15.000
# 419  Female  White- British       10.000             44     22.000
# 420    Male  White- British       20.000             70     70.000
#
#     smoking_status_merged  is.family.lung  ECOG_PS pathologyTNM  \
# 0               Ex-Smoker            True    0.000           IB
# 1               Ex-Smoker           False    0.000          IIB
# 2                  Smoker           False    0.000           IB
# 3               Ex-Smoker           False    1.000          IIA
# 4               Ex-Smoker           False    1.000           IB
# ..                    ...             ...      ...          ...
# 416             Ex-Smoker           False    1.000         IIIA
# 417             Ex-Smoker           False    1.000          IIB
# 418             Ex-Smoker            True    0.000          IIA
# 419                Smoker           False    1.000         IIIA
# 420                Smoker           False    1.000          IIA
#
#     pT_stage_per_patient  pN_stage_per_patient LVI_per_patient PL_per_patient  \
# 0                     2a                     0             Yes             No
# 1                      3                     0             Yes             No
# 2                     2a                     0             Yes            Yes
# 3                     2a                     1             Yes            Yes
# 4                     2a                     0             Yes            Yes
# ..                   ...                   ...             ...            ...
# 416                   1b                     2              No             No
# 417                    3                     0              No            Yes
# 418                   1b                     1              No             No
# 419                   2a                     2             Yes            Yes
# 420                   2b                     0             Yes            Yes
#
#     margin_status_per_patient  size_pathology_per_patient  \
# 0                          R0                      40.000
# 1                          R0                      75.000
# 2                          R0                      36.000
# 3                          R0                      35.000
# 4                          R0                      48.000
# ..                        ...                         ...
# 416                        R0                      25.000
# 417                        R0                     130.000
# 418                        R0                      27.000
# 419                        R0                      35.000
# 420                        R0                      62.000
#
#                          Surgery_type        histology_lesion1  \
# 0                           Lobectomy  Invasive adenocarcinoma
# 1                           Lobectomy                    LCNEC
# 2                           Lobectomy  Invasive adenocarcinoma
# 3    Segmentectomy or wedge resection  Squamous cell carcinoma
# 4                           Lobectomy  Invasive adenocarcinoma
# ..                                ...                      ...
# 416                         Lobectomy  Squamous cell carcinoma
# 417                         Lobectomy  Invasive adenocarcinoma
# 418                         Lobectomy  Invasive adenocarcinoma
# 419                         Lobectomy  Invasive adenocarcinoma
# 420                         Lobectomy  Invasive adenocarcinoma
#
#     histology_lesion1_merged  lesion1_sampled          histology_lesion2  \
# 0    Invasive adenocarcinoma             True                        NaN
# 1                      LCNEC             True                        NaN
# 2    Invasive adenocarcinoma             True                        NaN
# 3    Squamous cell carcinoma             True                        NaN
# 4    Invasive adenocarcinoma             True                        NaN
# ..                       ...              ...                        ...
# 416  Squamous cell carcinoma             True                        NaN
# 417  Invasive adenocarcinoma             True                        NaN
# 418  Invasive adenocarcinoma             True                        NaN
# 419  Invasive adenocarcinoma             True                        NaN
# 420  Invasive adenocarcinoma             True  Lesion1: collision tumour
#
#     lesion2_sampled histology_multi_full  \
# 0               NaN                 LUAD
# 1               NaN                Other
# 2               NaN                 LUAD
# 3               NaN                 LUSC
# 4               NaN                 LUAD
# ..              ...                  ...
# 416             NaN                 LUSC
# 417             NaN                 LUAD
# 418             NaN                 LUAD
# 419             NaN                 LUAD
# 420           False               LUADx2
#
#     histology_multi_full_genomically.confirmed LUAD_pred_subtype  \
# 0                                         LUAD            acinar
# 1                                        Other               NaN
# 2                                         LUAD            acinar
# 3                                         LUSC               NaN
# 4                                         LUAD         papillary
# ..                                         ...               ...
# 416                                       LUSC               NaN
# 417                                       LUAD             solid
# 418                                       LUAD             solid
# 419                                       LUAD            acinar
# 420                                     LUADx2            acinar
#
#     adjuvant_treatment_YN adjuvant_treatment_given num_cycle_na.added  \
# 0             No adjuvant                      NaN                  0
# 1             No adjuvant                      NaN                  0
# 2                Adjuvant           Platinum chemo                  4
# 3                Adjuvant           Platinum chemo                  3
# 4             No adjuvant                      NaN                  0
# ..                    ...                      ...                ...
# 416           No adjuvant                      NaN                  0
# 417              Adjuvant             Radiotherapy                  0
# 418              Adjuvant           Platinum chemo                  4
# 419              Adjuvant           Platinum chemo                  2
# 420           No adjuvant                      NaN                  0
#
#                                CHMPlatDgName_cleaned  \
# 0                                                NaN
# 1                                                NaN
# 2            Cisplatin;Cisplatin;Cisplatin;Cisplatin
# 3                      Cisplatin;Cisplatin;Cisplatin
# 4                                                NaN
# ..                                               ...
# 416                                              NaN
# 417                                              NaN
# 418  Carboplatin;Carboplatin;Carboplatin;Carboplatin
# 419                            Cisplatin;Carboplatin
# 420                                              NaN
#
#                                 CHMOthDgName_cleaned  AdjRadStartTime_manual  \
# 0                                                NaN                     NaN
# 1                                                NaN                     NaN
# 2    Vinorelbine;Vinorelbine;Vinorelbine;Vinorelbine                     NaN
# 3                Vinorelbine;Vinorelbine;Vinorelbine                     NaN
# 4                                                NaN                     NaN
# ..                                               ...                     ...
# 416                                              NaN                     NaN
# 417                                              NaN                  64.000
# 418  Vinorelbine;Vinorelbine;Vinorelbine;Vinorelbine                     NaN
# 419                          Vinorelbine;Vinorelbine                     NaN
# 420                                              NaN                     NaN
#
#      AdjRadEndTime_manual  Recurrence_time_use newPrim_time_use  \
# 0                     NaN                  NaN              NaN
# 1                     NaN                  NaN              NaN
# 2                     NaN                  NaN             1935
# 3                     NaN            1,143.000              NaN
# 4                     NaN              917.000              NaN
# ..                    ...                  ...              ...
# 416                   NaN              883.000              NaN
# 417                91.000              203.000              NaN
# 418                   NaN                  NaN              NaN
# 419                   NaN              197.000              NaN
# 420                   NaN              748.000              NaN
#
#     first_dfs_any_event_rec.or.new.primary first_event_during_followup  \
# 0                                      NaN                         NaN
# 1                                      NaN                       Death
# 2                              new_primary                 new_primary
# 3                               recurrence                  recurrence
# 4                               recurrence                  recurrence
# ..                                     ...                         ...
# 416                             recurrence                  recurrence
# 417                             recurrence                  recurrence
# 418                                    NaN                         NaN
# 419                             recurrence                  recurrence
# 420                             recurrence                  recurrence
#
#      cens_os  os_time  cens_dfs  dfs_time  cens_dfs_any_event  \
# 0          0     1849         0      1849                   0
# 1          1     1362         1      1362                   1
# 2          1     2224         1      2224                   1
# 3          0     2365         1      1143                   1
# 4          1      986         1       917                   1
# ..       ...      ...       ...       ...                 ...
# 416        1      893         1       883                   1
# 417        1      453         1       203                   1
# 418        0     1434         0      1434                   0
# 419        1      493         1       197                   1
# 420        1      758         1       748                   1
#
#      dfs_time_any_event  cens_lung_event  lung_event_time  \
# 0                  1849                0             1849
# 1                  1362                0             1362
# 2                  1935                0             2224
# 3                  1143                1             1143
# 4                   917                1              917
# ..                  ...              ...              ...
# 416                 883                1              883
# 417                 203                1              203
# 418                1434                0             1434
# 419                 197                1              197
# 420                 748                1              748
#
#              Relapse_cat Relapse_cat_new  tx100
# 0                    NaN          No rec   True
# 1                    NaN          No rec  False
# 2    Second primary lung          No rec  False
# 3          Intrathoracic   Intrathoracic   True
# 4          Intrathoracic   Intrathoracic   True
# ..                   ...             ...    ...
# 416        Intra & Extra   Intra & Extra  False
# 417        Intrathoracic   Intrathoracic  False
# 418                  NaN          No rec  False
# 419        Intra & Extra   Intra & Extra  False
# 420        Intrathoracic   Intrathoracic  False
#
# [421 rows x 50 columns]

# %% [markdown]
# #### Take PyClone clusters and create pooled tsvs

# %%
import numpy as np
import os
from metient.util import pairtree_data_extraction_util as pt_util
from metient.util import data_extraction_util as dutil
import csv
CONIPHER_CLUSTERING_DIR = os.path.join(TRACERX_DATA_DIR, 'conipher_outputs', 'TreeBuilding')

def is_diploid(patient, character_label):
    # chr23 = X, chr24 = Y
    chrom = int(character_label.split(":")[1])
    if chrom != 23 and chrom != 24:
        return True
    sex = tracerx_patient_info[tracerx_patient_info['cruk_id']==patient]['sex'].item()
    if sex == 'Female':
        return True
    return False

final_cols = ['anatomical_site_index','anatomical_site_label', 'cluster_index', 'character_index','character_label', 'ref', 'var', 'var_read_prob', 'site_category', 'sample_label','original_anatomical_site_label']

for patient_id in ["CRUK0762"]:
    # Load conipher pyclone clusters
    clusters_tsv_fn = os.path.join(CONIPHER_CLUSTERING_DIR, f"{patient_id}_conipher_SNVstreeTable_cleaned.tsv")
    pyclone_df = pd.read_csv(clusters_tsv_fn, delimiter="\t")
    df = pd.read_csv(os.path.join(OUTPUT_DIR, f"{patient_id}_SNVs.tsv"), delimiter="\t", index_col=0)
    mut_idx_to_cluster_id = dict()
    muts_no_cluster = set()
    
    # 1. Get mapping between mutation names and PyClone cluster ids
    for _, row in df.iterrows():
        mut_items = row['character_label'].split(":")
        cluster_id = pyclone_df[(pyclone_df['CHR']==int(mut_items[1]))&(pyclone_df['POS']==int(mut_items[2]))&(pyclone_df['REF']==mut_items[3])]['treeCLUSTER'].unique()
        assert(len(cluster_id) <= 1)
        if len(cluster_id) == 1:
            cluster_id = int(cluster_id.item())
            mut_idx_to_cluster_id[int(row['character_index'])] = cluster_id
        else:
            muts_no_cluster.add(int(row['character_index']))
    print("Mutations without a pyclone cluster", len(set(muts_no_cluster)))
    df = df[~df['character_index'].isin(muts_no_cluster)]
    for val in list(df['purity']):
        assert(val>0.1)
        
    df['diploid'] = df.apply(lambda row: is_diploid(patient_id, row['character_label']), axis=1)
    df['var_read_prob'] = df.apply(lambda row: dutil.calc_var_read_prob(row['major_cn'], row['minor_cn'], row['purity'], diploid=row['diploid']), axis=1)

    df['site_category'] = df.apply(lambda row: 'primary' if 'primary' in row['anatomical_site_label'] else 'metastasis', axis=1)
    # If there is not a primary and metastasis sample with >10% purity, don't use this patient
    if (set(df['site_category'])!=set(['primary', 'metastasis'])):
        print("Patient does not have high purity primary and met", patient_id)
        continue
    
    df['cluster_index'] = df.apply(lambda row: int(mut_idx_to_cluster_id[row['character_index']]), axis=1)
    df['character_label'] = df.apply(lambda row: row['character_label'].split(":")[0], axis=1)
    df = df[final_cols]
    output_fn = os.path.join(OUTPUT_DIR,"conipher_pyclone_clustered", f"{patient_id}_SNVs.tsv")
    # TODO: CHANGE BACK
    #output_fn = os.path.join(TRACERX_DATA_DIR,"CRUK0762_no_cna_testing", f"{patient_id}_SNVs.tsv")
    with open(output_fn, mode='w', newline='', encoding='utf-8') as file:
        writer = csv.writer(file, delimiter='\t')
        writer.writerow(df.columns)
        for _, row in df.iterrows():
            writer.writerow(row)
# Out:
# Mutations without a pyclone cluster 51
#       sample_index       sample_label  anatomical_site_index  \
# 388              3    CRUK0762_SU_LN1                      3
# 389              4    CRUK0762_SU_LN2                      4
# 390              5  CRUK0762_SU_T1.R1                      5
# 399              0   CRUK0762_SU_FLN1                      0
# 400              1   CRUK0762_SU_FLN2                      1
# ...            ...                ...                    ...
# 4313             1   CRUK0762_SU_FLN2                      1
# 4314             2   CRUK0762_SU_FLN3                      2
# 4315             3    CRUK0762_SU_LN1                      3
# 4316             4    CRUK0762_SU_LN2                      4
# 4317             5  CRUK0762_SU_T1.R1                      5
#
#      anatomical_site_label  character_index     character_label  ref  var  \
# 388              LN_SU_LN1               55  CENPB:20:3765957:C  188   16
# 389              LN_SU_LN2               55  CENPB:20:3765957:C  218   15
# 390          primary_SU_T1               55  CENPB:20:3765957:C  152   80
# 399             LN_SU_FLN1               57  CSMD2:1:34002668:G  118   21
# 400             LN_SU_FLN2               57  CSMD2:1:34002668:G  213   16
# ...                    ...              ...                 ...  ...  ...
# 4313            LN_SU_FLN2              616  CYR61:1:86048552:C  438    0
# 4314            LN_SU_FLN3              616  CYR61:1:86048552:C  431    0
# 4315             LN_SU_LN1              616  CYR61:1:86048552:C  526    0
# 4316             LN_SU_LN2              616  CYR61:1:86048552:C  608    0
# 4317         primary_SU_T1              616  CYR61:1:86048552:C  471   11
#
#      original_anatomical_site_label sample_type  purity  ploidy  major_cn  \
# 388                       LN_SU_LN1  metastasis   0.140   3.600         1
# 389                       LN_SU_LN2  metastasis   0.160   3.100         1
# 390                primary_SU_T1.R1     primary   0.550   3.100         1
# 399                      LN_SU_FLN1  metastasis   0.230   3.200         1
# 400                      LN_SU_FLN2  metastasis   0.130   3.550         1
# ...                             ...         ...     ...     ...       ...
# 4313                     LN_SU_FLN2  metastasis   0.130   3.550         1
# 4314                     LN_SU_FLN3  metastasis   0.160   3.400         1
# 4315                      LN_SU_LN1  metastasis   0.140   3.600         1
# 4316                      LN_SU_LN2  metastasis   0.160   3.100         1
# 4317               primary_SU_T1.R1     primary   0.550   3.100         1
#
#       minor_cn  diploid  var_read_prob
# 388          1     True          0.500
# 389          1     True          0.500
# 390          1     True          0.500
# 399          1     True          0.500
# 400          1     True          0.500
# ...        ...      ...            ...
# 4313         1     True          0.500
# 4314         1     True          0.500
# 4315         1     True          0.500
# 4316         1     True          0.500
# 4317         1     True          0.500
#
# [499 rows x 16 columns]

# %%
for patient in unique_patients:
    path = os.path.join(OUTPUT_DIR,"conipher_pyclone_clustered", f"{patient}_SNVs.tsv")
    if os.path.exists(path):
        df = pd.read_csv(path, sep="\t", index_col=False)
        if (set(df['site_category'])!=set(['primary', 'metastasis'])):
            print(patient)
