# %% [markdown]
# ### Generate a fake really large tree

# %%
import pandas as pd

NUM_NODES = 300
NUM_SITES = 4
NAME = "300nodes_4sites_simple"

class TreeNode:
    def __init__(self, val=0, left=None, right=None):
        self.val = val
        self.left = left
        self.right = right

def create_binary_tree(n):
    if n <= 0:
        return None, []
    
    nodes = [TreeNode(i) for i in range(0,n)]
    edges = []
    
    for i in range(n):
        left_index = 2 * i + 1
        right_index = 2 * i + 2
        if left_index < n:
            nodes[i].left = nodes[left_index]
            edges.append((nodes[i].val, nodes[left_index].val))
        if right_index < n:
            nodes[i].right = nodes[right_index]
            edges.append((nodes[i].val, nodes[right_index].val))
    
    return nodes[0], edges

def find_leaf_nodes(root):
    if not root:
        return []
    
    leaves = []
    stack = [root]
    
    while stack:
        node = stack.pop()
        if not node.left and not node.right:
            leaves.append(node.val)
        if node.right:
            stack.append(node.right)
        if node.left:
            stack.append(node.left)
    
    return leaves

def is_descendant(root, x_val, target_val):
    def find_node(node, val):
        if not node:
            return None
        if node.val == val:
            return node
        left_result = find_node(node.left, val)
        return left_result if left_result else find_node(node.right, val)

    def check_descendant(node, target_val):
        if not node:
            return False
        if node.val == target_val:
            return True
        return check_descendant(node.left, target_val) or check_descendant(node.right, target_val)

    x_node = find_node(root, x_val)
    if not x_node:
        return False
    return check_descendant(x_node, target_val)

# Create a binary tree with 100 nodes
root, edges = create_binary_tree(NUM_NODES)
with open(f'outputs/{NAME}.txt', 'w') as f:
    for edge in edges:
        f.write(f"{edge[0]} {edge[1]}")
        f.write("\n")

# Find all leaf nodes
leaf_nodes = find_leaf_nodes(root)

cols = ['anatomical_site_index','anatomical_site_label','cluster_index','cluster_label','present','site_category','num_mutations']

data = []


sites = ['primary'] + [f'met{x}' for x in range(1,NUM_SITES)]

site_to_subtree_roots = {"primary":[3],"met1":[4], "met2":[6,12,49],  "met3":[23,50]}

print(sites)
for node in range(0,NUM_NODES):
    for i,site in enumerate(sites):
        
        present = 0
        subtree_roots = site_to_subtree_roots[site]
        for subtree_root in subtree_roots:
            if node in leaf_nodes and is_descendant(root, subtree_root, node): 
                present = 1
        
        site_cat = 'primary' if site == 'primary' else 'metastasis'
        data.append([i, site, node, str(node), present, site_cat, 1])

df = pd.DataFrame(data, columns=cols)
df.to_csv(f"ouputs/{NAME}.tsv", sep="\t", index=False)
df
# Out:
# ['primary', 'met1', 'met2', 'met3']
#       anatomical_site_index anatomical_site_label  cluster_index  \
# 0                         0               primary              0
# 1                         1                  met1              0
# 2                         2                  met2              0
# 3                         3                  met3              0
# 4                         0               primary              1
# ...                     ...                   ...            ...
# 1195                      3                  met3            298
# 1196                      0               primary            299
# 1197                      1                  met1            299
# 1198                      2                  met2            299
# 1199                      3                  met3            299
#
#      cluster_label  present site_category  num_mutations
# 0                0        0       primary              1
# 1                0        0    metastasis              1
# 2                0        0    metastasis              1
# 3                0        0    metastasis              1
# 4                1        0       primary              1
# ...            ...      ...           ...            ...
# 1195           298        0    metastasis              1
# 1196           299        1       primary              1
# 1197           299        0    metastasis              1
# 1198           299        0    metastasis              1
# 1199           299        0    metastasis              1
#
# [1200 rows x 7 columns]

# %%
# %%prun
from metient.metient import *

evaluate_label_clone_tree(f"{NAME}.txt", f"{NAME}.tsv", Weights(), PrintConfig(), "outputs/", NAME, O=None,
                          solve_polytomies=False, batch_size=256)
# Out:
# 300nodes_4sites_simple.tsv
#   0%|          | 0/450 [00:00<?, ?it/s]
# ordered_sites ['primary', 'met1', 'met2', 'met3']
# 100%|██████████| 450/450 [05:04<00:00,  3.65it/s]
# pareto_metrics {(4, 3, 2), (8, 3, 1)}
# # final solutions: 2
# 300nodes_4sites_simple_primary
# 1000 unique trees were not found (2 were found). Retry with a higher sample size if you want to get more trees.
# /lila/home/koyyald/mambaforge/envs/met/lib/python3.8/site-packages/pygraphviz/agraph.py:1405: RuntimeWarning: Warning: node '100', graph '%3' size too small for label
# Warning: node '101', graph '%3' size too small for label
# Warning: node '102', graph '%3' size too small for label
# Warning: node '103', graph '%3' size too small for label
# Warning: node '104', graph '%3' size too small for label
# Warning: node '105', graph '%3' size too small for label
# Warning: node '106', graph '%3' size too small for label
# Warning: node '107', graph '%3' size too small for label
# Warning: node '108', graph '%3' size too small for label
# Warning: node '109', graph '%3' size too small for label
# Warning: node '110', graph '%3' size too small for label
# Warning: node '111', graph '%3' size too small for label
# Warning: node '112', graph '%3' size too small for label
# Warning: node '113', graph '%3' size too small for label
# Warning: node '114', graph '%3' size too small for label
# Warning: node '115', graph '%3' size too small for label
# Warning: node '116', graph '%3' size too small for label
# Warning: node '117', graph '%3' size too small for label
# Warning: node '118', graph '%3' size too small for label
# Warning: node '119', graph '%3' size too small for label
# Warning: node '120', graph '%3' size too small for label
# Warning: node '121', graph '%3' size too small for label
# Warning: node '122', graph '%3' size too small for label
# Warning: node '123', graph '%3' size too small for label
# Warning: node '124', graph '%3' size too small for label
# Warning: node '125', graph '%3' size too small for label
# Warning: node '126', graph '%3' size too small for label
# Warning: node '127', graph '%3' size too small for label
# Warning: node '128', graph '%3' size too small for label
# Warning: node '129', graph '%3' size too small for label
# Warning: node '130', graph '%3' size too small for label
# Warning: node '131', graph '%3' size too small for label
# Warning: node '132', graph '%3' size too small for label
# Warning: node '133', graph '%3' size too small for label
# Warning: node '134', graph '%3' size too small for label
# Warning: node '135', graph '%3' size too small for label
# Warning: node '136', graph '%3' size too small for label
# Warning: node '137', graph '%3' size too small for label
# Warning: node '138', graph '%3' size too small for label
# Warning: node '139', graph '%3' size too small for label
# Warning: node '140', graph '%3' size too small for label
# Warning: node '141', graph '%3' size too small for label
# Warning: node '142', graph '%3' size too small for label
# Warning: node '143', graph '%3' size too small for label
# Warning: node '144', graph '%3' size too small for label
# Warning: node '145', graph '%3' size too small for label
# Warning: node '146', graph '%3' size too small for label
# Warning: node '147', graph '%3' size too small for label
# Warning: node '148', graph '%3' size too small for label
# Warning: node '149', graph '%3' size too small for label
# Warning: node '150', graph '%3' size too small for label
# Warning: node '151', graph '%3' size too small for label
# Warning: node '152', graph '%3' size too small for label
# Warning: node '153', graph '%3' size too small for label
# Warning: node '154', graph '%3' size too small for label
# Warning: node '155', graph '%3' size too small for label
# Warning: node '156', graph '%3' size too small for label
# Warning: node '157', graph '%3' size too small for label
# Warning: node '158', graph '%3' size too small for label
# Warning: node '159', graph '%3' size too small for label
# Warning: node '160', graph '%3' size too small for label
# Warning: node '161', graph '%3' size too small for label
# Warning: node '162', graph '%3' size too small for label
# Warning: node '163', graph '%3' size too small for label
# Warning: node '164', graph '%3' size too small for label
# Warning: node '165', graph '%3' size too small for label
# Warning: node '166', graph '%3' size too small for label
# Warning: node '167', graph '%3' size too small for label
# Warning: node '168', graph '%3' size too small for label
# Warning: node '169', graph '%3' size too small for label
# Warning: node '170', graph '%3' size too small for label
# Warning: node '171', graph '%3' size too small for label
# Warning: node '172', graph '%3' size too small for label
# Warning: node '173', graph '%3' size too small for label
# Warning: node '174', graph '%3' size too small for label
# Warning: node '175', graph '%3' size too small for label
# Warning: node '176', graph '%3' size too small for label
# Warning: node '177', graph '%3' size too small for label
# Warning: node '178', graph '%3' size too small for label
# Warning: node '179', graph '%3' size too small for label
# Warning: node '180', graph '%3' size too small for label
# Warning: node '181', graph '%3' size too small for label
# Warning: node '182', graph '%3' size too small for label
# Warning: node '183', graph '%3' size too small for label
# Warning: node '184', graph '%3' size too small for label
# Warning: node '185', graph '%3' size too small for label
# Warning: node '186', graph '%3' size too small for label
# Warning: node '187', graph '%3' size too small for label
# Warning: node '188', graph '%3' size too small for label
# Warning: node '189', graph '%3' size too small for label
# Warning: node '190', graph '%3' size too small for label
# Warning: node '191', graph '%3' size too small for label
# Warning: node '192', graph '%3' size too small for label
# Warning: node '193', graph '%3' size too small for label
# Warning: node '194', graph '%3' size too small for label
# Warning: node '195', graph '%3' size too small for label
# Warning: node '196', graph '%3' size too small for label
# Warning: node '197', graph '%3' size too small for label
# Warning: node '198', graph '%3' size too small for label
# Warning: node '199', graph '%3' size too small for label
# Warning: node '200', graph '%3' size too small for label
# Warning: node '201', graph '%3' size too small for label
# Warning: node '202', graph '%3' size too small for label
# Warning: node '203', graph '%3' size too small for label
# Warning: node '204', graph '%3' size too small for label
# Warning: node '205', graph '%3' size too small for label
# Warning: node '206', graph '%3' size too small for label
# Warning: node '207', graph '%3' size too small for label
# Warning: node '208', graph '%3' size too small for label
# Warning: node '209', graph '%3' size too small for label
# Warning: node '210', graph '%3' size too small for label
# Warning: node '211', graph '%3' size too small for label
# Warning: node '212', graph '%3' size too small for label
# Warning: node '213', graph '%3' size too small for label
# Warning: node '214', graph '%3' size too small for label
# Warning: node '215', graph '%3' size too small for label
# Warning: node '216', graph '%3' size too small for label
# Warning: node '217', graph '%3' size too small for label
# Warning: node '218', graph '%3' size too small for label
# Warning: node '219', graph '%3' size too small for label
# Warning: node '220', graph '%3' size too small for label
# Warning: node '221', graph '%3' size too small for label
# Warning: node '222', graph '%3' size too small for label
# Warning: node '223', graph '%3' size too small for label
# Warning: node '224', graph '%3' size too small for label
# Warning: node '225', graph '%3' size too small for label
# Warning: node '226', graph '%3' size too small for label
# Warning: node '227', graph '%3' size too small for label
# Warning: node '228', graph '%3' size too small for label
# Warning: node '229', graph '%3' size too small for label
# Warning: node '230', graph '%3' size too small for label
# Warning: node '231', graph '%3' size too small for label
# Warning: node '232', graph '%3' size too small for label
# Warning: node '233', graph '%3' size too small for label
# Warning: node '234', graph '%3' size too small for label
# Warning: node '235', graph '%3' size too small for label
# Warning: node '236', graph '%3' size too small for label
# Warning: node '237', graph '%3' size too small for label
# Warning: node '238', graph '%3' size too small for label
# Warning: node '239', graph '%3' size too small for label
# Warning: node '240', graph '%3' size too small for label
# Warning: node '241', graph '%3' size too small for label
# Warning: node '242', graph '%3' size too small for label
# Warning: node '243', graph '%3' size too small for label
# Warning: node '244', graph '%3' size too small for label
# Warning: node '245', graph '%3' size too small for label
# Warning: node '246', graph '%3' size too small for label
# Warning: node '247', graph '%3' size too small for label
# Warning: node '248', graph '%3' size too small for label
# Warning: node '249', graph '%3' size too small for label
# Warning: node '250', graph '%3' size too small for label
# Warning: node '251', graph '%3' size too small for label
# Warning: node '252', graph '%3' size too small for label
# Warning: node '253', graph '%3' size too small for label
# Warning: node '254', graph '%3' size too small for label
# Warning: node '255', graph '%3' size too small for label
# Warning: node '256', graph '%3' size too small for label
# Warning: node '257', graph '%3' size too small for label
# Warning: node '258', graph '%3' size too small for label
# Warning: node '259', graph '%3' size too small for label
# Warning: node '260', graph '%3' size too small for label
# Warning: node '261', graph '%3' size too small for label
# Warning: node '262', graph '%3' size too small for label
# Warning: node '263', graph '%3' size too small for label
# Warning: node '264', graph '%3' size too small for label
# Warning: node '265', graph '%3' size too small for label
# Warning: node '266', graph '%3' size too small for label
# Warning: node '267', graph '%3' size too small for label
# Warning: node '268', graph '%3' size too small for label
# Warning: node '269', graph '%3' size too small for label
# Warning: node '270', graph '%3' size too small for label
# Warning: node '271', graph '%3' size too small for label
# Warning: node '272', graph '%3' size too small for label
# Warning: node '273', graph '%3' size too small for label
# Warning: node '274', graph '%3' size too small for label
# Warning: node '275', graph '%3' size too small for label
# Warning: node '276', graph '%3' size too small for label
# Warning: node '277', graph '%3' size too small for label
# Warning: node '278', graph '%3' size too small for label
# Warning: node '279', graph '%3' size too small for label
# Warning: node '280', graph '%3' size too small for label
# Warning: node '281', graph '%3' size too small for label
# Warning: node '282', graph '%3' size too small for label
# Warning: node '283', graph '%3' size too small for label
# Warning: node '284', graph '%3' size too small for label
# Warning: node '285', graph '%3' size too small for label
# Warning: node '286', graph '%3' size too small for label
# Warning: node '287', graph '%3' size too small for label
# Warning: node '288', graph '%3' size too small for label
# Warning: node '289', graph '%3' size too small for label
# Warning: node '290', graph '%3' size too small for label
# Warning: node '291', graph '%3' size too small for label
# Warning: node '292', graph '%3' size too small for label
# Warning: node '293', graph '%3' size too small for label
# Warning: node '294', graph '%3' size too small for label
# Warning: node '295', graph '%3' size too small for label
# Warning: node '296', graph '%3' size too small for label
# Warning: node '297', graph '%3' size too small for label
# Warning: node '298', graph '%3' size too small for label
# Warning: node '299', graph '%3' size too small for label
# Warning: node '300', graph '%3' size too small for label
# Warning: node '301', graph '%3' size too small for label
# Warning: node '302', graph '%3' size too small for label
# Warning: node '303', graph '%3' size too small for label
# Warning: node '304', graph '%3' size too small for label
# Warning: node '305', graph '%3' size too small for label
# Warning: node '306', graph '%3' size too small for label
# Warning: node '307', graph '%3' size too small for label
# Warning: node '308', graph '%3' size too small for label
# Warning: node '309', graph '%3' size too small for label
# Warning: node '310', graph '%3' size too small for label
# Warning: node '311', graph '%3' size too small for label
# Warning: node '312', graph '%3' size too small for label
# Warning: node '313', graph '%3' size too small for label
# Warning: node '314', graph '%3' size too small for label
# Warning: node '315', graph '%3' size too small for label
# Warning: node '316', graph '%3' size too small for label
# Warning: node '317', graph '%3' size too small for label
# Warning: node '318', graph '%3' size too small for label
# Warning: node '319', graph '%3' size too small for label
# Warning: node '320', graph '%3' size too small for label
# Warning: node '321', graph '%3' size too small for label
# Warning: node '322', graph '%3' size too small for label
# Warning: node '323', graph '%3' size too small for label
# Warning: node '324', graph '%3' size too small for label
# Warning: node '325', graph '%3' size too small for label
# Warning: node '326', graph '%3' size too small for label
# Warning: node '327', graph '%3' size too small for label
# Warning: node '328', graph '%3' size too small for label
# Warning: node '329', graph '%3' size too small for label
# Warning: node '330', graph '%3' size too small for label
# Warning: node '331', graph '%3' size too small for label
# Warning: node '332', graph '%3' size too small for label
# Warning: node '333', graph '%3' size too small for label
# Warning: node '334', graph '%3' size too small for label
# Warning: node '335', graph '%3' size too small for label
# Warning: node '336', graph '%3' size too small for label
# Warning: node '337', graph '%3' size too small for label
# Warning: node '338', graph '%3' size too small for label
# Warning: node '339', graph '%3' size too small for label
# Warning: node '340', graph '%3' size too small for label
# Warning: node '341', graph '%3' size too small for label
# Warning: node '342', graph '%3' size too small for label
# Warning: node '343', graph '%3' size too small for label
# Warning: node '344', graph '%3' size too small for label
# Warning: node '345', graph '%3' size too small for label
# Warning: node '346', graph '%3' size too small for label
# Warning: node '347', graph '%3' size too small for label
# Warning: node '348', graph '%3' size too small for label
# Warning: node '349', graph '%3' size too small for label
# Warning: node '350', graph '%3' size too small for label
# Warning: node '351', graph '%3' size too small for label
# Warning: node '352', graph '%3' size too small for label
# Warning: node '353', graph '%3' size too small for label
# Warning: node '354', graph '%3' size too small for label
# Warning: node '355', graph '%3' size too small for label
# Warning: node '356', graph '%3' size too small for label
# Warning: node '357', graph '%3' size too small for label
# Warning: node '358', graph '%3' size too small for label
# Warning: node '359', graph '%3' size too small for label
# Warning: node '360', graph '%3' size too small for label
# Warning: node '361', graph '%3' size too small for label
# Warning: node '362', graph '%3' size too small for label
# Warning: node '363', graph '%3' size too small for label
# Warning: node '364', graph '%3' size too small for label
# Warning: node '365', graph '%3' size too small for label
# Warning: node '366', graph '%3' size too small for label
# Warning: node '367', graph '%3' size too small for label
# Warning: node '368', graph '%3' size too small for label
# Warning: node '369', graph '%3' size too small for label
# Warning: node '370', graph '%3' size too small for label
# Warning: node '371', graph '%3' size too small for label
# Warning: node '372', graph '%3' size too small for label
# Warning: node '373', graph '%3' size too small for label
# Warning: node '374', graph '%3' size too small for label
# Warning: node '375', graph '%3' size too small for label
# Warning: node '376', graph '%3' size too small for label
# Warning: node '377', graph '%3' size too small for label
# Warning: node '378', graph '%3' size too small for label
# Warning: node '379', graph '%3' size too small for label
# Warning: node '380', graph '%3' size too small for label
# Warning: node '381', graph '%3' size too small for label
# Warning: node '382', graph '%3' size too small for label
# Warning: node '383', graph '%3' size too small for label
# Warning: node '384', graph '%3' size too small for label
# Warning: node '385', graph '%3' size too small for label
# Warning: node '386', graph '%3' size too small for label
# Warning: node '387', graph '%3' size too small for label
# Warning: node '388', graph '%3' size too small for label
# Warning: node '389', graph '%3' size too small for label
# Warning: node '390', graph '%3' size too small for label
# Warning: node '391', graph '%3' size too small for label
# Warning: node '392', graph '%3' size too small for label
# Warning: node '393', graph '%3' size too small for label
# Warning: node '394', graph '%3' size too small for label
# Warning: node '395', graph '%3' size too small for label
# Warning: node '396', graph '%3' size too small for label
# Warning: node '397', graph '%3' size too small for label
# Warning: node '398', graph '%3' size too small for label
# Warning: node '399', graph '%3' size too small for label
# Warning: node '400', graph '%3' size too small for label
# Warning: node '401', graph '%3' size too small for label
# Warning: node '402', graph '%3' size too small for label
# Warning: node '403', graph '%3' size too small for label
# Warning: node '404', graph '%3' size too small for label
# Warning: node '405', graph '%3' size too small for label
# Warning: node '406', graph '%3' size too small for label
# Warning: node '407', graph '%3' size too small for label
# Warning: node '408', graph '%3' size too small for label
# Warning: node '409', graph '%3' size too small for label
# Warning: node '410', graph '%3' size too small for label
# Warning: node '411', graph '%3' size too small for label
# Warning: node '412', graph '%3' size too small for label
# Warning: node '413', graph '%3' size too small for label
# Warning: node '414', graph '%3' size too small for label
# Warning: node '415', graph '%3' size too small for label
# Warning: node '416', graph '%3' size too small for label
# Warning: node '417', graph '%3' size too small for label
# Warning: node '418', graph '%3' size too small for label
# Warning: node '419', graph '%3' size too small for label
# Warning: node '420', graph '%3' size too small for label
# Warning: node '421', graph '%3' size too small for label
# Warning: node '422', graph '%3' size too small for label
# Warning: node '423', graph '%3' size too small for label
# Warning: node '424', graph '%3' size too small for label
# Warning: node '425', graph '%3' size too small for label
# Warning: node '426', graph '%3' size too small for label
# Warning: node '427', graph '%3' size too small for label
# Warning: node '428', graph '%3' size too small for label
# Warning: node '429', graph '%3' size too small for label
# Warning: node '430', graph '%3' size too small for label
# Warning: node '431', graph '%3' size too small for label
# Warning: node '432', graph '%3' size too small for label
# Warning: node '433', graph '%3' size too small for label
# Warning: node '434', graph '%3' size too small for label
# Warning: node '435', graph '%3' size too small for label
# Warning: node '436', graph '%3' size too small for label
# Warning: node '437', graph '%3' size too small for label
# Warning: node '438', graph '%3' size too small for label
# Warning: node '439', graph '%3' size too small for label
# Warning: node '440', graph '%3' size too small for label
# Warning: node '441', graph '%3' size too small for label
# Warning: node '442', graph '%3' size too small for label
# Warning: node '443', graph '%3' size too small for label
# Warning: node '444', graph '%3' size too small for label
# Warning: node '445', graph '%3' size too small for label
# Warning: node '446', graph '%3' size too small for label
# Warning: node '447', graph '%3' size too small for label
# Warning: node '448', graph '%3' size too small for label
# Warning: node '449', graph '%3' size too small for label
#
#   warnings.warn(b"".join(errors).decode(self.encoding), RuntimeWarning)
