# %%
import os
import matplotlib
import torch
from src.util import eval_util as eutil
from src.util import plotting_util as putil
from src.util.globals import *

REPO_DIR = os.path.join(os.getcwd(), "../../")
os.chdir(REPO_DIR)
SIMS_DIR = os.path.join(REPO_DIR, 'src/data/machina_sims')

def get_num_mut_trees(mut_tree_fn):
    with open(mut_tree_fn, 'r') as f:
        # look for line w/ "3 #trees" as an example
        for line in f:
            if  "#trees" in line:
                return int(line.strip().split()[0])
# Out:
# CUDA GPU: False

# %%
import fnmatch
import pandas as pd

SITES = ["m5", "m8"]
MIG_TYPES = ["mS", "M", "S", "R"]
types_map = {"mS":"single-source", "M":"multi-source", "S":"single-source", "R":"reseeding"}
overall_pattern_map = {"single-source":"single-source", "multi-source":"multi-source", "reseeding":"reseeding"}

x = 0
k = 5
LOSS_THRES = 0.0

mig_type_to_seeding_pattern_df = {}
mig_type_to_topk_seeding_pattern_df = {}
mig_type_to_topk_seeding_pattern_counts_df = {}
mig_type_to_consensus_pattern = {}
mig_type_to_top_pattern = {}

PREDICTION_DIR = os.path.join(REPO_DIR, "src/test/machina_simulated_data/predictions_bs256_solvepoly_calibrate_11012023")
for mig_type in MIG_TYPES:
    for site in SITES:
        print(site, mig_type)
        # Get all seeds for mig_type + site combo
        site_mig_type_dir = os.path.join(SIMS_DIR, site, mig_type)
        seeds = fnmatch.filter(os.listdir(site_mig_type_dir), 'clustering_observed_seed*.txt')
        seeds = [s.replace(".txt", "").replace("clustering_observed_seed", "") for s in seeds]
        for seed in seeds:
            num_trees = get_num_mut_trees(os.path.join(SIMS_DIR, f"{site}_mut_trees", f"mut_trees_{mig_type}_seed{seed}.txt"))
            consensus_patterns_losses = []
            for tree_num in range(num_trees):
                seeding_fn = os.path.join(PREDICTION_DIR, site, mig_type, f"tree{tree_num}_seed{seed}_eval_loss_by_seeding_pattern.txt")
                seeding_df = pd.read_csv(seeding_fn, sep=',')
                sort_seeding_df = seeding_df.sort_values(by='Evaluation loss', ascending=True).head(k)
                topk_counts_df = sort_seeding_df['Seeding pattern'].value_counts().to_frame().reset_index()
                mapped_type = types_map[mig_type]
                topk_patterns = topk_counts_df['Seeding pattern'].tolist()
                
                if mapped_type not in mig_type_to_seeding_pattern_df:
                    mig_type_to_seeding_pattern_df[mapped_type] = seeding_df
                    mig_type_to_topk_seeding_pattern_df[mapped_type] = sort_seeding_df
                    mig_type_to_topk_seeding_pattern_counts_df[mapped_type] = topk_counts_df
                    mig_type_to_consensus_pattern[mapped_type] = []
                    mig_type_to_top_pattern[mapped_type] = []
                else:
                    mig_type_to_seeding_pattern_df[mapped_type] = pd.concat([mig_type_to_seeding_pattern_df[mapped_type], seeding_df], axis=0)
                    mig_type_to_topk_seeding_pattern_df[mapped_type] = pd.concat([mig_type_to_topk_seeding_pattern_df[mapped_type], sort_seeding_df], axis=0)
                    mig_type_to_topk_seeding_pattern_counts_df[mapped_type] = pd.concat([mig_type_to_topk_seeding_pattern_counts_df[mapped_type], topk_counts_df], axis=0)
                
                mig_type_to_top_pattern[mapped_type].append(sort_seeding_df.head(1)['Seeding pattern'].item())
                
                consensus_fn = os.path.join(PREDICTION_DIR, site, mig_type, f"tree{tree_num}_seed{seed}_consensus_pattern.txt")
                with open(consensus_fn, 'r') as f:
                    for line in f:
                        items = line.strip().split(";")
                        pred_pattern = items[0]
                        pred_pattern_loss = items[1]
                        mig_type_to_consensus_pattern[mapped_type].append(pred_pattern)
                        consensus_patterns_losses.append((pred_pattern, pred_pattern_loss))
                if (mapped_type == 'single-source' and 'single-source' not in pred_pattern):
                    print(f"single-source mistaken as {pred_pattern}", site, mig_type, seed, tree_num)
                if (mapped_type == 'multi-source' and 'multi-source' not in pred_pattern):
                    print(f"multi-source mistaken as {pred_pattern}", site, mig_type, seed, tree_num)
                        
                x += 1
                
            best_trees = eutil.get_metient_min_loss_trees(os.path.join(PREDICTION_DIR, site, mig_type), seed, float("inf"), loss_thres=LOSS_THRES)
            for i, (loss, results_dict, met_tree_num) in enumerate(best_trees):
                if mapped_type not in mig_type_to_top_pattern:
                    mig_type_to_top_pattern[mapped_type] = []
                V = results_dict[OUT_LABElING_KEY][met_tree_num]
                A = results_dict[OUT_ADJ_KEY][met_tree_num]
                mig_type_to_top_pattern[mapped_type].append(putil.get_seeding_pattern(V,A))
                
assert(x==1647)
# Out:
# m5 mS
# 1
# 1
# 3
# 1
# 1
# 2
# 3
# 1
# 2
# 1
# m8 mS
# single-source mistaken as polyclonal reseeding m8 mS 0 0
# single-source mistaken as polyclonal reseeding m8 mS 0 1
# 2
# 1
# single-source mistaken as monoclonal reseeding m8 mS 4 0
# single-source mistaken as monoclonal reseeding m8 mS 4 7
# 6
# 1
# 1
# single-source mistaken as polyclonal reseeding m8 mS 3 3
# single-source mistaken as polyclonal reseeding m8 mS 3 4
# single-source mistaken as monoclonal reseeding m8 mS 3 6
# single-source mistaken as monoclonal reseeding m8 mS 3 7
# 1
# single-source mistaken as polyclonal reseeding m8 mS 12 102
# 2
# 2
# 1
# 1
# m5 M
# multi-source mistaken as polyclonal single-source seeding m5 M 209 2
# multi-source mistaken as polyclonal single-source seeding m5 M 209 5
# multi-source mistaken as polyclonal single-source seeding m5 M 209 6
# multi-source mistaken as polyclonal single-source seeding m5 M 209 7
# multi-source mistaken as polyclonal single-source seeding m5 M 209 8
# multi-source mistaken as polyclonal single-source seeding m5 M 209 9
# multi-source mistaken as polyclonal single-source seeding m5 M 209 10
# 2
# multi-source mistaken as polyclonal single-source seeding m5 M 534 0
# multi-source mistaken as polyclonal single-source seeding m5 M 534 1
# multi-source mistaken as polyclonal single-source seeding m5 M 534 2
# multi-source mistaken as polyclonal single-source seeding m5 M 534 8
# multi-source mistaken as polyclonal single-source seeding m5 M 534 9
# multi-source mistaken as polyclonal single-source seeding m5 M 534 12
# multi-source mistaken as polyclonal single-source seeding m5 M 534 13
# multi-source mistaken as polyclonal single-source seeding m5 M 534 16
# multi-source mistaken as polyclonal single-source seeding m5 M 534 17
# multi-source mistaken as polyclonal single-source seeding m5 M 534 18
# multi-source mistaken as polyclonal single-source seeding m5 M 534 19
# multi-source mistaken as polyclonal single-source seeding m5 M 534 23
# 1
# multi-source mistaken as polyclonal reseeding m5 M 694 1
# multi-source mistaken as polyclonal reseeding m5 M 694 15
# multi-source mistaken as polyclonal reseeding m5 M 694 19
# multi-source mistaken as polyclonal reseeding m5 M 694 21
# multi-source mistaken as polyclonal reseeding m5 M 694 24
# 2
# 3
# multi-source mistaken as polyclonal single-source seeding m5 M 545 0
# multi-source mistaken as polyclonal single-source seeding m5 M 545 1
# multi-source mistaken as polyclonal single-source seeding m5 M 545 2
# multi-source mistaken as polyclonal single-source seeding m5 M 545 3
# multi-source mistaken as polyclonal single-source seeding m5 M 545 4
# multi-source mistaken as polyclonal single-source seeding m5 M 545 5
# multi-source mistaken as polyclonal single-source seeding m5 M 545 6
# multi-source mistaken as polyclonal single-source seeding m5 M 545 7
# 4
# multi-source mistaken as polyclonal single-source seeding m5 M 865 0
# multi-source mistaken as polyclonal single-source seeding m5 M 865 1
# multi-source mistaken as polyclonal single-source seeding m5 M 865 3
# multi-source mistaken as polyclonal single-source seeding m5 M 865 4
# multi-source mistaken as polyclonal single-source seeding m5 M 865 5
# multi-source mistaken as polyclonal single-source seeding m5 M 865 7
# 1
# multi-source mistaken as polyclonal single-source seeding m5 M 907 1
# 1
# multi-source mistaken as polyclonal single-source seeding m5 M 76 0
# multi-source mistaken as polyclonal single-source seeding m5 M 76 1
# multi-source mistaken as polyclonal single-source seeding m5 M 76 2
# 2
# multi-source mistaken as polyclonal single-source seeding m5 M 565 0
# multi-source mistaken as polyclonal single-source seeding m5 M 565 1
# multi-source mistaken as polyclonal single-source seeding m5 M 565 2
# multi-source mistaken as polyclonal single-source seeding m5 M 565 3
# 1
# multi-source mistaken as polyclonal single-source seeding m5 M 473 0
# multi-source mistaken as polyclonal single-source seeding m5 M 473 3
# multi-source mistaken as polyclonal single-source seeding m5 M 473 4
# multi-source mistaken as polyclonal single-source seeding m5 M 473 6
# multi-source mistaken as polyclonal single-source seeding m5 M 473 7
# multi-source mistaken as polyclonal single-source seeding m5 M 473 8
# multi-source mistaken as polyclonal single-source seeding m5 M 473 9
# multi-source mistaken as polyclonal single-source seeding m5 M 473 12
# multi-source mistaken as polyclonal single-source seeding m5 M 473 13
# multi-source mistaken as polyclonal single-source seeding m5 M 473 14
# multi-source mistaken as polyclonal single-source seeding m5 M 473 16
# multi-source mistaken as polyclonal single-source seeding m5 M 473 17
# multi-source mistaken as polyclonal single-source seeding m5 M 473 19
# multi-source mistaken as polyclonal single-source seeding m5 M 473 20
# multi-source mistaken as polyclonal single-source seeding m5 M 473 21
# multi-source mistaken as polyclonal single-source seeding m5 M 473 22
# multi-source mistaken as polyclonal single-source seeding m5 M 473 23
# multi-source mistaken as polyclonal single-source seeding m5 M 473 24
# multi-source mistaken as polyclonal single-source seeding m5 M 473 26
# multi-source mistaken as polyclonal single-source seeding m5 M 473 27
# multi-source mistaken as polyclonal single-source seeding m5 M 473 28
# multi-source mistaken as polyclonal single-source seeding m5 M 473 30
# multi-source mistaken as polyclonal single-source seeding m5 M 473 35
# multi-source mistaken as polyclonal single-source seeding m5 M 473 36
# multi-source mistaken as polyclonal single-source seeding m5 M 473 37
# multi-source mistaken as polyclonal single-source seeding m5 M 473 38
# multi-source mistaken as polyclonal single-source seeding m5 M 473 39
# multi-source mistaken as polyclonal single-source seeding m5 M 473 40
# multi-source mistaken as polyclonal single-source seeding m5 M 473 41
# multi-source mistaken as polyclonal single-source seeding m5 M 473 42
# multi-source mistaken as polyclonal single-source seeding m5 M 473 43
# multi-source mistaken as polyclonal single-source seeding m5 M 473 44
# multi-source mistaken as polyclonal single-source seeding m5 M 473 45
# multi-source mistaken as polyclonal single-source seeding m5 M 473 46
# multi-source mistaken as polyclonal single-source seeding m5 M 473 47
# multi-source mistaken as polyclonal single-source seeding m5 M 473 48
# multi-source mistaken as polyclonal single-source seeding m5 M 473 49
# multi-source mistaken as polyclonal single-source seeding m5 M 473 50
# multi-source mistaken as polyclonal single-source seeding m5 M 473 51
# multi-source mistaken as polyclonal single-source seeding m5 M 473 55
# multi-source mistaken as polyclonal single-source seeding m5 M 473 56
# multi-source mistaken as polyclonal single-source seeding m5 M 473 60
# multi-source mistaken as polyclonal single-source seeding m5 M 473 62
# multi-source mistaken as polyclonal single-source seeding m5 M 473 63
# multi-source mistaken as polyclonal single-source seeding m5 M 473 65
# multi-source mistaken as polyclonal single-source seeding m5 M 473 66
# multi-source mistaken as polyclonal single-source seeding m5 M 473 67
# multi-source mistaken as polyclonal single-source seeding m5 M 473 68
# multi-source mistaken as polyclonal single-source seeding m5 M 473 69
# multi-source mistaken as polyclonal single-source seeding m5 M 473 70
# multi-source mistaken as polyclonal single-source seeding m5 M 473 71
# multi-source mistaken as polyclonal single-source seeding m5 M 473 72
# multi-source mistaken as polyclonal single-source seeding m5 M 473 74
# multi-source mistaken as polyclonal single-source seeding m5 M 473 76
# multi-source mistaken as polyclonal single-source seeding m5 M 473 78
# multi-source mistaken as polyclonal single-source seeding m5 M 473 79
# 1
# m8 M
# multi-source mistaken as polyclonal single-source seeding m8 M 45 0
# multi-source mistaken as polyclonal single-source seeding m8 M 45 1
# 1
# 1
# multi-source mistaken as polyclonal single-source seeding m8 M 35 19
# multi-source mistaken as polyclonal single-source seeding m8 M 35 22
# multi-source mistaken as polyclonal reseeding m8 M 35 25
# 2
# multi-source mistaken as polyclonal reseeding m8 M 243 0
# multi-source mistaken as polyclonal single-source seeding m8 M 243 1
# multi-source mistaken as polyclonal single-source seeding m8 M 243 2
# multi-source mistaken as polyclonal single-source seeding m8 M 243 3
# multi-source mistaken as polyclonal single-source seeding m8 M 243 4
# multi-source mistaken as polyclonal single-source seeding m8 M 243 5
# multi-source mistaken as polyclonal single-source seeding m8 M 243 6
# multi-source mistaken as polyclonal single-source seeding m8 M 243 7
# multi-source mistaken as polyclonal single-source seeding m8 M 243 9
# multi-source mistaken as polyclonal single-source seeding m8 M 243 10
# multi-source mistaken as polyclonal single-source seeding m8 M 243 11
# 2
# 1
# multi-source mistaken as monoclonal reseeding m8 M 239 0
# multi-source mistaken as monoclonal reseeding m8 M 239 1
# 2
# multi-source mistaken as polyclonal single-source seeding m8 M 19 4
# multi-source mistaken as polyclonal single-source seeding m8 M 19 6
# multi-source mistaken as polyclonal single-source seeding m8 M 19 10
# multi-source mistaken as polyclonal single-source seeding m8 M 19 11
# multi-source mistaken as polyclonal single-source seeding m8 M 19 12
# multi-source mistaken as polyclonal single-source seeding m8 M 19 13
# multi-source mistaken as polyclonal single-source seeding m8 M 19 14
# multi-source mistaken as polyclonal single-source seeding m8 M 19 18
# multi-source mistaken as polyclonal single-source seeding m8 M 19 19
# multi-source mistaken as polyclonal single-source seeding m8 M 19 20
# multi-source mistaken as polyclonal single-source seeding m8 M 19 21
# multi-source mistaken as polyclonal single-source seeding m8 M 19 22
# multi-source mistaken as polyclonal single-source seeding m8 M 19 23
# multi-source mistaken as polyclonal single-source seeding m8 M 19 25
# multi-source mistaken as polyclonal single-source seeding m8 M 19 27
# multi-source mistaken as polyclonal single-source seeding m8 M 19 32
# multi-source mistaken as polyclonal single-source seeding m8 M 19 34
# multi-source mistaken as polyclonal single-source seeding m8 M 19 36
# multi-source mistaken as polyclonal single-source seeding m8 M 19 37
# multi-source mistaken as polyclonal single-source seeding m8 M 19 42
# multi-source mistaken as polyclonal single-source seeding m8 M 19 43
# multi-source mistaken as polyclonal single-source seeding m8 M 19 44
# multi-source mistaken as polyclonal single-source seeding m8 M 19 45
# 2
# multi-source mistaken as polyclonal single-source seeding m8 M 76 1
# multi-source mistaken as polyclonal single-source seeding m8 M 76 2
# multi-source mistaken as polyclonal single-source seeding m8 M 76 3
# 1
# multi-source mistaken as polyclonal single-source seeding m8 M 172 2
# multi-source mistaken as polyclonal single-source seeding m8 M 172 3
# multi-source mistaken as polyclonal single-source seeding m8 M 172 4
# multi-source mistaken as polyclonal single-source seeding m8 M 172 6
# multi-source mistaken as polyclonal single-source seeding m8 M 172 7
# multi-source mistaken as polyclonal single-source seeding m8 M 172 8
# multi-source mistaken as polyclonal single-source seeding m8 M 172 9
# multi-source mistaken as polyclonal single-source seeding m8 M 172 10
# multi-source mistaken as polyclonal single-source seeding m8 M 172 11
# multi-source mistaken as polyclonal single-source seeding m8 M 172 12
# multi-source mistaken as polyclonal single-source seeding m8 M 172 13
# multi-source mistaken as polyclonal single-source seeding m8 M 172 14
# multi-source mistaken as polyclonal single-source seeding m8 M 172 16
# multi-source mistaken as polyclonal single-source seeding m8 M 172 17
# multi-source mistaken as polyclonal single-source seeding m8 M 172 18
# multi-source mistaken as polyclonal reseeding m8 M 172 19
# multi-source mistaken as polyclonal single-source seeding m8 M 172 20
# multi-source mistaken as polyclonal single-source seeding m8 M 172 21
# multi-source mistaken as polyclonal single-source seeding m8 M 172 22
# multi-source mistaken as polyclonal single-source seeding m8 M 172 23
# multi-source mistaken as polyclonal single-source seeding m8 M 172 24
# multi-source mistaken as polyclonal single-source seeding m8 M 172 25
# multi-source mistaken as polyclonal single-source seeding m8 M 172 26
# multi-source mistaken as polyclonal single-source seeding m8 M 172 27
# multi-source mistaken as polyclonal single-source seeding m8 M 172 28
# multi-source mistaken as polyclonal single-source seeding m8 M 172 29
# multi-source mistaken as polyclonal single-source seeding m8 M 172 30
# multi-source mistaken as polyclonal single-source seeding m8 M 172 31
# multi-source mistaken as polyclonal single-source seeding m8 M 172 32
# multi-source mistaken as polyclonal single-source seeding m8 M 172 33
# multi-source mistaken as polyclonal single-source seeding m8 M 172 35
# multi-source mistaken as polyclonal single-source seeding m8 M 172 36
# multi-source mistaken as polyclonal single-source seeding m8 M 172 37
# multi-source mistaken as polyclonal single-source seeding m8 M 172 39
# multi-source mistaken as polyclonal single-source seeding m8 M 172 41
# multi-source mistaken as polyclonal single-source seeding m8 M 172 43
# multi-source mistaken as polyclonal single-source seeding m8 M 172 45
# multi-source mistaken as polyclonal single-source seeding m8 M 172 46
# multi-source mistaken as polyclonal reseeding m8 M 172 48
# multi-source mistaken as polyclonal reseeding m8 M 172 49
# multi-source mistaken as polyclonal single-source seeding m8 M 172 50
# multi-source mistaken as polyclonal single-source seeding m8 M 172 51
# multi-source mistaken as polyclonal single-source seeding m8 M 172 52
# multi-source mistaken as polyclonal single-source seeding m8 M 172 53
# multi-source mistaken as polyclonal reseeding m8 M 172 55
# multi-source mistaken as polyclonal single-source seeding m8 M 172 57
# multi-source mistaken as polyclonal single-source seeding m8 M 172 59
# multi-source mistaken as polyclonal single-source seeding m8 M 172 62
# multi-source mistaken as polyclonal single-source seeding m8 M 172 63
# multi-source mistaken as polyclonal single-source seeding m8 M 172 65
# multi-source mistaken as polyclonal single-source seeding m8 M 172 68
# multi-source mistaken as polyclonal reseeding m8 M 172 69
# multi-source mistaken as polyclonal single-source seeding m8 M 172 70
# multi-source mistaken as polyclonal single-source seeding m8 M 172 71
# multi-source mistaken as polyclonal reseeding m8 M 172 76
# multi-source mistaken as polyclonal reseeding m8 M 172 78
# multi-source mistaken as polyclonal single-source seeding m8 M 172 79
# multi-source mistaken as polyclonal single-source seeding m8 M 172 80
# multi-source mistaken as polyclonal reseeding m8 M 172 81
# multi-source mistaken as polyclonal reseeding m8 M 172 82
# multi-source mistaken as polyclonal single-source seeding m8 M 172 85
# multi-source mistaken as polyclonal single-source seeding m8 M 172 86
# multi-source mistaken as polyclonal single-source seeding m8 M 172 87
# multi-source mistaken as polyclonal single-source seeding m8 M 172 88
# multi-source mistaken as polyclonal single-source seeding m8 M 172 89
# multi-source mistaken as polyclonal single-source seeding m8 M 172 91
# multi-source mistaken as polyclonal single-source seeding m8 M 172 92
# multi-source mistaken as polyclonal single-source seeding m8 M 172 94
# multi-source mistaken as polyclonal single-source seeding m8 M 172 95
# multi-source mistaken as polyclonal single-source seeding m8 M 172 96
# multi-source mistaken as polyclonal single-source seeding m8 M 172 97
# multi-source mistaken as polyclonal single-source seeding m8 M 172 98
# multi-source mistaken as polyclonal single-source seeding m8 M 172 99
# multi-source mistaken as polyclonal single-source seeding m8 M 172 100
# multi-source mistaken as polyclonal reseeding m8 M 172 104
# multi-source mistaken as polyclonal reseeding m8 M 172 105
# multi-source mistaken as polyclonal single-source seeding m8 M 172 108
# multi-source mistaken as polyclonal single-source seeding m8 M 172 109
# multi-source mistaken as polyclonal single-source seeding m8 M 172 110
# multi-source mistaken as polyclonal single-source seeding m8 M 172 112
# multi-source mistaken as polyclonal single-source seeding m8 M 172 114
# multi-source mistaken as polyclonal single-source seeding m8 M 172 115
# multi-source mistaken as polyclonal single-source seeding m8 M 172 119
# multi-source mistaken as polyclonal reseeding m8 M 172 120
# multi-source mistaken as polyclonal single-source seeding m8 M 172 123
# multi-source mistaken as polyclonal single-source seeding m8 M 172 124
# multi-source mistaken as polyclonal single-source seeding m8 M 172 125
# multi-source mistaken as polyclonal single-source seeding m8 M 172 126
# multi-source mistaken as polyclonal single-source seeding m8 M 172 127
# multi-source mistaken as polyclonal single-source seeding m8 M 172 130
# multi-source mistaken as polyclonal single-source seeding m8 M 172 133
# multi-source mistaken as polyclonal single-source seeding m8 M 172 134
# multi-source mistaken as polyclonal single-source seeding m8 M 172 135
# multi-source mistaken as polyclonal single-source seeding m8 M 172 136
# multi-source mistaken as polyclonal single-source seeding m8 M 172 137
# multi-source mistaken as polyclonal reseeding m8 M 172 138
# multi-source mistaken as polyclonal single-source seeding m8 M 172 139
# multi-source mistaken as polyclonal single-source seeding m8 M 172 140
# multi-source mistaken as polyclonal single-source seeding m8 M 172 141
# multi-source mistaken as polyclonal single-source seeding m8 M 172 142
# multi-source mistaken as polyclonal single-source seeding m8 M 172 143
# multi-source mistaken as polyclonal reseeding m8 M 172 144
# multi-source mistaken as polyclonal single-source seeding m8 M 172 145
# multi-source mistaken as polyclonal single-source seeding m8 M 172 151
# multi-source mistaken as polyclonal single-source seeding m8 M 172 152
# multi-source mistaken as polyclonal single-source seeding m8 M 172 153
# multi-source mistaken as polyclonal reseeding m8 M 172 154
# multi-source mistaken as polyclonal single-source seeding m8 M 172 156
# multi-source mistaken as polyclonal reseeding m8 M 172 157
# multi-source mistaken as polyclonal single-source seeding m8 M 172 158
# multi-source mistaken as polyclonal single-source seeding m8 M 172 159
# multi-source mistaken as polyclonal single-source seeding m8 M 172 160
# multi-source mistaken as polyclonal single-source seeding m8 M 172 161
# multi-source mistaken as polyclonal single-source seeding m8 M 172 163
# multi-source mistaken as polyclonal single-source seeding m8 M 172 164
# multi-source mistaken as polyclonal single-source seeding m8 M 172 165
# multi-source mistaken as polyclonal single-source seeding m8 M 172 166
# multi-source mistaken as polyclonal single-source seeding m8 M 172 168
# multi-source mistaken as polyclonal single-source seeding m8 M 172 170
# multi-source mistaken as polyclonal single-source seeding m8 M 172 171
# multi-source mistaken as polyclonal single-source seeding m8 M 172 173
# multi-source mistaken as polyclonal reseeding m8 M 172 174
# multi-source mistaken as polyclonal reseeding m8 M 172 175
# multi-source mistaken as polyclonal single-source seeding m8 M 172 176
# multi-source mistaken as polyclonal single-source seeding m8 M 172 179
# 1
# multi-source mistaken as polyclonal reseeding m8 M 241 4
# 1
# m5 S
# 2
# 1
# 1
# single-source mistaken as polyclonal reseeding m5 S 31 24
# single-source mistaken as polyclonal reseeding m5 S 31 25
# 1
# 1
# 12
# 1
# 1
# 2
# 1
# m8 S
# single-source mistaken as polyclonal multi-source seeding m8 S 0 0
# single-source mistaken as polyclonal multi-source seeding m8 S 0 1
# single-source mistaken as polyclonal multi-source seeding m8 S 0 2
# single-source mistaken as polyclonal multi-source seeding m8 S 0 3
# single-source mistaken as polyclonal multi-source seeding m8 S 0 4
# single-source mistaken as polyclonal multi-source seeding m8 S 0 5
# single-source mistaken as polyclonal multi-source seeding m8 S 0 6
# single-source mistaken as polyclonal multi-source seeding m8 S 0 7
# single-source mistaken as polyclonal multi-source seeding m8 S 0 9
# single-source mistaken as polyclonal multi-source seeding m8 S 0 10
# single-source mistaken as polyclonal multi-source seeding m8 S 0 11
# single-source mistaken as polyclonal multi-source seeding m8 S 0 12
# single-source mistaken as polyclonal reseeding m8 S 0 14
# single-source mistaken as polyclonal multi-source seeding m8 S 0 15
# single-source mistaken as polyclonal multi-source seeding m8 S 0 16
# single-source mistaken as polyclonal multi-source seeding m8 S 0 17
# single-source mistaken as polyclonal multi-source seeding m8 S 0 19
# single-source mistaken as polyclonal multi-source seeding m8 S 0 20
# single-source mistaken as polyclonal multi-source seeding m8 S 0 21
# single-source mistaken as polyclonal multi-source seeding m8 S 0 22
# single-source mistaken as polyclonal multi-source seeding m8 S 0 23
# single-source mistaken as polyclonal multi-source seeding m8 S 0 24
# single-source mistaken as polyclonal reseeding m8 S 0 25
# single-source mistaken as polyclonal multi-source seeding m8 S 0 26
# single-source mistaken as polyclonal multi-source seeding m8 S 0 27
# single-source mistaken as polyclonal multi-source seeding m8 S 0 28
# single-source mistaken as polyclonal multi-source seeding m8 S 0 29
# single-source mistaken as polyclonal multi-source seeding m8 S 0 30
# single-source mistaken as polyclonal reseeding m8 S 0 32
# single-source mistaken as polyclonal reseeding m8 S 0 34
# single-source mistaken as polyclonal multi-source seeding m8 S 0 36
# single-source mistaken as polyclonal reseeding m8 S 0 37
# single-source mistaken as polyclonal multi-source seeding m8 S 0 38
# single-source mistaken as polyclonal reseeding m8 S 0 39
# single-source mistaken as polyclonal multi-source seeding m8 S 0 41
# single-source mistaken as polyclonal multi-source seeding m8 S 0 42
# single-source mistaken as polyclonal multi-source seeding m8 S 0 43
# single-source mistaken as polyclonal multi-source seeding m8 S 0 44
# single-source mistaken as polyclonal multi-source seeding m8 S 0 45
# single-source mistaken as polyclonal multi-source seeding m8 S 0 46
# single-source mistaken as polyclonal multi-source seeding m8 S 0 47
# single-source mistaken as polyclonal multi-source seeding m8 S 0 48
# single-source mistaken as polyclonal multi-source seeding m8 S 0 49
# single-source mistaken as polyclonal multi-source seeding m8 S 0 50
# single-source mistaken as polyclonal multi-source seeding m8 S 0 51
# single-source mistaken as polyclonal multi-source seeding m8 S 0 52
# single-source mistaken as polyclonal multi-source seeding m8 S 0 53
# single-source mistaken as polyclonal multi-source seeding m8 S 0 54
# single-source mistaken as polyclonal multi-source seeding m8 S 0 55
# single-source mistaken as polyclonal multi-source seeding m8 S 0 56
# single-source mistaken as polyclonal multi-source seeding m8 S 0 57
# single-source mistaken as polyclonal multi-source seeding m8 S 0 58
# single-source mistaken as polyclonal multi-source seeding m8 S 0 59
# single-source mistaken as polyclonal multi-source seeding m8 S 0 60
# single-source mistaken as polyclonal multi-source seeding m8 S 0 61
# single-source mistaken as polyclonal multi-source seeding m8 S 0 62
# single-source mistaken as polyclonal multi-source seeding m8 S 0 63
# single-source mistaken as polyclonal multi-source seeding m8 S 0 64
# single-source mistaken as polyclonal multi-source seeding m8 S 0 65
# single-source mistaken as polyclonal multi-source seeding m8 S 0 67
# single-source mistaken as monoclonal reseeding m8 S 0 68
# single-source mistaken as polyclonal multi-source seeding m8 S 0 70
# single-source mistaken as polyclonal multi-source seeding m8 S 0 72
# single-source mistaken as polyclonal multi-source seeding m8 S 0 73
# single-source mistaken as polyclonal multi-source seeding m8 S 0 74
# single-source mistaken as polyclonal reseeding m8 S 0 75
# single-source mistaken as polyclonal multi-source seeding m8 S 0 76
# single-source mistaken as polyclonal reseeding m8 S 0 77
# single-source mistaken as polyclonal multi-source seeding m8 S 0 79
# single-source mistaken as polyclonal multi-source seeding m8 S 0 80
# single-source mistaken as monoclonal reseeding m8 S 0 81
# single-source mistaken as polyclonal reseeding m8 S 0 82
# single-source mistaken as polyclonal reseeding m8 S 0 83
# single-source mistaken as polyclonal multi-source seeding m8 S 0 84
# single-source mistaken as polyclonal multi-source seeding m8 S 0 85
# single-source mistaken as polyclonal multi-source seeding m8 S 0 86
# single-source mistaken as polyclonal multi-source seeding m8 S 0 87
# single-source mistaken as polyclonal multi-source seeding m8 S 0 88
# single-source mistaken as polyclonal multi-source seeding m8 S 0 89
# single-source mistaken as polyclonal multi-source seeding m8 S 0 90
# single-source mistaken as polyclonal multi-source seeding m8 S 0 91
# single-source mistaken as polyclonal multi-source seeding m8 S 0 92
# single-source mistaken as polyclonal multi-source seeding m8 S 0 93
# single-source mistaken as polyclonal multi-source seeding m8 S 0 94
# single-source mistaken as polyclonal multi-source seeding m8 S 0 95
# single-source mistaken as polyclonal multi-source seeding m8 S 0 96
# single-source mistaken as polyclonal multi-source seeding m8 S 0 97
# single-source mistaken as polyclonal multi-source seeding m8 S 0 98
# single-source mistaken as polyclonal multi-source seeding m8 S 0 99
# single-source mistaken as polyclonal multi-source seeding m8 S 0 100
# single-source mistaken as polyclonal multi-source seeding m8 S 0 101
# single-source mistaken as polyclonal multi-source seeding m8 S 0 102
# single-source mistaken as polyclonal reseeding m8 S 0 103
# single-source mistaken as polyclonal multi-source seeding m8 S 0 106
# single-source mistaken as polyclonal multi-source seeding m8 S 0 108
# single-source mistaken as polyclonal reseeding m8 S 0 109
# single-source mistaken as polyclonal multi-source seeding m8 S 0 111
# single-source mistaken as polyclonal multi-source seeding m8 S 0 112
# single-source mistaken as polyclonal multi-source seeding m8 S 0 113
# single-source mistaken as polyclonal multi-source seeding m8 S 0 114
# single-source mistaken as polyclonal multi-source seeding m8 S 0 116
# single-source mistaken as polyclonal multi-source seeding m8 S 0 118
# single-source mistaken as polyclonal multi-source seeding m8 S 0 119
# single-source mistaken as polyclonal multi-source seeding m8 S 0 121
# single-source mistaken as polyclonal multi-source seeding m8 S 0 125
# single-source mistaken as polyclonal multi-source seeding m8 S 0 126
# single-source mistaken as polyclonal reseeding m8 S 0 127
# single-source mistaken as polyclonal multi-source seeding m8 S 0 128
# single-source mistaken as polyclonal reseeding m8 S 0 129
# single-source mistaken as monoclonal reseeding m8 S 0 131
# single-source mistaken as polyclonal multi-source seeding m8 S 0 132
# single-source mistaken as polyclonal multi-source seeding m8 S 0 133
# single-source mistaken as polyclonal reseeding m8 S 0 134
# single-source mistaken as polyclonal reseeding m8 S 0 135
# single-source mistaken as polyclonal multi-source seeding m8 S 0 138
# single-source mistaken as polyclonal multi-source seeding m8 S 0 139
# single-source mistaken as polyclonal multi-source seeding m8 S 0 140
# single-source mistaken as polyclonal multi-source seeding m8 S 0 141
# single-source mistaken as polyclonal multi-source seeding m8 S 0 142
# single-source mistaken as polyclonal multi-source seeding m8 S 0 143
# single-source mistaken as polyclonal multi-source seeding m8 S 0 144
# single-source mistaken as polyclonal multi-source seeding m8 S 0 145
# single-source mistaken as polyclonal multi-source seeding m8 S 0 146
# single-source mistaken as polyclonal multi-source seeding m8 S 0 147
# single-source mistaken as polyclonal multi-source seeding m8 S 0 148
# single-source mistaken as polyclonal multi-source seeding m8 S 0 149
# single-source mistaken as polyclonal multi-source seeding m8 S 0 150
# single-source mistaken as polyclonal multi-source seeding m8 S 0 151
# single-source mistaken as polyclonal multi-source seeding m8 S 0 152
# single-source mistaken as polyclonal multi-source seeding m8 S 0 153
# single-source mistaken as polyclonal multi-source seeding m8 S 0 154
# single-source mistaken as polyclonal multi-source seeding m8 S 0 155
# single-source mistaken as polyclonal reseeding m8 S 0 156
# single-source mistaken as polyclonal multi-source seeding m8 S 0 157
# single-source mistaken as polyclonal multi-source seeding m8 S 0 160
# single-source mistaken as polyclonal reseeding m8 S 0 161
# single-source mistaken as polyclonal multi-source seeding m8 S 0 163
# single-source mistaken as polyclonal multi-source seeding m8 S 0 164
# single-source mistaken as polyclonal multi-source seeding m8 S 0 165
# single-source mistaken as polyclonal multi-source seeding m8 S 0 166
# single-source mistaken as polyclonal multi-source seeding m8 S 0 167
# single-source mistaken as polyclonal multi-source seeding m8 S 0 168
# single-source mistaken as polyclonal reseeding m8 S 0 170
# single-source mistaken as polyclonal multi-source seeding m8 S 0 171
# single-source mistaken as polyclonal reseeding m8 S 0 172
# single-source mistaken as polyclonal reseeding m8 S 0 174
# single-source mistaken as polyclonal multi-source seeding m8 S 0 175
# single-source mistaken as polyclonal multi-source seeding m8 S 0 178
# single-source mistaken as polyclonal reseeding m8 S 0 179
# single-source mistaken as monoclonal reseeding m8 S 0 180
# single-source mistaken as polyclonal reseeding m8 S 0 181
# single-source mistaken as polyclonal multi-source seeding m8 S 0 183
# single-source mistaken as polyclonal reseeding m8 S 0 184
# single-source mistaken as polyclonal multi-source seeding m8 S 0 185
# single-source mistaken as polyclonal multi-source seeding m8 S 0 186
# single-source mistaken as polyclonal multi-source seeding m8 S 0 187
# single-source mistaken as polyclonal multi-source seeding m8 S 0 188
# single-source mistaken as polyclonal reseeding m8 S 0 189
# single-source mistaken as polyclonal multi-source seeding m8 S 0 190
# single-source mistaken as polyclonal reseeding m8 S 0 191
# 1
# 5
# 2
# single-source mistaken as polyclonal multi-source seeding m8 S 31 0
# single-source mistaken as polyclonal multi-source seeding m8 S 31 1
# single-source mistaken as polyclonal multi-source seeding m8 S 31 2
# single-source mistaken as polyclonal multi-source seeding m8 S 31 3
# single-source mistaken as polyclonal multi-source seeding m8 S 31 4
# single-source mistaken as polyclonal multi-source seeding m8 S 31 5
# single-source mistaken as polyclonal multi-source seeding m8 S 31 7
# single-source mistaken as polyclonal multi-source seeding m8 S 31 8
# single-source mistaken as polyclonal multi-source seeding m8 S 31 9
# single-source mistaken as polyclonal multi-source seeding m8 S 31 10
# single-source mistaken as polyclonal multi-source seeding m8 S 31 11
# single-source mistaken as polyclonal multi-source seeding m8 S 31 37
# single-source mistaken as polyclonal multi-source seeding m8 S 31 40
# single-source mistaken as polyclonal multi-source seeding m8 S 31 41
# single-source mistaken as polyclonal multi-source seeding m8 S 31 42
# 10
# 1
# 2
# 2
# 1
# single-source mistaken as polyclonal multi-source seeding m8 S 2 0
# single-source mistaken as polyclonal multi-source seeding m8 S 2 1
# single-source mistaken as polyclonal multi-source seeding m8 S 2 13
# single-source mistaken as polyclonal multi-source seeding m8 S 2 16
# single-source mistaken as polyclonal multi-source seeding m8 S 2 18
# single-source mistaken as polyclonal multi-source seeding m8 S 2 19
# single-source mistaken as polyclonal multi-source seeding m8 S 2 22
# single-source mistaken as polyclonal multi-source seeding m8 S 2 24
# single-source mistaken as polyclonal multi-source seeding m8 S 2 25
# single-source mistaken as polyclonal multi-source seeding m8 S 2 27
# single-source mistaken as polyclonal multi-source seeding m8 S 2 32
# single-source mistaken as polyclonal multi-source seeding m8 S 2 35
# single-source mistaken as polyclonal multi-source seeding m8 S 2 36
# single-source mistaken as polyclonal multi-source seeding m8 S 2 37
# single-source mistaken as polyclonal multi-source seeding m8 S 2 39
# single-source mistaken as polyclonal multi-source seeding m8 S 2 40
# single-source mistaken as polyclonal multi-source seeding m8 S 2 41
# single-source mistaken as polyclonal multi-source seeding m8 S 2 43
# single-source mistaken as polyclonal multi-source seeding m8 S 2 44
# single-source mistaken as polyclonal multi-source seeding m8 S 2 45
# single-source mistaken as polyclonal multi-source seeding m8 S 2 46
# single-source mistaken as polyclonal multi-source seeding m8 S 2 47
# single-source mistaken as polyclonal multi-source seeding m8 S 2 48
# single-source mistaken as polyclonal multi-source seeding m8 S 2 50
# single-source mistaken as polyclonal multi-source seeding m8 S 2 51
# single-source mistaken as polyclonal multi-source seeding m8 S 2 53
# single-source mistaken as polyclonal multi-source seeding m8 S 2 56
# single-source mistaken as polyclonal multi-source seeding m8 S 2 58
# single-source mistaken as polyclonal multi-source seeding m8 S 2 60
# single-source mistaken as polyclonal multi-source seeding m8 S 2 62
# single-source mistaken as polyclonal multi-source seeding m8 S 2 63
# single-source mistaken as polyclonal multi-source seeding m8 S 2 64
# single-source mistaken as polyclonal multi-source seeding m8 S 2 66
# single-source mistaken as polyclonal reseeding m8 S 2 67
# single-source mistaken as polyclonal multi-source seeding m8 S 2 68
# single-source mistaken as polyclonal multi-source seeding m8 S 2 75
# single-source mistaken as polyclonal multi-source seeding m8 S 2 79
# single-source mistaken as polyclonal multi-source seeding m8 S 2 83
# single-source mistaken as polyclonal multi-source seeding m8 S 2 84
# single-source mistaken as polyclonal multi-source seeding m8 S 2 86
# single-source mistaken as polyclonal multi-source seeding m8 S 2 87
# single-source mistaken as polyclonal multi-source seeding m8 S 2 88
# single-source mistaken as polyclonal multi-source seeding m8 S 2 89
# single-source mistaken as polyclonal multi-source seeding m8 S 2 90
# single-source mistaken as polyclonal multi-source seeding m8 S 2 91
# single-source mistaken as polyclonal multi-source seeding m8 S 2 92
# single-source mistaken as polyclonal multi-source seeding m8 S 2 93
# single-source mistaken as polyclonal multi-source seeding m8 S 2 94
# single-source mistaken as polyclonal multi-source seeding m8 S 2 96
# single-source mistaken as polyclonal multi-source seeding m8 S 2 97
# single-source mistaken as polyclonal multi-source seeding m8 S 2 99
# single-source mistaken as polyclonal multi-source seeding m8 S 2 100
# single-source mistaken as polyclonal multi-source seeding m8 S 2 101
# single-source mistaken as polyclonal multi-source seeding m8 S 2 104
# single-source mistaken as polyclonal multi-source seeding m8 S 2 106
# single-source mistaken as polyclonal multi-source seeding m8 S 2 107
# single-source mistaken as polyclonal multi-source seeding m8 S 2 109
# single-source mistaken as polyclonal multi-source seeding m8 S 2 111
# single-source mistaken as polyclonal multi-source seeding m8 S 2 114
# single-source mistaken as polyclonal multi-source seeding m8 S 2 115
# single-source mistaken as polyclonal multi-source seeding m8 S 2 118
# single-source mistaken as polyclonal multi-source seeding m8 S 2 119
# single-source mistaken as polyclonal multi-source seeding m8 S 2 126
# single-source mistaken as polyclonal multi-source seeding m8 S 2 130
# single-source mistaken as polyclonal multi-source seeding m8 S 2 131
# single-source mistaken as polyclonal multi-source seeding m8 S 2 132
# single-source mistaken as polyclonal multi-source seeding m8 S 2 133
# single-source mistaken as polyclonal multi-source seeding m8 S 2 134
# single-source mistaken as polyclonal multi-source seeding m8 S 2 138
# single-source mistaken as polyclonal multi-source seeding m8 S 2 139
# single-source mistaken as polyclonal multi-source seeding m8 S 2 141
# single-source mistaken as polyclonal multi-source seeding m8 S 2 142
# single-source mistaken as polyclonal multi-source seeding m8 S 2 143
# 1
# 3
# m5 R
# 1
# 1
# 1
# 1
# 1
# 3
# 4
# 1
# 1
# 8
# m8 R
# 1
# 1
# 1
# 1
# 1
# 10
# 1
# 3
# 1
# 1

# %% [markdown]
# ### What is the distribution of genetic distance scores for each seeding pattern?

# %%
def get_overall_pattern(row):
    pattern = row['Seeding pattern'].split(" ")[1]
    # 3 options: single-source, multi-source, reseeding
    return overall_pattern_map[pattern]

# %%
import seaborn as sns
import matplotlib.pyplot as plt
from statannot import add_stat_annotation

for mig_type in mig_type_to_seeding_pattern_df:
    print("ground truth:",mig_type)
    mig_type_to_seeding_pattern_df[mig_type]['Overall Pattern'] = mig_type_to_seeding_pattern_df[mig_type].apply(lambda row: get_overall_pattern(row), axis=1)

    plt.figure(figsize=(8, 6))  # Optional: Set the size of the plot
    box_pairs = []
    for pattern_i in mig_type_to_seeding_pattern_df:
        for pattern_j in mig_type_to_seeding_pattern_df:
            if pattern_i != pattern_j:
                box_pairs.append((pattern_i,pattern_j))
    snsfig = sns.boxplot(x='Overall Pattern', y='Evaluation loss', data=mig_type_to_seeding_pattern_df[mig_type])
    add_stat_annotation(snsfig, data=mig_type_to_seeding_pattern_df[mig_type], x='Overall Pattern', y='Evaluation loss',
                    box_pairs=[("monoclonal", "polyclonal")], test='t-test_welch', text_format='star', loc='inside', verbose=1, fontsize=18, comparisons_correction=None)

    plt.xticks(rotation=45)
    plt.show()
# Out:
# ground truth: single-source
# ground truth: multi-source
# ground truth: reseeding

# %% [markdown]
# ### What is the genetic distance score of the top k solutions (by genetic distance score) for each seeding pattern?

# %%
import seaborn as sns
import matplotlib.pyplot as plt


for mig_type in mig_type_to_seeding_pattern_df:
    print("ground truth:",mig_type)
    mig_type_to_topk_seeding_pattern_df[mig_type]['Overall Pattern'] = mig_type_to_topk_seeding_pattern_df[mig_type].apply(lambda row: get_overall_pattern(row), axis=1)

    plt.figure(figsize=(8, 6))  # Optional: Set the size of the plot
    sns.boxplot(x='Overall Pattern', y='Evaluation loss', data=mig_type_to_topk_seeding_pattern_df[mig_type])
    plt.xticks(rotation=45)
    plt.show()
# Out:
# ground truth: single-source
# ground truth: multi-source
# ground truth: reseeding

# %% [markdown]
# ### What percent of the top k solutions (by genetic distance score) belong to each seeding pattern?

# %%
import seaborn as sns
import matplotlib.pyplot as plt


for mig_type in mig_type_to_seeding_pattern_df:
    print("ground truth:",mig_type)
    df = mig_type_to_topk_seeding_pattern_counts_df[mig_type]

    df['Overall Pattern'] = df.apply(lambda row: get_overall_pattern(row), axis=1)
    df['Percentage'] = df.apply(lambda row: row['count']/float(k), axis=1)

    plt.figure(figsize=(8, 6))  # Optional: Set the size of the plot
    sns.boxplot(x='Overall Pattern', y='Percentage', data=df)
    plt.xticks(rotation=45)
    plt.show()
# Out:
# ground truth: single-source
# ground truth: multi-source
# ground truth: reseeding

# %%
for pattern in mig_type_to_topk_seeding_pattern_counts_df:
    print("ground truth:", pattern)
    df = mig_type_to_topk_seeding_pattern_counts_df[pattern]
    print(df)
    grouped_df = df.groupby(['Overall Pattern'])['count'].sum()
    print(grouped_df)
    #sns.stripplot(data=grouped_df, x='Cell_Type', y='Fraction', hue='Marker', jitter=True, size=10, palette='Reds')
# Out:
# ground truth: single-source
#                      Seeding pattern  count Overall Pattern  Percentage
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   monoclonal single-source seeding      5   single-source       1.000
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   monoclonal single-source seeding      5   single-source       1.000
# ..                               ...    ...             ...         ...
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   polyclonal single-source seeding      5   single-source       1.000
#
# [1071 rows x 4 columns]
# Overall Pattern
# multi-source      855
# reseeding         924
# single-source    1706
# Name: count, dtype: int64
# ground truth: multi-source
#                      Seeding pattern  count Overall Pattern  Percentage
# 0    polyclonal multi-source seeding      5    multi-source       1.000
# 0    polyclonal multi-source seeding      5    multi-source       1.000
# 0    polyclonal multi-source seeding      3    multi-source       0.600
# 1   polyclonal single-source seeding      2   single-source       0.400
# 0    polyclonal multi-source seeding      5    multi-source       1.000
# ..                               ...    ...             ...         ...
# 0    polyclonal multi-source seeding      5    multi-source       1.000
# 0               polyclonal reseeding      4       reseeding       0.800
# 1    polyclonal multi-source seeding      1    multi-source       0.200
# 0    polyclonal multi-source seeding      4    multi-source       0.800
# 1               polyclonal reseeding      1       reseeding       0.200
#
# [815 rows x 4 columns]
# Overall Pattern
# multi-source     1275
# reseeding         285
# single-source     927
# Name: count, dtype: int64
# ground truth: reseeding
#                      Seeding pattern  count Overall Pattern  Percentage
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   polyclonal single-source seeding      5   single-source       1.000
# 0   polyclonal single-source seeding      5   single-source       1.000
# ..                               ...    ...             ...         ...
# 0               polyclonal reseeding      5       reseeding       1.000
# 0               polyclonal reseeding      5       reseeding       1.000
# 0               polyclonal reseeding      4       reseeding       0.800
# 1   polyclonal single-source seeding      1   single-source       0.200
# 0               polyclonal reseeding      5       reseeding       1.000
#
# [623 rows x 4 columns]
# Overall Pattern
# multi-source      511
# reseeding        1349
# single-source     400
# Name: count, dtype: int64

# %% [markdown]
# ### What is the confusion matrix for the consensus pattern?

# %%
def confusion_matrix(cm, title, name):
    with sns.plotting_context("notebook", font_scale=1.2):

        g = sns.heatmap(cm, annot=True, cmap="Blues", fmt=".0f",
                    xticklabels=[p.capitalize() for p in patterns],
                    yticklabels=[p.capitalize() for p in patterns])

        # Add labels, title, and customize the plot
        plt.xlabel("Predicted")
        plt.ylabel("True")
        plt.title(title)
        
        plt.savefig(os.path.join(REPO_DIR, "src/test/output_plots", f"{name}.png"), dpi=600) 
        plt.show()

        plt.close()

# %%
import numpy as np
patterns = [k for k in mig_type_to_consensus_pattern]
print(patterns)
cm = np.zeros((len(patterns), len(patterns)))
for i,gt_pattern in enumerate(patterns):
    print("ground truth:", gt_pattern)
    pred_consensus_df = pd.DataFrame(mig_type_to_consensus_pattern[gt_pattern], columns=["Seeding pattern"])
    pred_consensus_df['Overall Consensus Pattern'] = pred_consensus_df.apply(lambda row: get_overall_pattern(row), axis=1)
    counts_df = pred_consensus_df['Overall Consensus Pattern'].value_counts()
    print(counts_df)
    for j,pred_pattern in enumerate(patterns):
        cm[i,j] = counts_df[pred_pattern]

        
confusion_matrix(cm, "Genetic Distance Consensus Pattern Classification", "gd_classification_consensus_pattern_bs256_solvepoly_calibrate_10302023")
# Out:
# ['single-source', 'multi-source', 'reseeding']
# ground truth: single-source
# Overall Consensus Pattern
# single-source    438
# multi-source     217
# reseeding         42
# Name: count, dtype: int64
# ground truth: multi-source
# Overall Consensus Pattern
# single-source    244
# multi-source     226
# reseeding         28
# Name: count, dtype: int64
# ground truth: reseeding
# Overall Consensus Pattern
# reseeding        215
# single-source    153
# multi-source      84
# Name: count, dtype: int64

# %% [markdown]
# ### What is the confusion matrix for the top seeding pattern?

# %%
import numpy as np
patterns = [k for k in mig_type_to_top_pattern]
print(patterns)
cm = np.zeros((len(patterns), len(patterns)))
for i,gt_pattern in enumerate(patterns):
    print("ground truth:", gt_pattern)
    pred_df = pd.DataFrame(mig_type_to_top_pattern[gt_pattern], columns=["Seeding pattern"])
    pred_df['Overall Pattern'] = pred_df.apply(lambda row: get_overall_pattern(row), axis=1)
    counts_df = pred_df['Overall Pattern'].value_counts()
    print(counts_df)
    for j,pred_pattern in enumerate(patterns):
        cm[i,j] = counts_df[pred_pattern]

confusion_matrix(cm, "Calibrate mode: Genetic Distance Classification", "top_seeding_pattern_by_gd_eval_loss_bs256_solvepoly_calibrate_11012023")
# Out:
# ['single-source', 'multi-source', 'reseeding']
# ground truth: single-source
# Overall Pattern
# single-source    383
# reseeding        208
# multi-source     191
# Name: count, dtype: int64
# ground truth: multi-source
# Overall Pattern
# multi-source     321
# single-source    113
# reseeding         96
# Name: count, dtype: int64
# ground truth: reseeding
# Overall Pattern
# reseeding        323
# multi-source     101
# single-source     71
# Name: count, dtype: int64

# %% [markdown]
# ### What is the confusion matrix in evaluate mode?

# %%
import joblib
import glob
import gzip


def get_top_seeding_patterns_eval_mode(predictions_dir):
    eval_mode_mig_type_to_top_seeding_pattern = {}
    for mig_type in MIG_TYPES:
        for site in SITES:
            print(site, mig_type)
            site_mig_type_dir = os.path.join(SIMS_DIR, site, mig_type)
            seeds = fnmatch.filter(os.listdir(site_mig_type_dir), 'clustering_observed_seed*.txt')
            seeds = [s.replace(".txt", "").replace("clustering_observed_seed", "") for s in seeds]
            for seed in seeds:
                tree_pickles = glob.glob(os.path.join(predictions_dir, site, mig_type, f"*_seed{seed}.pkl.gz"))
                for tree_pickle in tree_pickles:

                    with gzip.open(tree_pickle,'rb') as f:
                        results_dict = joblib.load(f)
                    V = results_dict[OUT_LABElING_KEY][0]
                    A = results_dict[OUT_ADJ_KEY][0]

                    mapped_type = types_map[mig_type]
                    if mapped_type not in eval_mode_mig_type_to_top_seeding_pattern:
                        eval_mode_mig_type_to_top_seeding_pattern[mapped_type] = []
                    top_pattern = putil.get_seeding_pattern(V,A)
                    eval_mode_mig_type_to_top_seeding_pattern[mapped_type].append(top_pattern)

    patterns = [k for k in eval_mode_mig_type_to_top_seeding_pattern]
    print(patterns)
    cm = np.zeros((len(patterns), len(patterns)))
    for i,gt_pattern in enumerate(patterns):
        print("ground truth:", gt_pattern)
        pred_df = pd.DataFrame(eval_mode_mig_type_to_top_seeding_pattern[gt_pattern], columns=["Seeding pattern"])
        pred_df['Overall Pattern'] = pred_df.apply(lambda row: get_overall_pattern(row), axis=1)
        counts_df = pred_df['Overall Pattern'].value_counts()
        print(counts_df)
        for j,pred_pattern in enumerate(patterns):
            cm[i,j] = counts_df[pred_pattern]
    return cm

# %%
# Evaluate mode, maximum parsimony only
eval_mode_no_gd_dir = os.path.join(REPO_DIR, "src/test/machina_simulated_data/predictions_bs256_solvepoly_evaluate_nogd_11012023")
cm = get_top_seeding_patterns_eval_mode(eval_mode_no_gd_dir)
confusion_matrix(cm, "Evaluate mode: Maximum Parsimony Classification", "top_seeding_pattern_by_mp_bs256_solvepoly_evaluate_nogd_11012023")
# Out:
# m5 mS
# m8 mS
# m5 M
# m8 M
# m5 S
# m8 S
# m5 R
# m8 R
# ['single-source', 'multi-source', 'reseeding']
# ground truth: single-source
# Overall Pattern
# single-source    363
# multi-source     271
# reseeding         63
# Name: count, dtype: int64
# ground truth: multi-source
# Overall Pattern
# multi-source     313
# single-source     97
# reseeding         88
# Name: count, dtype: int64
# ground truth: reseeding
# Overall Pattern
# reseeding        229
# multi-source     119
# single-source    104
# Name: count, dtype: int64

# %%
# Evaluate mode, maximum parsimony and genetic distance
eval_mode_no_gd_dir = os.path.join(REPO_DIR, "src/test/machina_simulated_data/predictions_bs256_solvepoly_evaluate_gd_11012023")
cm = get_top_seeding_patterns_eval_mode(eval_mode_no_gd_dir)
confusion_matrix(cm, "Evaluate mode: Maximum Parsimony + \nGenetic Distance Classification", "top_seeding_pattern_by_mp_gd_bbs256_solvepoly_evaluate_gd_11012023")
# Out:
# m5 mS
# m8 mS
# m5 M
# m8 M
# m5 S
# m8 S
# m5 R
# m8 R
# ['single-source', 'multi-source', 'reseeding']
# ground truth: single-source
# Overall Pattern
# single-source    345
# multi-source     257
# reseeding         95
# Name: count, dtype: int64
# ground truth: multi-source
# Overall Pattern
# multi-source     409
# reseeding         73
# single-source     16
# Name: count, dtype: int64
# ground truth: reseeding
# Overall Pattern
# reseeding        250
# multi-source     103
# single-source     99
# Name: count, dtype: int64
