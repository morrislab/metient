# %% [markdown]
# ### Load paths

# %%
import pyreadr
import os
import pandas as pd

pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)

REPO_DIR = os.path.join(os.getcwd(), "../../")
os.chdir(REPO_DIR)

TRACERX_DATA_DIR = os.path.join(REPO_DIR, "src/data/tracerx_nsclc/")
OUTPUT_DIR = os.path.join(REPO_DIR, "src/data/tracerx_nsclc/patient_data")
CONIPHER_DIR = os.path.join(REPO_DIR, "src/data/tracerx_nsclc/conipher_inputs")

# %% [markdown]
# ### Load sample overview information (from TRACERx publicly available data)

# %%
sample_info_df= pd.read_csv(os.path.join(TRACERX_DATA_DIR,"sample_overview_original.txt"), sep="\t")
print(sample_info_df['sampleType'].value_counts())
print(sample_info_df['sampleTypeDetail'].value_counts())
sample_info_df
# Out:
# primary       476
# metastasis    218
# Name: sampleType, dtype: int64
# primary            476
# LN                 148
# metachronousMet     67
# synchronousMet       3
# Name: sampleTypeDetail, dtype: int64
#     patient_id tumour_id             region  sampleType sampleTypeDetail
# 0     CRUK0010  CRUK0010  CRUK0010_SU_T1.R1     primary          primary
# 1     CRUK0010  CRUK0010  CRUK0010_SU_T1.R2     primary          primary
# 2     CRUK0010  CRUK0010   CRUK0010_SU_FLN1  metastasis               LN
# 3     CRUK0010  CRUK0010    CRUK0010_BR_LN1  metastasis  metachronousMet
# 4     CRUK0010  CRUK0010    CRUK0010_BR_LN2  metastasis  metachronousMet
# ..         ...       ...                ...         ...              ...
# 689   CRUK0872  CRUK0872  CRUK0872_SU_T1.R1     primary          primary
# 690   CRUK0872  CRUK0872  CRUK0872_SU_T1.R2     primary          primary
# 691   CRUK0872  CRUK0872  CRUK0872_SU_T1.R3     primary          primary
# 692   CRUK0872  CRUK0872  CRUK0872_SU_T1.R4     primary          primary
# 693   CRUK0872  CRUK0872   CRUK0872_SU_FLN1  metastasis               LN
#
# [694 rows x 5 columns]

# %% [markdown]
# ### Load purity and ploidy information (from TRACERx publicly available data)

# %%
purity_ploidy_df = pd.read_csv(os.path.join(TRACERX_DATA_DIR, "20220808_purityandploidy.txt"), sep="\t")
purity_ploidy_df
# Out:
#       Patient             Sample  final.purity  final.ploidy
# 0    CRUK0090  CRUK0090_SU_T1.R2          0.54          3.15
# 1    CRUK0090  CRUK0090_BP_T1.R1          0.74          3.25
# 2    CRUK0090  CRUK0090_BR_T1.R1          0.20          3.30
# 3    CRUK0090  CRUK0090_SU_T1.R1          0.58          3.20
# 4    CRUK0090  CRUK0090_BP_T2.R1          0.23          3.40
# ..        ...                ...           ...           ...
# 689  CRUK0810  CRUK0810_SU_T1.R4          0.49          3.85
# 690  CRUK0810  CRUK0810_SU_T1.R1          0.25          3.70
# 691  CRUK0810  CRUK0810_SU_T1.R8          0.20          3.95
# 692  CRUK0810  CRUK0810_SU_T1.R6          0.39          3.65
# 693  CRUK0810  CRUK0810_SU_T1.R5          0.51          3.75
#
# [694 rows x 4 columns]

# %% [markdown]
# ### Load all patient mutation data (from TRACERx publicly available data)

# %%
patient_data_all = pyreadr.read_r(os.path.join(TRACERX_DATA_DIR, 'mutTableAll.cloneInfo.20220726.rda'))
patient_data_all_df = patient_data_all['mutTableAll']
print("Patient data columns:\n ", patient_data_all_df.columns)
print(patient_data_all_df[:10]['RegionSum'])

patient_data_all_df = patient_data_all_df[['mutation_id', 'patient_id', 'Hugo_Symbol','exonic.func','NucleotideChange', 'RegionSum' , 'MajorCPN_SC', 'MinorCPN_SC', 'chr', 'start', 'stop', 'ref', 'var']]
unique_patients = patient_data_all_df['patient_id'].unique()
print("Number of unique patients:", len(unique_patients))
patient_data_all_df
# Out:
# Patient data columns:
#   Index(['mutation_id', 'patient_id', 'tumour_id', 'chr', 'start', 'stop', 'ref',
#        'var', 'Hugo_Symbol', 'func', 'exonic.func', 'NucleotideChange',
#        'AAChange', 'GL_VAF', 'GL_nAlt', 'GL_depth', 'ITHState', 'RegionSum',
#        'Is.present', 'PyCloneClonal_SC', 'PyCloneCluster_SC',
#        'cleanCluster_SC', 'PhyloCCF_SC', 'combTiming_SC', 'MutCPN_SC',
#        'MajorCPN_SC', 'MinorCPN_SC', 'DriverMut', 'treeClones',
#        'seedingClones', 'clonalClones', 'sharedClones', 'primaryClones',
#        'metClones'],
#       dtype='object')
# 0              BR_LN1:40/168;BR_LN2:64/276;BR_LN3:47/235;SU_FLN1:96/518;SU_T1.R1:236/317;SU_T1.R2:80/227
# 1               BR_LN1:14/106;BR_LN2:18/155;BR_LN3:18/138;SU_FLN1:12/102;SU_T1.R1:94/153;SU_T1.R2:27/175
# 2              BR_LN1:44/191;BR_LN2:55/233;BR_LN3:75/260;SU_FLN1:86/288;SU_T1.R1:148/245;SU_T1.R2:92/270
# 3             BR_LN1:71/525;BR_LN2:61/694;BR_LN3:60/675;SU_FLN1:57/485;SU_T1.R1:385/647;SU_T1.R2:103/654
# 4               BR_LN1:16/116;BR_LN2:21/141;BR_LN3:27/180;SU_FLN1:49/281;SU_T1.R1:76/152;SU_T1.R2:31/139
# 5            BR_LN1:55/456;BR_LN2:54/702;BR_LN3:84/653;SU_FLN1:131/863;SU_T1.R1:278/559;SU_T1.R2:152/626
# 6    BR_LN1:136/815;BR_LN2:190/1083;BR_LN3:222/1104;SU_FLN1:161/1095;SU_T1.R1:669/1375;SU_T1.R2:291/1096
# 7           BR_LN1:63/368;BR_LN2:86/542;BR_LN3:103/571;SU_FLN1:112/585;SU_T1.R1:312/677;SU_T1.R2:127/528
# 8              BR_LN1:39/333;BR_LN2:43/454;BR_LN3:65/486;SU_FLN1:41/435;SU_T1.R1:270/604;SU_T1.R2:66/431
# 9              BR_LN1:39/291;BR_LN2:45/420;BR_LN3:56/445;SU_FLN1:76/570;SU_T1.R1:225/534;SU_T1.R2:99/437
# Name: RegionSum, dtype: object
# Number of unique patients: 126
#                    mutation_id patient_id Hugo_Symbol        exonic.func  \
# 0        CRUK0010:3:47103798:G   CRUK0010       SETD2       stopgain SNV
# 1        CRUK0010:6:45459895:C   CRUK0010       RUNX2                NaN
# 2       CRUK0010:1:156105064:C   CRUK0010        LMNA     synonymous SNV
# 3        CRUK0010:6:25850091:C   CRUK0010     SLC17A3       stopgain SNV
# 4        CRUK0010:8:16001109:G   CRUK0010        MSR1  nonsynonymous SNV
# ...                        ...        ...         ...                ...
# 136310  CRUK0872:22:40080280:C   CRUK0872     CACNA1I                NaN
# 136311  CRUK0872:14:99872776:T   CRUK0872       SETD3                NaN
# 136312  CRUK0872:8:110131566:C   CRUK0872        TRHR       stopgain SNV
# 136313   CRUK0872:1:51032853:G   CRUK0872        FAF1  nonsynonymous SNV
# 136314  CRUK0872:20:24524120:G   CRUK0872     SYNDIG1     synonymous SNV
#
#        NucleotideChange  \
# 0              c.C6148T
# 1                   NaN
# 2               c.C561T
# 3               c.G979T
# 4               c.C991G
# ...                 ...
# 136310              NaN
# 136311              NaN
# 136312         c.C1079A
# 136313         c.C1164G
# 136314          c.G387A
#
#                                                                                          RegionSum  \
# 0        BR_LN1:40/168;BR_LN2:64/276;BR_LN3:47/235;SU_FLN1:96/518;SU_T1.R1:236/317;SU_T1.R2:80/227
# 1         BR_LN1:14/106;BR_LN2:18/155;BR_LN3:18/138;SU_FLN1:12/102;SU_T1.R1:94/153;SU_T1.R2:27/175
# 2        BR_LN1:44/191;BR_LN2:55/233;BR_LN3:75/260;SU_FLN1:86/288;SU_T1.R1:148/245;SU_T1.R2:92/270
# 3       BR_LN1:71/525;BR_LN2:61/694;BR_LN3:60/675;SU_FLN1:57/485;SU_T1.R1:385/647;SU_T1.R2:103/654
# 4         BR_LN1:16/116;BR_LN2:21/141;BR_LN3:27/180;SU_FLN1:49/281;SU_T1.R1:76/152;SU_T1.R2:31/139
# ...                                                                                            ...
# 136310     SU_FLN1:18/668;SU_LN1:1/446;SU_T1.R1:0/602;SU_T1.R2:0/501;SU_T1.R3:0/443;SU_T1.R4:0/463
# 136311     SU_FLN1:0/573;SU_LN1:0/518;SU_T1.R1:0/609;SU_T1.R2:0/625;SU_T1.R3:0/581;SU_T1.R4:13/510
# 136312     SU_FLN1:0/562;SU_LN1:3/616;SU_T1.R1:2/716;SU_T1.R2:0/763;SU_T1.R3:0/722;SU_T1.R4:16/650
# 136313     SU_FLN1:0/389;SU_LN1:0/394;SU_T1.R1:0/464;SU_T1.R2:0/484;SU_T1.R3:11/449;SU_T1.R4:0/428
# 136314   SU_FLN1:10/1295;SU_LN1:15/612;SU_T1.R1:0/745;SU_T1.R2:1/716;SU_T1.R3:0/740;SU_T1.R4:0/621
#
#                                                        MajorCPN_SC  \
# 0       SU_T1.R1:3;SU_T1.R2:2;SU_FLN1:2;BR_LN1:2;BR_LN2:2;BR_LN3:2
# 1       SU_T1.R1:2;SU_T1.R2:1;SU_FLN1:1;BR_LN1:1;BR_LN2:1;BR_LN3:1
# 2       SU_T1.R1:2;SU_T1.R2:2;SU_FLN1:3;BR_LN1:2;BR_LN2:2;BR_LN3:3
# 3       SU_T1.R1:2;SU_T1.R2:1;SU_FLN1:2;BR_LN1:1;BR_LN2:1;BR_LN3:1
# 4       SU_T1.R1:1;SU_T1.R2:1;SU_FLN1:1;BR_LN1:1;BR_LN2:1;BR_LN3:1
# ...                                                            ...
# 136310       SU_T1.R1:3;SU_T1.R2:3;SU_T1.R3:2;SU_T1.R4:3;SU_FLN1:3
# 136311       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:2
# 136312       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:2
# 136313       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:2
# 136314                                                         NaN
#
#                                                        MinorCPN_SC    chr  \
# 0       SU_T1.R1:0;SU_T1.R2:0;SU_FLN1:0;BR_LN1:0;BR_LN2:0;BR_LN3:0   chr3
# 1       SU_T1.R1:0;SU_T1.R2:1;SU_FLN1:1;BR_LN1:1;BR_LN2:1;BR_LN3:1   chr6
# 2       SU_T1.R1:0;SU_T1.R2:0;SU_FLN1:0;BR_LN1:0;BR_LN2:0;BR_LN3:0   chr1
# 3       SU_T1.R1:0;SU_T1.R2:1;SU_FLN1:1;BR_LN1:1;BR_LN2:1;BR_LN3:1   chr6
# 4       SU_T1.R1:0;SU_T1.R2:0;SU_FLN1:0;BR_LN1:0;BR_LN2:0;BR_LN3:0   chr8
# ...                                                            ...    ...
# 136310       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:3;SU_FLN1:2  chr22
# 136311       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:2  chr14
# 136312       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:2   chr8
# 136313       SU_T1.R1:2;SU_T1.R2:2;SU_T1.R3:2;SU_T1.R4:2;SU_FLN1:1   chr1
# 136314                                                         NaN  chr20
#
#             start       stop ref var
# 0        47103798   47103798   G   A
# 1        45459895   45459895   C   G
# 2       156105064  156105064   C   T
# 3        25850091   25850091   C   A
# 4        16001109   16001109   G   C
# ...           ...        ...  ..  ..
# 136310   40080280   40080280   C   T
# 136311   99872776   99872776   T   C
# 136312  110131566  110131566   C   A
# 136313   51032853   51032853   G   C
# 136314   24524120   24524120   G   A
#
# [136315 rows x 13 columns]

# %% [markdown]
# ### Update sample overview df since some sample information is missing

# %%
'''
Examples of missing sample info:
CRUK0361_SU_FLN1
CRUK0702_SU_LN2
CRUK0027_SU_T1.R3
'''

# rows_to_add = []
# missing_sample_names = []
# for patient_id in unique_patients:
#     sample_names = patient_data_all_df[patient_data_all_df['patient_id']==patient_id]['RegionSum'].iloc[0]
#     sample_names = [patient_id +"_"+x.split(":")[0] for x in sample_names.split(";")]
#     for sample_name in sample_names:
#         sample_info = sample_info_df[sample_info_df['region']==sample_name]
#         if len(sample_info) == 0:
#             missing_sample_names.append(sample_name)
#             # Use the same sampleType and sampleTypeDetail as the other matching samples for that patient
#             # e.g. CRUK0361_SU_FLN1 and CRUK0361_SU_FLN2 should get the sample sample info
#             patient_samples = sample_info_df[sample_info_df['patient_id']==patient_id]
#             if ("FLN" in sample_name) or ("LN" in sample_name):
#                 rows_to_add.append([patient_id, patient_id, sample_name, "metastasis", "LN"])
#             else:
#                 matching = patient_samples[patient_samples['region'].str.contains(sample_name.split(".")[0])].iloc[0]
#                 rows_to_add.append([patient_id, matching['tumour_id'], sample_name, matching['sampleType'], matching['sampleTypeDetail']])

# print(missing_sample_names)
# updated_sample_df = pd.concat([sample_info_df, pd.DataFrame(rows_to_add, columns=sample_info_df.columns)], ignore_index=True)
# updated_sample_df.to_csv(os.path.join(TRACERX_DATA_DIR,"sample_overview_complete.txt"), index=False, sep='\t')
# Out:
# ['CRUK0361_SU_FLN1', 'CRUK0361_SU_FLN2', 'CRUK0361_SU_FLN3', 'CRUK0702_SU_LN2', 'CRUK0027_SU_T1.R3', 'CRUK0286_SU_T1.R2', 'CRUK0227_SU_T1.R1', 'CRUK0478_SU_T1.R2', 'CRUK0598_SU_FLN1', 'CRUK0524_SU_T1.R2', 'CRUK0693_SU_FLN2', 'CRUK0722_SU_T1.R4', 'CRUK0719_SU_T1.R5', 'CRUK0719_SU_T1.R6', 'CRUK0003_SU_T1.R5', 'CRUK0089_SU_T1.R1', 'CRUK0412_SU_FLN3', 'CRUK0745_SU_T1.R6', 'CRUK0074_SU_T1.R3', 'CRUK0299_SU_FLN1', 'CRUK0369_SU_FLN2', 'CRUK0369_SU_T1.R5', 'CRUK0301_SU_T1.R2', 'CRUK0707_SU_T1.R1', 'CRUK0325_SU_T1.R1', 'CRUK0325_SU_T1.R3', 'CRUK0325_SU_T1.R4', 'CRUK0099_SU_FLN1', 'CRUK0099_SU_LN01', 'CRUK0099_SU_T1.R2', 'CRUK0099_SU_T1.R4', 'CRUK0099_SU_T1.R5', 'CRUK0368_SU_FLN1', 'CRUK0572_SU_T1.R1', 'CRUK0572_SU_T1.R2', 'CRUK0063_SU_T1.R1', 'CRUK0029_SU_T1.R1', 'CRUK0372_SU_T1.R3', 'CRUK0344_SU_T1.R4', 'CRUK0407_SU_FLN2', 'CRUK0584_SU_T1.R1', 'CRUK0589_SU_T1.R5', 'CRUK0737_SU_T1.R2', 'CRUK0733_SU_FLN2', 'CRUK0495_SU_T1.R5', 'CRUK0872_SU_LN1']

# %% [markdown]
# ### Prep data for input into tree building methods (CONIPHER, PairTree, Orchard) and migration history methods (Metient and MACHINA)

# %%
'''
For Matient/MACHINA, need a tsv with minimum columns: ['#sample_index', 'sample_label', 'anatomical_site_index',
'anatomical_site_label', 'character_index', 'character_label','ref', 'var']

For CONIPHER, need a tsv with minimum columns: ['CASE_ID', 'SAMPLE', 'CHR', 'POS', 'REF', 'ALT', 
'REF_COUNT', 'VAR_COUNT', 'DEPTH', 'COPY_NUMBER_A', 'COPY_NUMBER_B', 'ACF', 'PLOIDY']
'''

import re
from src.util import pairtree_data_extraction_util as pt_util

def remove_region_suffix(input_string):
    pattern = r'\.R\d+$'
    modified_string = re.sub(pattern, '', input_string)
    return modified_string

def generate_sample_and_mut_info(row):
    '''
    Given a row in the patient_data_all_df dataframe, yields two lists:
        (1) the first for MACHINA/Matient input, 
        with columns: [sample_name, mutation_name, sample_type_detailed, ref_count,var_count, sample_type, purity, ploidy]
        e.g. ["SETD3:2:14:99872776:T", "BR_LN1", "LN_SU_FLN1", 43,270, "metastasis", 0.54, 3.19]
        
        (2) the second for CONIPHER input,
        with columns: [patient_id, sample_name, chr, pos, ref, alt, ref_count, var_count, depth,
        copy_number_a, copy_number_b, purity, ploidy]
        
    '''
    mut_id = ":".join(row['mutation_id'].split(":")[1:])
    mut_name = f"{row['Hugo_Symbol']}:{mut_id}"
        
    # RegionSum  column values need to be split by sample 
    # (e.g. "SU_FLN1:0/562;SU_LN1:3/616")    
    sample_name_to_mut_counts = {x.split(":")[0]:x.split(":")[1] for x in row['RegionSum'].split(";")}
    # For missing major CN or minor CN values
    nan_dict = {sample:np.nan for sample in sample_name_to_mut_counts.keys()}
        
    if isinstance(row['MajorCPN_SC'], float):
        sample_name_to_major_cn = nan_dict
    else:
        sample_name_to_major_cn = {x.split(":")[0]:x.split(":")[1] for x in row['MajorCPN_SC'].split(";")}
        
    if isinstance(row['MinorCPN_SC'], float):
        sample_name_to_minor_cn = nan_dict
    else:
        sample_name_to_minor_cn = {x.split(":")[0]:x.split(":")[1] for x in row['MinorCPN_SC'].split(";")}


    for sample_name in sample_name_to_mut_counts.keys():
        mut_count = sample_name_to_mut_counts[sample_name]
        # Lookup sample info in sample_overview dataframe
        patient_sample_name = row['patient_id']+"_"+sample_name
        sample_info = updated_sample_df[updated_sample_df['region']==patient_sample_name]
        if len(sample_info) == 0:
            print(patient_sample_name)
            yield None
            return
        
        sample_type = sample_info['sampleType'].item()
        sample_type_detailed = sample_info['sampleTypeDetail'].item()+"_"+sample_name
        
        # Lookup purity and ploidy info
        purity_ploidy_info = purity_ploidy_df[purity_ploidy_df["Sample"]==patient_sample_name]
        if len(purity_ploidy_info) == 0:
            purity, ploidy = np.nan, np.nan
        else:
            purity = purity_ploidy_info["final.purity"].item()
            ploidy =  purity_ploidy_info["final.ploidy"].item()
        
        # Get ref and var counts, # TODO confirm with TRACERx that these are the right values
        var = int(mut_count.split("/")[0])
        total = int(mut_count.split("/")[1])
        ref = total - var
        
        cn_a_count = np.nan
        if sample_name in sample_name_to_major_cn:
            cn_a_count = sample_name_to_major_cn[sample_name]
        else:
            print("not found",sample_name,  sample_name_to_major_cn, sample_name_to_mut_counts)

        cn_b_count = np.nan
        if sample_name in sample_name_to_minor_cn:
            cn_b_count = sample_name_to_minor_cn[sample_name]
            
        # remove_region_suffix(sample_type_detailed) means samples from multiple regions
        # of the same primary get mapped to the same anatomical site label, e.g. primary.T1.R1 
        # and primary.T1.R2 get mapped to primary.T1. This means they get pooled together below as well.
        mig_hist_input = [mut_name, patient_sample_name, remove_region_suffix(sample_type_detailed), 
                          ref, var,  sample_type_detailed, sample_type, purity, ploidy]
            
        conipher_input = [ row['patient_id'], patient_sample_name, row['chr'].replace('chr', ''), row['start'], 
                          row['ref'], row['var'], ref, var, total,cn_a_count, cn_b_count, purity, ploidy ]
        
        yield mig_hist_input, conipher_input

        
def format_mig_hist_df(data):
    sample_mut_df = pd.DataFrame(data)
    sample_mut_df.columns = ["character_label", "sample_label", "anatomical_site_label", "ref",
                            "var", "original_anatomical_site_label", "sample_type", "purity", "ploidy"]
    
    #assert(len(sample_mut_df['anatomical_site_label'].unique()) == len(sample_mut_df['sample_label'].unique()))
    # Add indices for mutations, samples and anatomical sites as needed for input format
    sample_mut_df['#sample_index'] = sample_mut_df.apply(lambda row: list(sample_mut_df['sample_label'].unique()).index(row["sample_label"]), axis=1)    
    sample_mut_df['character_index'] = sample_mut_df.apply(lambda row: list(sample_mut_df['character_label'].unique()).index(row["character_label"]), axis=1)
    sample_mut_df['anatomical_site_index'] = sample_mut_df.apply(lambda row: list(sample_mut_df['anatomical_site_label'].unique()).index(row["anatomical_site_label"]), axis=1)
    
    sample_mut_df = sample_mut_df[['#sample_index', "sample_label", "anatomical_site_index", "anatomical_site_label", 
                                 'character_index', "character_label", "ref","var", "original_anatomical_site_label", "sample_type","purity", "ploidy"]]

    return sample_mut_df

def format_conipher_df(data):
    sample_mut_df = pd.DataFrame(data)
    sample_mut_df.columns = ['CASE_ID', 'SAMPLE', 'CHR', 'POS', 'REF', 'ALT', 'REF_COUNT', 'VAR_COUNT', 
                             'DEPTH', 'COPY_NUMBER_A', 'COPY_NUMBER_B', 'ACF', 'PLOIDY']
    sample_mut_df = sample_mut_df.dropna()
    return sample_mut_df

unique_patients=['CRUK0361']
for patient_id in unique_patients:
    print(patient_id)
    output_rows = []
    subset = patient_data_all_df[patient_data_all_df['patient_id'] == patient_id]
    print(len(subset))
    
    mig_hist_data = []
    conipher_data = []
    missing_info = False
    for _, row in subset.iterrows(): # each row is one mutation
        generator = generate_sample_and_mut_info(row)
        for data in generator:
            if data == None:
                missing_info = True
                break
            mig_hist_input, conipher_input = data
            mig_hist_data.append(mig_hist_input)
            conipher_data.append(conipher_input)
                
    if missing_info:
        print("Missing sample info, skipping patient", patient_id)
        continue
        
    mig_hist_df = format_mig_hist_df(mig_hist_data)
    conipher_df = format_conipher_df(conipher_data)
    # Write migration history inputs
    mig_hist_df.to_csv(os.path.join(OUTPUT_DIR, f"{patient_id}_SNVs.tsv"), sep="\t")
    # Write conipher inputs
    conipher_df.to_csv(os.path.join(CONIPHER_DIR, f"{patient_id}_conipher_SNVs.tsv"), sep="\t")
    # Write pairtree inputs
    pt_util.write_pairtree_inputs(mig_hist_df, patient_id, OUTPUT_DIR)
# Out:
# CRUK0361
# 1484
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '18/55', 'SU_FLN1': '2/37', 'SU_FLN2': '4/42', 'SU_FLN3': '2/33', 'SU_T1.R1': '24/41', 'SU_T1.R2': '25/30', 'SU_T1.R3': '22/39', 'SU_T1.R4': '32/43'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '18/55', 'SU_FLN1': '2/37', 'SU_FLN2': '4/42', 'SU_FLN3': '2/33', 'SU_T1.R1': '24/41', 'SU_T1.R2': '25/30', 'SU_T1.R3': '22/39', 'SU_T1.R4': '32/43'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '18/55', 'SU_FLN1': '2/37', 'SU_FLN2': '4/42', 'SU_FLN3': '2/33', 'SU_T1.R1': '24/41', 'SU_T1.R2': '25/30', 'SU_T1.R3': '22/39', 'SU_T1.R4': '32/43'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '161/441', 'SU_FLN1': '9/194', 'SU_FLN2': '23/154', 'SU_FLN3': '37/284', 'SU_T1.R1': '274/419', 'SU_T1.R2': '330/453', 'SU_T1.R3': '190/439', 'SU_T1.R4': '278/367'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '161/441', 'SU_FLN1': '9/194', 'SU_FLN2': '23/154', 'SU_FLN3': '37/284', 'SU_T1.R1': '274/419', 'SU_T1.R2': '330/453', 'SU_T1.R3': '190/439', 'SU_T1.R4': '278/367'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '161/441', 'SU_FLN1': '9/194', 'SU_FLN2': '23/154', 'SU_FLN3': '37/284', 'SU_T1.R1': '274/419', 'SU_T1.R2': '330/453', 'SU_T1.R3': '190/439', 'SU_T1.R4': '278/367'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '134/413', 'SU_FLN1': '8/102', 'SU_FLN2': '30/156', 'SU_FLN3': '35/240', 'SU_T1.R1': '168/259', 'SU_T1.R2': '249/336', 'SU_T1.R3': '142/291', 'SU_T1.R4': '211/279'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '134/413', 'SU_FLN1': '8/102', 'SU_FLN2': '30/156', 'SU_FLN3': '35/240', 'SU_T1.R1': '168/259', 'SU_T1.R2': '249/336', 'SU_T1.R3': '142/291', 'SU_T1.R4': '211/279'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '134/413', 'SU_FLN1': '8/102', 'SU_FLN2': '30/156', 'SU_FLN3': '35/240', 'SU_T1.R1': '168/259', 'SU_T1.R2': '249/336', 'SU_T1.R3': '142/291', 'SU_T1.R4': '211/279'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1':
}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '1', 'SU_T1.R3': '1', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/561', 'SU_FLN1': '0/186', 'SU_FLN2': '0/247', 'SU_FLN3': '0/445', 'SU_T1.R1': '0/673', 'SU_T1.R2': '0/585', 'SU_T1.R3': '0/544', 'SU_T1.R4': '17/643'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '1', 'SU_T1.R3': '1', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/561', 'SU_FLN1': '0/186', 'SU_FLN2': '0/247', 'SU_FLN3': '0/445', 'SU_T1.R1': '0/673', 'SU_T1.R2': '0/585', 'SU_T1.R3': '0/544', 'SU_T1.R4': '17/643'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '1', 'SU_T1.R3': '1', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/561', 'SU_FLN1': '0/186', 'SU_FLN2': '0/247', 'SU_FLN3': '0/445', 'SU_T1.R1': '0/673', 'SU_T1.R2': '0/585', 'SU_T1.R3': '0/544', 'SU_T1.R4': '17/643'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '15/577', 'SU_FLN1': '1/186', 'SU_FLN2': '0/332', 'SU_FLN3': '0/512', 'SU_T1.R1': '0/362', 'SU_T1.R2': '0/426', 'SU_T1.R3': '0/353', 'SU_T1.R4': '0/400'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '15/577', 'SU_FLN1': '1/186', 'SU_FLN2': '0/332', 'SU_FLN3': '0/512', 'SU_T1.R1': '0/362', 'SU_T1.R2': '0/426', 'SU_T1.R3': '0/353', 'SU_T1.R4': '0/400'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '15/577', 'SU_FLN1': '1/186', 'SU_FLN2': '0/332', 'SU_FLN3': '0/512', 'SU_T1.R1': '0/362', 'SU_T1.R2': '0/426', 'SU_T1.R3': '0/353', 'SU_T1.R4': '0/400'}
# not found SU_FLN1 {'SU_T1.R1': '5', 'SU_T1.R2': '4', 'SU_T1.R3': '3', 'SU_T1.R4': '5', 'BR_T1.R1': '4'} {'BR_T1.R1': '0/753', 'SU_FLN1': '0/159', 'SU_FLN2': '0/214', 'SU_FLN3': '0/452', 'SU_T1.R1': '0/910', 'SU_T1.R2': '0/957', 'SU_T1.R3': '0/639', 'SU_T1.R4': '26/1011'}
# not found SU_FLN2 {'SU_T1.R1': '5', 'SU_T1.R2': '4', 'SU_T1.R3': '3', 'SU_T1.R4': '5', 'BR_T1.R1': '4'} {'BR_T1.R1': '0/753', 'SU_FLN1': '0/159', 'SU_FLN2': '0/214', 'SU_FLN3': '0/452', 'SU_T1.R1': '0/910', 'SU_T1.R2': '0/957', 'SU_T1.R3': '0/639', 'SU_T1.R4': '26/1011'}
# not found SU_FLN3 {'SU_T1.R1': '5', 'SU_T1.R2': '4', 'SU_T1.R3': '3', 'SU_T1.R4': '5', 'BR_T1.R1': '4'} {'BR_T1.R1': '0/753', 'SU_FLN1': '0/159', 'SU_FLN2': '0/214', 'SU_FLN3': '0/452', 'SU_T1.R1': '0/910', 'SU_T1.R2': '0/957', 'SU_T1.R3': '0/639', 'SU_T1.R4': '26/1011'}
# not found SU_FLN1 {'SU_T1.R1': '5', 'SU_T1.R2': '4', 'SU_T1.R3': '3', 'SU_T1.R4': '5', 'BR_T1.R1': '4'} {'BR_T1.R1': '0/800', 'SU_FLN1': '0/295', 'SU_FLN2': '0/457', 'SU_FLN3': '0/741', 'SU_T1.R1': '20/788', 'SU_T1.R2': '0/871', 'SU_T1.R3': '0/565', 'SU_T1.R4': '0/968'}
# not found SU_FLN2 {'SU_T1.R1': '5', 'SU_T1.R2': '4', 'SU_T1.R3': '3', 'SU_T1.R4': '5', 'BR_T1.R1': '4'} {'BR_T1.R1': '0/800', 'SU_FLN1': '0/295', 'SU_FLN2': '0/457', 'SU_FLN3': '0/741', 'SU_T1.R1': '20/788', 'SU_T1.R2': '0/871', 'SU_T1.R3': '0/565', 'SU_T1.R4': '0/968'}
# not found SU_FLN3 {'SU_T1.R1': '5', 'SU_T1.R2': '4', 'SU_T1.R3': '3', 'SU_T1.R4': '5', 'BR_T1.R1': '4'} {'BR_T1.R1': '0/800', 'SU_FLN1': '0/295', 'SU_FLN2': '0/457', 'SU_FLN3': '0/741', 'SU_T1.R1': '20/788', 'SU_T1.R2': '0/871', 'SU_T1.R3': '0/565', 'SU_T1.R4': '0/968'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '3', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/516', 'SU_FLN1': '0/151', 'SU_FLN2': '0/173', 'SU_FLN3': '0/331', 'SU_T1.R1': '0/585', 'SU_T1.R2': '0/619', 'SU_T1.R3': '0/610', 'SU_T1.R4': '16/632'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '3', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/516', 'SU_FLN1': '0/151', 'SU_FLN2': '0/173', 'SU_FLN3': '0/331', 'SU_T1.R1': '0/585', 'SU_T1.R2': '0/619', 'SU_T1.R3': '0/610', 'SU_T1.R4': '16/632'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '3', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/516', 'SU_FLN1': '0/151', 'SU_FLN2': '0/173', 'SU_FLN3': '0/331', 'SU_T1.R1': '0/585', 'SU_T1.R2': '0/619', 'SU_T1.R3': '0/610', 'SU_T1.R4': '16/632'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/529', 'SU_FLN1': '0/145', 'SU_FLN2': '0/241', 'SU_FLN3': '0/328', 'SU_T1.R1': '0/806', 'SU_T1.R2': '0/902', 'SU_T1.R3': '18/717', 'SU_T1.R4': '0/705'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/529', 'SU_FLN1': '0/145', 'SU_FLN2': '0/241', 'SU_FLN3': '0/328', 'SU_T1.R1': '0/806', 'SU_T1.R2': '0/902', 'SU_T1.R3': '18/717', 'SU_T1.R4': '0/705'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/529', 'SU_FLN1': '0/145', 'SU_FLN2': '0/241', 'SU_FLN3': '0/328', 'SU_T1.R1': '0/806', 'SU_T1.R2': '0/902', 'SU_T1.R3': '18/717', 'SU_T1.R4': '0/705'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/564', 'SU_FLN1': '0/182', 'SU_FLN2': '0/221', 'SU_FLN3': '0/389', 'SU_T1.R1': '0/771', 'SU_T1.R2': '0/908', 'SU_T1.R3': '0/776', 'SU_T1.R4': '18/743'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/564', 'SU_FLN1': '0/182', 'SU_FLN2': '0/221', 'SU_FLN3': '0/389', 'SU_T1.R1': '0/771', 'SU_T1.R2': '0/908', 'SU_T1.R3': '0/776', 'SU_T1.R4': '18/743'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/564', 'SU_FLN1': '0/182', 'SU_FLN2': '0/221', 'SU_FLN3': '0/389', 'SU_T1.R1': '0/771', 'SU_T1.R2': '0/908', 'SU_T1.R3': '0/776', 'SU_T1.R4': '18/743'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '3', 'SU_T1.R4': '3', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/840', 'SU_FLN1': '0/225', 'SU_FLN2': '0/449', 'SU_FLN3': '0/661', 'SU_T1.R1': '0/847', 'SU_T1.R2': '0/920', 'SU_T1.R3': '20/839', 'SU_T1.R4': '0/865'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '3', 'SU_T1.R4': '3', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/840', 'SU_FLN1': '0/225', 'SU_FLN2': '0/449', 'SU_FLN3': '0/661', 'SU_T1.R1': '0/847', 'SU_T1.R2': '0/920', 'SU_T1.R3': '20/839', 'SU_T1.R4': '0/865'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '3', 'SU_T1.R4': '3', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/840', 'SU_FLN1': '0/225', 'SU_FLN2': '0/449', 'SU_FLN3': '0/661', 'SU_T1.R1': '0/847', 'SU_T1.R2': '0/920', 'SU_T1.R3': '20/839', 'SU_T1.R4': '0/865'}
# not found SU_FLN1 {'SU_T1.R1': '5', 'SU_T1.R2': '4', 'SU_T1.R3': '3', 'SU_T1.R4': '5', 'BR_T1.R1': '4'} {'BR_T1.R1': '0/1387', 'SU_FLN1': '0/198', 'SU_FLN2': '0/436', 'SU_FLN3': '1/953', 'SU_T1.R1': '2/1911', 'SU_T1.R2': '2/2211', 'SU_T1.R3': '34/1463', 'SU_T1.R4': '0/2183'}
# not found SU_FLN2 {'SU_T1.R1': '5', 'SU_T1.R2': '4', 'SU_T1.R3': '3', 'SU_T1.R4': '5', 'BR_T1.R1': '4'} {'BR_T1.R1': '0/1387', 'SU_FLN1': '0/198', 'SU_FLN2': '0/436', 'SU_FLN3': '1/953', 'SU_T1.R1': '2/1911', 'SU_T1.R2': '2/2211', 'SU_T1.R3': '34/1463', 'SU_T1.R4': '0/2183'}
# not found SU_FLN3 {'SU_T1.R1': '5', 'SU_T1.R2': '4', 'SU_T1.R3': '3', 'SU_T1.R4': '5', 'BR_T1.R1': '4'} {'BR_T1.R1': '0/1387', 'SU_FLN1': '0/198', 'SU_FLN2': '0/436', 'SU_FLN3': '1/953', 'SU_T1.R1': '2/1911', 'SU_T1.R2': '2/2211', 'SU_T1.R3': '34/1463', 'SU_T1.R4': '0/2183'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/425', 'SU_FLN1': '0/155', 'SU_FLN2': '0/206', 'SU_FLN3': '0/346', 'SU_T1.R1': '14/624', 'SU_T1.R2': '0/729', 'SU_T1.R3': '0/609', 'SU_T1.R4': '0/623'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/425', 'SU_FLN1': '0/155', 'SU_FLN2': '0/206', 'SU_FLN3': '0/346', 'SU_T1.R1': '14/624', 'SU_T1.R2': '0/729', 'SU_T1.R3': '0/609', 'SU_T1.R4': '0/623'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/425', 'SU_FLN1': '0/155', 'SU_FLN2': '0/206', 'SU_FLN3': '0/346', 'SU_T1.R1': '14/624', 'SU_T1.R2': '0/729', 'SU_T1.R3': '0/609', 'SU_T1.R4': '0/623'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '1', 'SU_T1.R3': '1', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/879', 'SU_FLN1': '0/205', 'SU_FLN2': '0/527', 'SU_FLN3': '0/1074', 'SU_T1.R1': '0/917', 'SU_T1.R2': '0/785', 'SU_T1.R3': '0/816', 'SU_T1.R4': '21/944'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '1', 'SU_T1.R3': '1', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/879', 'SU_FLN1': '0/205', 'SU_FLN2': '0/527', 'SU_FLN3': '0/1074', 'SU_T1.R1': '0/917', 'SU_T1.R2': '0/785', 'SU_T1.R3': '0/816', 'SU_T1.R4': '21/944'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '1', 'SU_T1.R3': '1', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/879', 'SU_FLN1': '0/205', 'SU_FLN2': '0/527', 'SU_FLN3': '0/1074', 'SU_T1.R1': '0/917', 'SU_T1.R2': '0/785', 'SU_T1.R3': '0/816', 'SU_T1.R4': '21/944'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/1022', 'SU_FLN1': '0/248', 'SU_FLN2': '0/505', 'SU_FLN3': '0/945', 'SU_T1.R1': '0/1408', 'SU_T1.R2': '0/1745', 'SU_T1.R3': '0/1423', 'SU_T1.R4': '30/1376'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/1022', 'SU_FLN1': '0/248', 'SU_FLN2': '0/505', 'SU_FLN3': '0/945', 'SU_T1.R1': '0/1408', 'SU_T1.R2': '0/1745', 'SU_T1.R3': '0/1423', 'SU_T1.R4': '30/1376'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/1022', 'SU_FLN1': '0/248', 'SU_FLN2': '0/505', 'SU_FLN3': '0/945', 'SU_T1.R1': '0/1408', 'SU_T1.R2': '0/1745', 'SU_T1.R3': '0/1423', 'SU_T1.R4': '30/1376'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/1072', 'SU_FLN1': '0/244', 'SU_FLN2': '0/374', 'SU_FLN3': '0/808', 'SU_T1.R1': '23/1064', 'SU_T1.R2': '0/1180', 'SU_T1.R3': '0/1046', 'SU_T1.R4': '0/1074'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/1072', 'SU_FLN1': '0/244', 'SU_FLN2': '0/374', 'SU_FLN3': '0/808', 'SU_T1.R1': '23/1064', 'SU_T1.R2': '0/1180', 'SU_T1.R3': '0/1046', 'SU_T1.R4': '0/1074'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/1072', 'SU_FLN1': '0/244', 'SU_FLN2': '0/374', 'SU_FLN3': '0/808', 'SU_T1.R1': '23/1064', 'SU_T1.R2': '0/1180', 'SU_T1.R3': '0/1046', 'SU_T1.R4': '0/1074'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/635', 'SU_FLN1': '0/191', 'SU_FLN2': '0/289', 'SU_FLN3': '1/474', 'SU_T1.R1': '13/609', 'SU_T1.R2': '0/533', 'SU_T1.R3': '2/479', 'SU_T1.R4': '0/571'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/635', 'SU_FLN1': '0/191', 'SU_FLN2': '0/289', 'SU_FLN3': '1/474', 'SU_T1.R1': '13/609', 'SU_T1.R2': '0/533', 'SU_T1.R3': '2/479', 'SU_T1.R4': '0/571'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/635', 'SU_FLN1': '0/191', 'SU_FLN2': '0/289', 'SU_FLN3': '1/474', 'SU_T1.R1': '13/609', 'SU_T1.R2': '0/533', 'SU_T1.R3': '2/479', 'SU_T1.R4': '0/571'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/1002', 'SU_FLN1': '1/233', 'SU_FLN2': '1/350', 'SU_FLN3': '1/678', 'SU_T1.R1': '0/1216', 'SU_T1.R2': '0/1375', 'SU_T1.R3': '0/1156', 'SU_T1.R4': '24/1173'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/1002', 'SU_FLN1': '1/233', 'SU_FLN2': '1/350', 'SU_FLN3': '1/678', 'SU_T1.R1': '0/1216', 'SU_T1.R2': '0/1375', 'SU_T1.R3': '0/1156', 'SU_T1.R4': '24/1173'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '2', 'SU_T1.R4': '2', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/1002', 'SU_FLN1': '1/233', 'SU_FLN2': '1/350', 'SU_FLN3': '1/678', 'SU_T1.R1': '0/1216', 'SU_T1.R2': '0/1375', 'SU_T1.R3': '0/1156', 'SU_T1.R4': '24/1173'}
# not found SU_FLN1 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '3', 'SU_T1.R4': '3', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/828', 'SU_FLN1': '0/171', 'SU_FLN2': '0/294', 'SU_FLN3': '0/533', 'SU_T1.R1': '0/872', 'SU_T1.R2': '0/1000', 'SU_T1.R3': '19/936', 'SU_T1.R4': '0/1021'}
# not found SU_FLN2 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '3', 'SU_T1.R4': '3', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/828', 'SU_FLN1': '0/171', 'SU_FLN2': '0/294', 'SU_FLN3': '0/533', 'SU_T1.R1': '0/872', 'SU_T1.R2': '0/1000', 'SU_T1.R3': '19/936', 'SU_T1.R4': '0/1021'}
# not found SU_FLN3 {'SU_T1.R1': '2', 'SU_T1.R2': '2', 'SU_T1.R3': '3', 'SU_T1.R4': '3', 'BR_T1.R1': '2'} {'BR_T1.R1': '0/828', 'SU_FLN1': '0/171', 'SU_FLN2': '0/294', 'SU_FLN3': '0/533', 'SU_T1.R1': '0/872', 'SU_T1.R2': '0/1000', 'SU_T1.R3': '19/936', 'SU_T1.R4': '0/1021'}

# %% [markdown]
# ### Above is all on individual mutations. After clustering mutations using PairTree's clustervars, we pool together those clustered mutations

# %%
import numpy as np
from src.util import pairtree_data_extraction_util as pt_util

agg_rules = {'ploidy':np.mean,'purity':np.mean,'sample_type':'first', 'original_anatomical_site_label':lambda x: ';'.join(set(x))}

for patient_id in unique_patients:
    pt_util.write_pooled_tsv_from_pairtree_clusters(os.path.join(OUTPUT_DIR, f"{patient_id}_SNVS.tsv"), 
                                                    os.path.join(OUTPUT_DIR, f"{patient_id}.ssm"),
                                                    os.path.join(OUTPUT_DIR, f"{patient_id}_clustered.params.json"),
                                                    agg_rules, OUTPUT_DIR, patient_id)
