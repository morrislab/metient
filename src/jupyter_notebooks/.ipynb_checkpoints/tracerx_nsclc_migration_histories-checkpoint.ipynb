# %% [markdown]
# ### Setup paths

# %%
import sys
import os
import seaborn as sns
import pandas as pd
import torch
import matplotlib.pyplot as plt
from src.lib import vertex_labeling
from src.util import data_extraction_util as data_util
from src.util import pairtree_data_extraction_util as pt_util
from src.util import vertex_labeling_util as vert_util
from src.util import plotting_util as plot_util

repo_dir = "/Users/divyakoyyalagunta/Desktop/Cornell_Research/Morris_Lab/met_history_prediction/"
os.chdir(repo_dir)

plt.rcParams['figure.figsize'] = [3, 3]

TRACERX_DATA_DIR = os.path.join(repo_dir, 'src/data/tracerx_nsclc/')
INPUT_TSVS_DIR = os.path.join(TRACERX_DATA_DIR, 'patient_data')
ORCHARD_TREES_DIR = os.path.join(TRACERX_DATA_DIR, 'orchard_trees')
custom_colors = ["#6aa84fff","#c27ba0ff", "#e69138ff", "#be5742e1", "#2496c8ff", "#674ea7ff"] + sns.color_palette("Paired").as_hex()
# Out:
# CUDA GPU: False

# %% [markdown]
# ### blah

# %%
def find_labeling(ref_var_fn, orchard_results_fn, custom_colors, primary_site, patient_name):    
    ref_matrix, var_matrix, unique_sites, idx_to_cluster_label = data_util.get_ref_var_matrices_from_real_data(ref_var_fn)
    data = pt_util.get_adj_matrices_from_pairtree_results(orchard_results_fn)
    T, _ = data[0] # Use best tree

    for ix in idx_to_cluster_label:
        og_label_muts = idx_to_cluster_label[ix].split(';') # e.g. CUL3:2:225371655:T;TRPM6:9:77431650:C
        if len(og_label_muts) > 3:
            og_label_muts = og_label_muts[:3]
        gene_names = []
        for mut_label in og_label_muts:
            gene_names.append(mut_label.split(":")[0])
        idx_to_cluster_label[ix] = ("_").join(gene_names)

    print(f"Anatomical sites: {unique_sites}")   
    primary_idx = unique_sites.index(primary_site)
    p = torch.nn.functional.one_hot(torch.tensor([primary_idx]), num_classes=len(unique_sites)).T
    weights = vertex_labeling.Weights(data_fit=1.0, mig=3.0, comig=2.0, seed_site=1.0, reg=2.0, gen_dist=0.0)
    print_config = plot_util.PrintConfig(visualize=False, verbose=False, viz_intermeds=False, k_best_trees=2)
    vertex_labeling.get_migration_history(T, ref_matrix, var_matrix, unique_sites, p, idx_to_cluster_label, weights,
                                          print_config, os.path.join(TRACERX_DATA_DIR, "metient_outputs"), patient_name,
                                          custom_colors=custom_colors, batch_size=32, max_iter=100)

# %%
import concurrent.futures
        
def run_patient(patient):
    space = "x"*44
    tsv_fn = os.path.join(INPUT_TSVS_DIR, f"{patient}_SNVs.tsv")
    print(f"{space} PATIENT {patient} {space}")
    df = pd.read_csv(tsv_fn, delimiter="\t")
    primary_sites = list(df[df['sample_type']=='primary']['anatomical_site_label'].unique())
    if (len(primary_sites) > 1):
        print("*Multiple primary samples, running metient once for each possible primary*")

    for primary_site in primary_sites:
        print(f"Primary site: {primary_site}")
        run_name = f"{patient}_{primary_site}"
        find_labeling(tsv_fn, os.path.join(ORCHARD_TREES_DIR, f"{patient}.results.npz"),
                     custom_colors, primary_site, run_name)
    
def run_patients(patients):
    for patient in patients:
        run_patient(patient)

patients = set()
for file in os.listdir(ORCHARD_TREES_DIR):
    if "_clustered.results.npz" in file:
        patients.add(file.split(".")[0])
print(f"{len(patients)} patients, {patients}")

run_patients(list(patients))
# Out:
# 126 patients, {'CRUK0337_clustered', 'CRUK0296_clustered', 'CRUK0691_clustered', 'CRUK0250_clustered', 'CRUK0640_clustered', 'CRUK0041_clustered', 'CRUK0035_clustered', 'CRUK0410_clustered', 'CRUK0090_clustered', 'CRUK0698_clustered', 'CRUK0299_clustered', 'CRUK0325_clustered', 'CRUK0183_clustered', 'CRUK0745_clustered', 'CRUK0589_clustered', 'CRUK0242_clustered', 'CRUK0453_clustered', 'CRUK0707_clustered', 'CRUK0468_clustered', 'CRUK0733_clustered', 'CRUK0559_clustered', 'CRUK0284_clustered', 'CRUK0100_clustered', 'CRUK0452_clustered', 'CRUK0236_clustered', 'CRUK0719_clustered', 'CRUK0567_clustered', 'CRUK0636_clustered', 'CRUK0099_clustered', 'CRUK0495_clustered', 'CRUK0352_clustered', 'CRUK0572_clustered', 'CRUK0074_clustered', 'CRUK0013_clustered', 'CRUK0766_clustered', 'CRUK0052_clustered', 'CRUK0388_clustered', 'CRUK0598_clustered', 'CRUK0286_clustered', 'CRUK0557_clustered', 'CRUK0092_clustered', 'CRUK0736_clustered', 'CRUK0412_clustered', 'CRUK0769_clustered', 'CRUK0584_clustered', 'CRUK0084_clustered', 'CRUK0587_clustered', 'CRUK0596_clustered', 'CRUK0484_clustered', 'CRUK0530_clustered', 'CRUK0097_clustered', 'CRUK0003_clustered', 'CRUK0625_clustered', 'CRUK0721_clustered', 'CRUK0361_clustered', 'CRUK0044_clustered', 'CRUK0036_clustered', 'CRUK0817_clustered', 'CRUK0467_clustered', 'CRUK0496_clustered', 'CRUK0714_clustered', 'CRUK0609_clustered', 'CRUK0620_clustered', 'CRUK0343_clustered', 'CRUK0666_clustered', 'CRUK0718_clustered', 'CRUK0799_clustered', 'CRUK0472_clustered', 'CRUK0227_clustered', 'CRUK0702_clustered', 'CRUK0087_clustered', 'CRUK0089_clustered', 'CRUK0029_clustered', 'CRUK0810_clustered', 'CRUK0256_clustered', 'CRUK0590_clustered', 'CRUK0444_clustered', 'CRUK0418_clustered', 'CRUK0528_clustered', 'CRUK0407_clustered', 'CRUK0290_clustered', 'CRUK0497_clustered', 'CRUK0476_clustered', 'CRUK0368_clustered', 'CRUK0722_clustered', 'CRUK0514_clustered', 'CRUK0010_clustered', 'CRUK0372_clustered', 'CRUK0344_clustered', 'CRUK0748_clustered', 'CRUK0178_clustered', 'CRUK0083_clustered', 'CRUK0451_clustered', 'CRUK0311_clustered', 'CRUK0516_clustered', 'CRUK0301_clustered', 'CRUK0737_clustered', 'CRUK0872_clustered', 'CRUK0004_clustered', 'CRUK0245_clustered', 'CRUK0510_clustered', 'CRUK0009_clustered', 'CRUK0537_clustered', 'CRUK0063_clustered', 'CRUK0027_clustered', 'CRUK0485_clustered', 'CRUK0422_clustered', 'CRUK0730_clustered', 'CRUK0552_clustered', 'CRUK0048_clustered', 'CRUK0617_clustered', 'CRUK0693_clustered', 'CRUK0794_clustered', 'CRUK0762_clustered', 'CRUK0415_clustered', 'CRUK0487_clustered', 'CRUK0667_clustered', 'CRUK0742_clustered', 'CRUK0543_clustered', 'CRUK0478_clustered', 'CRUK0524_clustered', 'CRUK0465_clustered', 'CRUK0022_clustered', 'CRUK0369_clustered', 'CRUK0519_clustered', 'CRUK0206_clustered'}
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0337_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0296_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0691_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0250_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0640_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0041_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0035_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Primary site: primary_SU_T1
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0410_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Primary site: primary_SU_T1
# Primary site: primary_SU_T1
# Primary site: primary_SU_T1
# Primary site: primary_SU_T1
# Primary site: primary_SU_T1
# Primary site: primary_SU_T1
# Primary site: primary_SU_T1
# Anatomical sites: ['metachronousMet_MR_T1.FR1', 'primary_SU_T1']
# Anatomical sites: ['metachronousMet_BR_T1', 'primary_SU_T1']
# Anatomical sites: ['LN_SU_FLN1', 'primary_SU_T1']
# Anatomical sites: ['LN_SU_FLN1', 'primary_SU_T1']
# Anatomical sites: ['LN_SU_FLN1', 'LN_SU_FLN2', 'LN_SU_LN01', 'metachronousMet_BP_T1', 'metachronousMet_BR_T1', 'primary_SU_T1']
# Anatomical sites: ['metachronousMet_BR_LN1', 'primary_SU_T1']
# Anatomical sites: ['metachronousMet_BR_T1.FR1', 'primary_SU_T1']
# Anatomical sites: ['LN_SU_FLN2', 'primary_SU_T1']
# /Users/divyakoyyalagunta/Desktop/Cornell_Research/Morris_Lab/met_history_prediction/src/util/plotting_util.py:750: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Saving CRUK0337_clustered_primary_SU_T1 to /Users/divyakoyyalagunta/Desktop/Cornell_Research/Morris_Lab/met_history_prediction/src/data/tracerx_nsclc/metient_outputs
# /Users/divyakoyyalagunta/mambaforge/envs/metf/lib/python3.7/site-packages/numpy/lib/npyio.py:719: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   val = np.asanyarray(val)
# /Users/divyakoyyalagunta/mambaforge/envs/metf/lib/python3.7/site-packages/numpy/lib/npyio.py:719: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   val = np.asanyarray(val)
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0325_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Primary site: primary_SU_T1
# Anatomical sites: ['LN_SU_FLN1', 'metachronousMet_BR_T1.FR1', 'primary_SU_T1']
# /Users/divyakoyyalagunta/Desktop/Cornell_Research/Morris_Lab/met_history_prediction/src/util/plotting_util.py:750: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Saving CRUK0041_clustered_primary_SU_T1 to /Users/divyakoyyalagunta/Desktop/Cornell_Research/Morris_Lab/met_history_prediction/src/data/tracerx_nsclc/metient_outputs
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0090_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Primary site: primary_SU_T1
# Anatomical sites: ['metachronousMet_BP_T1', 'metachronousMet_BP_T2', 'metachronousMet_BR_T1', 'primary_SU_T1']
# /Users/divyakoyyalagunta/mambaforge/envs/metf/lib/python3.7/site-packages/numpy/lib/npyio.py:719: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   val = np.asanyarray(val)
# /Users/divyakoyyalagunta/mambaforge/envs/metf/lib/python3.7/site-packages/numpy/lib/npyio.py:719: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   val = np.asanyarray(val)
# /Users/divyakoyyalagunta/Desktop/Cornell_Research/Morris_Lab/met_history_prediction/src/util/plotting_util.py:750: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout()
# Saving CRUK0296_clustered_primary_SU_T1 to /Users/divyakoyyalagunta/Desktop/Cornell_Research/Morris_Lab/met_history_prediction/src/data/tracerx_nsclc/metient_outputs
# xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx PATIENT CRUK0698_clustered xxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxxx
# Primary site: primary_SU_T1
# Anatomical sites: ['LN_SU_FLN1', 'LN_SU_LN1', 'primary_SU_T1']
# /Users/divyakoyyalagunta/mambaforge/envs/metf/lib/python3.7/site-packages/numpy/lib/npyio.py:719: FutureWarning: The input object of type 'Tensor' is an array-like implementing one of the corresponding protocols (`__array__`, `__array_interface__` or `__array_struct__`); but not a sequence (or 0-D). In the future, this object will be coerced as if it was first converted using `np.array(obj)`. To retain the old behaviour, you have to either modify the type 'Tensor', or assign to an empty array created with `np.empty(correct_shape, dtype=object)`.
#   val = np.asanyarray(val)
# /Users/divyakoyyalagunta/mambaforge/envs/metf/lib/python3.7/site-packages/numpy/lib/npyio.py:719: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   val = np.asanyarray(val)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /var/folders/35/l3stl61s6n14w337drj2gt9m0000gn/T/ipykernel_55020/728668024.py in <module>
#      30 print(f"{len(patients)} patients, {patients}")
#      31
# ---> 32 run_patients(list(patients))
#
# /var/folders/35/l3stl61s6n14w337drj2gt9m0000gn/T/ipykernel_55020/728668024.py in run_patients(patients)
#      22         #run_patient(patient)
#      23         futures.append(executor.submit(run_patient, patient))
# ---> 24     concurrent.futures.wait(futures)
#      25
#      26 patients = set()
#
# ~/mambaforge/envs/metf/lib/python3.7/concurrent/futures/_base.py in wait(fs, timeout, return_when)
#     299         waiter = _create_and_install_waiters(fs, return_when)
#     300
# --> 301     waiter.event.wait(timeout)
#     302     for f in fs:
#     303         with f._condition:
#
# ~/mambaforge/envs/metf/lib/python3.7/threading.py in wait(self, timeout)
#     550             signaled = self._flag
#     551             if not signaled:
# --> 552                 signaled = self._cond.wait(timeout)
#     553             return signaled
#     554
#
# ~/mambaforge/envs/metf/lib/python3.7/threading.py in wait(self, timeout)
#     294         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     295             if timeout is None:
# --> 296                 waiter.acquire()
#     297                 gotit = True
#     298             else:
#
# KeyboardInterrupt:

# %%
import numpy as np
npzfile = np.load(os.path.join(TRACERX_DATA_DIR, "metient_outputs", "CRUK0337_clustered_primary_SU_T1.results.npz"), allow_pickle=True)
print(npzfile.files)
npzfile['node_idx_to_label']
# Out:
# ['ancestral_labelings', 'subclonal_presence_matrices', 'full_adjacencey_matrices', 'ordered_anatomical_sites', 'node_idx_to_label']
# array({0: 'GPATCH1_GPATCH1', 1: 'SLCO1B1_GIT2_ZAN', 2: 'MUM1_POM121L2_DHX37', 3: 'POLE_KERA_PKHD1', 4: 'COL5A1_STRAP_FBXL20', 5: 'GNS_ADAMTSL5_GTSF1', 6: 'KRT26_ITPR2_FCHSD2', 7: 'FAT3_STAB2_HDAC7', 8: 'TTC40_MUSK_N6AMT1', 9: 'TRIM29_UNC5D_FLJ45513', 10: 'IQCA1_AGXT_TMEM214', 11: 'FHL5_TENM2_CTSE', 12: 'SLCO2A1_CHRDL1_ECE2', 13: 'ITSN2_TFCP2L1_SNORD89', 14: 'FAM193B_SNAP25_USH2A', 15: 'DOCK2_IMPA1_ITGA8', 16: 'SELE_PPP1R3A_JAKMIP3', 17: 'BRWD3_PPFIA1_COL5A2', 18: 'CLMN_OR2M2_PDCD11', 19: 'STK17B_ASXL3_SERPINB7', 20: 'WAC_CPSF7_CNTRL', 21: 'DMRTA2_VPS41_C16orf78', 22: 'CNBD1_SLC4A7_ORMDL3', 23: 'CNTNAP5_MORC2_MAP3K4', 24: 'ABL1_POLR2A', 25: 'KPNA4_EHD3_PHF21B', 26: 'GCH1_ENG_ADRBK2', 27: 'PRODH_CRADD_C9orf69', 28: 'ERMP1_NKX2-4_EQTN', 29: 'GABPB2_SRRM3_MOCOS', 30: 'TBC1D8B_PTPRR_TDRKH', 31: 'FXYD7_CTNS_PRSS3P2'},
#       dtype=object)
