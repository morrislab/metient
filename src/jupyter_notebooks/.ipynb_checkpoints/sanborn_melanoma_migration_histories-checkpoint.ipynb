# %%
# Test migration history reconstruction on Sanborn et. al. Melanoma data

import sys
import os

repo_dir = "/Users/divyakoyyalagunta/Desktop/Cornell_Research/Morris_Lab/met_history_prediction/"
os.chdir(repo_dir)
from src.lib import vertex_labeling

from src.util import data_extraction_util as data_util
from src.util import vertex_labeling_util as vert_util
import matplotlib
import torch

SANBORN_DATA_DIR = os.path.join(repo_dir, 'src/data/sanborn_melanoma_2015')
# Out:
# 16:29:44 INFO
# NumExpr defaulting to 8 threads.
# CUDA GPU: False
# CUDA GPU: False
# CUDA GPU: False

# %%
def find_labeling(all_mut_trees_fn, ref_var_fn, custom_colors):    
    ref_matrix, var_matrix, unique_sites, cluster_label_to_idx = data_util.get_ref_var_matrices_from_real_data(ref_var_fn)
    data = data_util.get_adj_matrices_from_all_mutation_trees(all_mut_trees_fn, cluster_label_to_idx)
    print("num trees:", len(data))
    
    for adj_matrix, pruned_cluster_label_to_idx in data:
        T = torch.tensor(adj_matrix, dtype = torch.float32)
        B = vert_util.get_mutation_matrix_tensor(T)

        idx_to_label = {v:str(v) for k,v in pruned_cluster_label_to_idx.items()}
        G = data_util.get_genetic_distance_tensor_from_adj_matrix(T, pruned_cluster_label_to_idx, "_")

        print(unique_sites)   
        primary_idx = unique_sites.index('primary')
        r = torch.nn.functional.one_hot(torch.tensor([primary_idx]), num_classes=len(unique_sites)).T
        weights = vertex_labeling.Weights(data_fit=1.0, mig=10.0, comig=5.0, seed_site=1.0, reg=2.0, gen_dist=0.0)
        print_config = vert_util.PrintConfig(visualize=True, verbose=True, viz_intermeds=True)
        vertex_labeling.gumbel_softmax_optimization(T, ref_matrix, var_matrix, B, G=G, ordered_sites=unique_sites, 
                                                    weights=weights, p=r, node_idx_to_label=idx_to_label, lr=0.1,
                                                    max_iter=200, batch_size=64, print_config=print_config,
                                                    custom_colors=custom_colors, primary="primary", 
                                                    weight_init_primary=True, lr_sched="constant")

# %%
# Patient A
patient = "A"
custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'red',  'purple', 'darkorange',]]
custom_colors = ["#6aa84fff","#c27ba0ff", "#be5742e1", "#6fa8dcff", "#e69138ff", "#9e9e9eff"]

find_labeling(os.path.join(SANBORN_DATA_DIR, f"{patient}_mut_trees.txt"), os.path.join(SANBORN_DATA_DIR, f"{patient}_0.95.tsv"), custom_colors)
# Out:
# num trees: 1
# ['primary', 'parotid_gland', 'locoregional_1', 'locoregional_2']
# Time elapsed: 18.733126
# ============================== INTERMEDIATE TREE ==============================
#
# Iteration: 0, Intermediate best tree idx 4
# soft_X
#     primary  parotid_gland  locoregional_1  locoregional_2
# 1    0.301          0.232           0.234           0.233
# 2    0.275          0.266           0.232           0.226
# 3    0.290          0.226           0.236           0.248
# Migration number: 12.0
# Comigration number: 3.0
# Seeding site number: 1.0
# Neg log likelihood: 954.751
# Reg: 4.0
# Genetic distance: 120.0
# Loss: 1158.751
# ============================== INTERMEDIATE TREE ==============================
#
# Iteration: 20, Intermediate best tree idx 4
# soft_X
#     primary  parotid_gland  locoregional_1  locoregional_2
# 1    0.274          0.244           0.236           0.246
# 2    0.305          0.241           0.240           0.214
# 3    0.258          0.237           0.244           0.261
# Migration number: 9.0
# Comigration number: 4.0
# Seeding site number: 2.0
# Neg log likelihood: 77.858
# Reg: 4.0
# Genetic distance: -38.0
# Loss: 178.858
# ============================== INTERMEDIATE TREE ==============================
#
# Iteration: 40, Intermediate best tree idx 4
# soft_X
#     primary  parotid_gland  locoregional_1  locoregional_2
# 1    0.296          0.231           0.244           0.230
# 2    0.334          0.205           0.238           0.222
# 3    0.242          0.246           0.256           0.257
# Migration number: 9.0
# Comigration number: 5.0
# Seeding site number: 2.0
# Neg log likelihood: 14.842
# Reg: 4.0
# Genetic distance: -38.0
# Loss: 120.842
# ============================== INTERMEDIATE TREE ==============================
#
# Iteration: 60, Intermediate best tree idx 4
# soft_X
#     primary  parotid_gland  locoregional_1  locoregional_2
# 1    0.309          0.219           0.237           0.236
# 2    0.344          0.210           0.213           0.233
# 3    0.232          0.238           0.267           0.263
# Migration number: 5.0
# Comigration number: 3.0
# Seeding site number: 1.0
# Neg log likelihood: 10.277
# Reg: 4.0
# Genetic distance: -78.0
# Loss: 45.277
# ============================== INTERMEDIATE TREE ==============================
#
# Iteration: 80, Intermediate best tree idx 4
# soft_X
#     primary  parotid_gland  locoregional_1  locoregional_2
# 1    0.386          0.184           0.197           0.232
# 2    0.364          0.186           0.177           0.274
# 3    0.155          0.248           0.347           0.250
# Migration number: 5.0
# Comigration number: 3.0
# Seeding site number: 1.0
# Neg log likelihood: 7.679
# Reg: 4.0
# Genetic distance: -78.0
# Loss: 42.679
# ============================== INTERMEDIATE TREE ==============================
#
# Iteration: 100, Intermediate best tree idx 4
# soft_X
#     primary  parotid_gland  locoregional_1  locoregional_2
# 1    0.549          0.200           0.127           0.123
# 2    0.356          0.190           0.112           0.342
# 3    0.086          0.271           0.401           0.243
# Migration number: 5.0
# Comigration number: 3.0
# Seeding site number: 1.0
# Neg log likelihood: 6.418
# Reg: 4.0
# Genetic distance: -78.0
# Loss: 41.418
# ============================== INTERMEDIATE TREE ==============================
#
# Iteration: 120, Intermediate best tree idx 4
# soft_X
#     primary  parotid_gland  locoregional_1  locoregional_2
# 1    0.830          0.056           0.044           0.069
# 2    0.376          0.149           0.037           0.438
# 3    0.035          0.155           0.638           0.172
# Migration number: 5.0
# Comigration number: 3.0
# Seeding site number: 2.0
# Neg log likelihood: 5.604
# Reg: 3.999999761581421
# Genetic distance: -89.0
# Loss: 36.104
# ============================== INTERMEDIATE TREE ==============================
#
# Iteration: 140, Intermediate best tree idx 4
# soft_X
#     primary  parotid_gland  locoregional_1  locoregional_2
# 1    0.988          0.004           0.003           0.006
# 2    0.062          0.068           0.005           0.865
# 3    0.004          0.021           0.944           0.031
# Migration number: 5.0
# Comigration number: 3.0
# Seeding site number: 2.0
# Neg log likelihood: 5.02
# Reg: 4.0
# Genetic distance: -89.0
# Loss: 35.52
# ============================== INTERMEDIATE TREE ==============================
#
# Iteration: 160, Intermediate best tree idx 4
# soft_X
#     primary  parotid_gland  locoregional_1  locoregional_2
# 1    1.000          0.000           0.000           0.000
# 2    0.007          0.017           0.000           0.976
# 3    0.000          0.001           0.999           0.001
# Migration number: 4.0
# Comigration number: 3.0
# Seeding site number: 2.0
# Neg log likelihood: 4.593
# Reg: 3.999999761581421
# Genetic distance: -99.0
# Loss: 20.093
# ============================== INTERMEDIATE TREE ==============================
#
# Iteration: 180, Intermediate best tree idx 4
# soft_X
#     primary  parotid_gland  locoregional_1  locoregional_2
# 1    1.000          0.000           0.000           0.000
# 2    0.000          0.000           0.000           1.000
# 3    0.000          0.000           1.000           0.000
# Migration number: 4.0
# Comigration number: 3.0
# Seeding site number: 2.0
# Neg log likelihood: 4.269
# Reg: 4.0
# Genetic distance: -99.0
# Loss: 19.769
# ****************************** BEST TREE ******************************
#
# Migration number: 4.0
# Comigration number: 3.0
# Seeding site number: 2.0
# Neg log likelihood: 41.615
# Reg: 3.7973287105560303
# Genetic distance: -99.0
# Loss: 56.709

# %%
# Patient C
patient = "C"
custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'purple', 'darkorange']]
custom_colors = ["#6aa84fff","#c27ba0ff", "#be5742e1", "#6fa8dcff", "#e69138ff", "#9e9e9eff"]

find_labeling(os.path.join(SANBORN_DATA_DIR, f"{patient}_mut_trees.txt"), os.path.join(SANBORN_DATA_DIR, f"{patient}_0.95.tsv"), custom_colors)
# Out:
# num trees: 1
# ['primary', 'locoregional_1', 'locoregional_2']
# Time elapsed: 18.152846
# ****************************** BEST TREE ******************************
#
# Migration number: 2.0
# Comigration number: 2.0
# Seeding site number: 1.0
# Neg log likelihood: 13.781
# Reg: 3.0
# Loss: 50.781

# %%
# Patient D
patient = "D"
custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'royalblue', 'purple', 'darkorange', ]]
custom_colors = ["#6aa84fff","#c27ba0ff", "#be5742e1", "#6fa8dcff", "#e69138ff", "#9e9e9eff"]

find_labeling(os.path.join(SANBORN_DATA_DIR, f"{patient}_mut_trees.txt"), os.path.join(SANBORN_DATA_DIR, f"{patient}_0.95.tsv"), custom_colors)
# Out:
# num trees: 1
# ['primary', 'lymph_node', 'locoregional_1', 'locoregional_2']
# Time elapsed: 17.906584
# ****************************** BEST TREE ******************************
#
# Migration number: 4.0
# Comigration number: 3.0
# Seeding site number: 1.0
# Neg log likelihood: 3.63
# Reg: 4.0
# Loss: 67.63

# %%
# Patient E
patient = "E"
custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'purple', 'darkorange', 'royalblue', 'red', ]]
custom_colors = ["#6aa84fff","#c27ba0ff", "#be5742e1", "#6fa8dcff", "#e69138ff", "#9e9e9eff"]

find_labeling(os.path.join(SANBORN_DATA_DIR, f"{patient}_mut_trees.txt"), os.path.join(SANBORN_DATA_DIR, f"{patient}_0.95.tsv"), custom_colors)
# Out:
# num trees: 1
# ['primary', 'locoregional_1', 'locoregional_2', 'lymph_node', 'locoregional_3']
# Time elapsed: 18.90009
# ****************************** BEST TREE ******************************
#
# Migration number: 5.0
# Comigration number: 4.0
# Seeding site number: 2.0
# Neg log likelihood: 2.508
# Reg: 4.999999523162842
# Loss: 84.508

# %%
# Patient F
patient = "F"
custom_colors = [matplotlib.colors.to_hex(c) for c in ['limegreen', 'royalblue', 'darkorange', 'hotpink']]
custom_colors = ["#6aa84fff","#c27ba0ff", "#be5742e1", "#6fa8dcff", "#e69138ff", "#9e9e9eff"]

find_labeling(os.path.join(SANBORN_DATA_DIR, f"{patient}_mut_trees.txt"), os.path.join(SANBORN_DATA_DIR, f"{patient}_0.95.tsv"), custom_colors)
# Out:
# num trees: 1
# ['primary', 'lymph_node', 'locoregional', 'distant']
# Time elapsed: 20.443505
# ****************************** BEST TREE ******************************
#
# Migration number: 13.0
# Comigration number: 3.0
# Seeding site number: 1.0
# Neg log likelihood: 18.742
# Reg: 3.999999761581421
# Loss: 172.742
