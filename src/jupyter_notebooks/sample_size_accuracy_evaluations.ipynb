# %%
import os
from src.util import plotting_util as putil
import pandas as pd
import fnmatch
from src.util import eval_util as eutil
import seaborn as sns

REPO_DIR = os.path.join(os.getcwd(), "../")
os.chdir(REPO_DIR)
# Out:
# CUDA GPU: False

# %%
SITES = ["m5", "m8"]
MIG_TYPES = ["mS", "M", "S", "R"]
CUTOFF = 1.0
k = 100000
LOSS_THRES=0.5

DATE = "12062023"
PARAMS = "calibrate_solvepoly_wip_gen0.2"

# %%
# Get number of clusters (tree vertices to label) per site/mig_type/seed combo
def get_num_mut_trees(mut_tree_fn):
    with open(mut_tree_fn, 'r') as f:
        # look for line w/ "3 #trees" as an example
        for line in f:
            if  "#trees" in line:
                return int(line.strip().split()[0])
sims_dir = os.path.join(REPO_DIR, "data/machina_sims")
data = []
tot = 0
for site in SITES:
    for mig_type in MIG_TYPES:
        site_mig_type_dir = os.path.join(sims_dir, site, mig_type)
        seeds = fnmatch.filter(os.listdir(site_mig_type_dir), 'clustering_observed_seed*.txt')
        seeds = [s.replace(".txt", "").replace("clustering_observed_seed", "") for s in seeds]
        for seed in seeds:
            fn = os.path.join(site_mig_type_dir, f"clustering_observed_seed{seed}.txt")
            num_lines = sum(1 for _ in open(fn))
            fn = os.path.join(site_mig_type_dir, f"T_seed{seed}.labeling")
            sites = set()
            with open(fn) as f:
                for line in f:
                    sites.add(line.strip().split()[1])
            n = get_num_mut_trees(os.path.join(sims_dir, f"{site}_mut_trees", f"mut_trees_{mig_type}_seed{seed}.txt"))
            #print(n)
            tot+=n
            for i in range(n):
                data.append([seed, site, mig_type, num_lines, len(sites), i])
print("tot",tot)
cols = ["seed", "site", "mig_type", "clusters", "sites", "tree_num"]
cluster_num_df = pd.DataFrame(data, columns=cols)
cluster_num_df["seed"] = cluster_num_df["seed"].astype(int)
print(cluster_num_df['clusters'].max())

cluster_num_df['cluster_bins'] = pd.qcut(cluster_num_df['clusters'], 3, labels=False, duplicates='drop')
denom=10000
def calc_prob_size(num_sites, num_nodes):
    return (num_sites**(num_nodes-1))
cluster_num_df['prob_size'] = cluster_num_df.apply(lambda row: calc_prob_size(row["sites"], row['clusters'])/denom, axis=1)
cluster_num_df['prob_size_bins'] = pd.qcut(cluster_num_df['prob_size'], 3, labels=False, duplicates='drop')

sns.histplot(cluster_num_df['clusters'], kde=True, color='skyblue')
# Out:
# tot 1647
# 29
# <Axes: xlabel='clusters', ylabel='Count'>

# %% [markdown]
# ### Evaluate Metient's best trees based on batch size, tree size and number of anatomical sites

# %%
from tqdm import tqdm

batch_sizes = ['64', '256', '1024']
num_runs = 5

bs_to_num_nodes_to_ground_truth_slns = {bs:{} for bs in batch_sizes}
bs_to_num_sites_to_ground_truth_slns = {bs:{} for bs in batch_sizes}
bs_to_prob_size_bin_to_ground_truth_slns = {bs:{} for bs in batch_sizes}

for bs in batch_sizes:
    for run in range(1,num_runs+1):
        prediction_dir = os.path.join(REPO_DIR, 'test', 'machina_simulated_data', f'sample_size_experiments_{PARAMS}_{DATE}/predictions_batch_exp_bs{bs}_{PARAMS}_r{run}_{DATE}')

        print(prediction_dir)
        grad_m5_f1_scores = []
        grad_m8_f1_scores = []
        ct = 0
        tot = 0
        for site in SITES:
            for mig_type in tqdm(MIG_TYPES):
                true_site_mig_type_data_dir = os.path.join(sims_dir, site, mig_type)
                predicted_site_mig_type_data_dir = os.path.join(prediction_dir, site, mig_type)
                filenames = fnmatch.filter(os.listdir(predicted_site_mig_type_data_dir), 'T_tree*.predicted.tree')
                seeds = set([int(s[s.find("seed")+4:s.find(".predicted")]) for s in filenames])
                for seed in seeds:
                    seed_filenames = [f for f in filenames if seed == f[f.find("seed")+4:f.find(".predicted")]]
                    tree_info = eutil.get_metient_min_loss_trees(predicted_site_mig_type_data_dir, seed, k, loss_thres=LOSS_THRES)
                    ground_truth_clones_found = False
                    ground_truth_mig_graph_found = False
                    Fs, F_G2s = [], []

                    for i, (loss, met_results_dict, met_tree_num) in enumerate(tree_info):
                        recall, precision, F, has_resolved_polytomy = eutil.evaluate_seeding_clones(os.path.join(true_site_mig_type_data_dir, f"T_seed{seed}.tree"),
                                                                      os.path.join(true_site_mig_type_data_dir, f"T_seed{seed}.vertex.labeling"),
                                                                      met_results_dict, met_tree_num)

                        if F >= CUTOFF:
                            ground_truth_clones_found = True

                        recall_G2, precision_G2, F_G2 = eutil.evaluate_migration_multigraph(os.path.join(true_site_mig_type_data_dir, f"G_seed{seed}.tree"),
                                                                                            met_results_dict, met_tree_num)
                        if F_G2 >= CUTOFF:
                            ground_truth_mig_graph_found = True   
                        Fs.append(F)
                        F_G2s.append(F_G2)
                    subset_df = cluster_num_df[(cluster_num_df['seed']==int(seed))&(cluster_num_df['site']==site)&(cluster_num_df['mig_type']==mig_type)]
                    num_nodes = subset_df.iloc[0]['clusters']
                    rng = subset_df['cluster_bins'].unique().item()
                    if rng not in bs_to_num_nodes_to_ground_truth_slns[bs]:
                        bs_to_num_nodes_to_ground_truth_slns[bs][rng] = []
                    if sum(Fs)/len(Fs) < min(Fs):
                        ct += 1
                    tot+= 1
                    info = (ground_truth_clones_found, ground_truth_mig_graph_found, sum(Fs)/len(Fs), sum(F_G2s)/len(F_G2s))
                    bs_to_num_nodes_to_ground_truth_slns[bs][rng].append(info)

                    num_sites = subset_df.iloc[0]['sites']
                    if num_sites not in bs_to_num_sites_to_ground_truth_slns[bs]:
                        bs_to_num_sites_to_ground_truth_slns[bs][num_sites] = []
                    bs_to_num_sites_to_ground_truth_slns[bs][num_sites].append(info)
                    
                    prob_size_bin = subset_df['prob_size_bins'].unique().item()
                    if prob_size_bin not in bs_to_prob_size_bin_to_ground_truth_slns[bs]:
                        bs_to_prob_size_bin_to_ground_truth_slns[bs][prob_size_bin] = []
                    bs_to_prob_size_bin_to_ground_truth_slns[bs][prob_size_bin].append(info)

bs_to_prob_size_bin_to_ground_truth_slns
# Out:
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs64_calibrate_solvepoly_wip_gen0.2_r1_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
#  25%|██▌       | 1/4 [00:00<00:00,  3.81it/s]
# # min loss trees: 7
# # min loss trees: 2
# # min loss trees: 18
# # min loss trees: 11
# # min loss trees: 11
# # min loss trees: 4
# # min loss trees: 4
# # min loss trees: 11
# # min loss trees: 8
# # min loss trees: 2
# # min loss trees: 8
#  50%|█████     | 2/4 [00:01<00:01,  1.25it/s]
# # min loss trees: 19
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 9
# # min loss trees: 2
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:01<00:00,  1.54it/s]
# # min loss trees: 10
# # min loss trees: 1
# # min loss trees: 25
# # min loss trees: 39
# # min loss trees: 19
# # min loss trees: 6
# # min loss trees: 6
# 100%|██████████| 4/4 [00:03<00:00,  1.09it/s]
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 7
# # min loss trees: 7
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 8
# # min loss trees: 10
# # min loss trees: 15
# # min loss trees: 5
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 2
# # min loss trees: 12
#  25%|██▌       | 1/4 [00:01<00:03,  1.17s/it]
# # min loss trees: 44
# # min loss trees: 18
# # min loss trees: 7
# # min loss trees: 11
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 3
# # min loss trees: 9
# # min loss trees: 5
#  50%|█████     | 2/4 [00:03<00:03,  1.87s/it]
# # min loss trees: 28
# # min loss trees: 4
# # min loss trees: 101
# # min loss trees: 58
# # min loss trees: 7
# # min loss trees: 11
# # min loss trees: 16
# # min loss trees: 5
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 8
#  75%|███████▌  | 3/4 [00:08<00:03,  3.16s/it]
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 17
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 15
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 25
# 100%|██████████| 4/4 [00:09<00:00,  2.41s/it]
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs64_calibrate_solvepoly_wip_gen0.2_r2_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 6
#  25%|██▌       | 1/4 [00:00<00:00,  3.22it/s]
# # min loss trees: 3
# # min loss trees: 8
# # min loss trees: 2
# # min loss trees: 18
# # min loss trees: 11
# # min loss trees: 11
# # min loss trees: 4
# # min loss trees: 4
# # min loss trees: 11
# # min loss trees: 8
# # min loss trees: 2
# # min loss trees: 8
#  50%|█████     | 2/4 [00:01<00:01,  1.00it/s]
# # min loss trees: 19
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 9
# # min loss trees: 2
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:02<00:00,  1.23it/s]
# # min loss trees: 10
# # min loss trees: 1
# # min loss trees: 24
# # min loss trees: 39
# # min loss trees: 19
# # min loss trees: 6
# # min loss trees: 7
# 100%|██████████| 4/4 [00:04<00:00,  1.07s/it]
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 7
# # min loss trees: 7
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 8
# # min loss trees: 10
# # min loss trees: 17
# # min loss trees: 5
# # min loss trees: 4
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 13
#  25%|██▌       | 1/4 [00:01<00:03,  1.29s/it]
# # min loss trees: 43
# # min loss trees: 18
# # min loss trees: 7
# # min loss trees: 11
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 3
# # min loss trees: 8
# # min loss trees: 5
#  50%|█████     | 2/4 [00:03<00:03,  1.82s/it]
# # min loss trees: 28
# # min loss trees: 4
# # min loss trees: 98
# # min loss trees: 58
# # min loss trees: 7
# # min loss trees: 10
# # min loss trees: 16
# # min loss trees: 5
# # min loss trees: 5
# # min loss trees: 4
# # min loss trees: 6
#  75%|███████▌  | 3/4 [00:07<00:03,  3.00s/it]
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 17
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 15
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 20
# 100%|██████████| 4/4 [00:09<00:00,  2.27s/it]
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs64_calibrate_solvepoly_wip_gen0.2_r3_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
#  25%|██▌       | 1/4 [00:00<00:00,  3.98it/s]
# # min loss trees: 8
# # min loss trees: 2
# # min loss trees: 18
# # min loss trees: 10
# # min loss trees: 11
# # min loss trees: 4
# # min loss trees: 4
# # min loss trees: 11
# # min loss trees: 8
# # min loss trees: 2
# # min loss trees: 8
#  50%|█████     | 2/4 [00:01<00:01,  1.24it/s]
# # min loss trees: 19
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 9
# # min loss trees: 2
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:01<00:00,  1.54it/s]
# # min loss trees: 10
# # min loss trees: 1
# # min loss trees: 22
# # min loss trees: 39
# # min loss trees: 19
# # min loss trees: 6
# # min loss trees: 7
# 100%|██████████| 4/4 [00:03<00:00,  1.08it/s]
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 7
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 9
# # min loss trees: 7
# # min loss trees: 10
# # min loss trees: 15
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 12
#  25%|██▌       | 1/4 [00:01<00:03,  1.26s/it]
# # min loss trees: 43
# # min loss trees: 18
# # min loss trees: 7
# # min loss trees: 11
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 2
# # min loss trees: 8
# # min loss trees: 5
#  50%|█████     | 2/4 [00:03<00:03,  1.75s/it]
# # min loss trees: 28
# # min loss trees: 4
# # min loss trees: 98
# # min loss trees: 58
# # min loss trees: 7
# # min loss trees: 10
# # min loss trees: 23
# # min loss trees: 5
# # min loss trees: 5
# # min loss trees: 4
# # min loss trees: 6
#  75%|███████▌  | 3/4 [00:07<00:02,  2.74s/it]
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 16
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 15
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 20
# 100%|██████████| 4/4 [00:08<00:00,  2.11s/it]
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs64_calibrate_solvepoly_wip_gen0.2_r4_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
#  25%|██▌       | 1/4 [00:00<00:00,  3.86it/s]
# # min loss trees: 7
# # min loss trees: 2
# # min loss trees: 18
# # min loss trees: 11
# # min loss trees: 11
# # min loss trees: 4
# # min loss trees: 4
# # min loss trees: 11
# # min loss trees: 8
# # min loss trees: 2
# # min loss trees: 8
#  50%|█████     | 2/4 [00:01<00:01,  1.17it/s]
# # min loss trees: 19
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 9
# # min loss trees: 2
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:02<00:00,  1.45it/s]
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 23
# # min loss trees: 39
# # min loss trees: 19
# # min loss trees: 5
# # min loss trees: 7
# 100%|██████████| 4/4 [00:03<00:00,  1.02it/s]
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 7
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 9
# # min loss trees: 8
# # min loss trees: 10
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 4
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 12
#  25%|██▌       | 1/4 [00:01<00:04,  1.35s/it]
# # min loss trees: 43
# # min loss trees: 18
# # min loss trees: 7
# # min loss trees: 11
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 3
# # min loss trees: 9
# # min loss trees: 5
# # min loss trees: 28
# # min loss trees: 4
#  50%|█████     | 2/4 [00:03<00:03,  1.85s/it]
# # min loss trees: 101
# # min loss trees: 58
# # min loss trees: 7
# # min loss trees: 11
# # min loss trees: 16
# # min loss trees: 5
# # min loss trees: 5
# # min loss trees: 4
# # min loss trees: 6
#  75%|███████▌  | 3/4 [00:07<00:02,  2.78s/it]
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 16
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 15
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 25
# 100%|██████████| 4/4 [00:08<00:00,  2.16s/it]
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs64_calibrate_solvepoly_wip_gen0.2_r5_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
#  25%|██▌       | 1/4 [00:00<00:00,  3.96it/s]
# # min loss trees: 8
# # min loss trees: 2
# # min loss trees: 18
# # min loss trees: 10
# # min loss trees: 11
# # min loss trees: 4
# # min loss trees: 4
# # min loss trees: 11
# # min loss trees: 9
# # min loss trees: 2
# # min loss trees: 8
#  50%|█████     | 2/4 [00:01<00:01,  1.25it/s]
# # min loss trees: 19
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 9
# # min loss trees: 2
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:01<00:00,  1.55it/s]
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 22
# # min loss trees: 39
# # min loss trees: 19
# # min loss trees: 6
# # min loss trees: 7
# 100%|██████████| 4/4 [00:03<00:00,  1.09it/s]
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 7
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 3
# # min loss trees: 7
# # min loss trees: 10
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 2
# # min loss trees: 12
#  25%|██▌       | 1/4 [00:01<00:03,  1.18s/it]
# # min loss trees: 43
# # min loss trees: 18
# # min loss trees: 9
# # min loss trees: 11
# # min loss trees: 3
# # min loss trees: 3
# # min loss trees: 2
# # min loss trees: 9
# # min loss trees: 5
#  50%|█████     | 2/4 [00:03<00:03,  1.88s/it]
# # min loss trees: 28
# # min loss trees: 4
# # min loss trees: 101
# # min loss trees: 58
# # min loss trees: 7
# # min loss trees: 10
# # min loss trees: 23
# # min loss trees: 5
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 6
#  75%|███████▌  | 3/4 [00:07<00:02,  2.84s/it]
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 16
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 15
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 20
# 100%|██████████| 4/4 [00:08<00:00,  2.18s/it]
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs256_calibrate_solvepoly_wip_gen0.2_r1_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 9
#  25%|██▌       | 1/4 [00:00<00:00,  3.82it/s]
# # min loss trees: 2
# # min loss trees: 25
# # min loss trees: 4
# # min loss trees: 12
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 8
# # min loss trees: 10
# # min loss trees: 4
# # min loss trees: 22
#  50%|█████     | 2/4 [00:01<00:01,  1.05it/s]
# # min loss trees: 17
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 14
# # min loss trees: 2
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:02<00:00,  1.32it/s]
# # min loss trees: 15
# # min loss trees: 1
# # min loss trees: 36
# # min loss trees: 7
# # min loss trees: 18
# # min loss trees: 4
# # min loss trees: 9
# 100%|██████████| 4/4 [00:04<00:00,  1.08s/it]
# # min loss trees: 23
# # min loss trees: 3
# # min loss trees: 8
# # min loss trees: 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 25
# # min loss trees: 6
# # min loss trees: 45
# # min loss trees: 1
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 84
#  25%|██▌       | 1/4 [00:01<00:05,  1.88s/it]
# # min loss trees: 18
# # min loss trees: 12
# # min loss trees: 17
# # min loss trees: 10
# # min loss trees: 4
# # min loss trees: 2
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 49
#  50%|█████     | 2/4 [00:04<00:04,  2.41s/it]
# # min loss trees: 11
# # min loss trees: 53
# # min loss trees: 171
# # min loss trees: 12
# # min loss trees: 11
# # min loss trees: 8
# # min loss trees: 3
# # min loss trees: 8
# # min loss trees: 1
# # min loss trees: 4
#  75%|███████▌  | 3/4 [00:09<00:03,  3.29s/it]
# # min loss trees: 32
# # min loss trees: 2
# # min loss trees: 33
# # min loss trees: 26
# # min loss trees: 8
# # min loss trees: 14
# # min loss trees: 22
# # min loss trees: 7
# # min loss trees: 5
# # min loss trees: 3
# 100%|██████████| 4/4 [00:10<00:00,  2.64s/it]
# # min loss trees: 14
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs256_calibrate_solvepoly_wip_gen0.2_r2_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:00,  4.90it/s]
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 25
# # min loss trees: 4
# # min loss trees: 12
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 8
# # min loss trees: 10
# # min loss trees: 4
# # min loss trees: 22
#  50%|█████     | 2/4 [00:01<00:01,  1.22it/s]
# # min loss trees: 17
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 14
# # min loss trees: 2
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:01<00:00,  1.48it/s]
# # min loss trees: 15
# # min loss trees: 1
# # min loss trees: 37
# # min loss trees: 7
# # min loss trees: 18
# # min loss trees: 4
# # min loss trees: 9
# 100%|██████████| 4/4 [00:04<00:00,  1.00s/it]
# # min loss trees: 23
# # min loss trees: 3
# # min loss trees: 7
# # min loss trees: 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 25
# # min loss trees: 6
# # min loss trees: 46
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 84
#  25%|██▌       | 1/4 [00:01<00:05,  1.91s/it]
# # min loss trees: 18
# # min loss trees: 12
# # min loss trees: 17
# # min loss trees: 8
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 49
#  50%|█████     | 2/4 [00:04<00:04,  2.48s/it]
# # min loss trees: 11
# # min loss trees: 53
# # min loss trees: 170
# # min loss trees: 12
# # min loss trees: 10
# # min loss trees: 9
# # min loss trees: 2
# # min loss trees: 8
# # min loss trees: 1
# # min loss trees: 4
#  75%|███████▌  | 3/4 [00:09<00:03,  3.62s/it]
# # min loss trees: 32
# # min loss trees: 2
# # min loss trees: 33
# # min loss trees: 26
# # min loss trees: 8
# # min loss trees: 14
# # min loss trees: 22
# # min loss trees: 6
# # min loss trees: 5
# # min loss trees: 3
# 100%|██████████| 4/4 [00:11<00:00,  2.90s/it]
# # min loss trees: 10
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs256_calibrate_solvepoly_wip_gen0.2_r3_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 4
# # min loss trees: 4
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:00,  4.72it/s]
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 3
# # min loss trees: 2
# # min loss trees: 25
# # min loss trees: 4
# # min loss trees: 12
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 8
# # min loss trees: 10
# # min loss trees: 4
# # min loss trees: 22
#  50%|█████     | 2/4 [00:01<00:01,  1.20it/s]
# # min loss trees: 17
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 14
# # min loss trees: 2
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:02<00:00,  1.43it/s]
# # min loss trees: 15
# # min loss trees: 1
# # min loss trees: 36
# # min loss trees: 7
# # min loss trees: 18
# # min loss trees: 5
# # min loss trees: 9
# 100%|██████████| 4/4 [00:04<00:00,  1.07s/it]
# # min loss trees: 23
# # min loss trees: 2
# # min loss trees: 7
# # min loss trees: 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 25
# # min loss trees: 6
# # min loss trees: 46
# # min loss trees: 1
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 84
#  25%|██▌       | 1/4 [00:02<00:06,  2.23s/it]
# # min loss trees: 18
# # min loss trees: 12
# # min loss trees: 17
# # min loss trees: 10
# # min loss trees: 4
# # min loss trees: 2
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 49
#  50%|█████     | 2/4 [00:05<00:05,  2.57s/it]
# # min loss trees: 11
# # min loss trees: 53
# # min loss trees: 170
# # min loss trees: 12
# # min loss trees: 10
# # min loss trees: 8
# # min loss trees: 2
# # min loss trees: 8
# # min loss trees: 1
# # min loss trees: 4
#  75%|███████▌  | 3/4 [00:09<00:03,  3.37s/it]
# # min loss trees: 32
# # min loss trees: 2
# # min loss trees: 33
# # min loss trees: 26
# # min loss trees: 8
# # min loss trees: 14
# # min loss trees: 22
# # min loss trees: 7
# # min loss trees: 5
# # min loss trees: 3
# 100%|██████████| 4/4 [00:10<00:00,  2.73s/it]
# # min loss trees: 14
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs256_calibrate_solvepoly_wip_gen0.2_r4_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 4
# # min loss trees: 4
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:00,  4.85it/s]
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 25
# # min loss trees: 4
# # min loss trees: 12
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 8
# # min loss trees: 10
# # min loss trees: 4
# # min loss trees: 22
#  50%|█████     | 2/4 [00:01<00:01,  1.21it/s]
# # min loss trees: 17
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 14
# # min loss trees: 2
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:01<00:00,  1.48it/s]
# # min loss trees: 15
# # min loss trees: 1
# # min loss trees: 36
# # min loss trees: 7
# # min loss trees: 18
# # min loss trees: 4
# # min loss trees: 10
# 100%|██████████| 4/4 [00:03<00:00,  1.01it/s]
# # min loss trees: 23
# # min loss trees: 2
# # min loss trees: 7
# # min loss trees: 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 25
# # min loss trees: 6
# # min loss trees: 45
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 84
#  25%|██▌       | 1/4 [00:01<00:05,  1.90s/it]
# # min loss trees: 18
# # min loss trees: 12
# # min loss trees: 15
# # min loss trees: 8
# # min loss trees: 4
# # min loss trees: 2
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 49
#  50%|█████     | 2/4 [00:04<00:04,  2.39s/it]
# # min loss trees: 11
# # min loss trees: 53
# # min loss trees: 170
# # min loss trees: 12
# # min loss trees: 10
# # min loss trees: 8
# # min loss trees: 3
# # min loss trees: 8
# # min loss trees: 1
# # min loss trees: 4
#  75%|███████▌  | 3/4 [00:08<00:03,  3.21s/it]
# # min loss trees: 32
# # min loss trees: 2
# # min loss trees: 33
# # min loss trees: 26
# # min loss trees: 8
# # min loss trees: 14
# # min loss trees: 22
# # min loss trees: 6
# # min loss trees: 5
# # min loss trees: 3
# 100%|██████████| 4/4 [00:10<00:00,  2.60s/it]
# # min loss trees: 14
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs256_calibrate_solvepoly_wip_gen0.2_r5_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 4
# # min loss trees: 3
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:00,  4.76it/s]
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 25
# # min loss trees: 4
# # min loss trees: 12
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 8
# # min loss trees: 10
# # min loss trees: 4
# # min loss trees: 22
#  50%|█████     | 2/4 [00:01<00:01,  1.22it/s]
# # min loss trees: 17
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 14
# # min loss trees: 2
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:01<00:00,  1.49it/s]
# # min loss trees: 15
# # min loss trees: 1
# # min loss trees: 37
# # min loss trees: 7
# # min loss trees: 18
# # min loss trees: 5
# # min loss trees: 10
# 100%|██████████| 4/4 [00:03<00:00,  1.00it/s]
# # min loss trees: 23
# # min loss trees: 3
# # min loss trees: 7
# # min loss trees: 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 24
# # min loss trees: 6
# # min loss trees: 46
# # min loss trees: 2
# # min loss trees: 5
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 4
# # min loss trees: 85
#  25%|██▌       | 1/4 [00:01<00:05,  1.99s/it]
# # min loss trees: 18
# # min loss trees: 12
# # min loss trees: 17
# # min loss trees: 11
# # min loss trees: 4
# # min loss trees: 2
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 49
#  50%|█████     | 2/4 [00:04<00:05,  2.55s/it]
# # min loss trees: 11
# # min loss trees: 52
# # min loss trees: 171
# # min loss trees: 12
# # min loss trees: 11
# # min loss trees: 8
# # min loss trees: 3
# # min loss trees: 8
# # min loss trees: 1
# # min loss trees: 4
#  75%|███████▌  | 3/4 [00:09<00:03,  3.33s/it]
# # min loss trees: 32
# # min loss trees: 2
# # min loss trees: 33
# # min loss trees: 26
# # min loss trees: 8
# # min loss trees: 14
# # min loss trees: 22
# # min loss trees: 6
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 14
# 100%|██████████| 4/4 [00:10<00:00,  2.70s/it]
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs1024_calibrate_solvepoly_wip_gen0.2_r1_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 3
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 2
#  25%|██▌       | 1/4 [00:00<00:00,  4.80it/s]
# # min loss trees: 2
# # min loss trees: 34
# # min loss trees: 4
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 6
# # min loss trees: 9
# # min loss trees: 11
# # min loss trees: 5
# # min loss trees: 20
#  50%|█████     | 2/4 [00:01<00:01,  1.04it/s]
# # min loss trees: 22
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:02<00:00,  1.39it/s]
# # min loss trees: 16
# # min loss trees: 2
# # min loss trees: 40
# # min loss trees: 16
# # min loss trees: 15
# # min loss trees: 2
# # min loss trees: 12
# # min loss trees: 29
# # min loss trees: 5
# # min loss trees: 12
# 100%|██████████| 4/4 [00:04<00:00,  1.24s/it]
# # min loss trees: 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 3
# # min loss trees: 57
# # min loss trees: 9
# # min loss trees: 80
# # min loss trees: 2
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 5
# # min loss trees: 4
# # min loss trees: 126
#  25%|██▌       | 1/4 [00:04<00:14,  4.77s/it]
# # min loss trees: 45
# # min loss trees: 14
# # min loss trees: 57
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 7
# # min loss trees: 20
# # min loss trees: 29
#  50%|█████     | 2/4 [00:08<00:08,  4.07s/it]
# # min loss trees: 25
# # min loss trees: 250
# # min loss trees: 402
# # min loss trees: 28
# # min loss trees: 8
# # min loss trees: 45
# # min loss trees: 7
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 3
# # min loss trees: 61
#  75%|███████▌  | 3/4 [00:16<00:05,  5.88s/it]
# # min loss trees: 3
# # min loss trees: 38
# # min loss trees: 60
# # min loss trees: 12
# # min loss trees: 29
# # min loss trees: 14
# # min loss trees: 14
# # min loss trees: 7
# # min loss trees: 2
# # min loss trees: 19
# 100%|██████████| 4/4 [00:18<00:00,  4.64s/it]
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs1024_calibrate_solvepoly_wip_gen0.2_r2_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 3
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 2
#  25%|██▌       | 1/4 [00:00<00:00,  4.97it/s]
# # min loss trees: 34
# # min loss trees: 4
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 6
# # min loss trees: 9
# # min loss trees: 11
# # min loss trees: 5
# # min loss trees: 20
#  50%|█████     | 2/4 [00:01<00:01,  1.02it/s]
# # min loss trees: 22
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:02<00:00,  1.32it/s]
# # min loss trees: 16
# # min loss trees: 2
# # min loss trees: 40
# # min loss trees: 16
# # min loss trees: 15
# # min loss trees: 5
# # min loss trees: 11
# # min loss trees: 29
# # min loss trees: 5
# # min loss trees: 12
# 100%|██████████| 4/4 [00:04<00:00,  1.21s/it]
# # min loss trees: 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 3
# # min loss trees: 57
# # min loss trees: 9
# # min loss trees: 78
# # min loss trees: 2
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 5
# # min loss trees: 4
# # min loss trees: 124
#  25%|██▌       | 1/4 [00:04<00:14,  4.73s/it]
# # min loss trees: 45
# # min loss trees: 14
# # min loss trees: 57
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 7
# # min loss trees: 14
# # min loss trees: 29
#  50%|█████     | 2/4 [00:08<00:07,  3.99s/it]
# # min loss trees: 25
# # min loss trees: 254
# # min loss trees: 409
# # min loss trees: 28
# # min loss trees: 8
# # min loss trees: 44
# # min loss trees: 7
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 3
# # min loss trees: 61
#  75%|███████▌  | 3/4 [00:16<00:05,  5.96s/it]
# # min loss trees: 3
# # min loss trees: 37
# # min loss trees: 24
# # min loss trees: 14
# # min loss trees: 29
# # min loss trees: 14
# # min loss trees: 14
# # min loss trees: 7
# # min loss trees: 2
# 100%|██████████| 4/4 [00:18<00:00,  4.73s/it]
# # min loss trees: 24
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs1024_calibrate_solvepoly_wip_gen0.2_r3_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 3
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 6
#  25%|██▌       | 1/4 [00:00<00:00,  3.88it/s]
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 34
# # min loss trees: 4
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 6
# # min loss trees: 9
# # min loss trees: 11
# # min loss trees: 5
# # min loss trees: 20
#  50%|█████     | 2/4 [00:01<00:02,  1.04s/it]
# # min loss trees: 22
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:02<00:00,  1.29it/s]
# # min loss trees: 16
# # min loss trees: 2
# # min loss trees: 41
# # min loss trees: 16
# # min loss trees: 15
# # min loss trees: 5
# # min loss trees: 11
# # min loss trees: 29
# # min loss trees: 5
# # min loss trees: 13
# 100%|██████████| 4/4 [00:05<00:00,  1.30s/it]
# # min loss trees: 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 3
# # min loss trees: 57
# # min loss trees: 9
# # min loss trees: 79
# # min loss trees: 2
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 124
#  25%|██▌       | 1/4 [00:04<00:12,  4.04s/it]
# # min loss trees: 45
# # min loss trees: 14
# # min loss trees: 57
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 7
# # min loss trees: 20
# # min loss trees: 29
#  50%|█████     | 2/4 [00:07<00:07,  3.57s/it]
# # min loss trees: 25
# # min loss trees: 253
# # min loss trees: 409
# # min loss trees: 28
# # min loss trees: 7
# # min loss trees: 45
# # min loss trees: 7
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 3
#  75%|███████▌  | 3/4 [00:15<00:05,  5.69s/it]
# # min loss trees: 61
# # min loss trees: 3
# # min loss trees: 37
# # min loss trees: 24
# # min loss trees: 14
# # min loss trees: 29
# # min loss trees: 14
# # min loss trees: 14
# # min loss trees: 7
# # min loss trees: 2
# 100%|██████████| 4/4 [00:17<00:00,  4.36s/it]
# # min loss trees: 19
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs1024_calibrate_solvepoly_wip_gen0.2_r4_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 3
# # min loss trees: 1
# # min loss trees: 1
#  25%|██▌       | 1/4 [00:00<00:00,  4.76it/s]
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 34
# # min loss trees: 4
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 6
# # min loss trees: 9
# # min loss trees: 11
# # min loss trees: 5
# # min loss trees: 20
#  50%|█████     | 2/4 [00:01<00:01,  1.04it/s]
# # min loss trees: 22
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:02<00:00,  1.38it/s]
# # min loss trees: 16
# # min loss trees: 2
# # min loss trees: 41
# # min loss trees: 16
# # min loss trees: 15
# # min loss trees: 2
# # min loss trees: 12
# # min loss trees: 29
# # min loss trees: 5
# # min loss trees: 12
# 100%|██████████| 4/4 [00:04<00:00,  1.20s/it]
# # min loss trees: 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 3
# # min loss trees: 57
# # min loss trees: 9
# # min loss trees: 78
# # min loss trees: 3
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 5
# # min loss trees: 4
# # min loss trees: 124
#  25%|██▌       | 1/4 [00:04<00:13,  4.36s/it]
# # min loss trees: 45
# # min loss trees: 14
# # min loss trees: 57
# # min loss trees: 7
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 7
# # min loss trees: 14
# # min loss trees: 29
#  50%|█████     | 2/4 [00:07<00:07,  3.92s/it]
# # min loss trees: 25
# # min loss trees: 250
# # min loss trees: 409
# # min loss trees: 28
# # min loss trees: 7
# # min loss trees: 44
# # min loss trees: 7
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 3
# # min loss trees: 61
#  75%|███████▌  | 3/4 [00:15<00:05,  5.69s/it]
# # min loss trees: 3
# # min loss trees: 37
# # min loss trees: 24
# # min loss trees: 14
# # min loss trees: 29
# # min loss trees: 14
# # min loss trees: 16
# # min loss trees: 6
# # min loss trees: 2
# 100%|██████████| 4/4 [00:17<00:00,  4.44s/it]
# # min loss trees: 19
# /lila/data/morrisq/divyak/projects/met_history_prediction/src/jupyter_notebooks/../test/machina_simulated_data/sample_size_experiments_calibrate_solvepoly_wip_gen0.2_12062023/predictions_batch_exp_bs1024_calibrate_solvepoly_wip_gen0.2_r5_12062023
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 3
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 1
# # min loss trees: 2
# # min loss trees: 2
#  25%|██▌       | 1/4 [00:00<00:00,  4.66it/s]
# # min loss trees: 34
# # min loss trees: 4
# # min loss trees: 16
# # min loss trees: 4
# # min loss trees: 6
# # min loss trees: 9
# # min loss trees: 11
# # min loss trees: 5
# # min loss trees: 20
#  50%|█████     | 2/4 [00:01<00:02,  1.08s/it]
# # min loss trees: 22
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 6
# # min loss trees: 3
# # min loss trees: 4
# # min loss trees: 1
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 2
#  75%|███████▌  | 3/4 [00:02<00:00,  1.26it/s]
# # min loss trees: 16
# # min loss trees: 2
# # min loss trees: 40
# # min loss trees: 16
# # min loss trees: 15
# # min loss trees: 5
# # min loss trees: 11
# # min loss trees: 29
# # min loss trees: 5
# # min loss trees: 14
# 100%|██████████| 4/4 [00:04<00:00,  1.22s/it]
# # min loss trees: 8
#   0%|          | 0/4 [00:00<?, ?it/s]
# # min loss trees: 2
# # min loss trees: 58
# # min loss trees: 9
# # min loss trees: 78
# # min loss trees: 2
# # min loss trees: 5
# # min loss trees: 3
# # min loss trees: 1
# # min loss trees: 4
# # min loss trees: 124
#  25%|██▌       | 1/4 [00:04<00:13,  4.51s/it]
# # min loss trees: 45
# # min loss trees: 14
# # min loss trees: 57
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 2
# # min loss trees: 7
# # min loss trees: 14
# # min loss trees: 29
#  50%|█████     | 2/4 [00:07<00:07,  3.77s/it]
# # min loss trees: 25
# # min loss trees: 250
# # min loss trees: 409
# # min loss trees: 28
# # min loss trees: 9
# # min loss trees: 44
# # min loss trees: 7
# # min loss trees: 6
# # min loss trees: 2
# # min loss trees: 3
# # min loss trees: 61
#  75%|███████▌  | 3/4 [00:15<00:05,  5.62s/it]
# # min loss trees: 3
# # min loss trees: 36
# # min loss trees: 24
# # min loss trees: 14
# # min loss trees: 29
# # min loss trees: 14
# # min loss trees: 14
# # min loss trees: 6
# # min loss trees: 2
# 100%|██████████| 4/4 [00:17<00:00,  4.40s/it]
# # min loss trees: 25
# {'64': {0: [(True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.611111111111111),
#    (True, True, 1.0, 0.75),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.8333333333333334, 0.8333333333333334),
#    (True, False, 1.0, 0.6984126984126984),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.9574635241301908, 0.6681651681651682),
#    (True, False, 0.98989898989899, 0.7297702297702298),
#    (True, True, 1.0, 0.5754245754245754),
#    (True, False, 0.9772727272727273, 0.7404761904761905),
#    (False, False, 0.8888888888888888, 0.8333333333333334),
#    (False, True, 0.7045454545454546, 0.7862137862137861),
#    (True, False, 1.0, 0.6875),
#    (True, True, 1.0, 0.9615384615384615),
#    (False, False, 0.7187499999999999, 0.8087121212121213),
#    (True, True, 0.9285714285714286, 0.9),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.5476190476190476, 0.8838383838383838),
#    (True, True, 0.8950617283950617, 0.8222222222222221),
#    (True, True, 1.0, 0.8636363636363636),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 0.9166666666666667),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9571428571428573, 0.5609090909090909),
#    (True, False, 1.0, 0.7272727272727273),
#    (False, False, 0.8888888888888892, 0.6964705882352941),
#    (True, True, 0.9971509971509971, 0.6120857699805066),
#    (True, False, 0.8947368421052635, 0.9011164274322165),
#    (False, False, 0.888888888888889, 0.6454545454545455),
#    (False, False, 0.8592592592592592, 0.42857142857142866),
#    (False, False, 0.8571428571428573, 0.28571428571428564),
#    (True, False, 1.0, 0.7692307692307694),
#    (False, False, 0.75, 0.43809523809523804),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.95, 0.59375),
#    (True, False, 0.9285714285714286, 0.5441176470588236),
#    (True, True, 1.0, 0.8333333333333331),
#    (True, False, 1.0, 0.2962962962962963),
#    (True, True, 0.9833333333333334, 0.6432748538011696),
#    (True, True, 1.0, 0.705),
#    (False, False, 0.8437500000000002, 0.7921052631578945),
#    (False, False, 0.8, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.611111111111111),
#    (True, True, 1.0, 0.75),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.8333333333333334, 0.8333333333333334),
#    (True, False, 1.0, 0.7222222222222223),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.9574635241301908, 0.6681651681651682),
#    (True, False, 0.98989898989899, 0.7297702297702298),
#    (True, True, 1.0, 0.5754245754245754),
#    (True, False, 0.9772727272727273, 0.7404761904761905),
#    (False, False, 0.8888888888888888, 0.8333333333333334),
#    (False, True, 0.7045454545454546, 0.7862137862137861),
#    (True, False, 1.0, 0.6875),
#    (True, True, 1.0, 0.9615384615384615),
#    (False, False, 0.7187499999999999, 0.8087121212121213),
#    (True, True, 0.9285714285714286, 0.9),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.5476190476190476, 0.8838383838383838),
#    (True, True, 0.8950617283950617, 0.8222222222222221),
#    (True, True, 1.0, 0.8636363636363636),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 0.9166666666666667),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9571428571428573, 0.5609090909090909),
#    (True, False, 1.0, 0.7272727272727273),
#    (False, False, 0.8888888888888892, 0.6960784313725489),
#    (True, True, 0.9971509971509971, 0.6120857699805066),
#    (True, False, 0.8947368421052635, 0.9011164274322165),
#    (False, False, 0.888888888888889, 0.6454545454545455),
#    (False, False, 0.8634920634920634, 0.4285714285714287),
#    (False, False, 0.8571428571428573, 0.28571428571428564),
#    (True, False, 1.0, 0.7692307692307694),
#    (False, False, 0.75, 0.43809523809523804),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.95, 0.59375),
#    (True, False, 1.0, 0.6875),
#    (True, True, 1.0, 0.835164835164835),
#    (True, False, 1.0, 0.2962962962962963),
#    (True, True, 0.9833333333333334, 0.6432748538011696),
#    (True, True, 1.0, 0.705),
#    (False, False, 0.8392857142857144, 0.7929824561403508),
#    (False, False, 0.8, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.611111111111111),
#    (True, True, 1.0, 0.75),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.8333333333333334, 0.8333333333333334),
#    (True, False, 1.0, 0.7222222222222223),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.9574635241301908, 0.6681651681651682),
#    (True, False, 0.9888888888888889, 0.7527472527472527),
#    (True, True, 1.0, 0.5754245754245754),
#    (True, False, 0.9772727272727273, 0.7404761904761905),
#    (False, False, 0.8888888888888888, 0.8333333333333334),
#    (False, True, 0.7045454545454546, 0.7862137862137861),
#    (True, False, 1.0, 0.6875),
#    (True, True, 1.0, 0.9615384615384615),
#    (False, False, 0.7187499999999999, 0.8087121212121213),
#    (True, True, 0.9285714285714286, 0.9),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.5476190476190476, 0.8838383838383838),
#    (True, True, 0.8950617283950617, 0.8222222222222221),
#    (True, True, 1.0, 0.8636363636363636),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 0.9166666666666667),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9571428571428573, 0.5609090909090909),
#    (True, False, 1.0, 0.7272727272727273),
#    (False, False, 0.8888888888888892, 0.7379679144385026),
#    (True, True, 0.9971509971509971, 0.6120857699805066),
#    (True, False, 0.8947368421052635, 0.9011164274322165),
#    (False, False, 0.888888888888889, 0.6454545454545455),
#    (False, False, 0.8634920634920634, 0.4285714285714287),
#    (False, False, 0.8571428571428573, 0.28571428571428564),
#    (True, False, 1.0, 0.7692307692307694),
#    (False, False, 0.75, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9428571428571428, 0.5714285714285714),
#    (True, False, 0.9285714285714286, 0.5441176470588236),
#    (True, True, 1.0, 0.8333333333333331),
#    (True, False, 1.0, 0.2777777777777778),
#    (True, True, 0.9833333333333334, 0.6432748538011696),
#    (True, True, 1.0, 0.705),
#    (False, False, 0.8392857142857144, 0.7929824561403508),
#    (False, False, 0.8, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.611111111111111),
#    (True, True, 1.0, 0.75),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.8333333333333334, 0.8333333333333334),
#    (True, False, 1.0, 0.6984126984126984),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.9574635241301908, 0.6681651681651682),
#    (True, False, 0.98989898989899, 0.7297702297702298),
#    (True, True, 1.0, 0.5754245754245754),
#    (True, False, 0.9772727272727273, 0.7404761904761905),
#    (False, False, 0.8888888888888888, 0.8333333333333334),
#    (False, True, 0.7045454545454546, 0.7862137862137861),
#    (True, False, 1.0, 0.6875),
#    (True, True, 1.0, 0.9615384615384615),
#    (False, False, 0.7187499999999999, 0.8087121212121213),
#    (True, True, 0.9285714285714286, 0.9),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.5476190476190476, 0.8838383838383838),
#    (True, True, 0.8950617283950617, 0.8222222222222221),
#    (True, True, 1.0, 0.8636363636363636),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 0.9166666666666667),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.5563636363636364),
#    (True, False, 1.0, 0.7272727272727273),
#    (False, False, 0.8888888888888892, 0.7109974424552429),
#    (True, True, 0.9971509971509971, 0.6120857699805066),
#    (True, False, 0.8947368421052635, 0.9011164274322165),
#    (False, False, 0.888888888888889, 0.6290909090909091),
#    (False, False, 0.8634920634920634, 0.4285714285714287),
#    (False, False, 0.8571428571428573, 0.28571428571428564),
#    (True, False, 1.0, 0.7692307692307694),
#    (False, False, 0.75, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.95, 0.59375),
#    (True, False, 0.9285714285714286, 0.5441176470588236),
#    (True, True, 1.0, 0.8333333333333331),
#    (True, False, 1.0, 0.2962962962962963),
#    (True, True, 0.9833333333333334, 0.6432748538011696),
#    (True, True, 1.0, 0.705),
#    (False, False, 0.8392857142857144, 0.7929824561403508),
#    (False, False, 0.8, 0.6666666666666666),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.611111111111111),
#    (True, True, 1.0, 0.75),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.8333333333333334, 0.8333333333333334),
#    (True, False, 1.0, 0.7222222222222223),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.9574635241301908, 0.6681651681651682),
#    (True, False, 0.9888888888888889, 0.7527472527472527),
#    (True, True, 1.0, 0.5754245754245754),
#    (True, False, 0.9772727272727273, 0.7404761904761905),
#    (False, False, 0.8888888888888888, 0.8333333333333334),
#    (False, True, 0.7045454545454546, 0.7862137862137861),
#    (True, False, 1.0, 0.6666666666666666),
#    (True, True, 1.0, 0.9615384615384615),
#    (False, False, 0.7187499999999999, 0.8087121212121213),
#    (True, True, 0.9285714285714286, 0.9),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.5476190476190476, 0.8838383838383838),
#    (True, True, 0.8950617283950617, 0.8222222222222221),
#    (True, True, 1.0, 0.8636363636363636),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 0.9166666666666667),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.5563636363636364),
#    (True, False, 1.0, 0.7272727272727273),
#    (False, False, 0.8888888888888892, 0.7112299465240641),
#    (True, True, 0.9971509971509971, 0.6120857699805066),
#    (True, False, 0.8947368421052635, 0.9011164274322165),
#    (False, False, 0.888888888888889, 0.6454545454545455),
#    (False, False, 0.8634920634920634, 0.4285714285714287),
#    (False, False, 0.8571428571428573, 0.2857142857142857),
#    (True, False, 1.0, 0.7692307692307694),
#    (False, False, 0.75, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9428571428571428, 0.5714285714285714),
#    (True, False, 0.9285714285714286, 0.5441176470588236),
#    (True, True, 1.0, 0.8333333333333331),
#    (True, False, 1.0, 0.2777777777777778),
#    (True, True, 0.9833333333333334, 0.6432748538011696),
#    (True, True, 1.0, 0.705),
#    (False, False, 0.8392857142857144, 0.7929824561403508),
#    (False, False, 0.8, 0.6666666666666666)],
#   1: [(True, True, 1.0, 1.0),
#    (True, False, 0.9508771929824561, 0.6624060150375941),
#    (False, True, 0.6577777777777777, 0.8761904761904761),
#    (True, False, 0.9428571428571428, 0.8723809523809523),
#    (True, True, 0.9285714285714286, 1.0),
#    (True, True, 0.9520202020202018, 0.9715909090909091),
#    (True, False, 0.9898989898989898, 0.5485810485810485),
#    (False, True, 0.8571428571428574, 0.87593984962406),
#    (True, False, 0.9476190476190476, 0.7),
#    (True, False, 0.9629629629629629, 0.6363636363636364),
#    (True, False, 0.9208754208754208, 0.6672552841799487),
#    (True, False, 1.0, 0.6666666666666667),
#    (True, False, 0.9977011494252873, 0.735557545902373),
#    (True, False, 0.9930555555555556, 0.571875),
#    (True, True, 0.9428571428571428, 0.8433333333333334),
#    (True, False, 1.0, 0.13333333333333333),
#    (True, True, 0.7625000000000001, 0.6962316176470588),
#    (False, True, 0.6515837104072397, 0.56484348125215),
#    (True, False, 0.9666666666666667, 0.683625730994152),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8888888888888886, 0.3137254901960784),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9508771929824561, 0.6624060150375941),
#    (False, True, 0.6549019607843136, 0.8739495798319327),
#    (True, False, 0.9428571428571428, 0.8723809523809523),
#    (True, True, 0.9285714285714286, 1.0),
#    (True, True, 0.9509043927648578, 0.9738372093023255),
#    (True, False, 0.9898989898989898, 0.5485810485810485),
#    (False, True, 0.8571428571428574, 0.87593984962406),
#    (True, False, 0.9476190476190476, 0.7),
#    (True, False, 0.9629629629629629, 0.6363636363636364),
#    (True, False, 0.9223484848484849, 0.6848727210182318),
#    (True, False, 1.0, 0.6666666666666667),
#    (True, False, 0.9977011494252873, 0.735557545902373),
#    (True, False, 0.9930555555555556, 0.571875),
#    (True, True, 0.9428571428571428, 0.8433333333333334),
#    (True, False, 0.9772727272727273, 0.2),
#    (True, True, 0.7625000000000001, 0.6962316176470588),
#    (False, True, 0.6515837104072397, 0.56484348125215),
#    (True, False, 0.9666666666666667, 0.683625730994152),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8888888888888886, 0.3137254901960784),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9508771929824561, 0.6624060150375941),
#    (False, True, 0.6577777777777777, 0.8666666666666666),
#    (True, False, 0.9428571428571428, 0.8723809523809523),
#    (True, True, 0.9523809523809524, 1.0),
#    (True, True, 0.9509043927648578, 0.9738372093023255),
#    (True, False, 0.9898989898989898, 0.5485810485810485),
#    (False, True, 0.8571428571428574, 0.87593984962406),
#    (True, False, 0.9476190476190476, 0.7),
#    (True, False, 1.0, 0.6534914361001317),
#    (True, False, 0.9223484848484849, 0.6848727210182318),
#    (True, False, 1.0, 0.6666666666666667),
#    (True, False, 0.9977011494252873, 0.735557545902373),
#    (True, False, 0.9903381642512078, 0.5891304347826088),
# ...
#    (False, False, 0.8571428571428572, 0.8571428571428571),
#    (True, False, 1.0, 0.7222222222222223),
#    (True, False, 0.9314134141720348, 0.772131478120589),
#    (True, False, 0.9324675324675324, 0.6869047619047619),
#    (False, False, 0.8571428571428572, 0.8631578947368421),
#    (False, False, 0.7555555555555555, 0.777777777777778),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.888888888888889, 0.75),
#    (True, False, 1.0, 0.75),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8, 0.75),
#    (False, False, 0.8571428571428572, 0.625),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.9494949494949495, 0.5982448923625393),
#    (True, False, 1.0, 0.7912087912087914),
#    (True, False, 1.0, 0.5137362637362637),
#    (True, True, 0.9545454545454546, 0.7666666666666666),
#    (False, False, 0.8592592592592592, 0.8333333333333334),
#    (False, True, 0.7222222222222222, 0.7680097680097681),
#    (True, False, 0.98989898989899, 0.6515151515151515),
#    (True, True, 0.9595959595959596, 0.9846153846153847),
#    (False, False, 0.7113095238095237, 0.7810606060606058),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.5476190476190476, 0.8838383838383838),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, False, 1.0, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9732142857142858, 0.5897727272727271),
#    (True, False, 0.875, 0.7272727272727273),
#    (False, False, 0.886720867208672, 0.3789454806312767),
#    (True, False, 1.0, 0.33333333333333326),
#    (True, False, 0.8666666666666669, 0.8939393939393939),
#    (False, False, 0.888888888888889, 0.7236363636363637),
#    (False, False, 0.872727272727273, 0.42857142857142877),
#    (False, False, 0.7857142857142859, 0.28571428571428564),
#    (True, False, 0.8777777777777779, 0.7692307692307694),
#    (False, False, 0.7435897435897435, 0.7179487179487178),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.8994152046783616, 0.5384416924664602),
#    (True, False, 1.0, 0.625),
#    (False, False, 0.8571428571428572, 0.8571428571428571),
#    (True, False, 1.0, 0.7222222222222223),
#    (True, False, 0.9314134141720348, 0.772131478120589),
#    (True, False, 0.9324675324675324, 0.6869047619047619),
#    (False, False, 0.8571428571428572, 0.8631578947368421),
#    (False, False, 0.7555555555555555, 0.777777777777778),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.888888888888889, 0.75),
#    (True, False, 1.0, 0.75),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8, 0.75),
#    (False, False, 0.8571428571428572, 0.625),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.9494949494949495, 0.5982448923625393),
#    (True, False, 1.0, 0.7912087912087914),
#    (True, False, 1.0, 0.5137362637362637),
#    (True, True, 0.9545454545454546, 0.7666666666666666),
#    (False, False, 0.8592592592592592, 0.8333333333333334),
#    (False, True, 0.7222222222222222, 0.7680097680097681),
#    (True, False, 0.98989898989899, 0.6515151515151515),
#    (True, True, 0.9595959595959596, 0.9846153846153847),
#    (False, False, 0.7113095238095237, 0.7810606060606058),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.5476190476190476, 0.8838383838383838),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, False, 1.0, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9732142857142858, 0.5897727272727271),
#    (True, False, 0.875, 0.7272727272727273),
#    (True, False, 0.889430894308943, 0.3814960943727082),
#    (True, False, 1.0, 0.33333333333333326),
#    (True, False, 0.8666666666666669, 0.8939393939393939),
#    (False, False, 0.8888888888888888, 0.7545454545454546),
#    (False, False, 0.866666666666667, 0.42857142857142877),
#    (False, False, 0.7857142857142859, 0.28571428571428564),
#    (True, False, 0.8777777777777779, 0.7692307692307694),
#    (False, False, 0.7430555555555555, 0.6444444444444445),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9099415204678354, 0.5362487100103198),
#    (True, False, 0.9714285714285715, 0.7),
#    (False, False, 0.8571428571428572, 0.8571428571428571),
#    (True, False, 1.0, 0.7222222222222223),
#    (True, False, 0.9314134141720348, 0.772131478120589),
#    (True, False, 0.9324675324675324, 0.6869047619047619),
#    (False, False, 0.8571428571428572, 0.8631578947368421),
#    (False, False, 0.7555555555555555, 0.777777777777778),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.888888888888889, 0.75),
#    (True, False, 1.0, 0.75),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (True, True, 1.0, 1.0),
#    (False, False, 0.8, 0.75),
#    (False, False, 0.8571428571428572, 0.625),
#    (True, True, 1.0, 1.0),
#    (True, True, 0.9494949494949495, 0.5982448923625393),
#    (True, False, 1.0, 0.7912087912087914),
#    (True, False, 1.0, 0.5137362637362637),
#    (True, True, 0.9545454545454546, 0.7666666666666666),
#    (False, False, 0.8592592592592592, 0.8333333333333334),
#    (False, True, 0.7222222222222222, 0.7680097680097681),
#    (True, False, 0.98989898989899, 0.6515151515151515),
#    (True, True, 0.9595959595959596, 0.9846153846153847),
#    (False, False, 0.7113095238095237, 0.7810606060606058),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (False, False, 0.5476190476190476, 0.8838383838383838),
#    (False, False, 0.8571428571428572, 0.8),
#    (True, False, 1.0, 0.8),
#    (True, True, 1.0, 1.0),
#    (True, False, 1.0, 0.8333333333333334),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9732142857142858, 0.5897727272727271),
#    (True, False, 0.875, 0.7272727272727273),
#    (False, False, 0.8866666666666667, 0.3854779411764704),
#    (True, False, 1.0, 0.33333333333333326),
#    (True, False, 0.8666666666666669, 0.8939393939393939),
#    (False, False, 0.888888888888889, 0.7236363636363637),
#    (False, False, 0.872727272727273, 0.42857142857142877),
#    (False, False, 0.7857142857142859, 0.28571428571428564),
#    (True, False, 0.8777777777777779, 0.7692307692307694),
#    (False, False, 0.744047619047619, 0.6761904761904762),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9045977011494244, 0.5377789046653143),
#    (True, False, 1.0, 0.625),
#    (False, False, 0.8571428571428572, 0.8571428571428571),
#    (True, False, 1.0, 0.7222222222222223),
#    (True, False, 0.9314134141720348, 0.772131478120589),
#    (True, False, 0.9324675324675324, 0.6869047619047619),
#    (False, False, 0.8571428571428572, 0.8631578947368421),
#    (False, False, 0.7555555555555555, 0.777777777777778)],
#   1: [(True, True, 1.0, 1.0),
#    (True, False, 0.9279220779220781, 0.646969696969697),
#    (False, True, 0.6208333333333341, 0.8767857142857137),
#    (True, True, 0.8333333333333333, 1.0),
#    (True, True, 0.9142857142857143, 1.0),
#    (True, True, 0.9386243386243377, 0.9345238095238095),
#    (True, False, 0.9655892255892254, 0.4593554593554594),
#    (False, True, 0.8494897959183677, 0.8452918009308988),
#    (False, False, 0.8935286935286935, 0.6999999999999998),
#    (True, True, 1.0, 0.6818181818181819),
#    (True, True, 1.0, 0.8571428571428571),
#    (True, False, 0.9865734265734265, 0.5501754385964912),
#    (True, True, 0.9935086472399902, 0.7284980143513554),
#    (True, False, 0.918518518518518, 0.5642592592592597),
#    (True, False, 0.9523809523809526, 0.9333333333333335),
#    (False, False, 0.8444444444444444, 0.13333333333333333),
#    (True, False, 0.8455042225534023, 0.5254339440694311),
#    (False, False, 0.6545209176788127, 0.4736842105263157),
#    (True, False, 0.9421212121212115, 0.6818170426065162),
#    (True, True, 0.9604700854700855, 0.888888888888889),
#    (False, False, 0.8874458874458873, 0.3529411764705882),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9279220779220781, 0.646969696969697),
#    (False, True, 0.6213675213675222, 0.875457875457875),
#    (True, True, 0.8333333333333333, 1.0),
#    (True, True, 0.9142857142857143, 1.0),
#    (True, True, 0.9407706093189955, 0.9334677419354839),
#    (True, False, 0.9655892255892254, 0.4593554593554594),
#    (False, True, 0.8494897959183677, 0.8452918009308988),
#    (False, False, 0.8918192918192918, 0.7166666666666667),
#    (True, True, 1.0, 0.6818181818181819),
#    (True, True, 1.0, 0.8571428571428571),
#    (True, False, 0.9865734265734265, 0.5501754385964912),
#    (True, True, 0.9936197461869831, 0.7269846485324312),
#    (True, False, 0.9191919191919187, 0.5619318181818185),
#    (True, False, 0.9523809523809526, 0.9333333333333335),
#    (False, False, 0.8444444444444444, 0.13333333333333333),
#    (True, False, 0.8455042225534023, 0.5254339440694311),
#    (False, False, 0.6541926541926544, 0.4694167852062588),
#    (True, False, 0.9878787878787879, 0.6713972431077694),
#    (True, True, 0.9661172161172161, 0.896825396825397),
#    (False, False, 0.8874458874458873, 0.3529411764705882),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9279220779220781, 0.646969696969697),
#    (False, True, 0.6210970464135028, 0.873417721518987),
#    (True, True, 0.8333333333333333, 1.0),
#    (True, True, 0.9142857142857143, 1.0),
#    (True, True, 0.9407706093189955, 0.9334677419354839),
#    (True, False, 0.9655892255892254, 0.4593554593554594),
#    (False, True, 0.8494897959183677, 0.8452918009308988),
#    (False, False, 0.8935286935286935, 0.6999999999999998),
#    (True, True, 1.0, 0.6818181818181819),
#    (True, True, 0.987012987012987, 0.7861811391223156),
#    (True, False, 0.9865734265734265, 0.5501754385964912),
#    (True, True, 0.9936197461869831, 0.7269846485324312),
#    (True, False, 0.920987654320987, 0.5612962962962966),
#    (True, False, 0.9523809523809526, 0.9333333333333335),
#    (False, False, 0.8444444444444444, 0.13333333333333333),
#    (True, False, 0.8455042225534023, 0.5254339440694311),
#    (False, False, 0.6541926541926544, 0.4694167852062588),
#    (True, False, 0.9878787878787879, 0.6713972431077694),
#    (True, True, 0.9661172161172161, 0.896825396825397),
#    (False, False, 0.8874458874458873, 0.3529411764705882),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9279220779220781, 0.646969696969697),
#    (False, True, 0.6213675213675222, 0.875457875457875),
#    (True, True, 0.8412698412698413, 1.0),
#    (True, True, 0.9142857142857143, 1.0),
#    (True, True, 0.9407706093189955, 0.9334677419354839),
#    (True, False, 0.9655892255892254, 0.4593554593554594),
#    (False, True, 0.8494897959183677, 0.8452918009308988),
#    (False, False, 0.8977498691784406, 0.7),
#    (True, True, 1.0, 0.6818181818181819),
#    (True, True, 1.0, 0.8571428571428571),
#    (True, False, 0.9865734265734265, 0.5501754385964912),
#    (True, True, 0.9936197461869831, 0.7269846485324312),
#    (True, False, 0.9191919191919187, 0.5649621212121215),
#    (True, False, 0.9523809523809526, 0.9333333333333335),
#    (False, False, 0.8444444444444444, 0.13333333333333333),
#    (True, False, 0.8455042225534023, 0.5254339440694311),
#    (False, False, 0.6541926541926544, 0.4694167852062588),
#    (True, False, 0.9878787878787879, 0.6713972431077694),
#    (True, True, 0.9661172161172161, 0.896825396825397),
#    (False, False, 0.8874458874458873, 0.3529411764705882),
#    (True, True, 1.0, 1.0),
#    (True, False, 0.9279220779220781, 0.646969696969697),
#    (False, True, 0.6213675213675222, 0.875457875457875),
#    (True, True, 0.8333333333333333, 1.0),
#    (True, True, 0.9142857142857143, 1.0),
#    (True, True, 0.9407706093189955, 0.9334677419354839),
#    (True, False, 0.9655892255892254, 0.4593554593554594),
#    (False, True, 0.8494897959183677, 0.8452918009308988),
#    (False, False, 0.8918192918192918, 0.7166666666666667),
#    (True, True, 1.0, 0.6818181818181819),
#    (True, True, 0.987012987012987, 0.7861811391223156),
#    (True, False, 0.9865734265734265, 0.5501754385964912),
#    (True, True, 0.9936197461869831, 0.7269846485324312),
#    (True, False, 0.9191919191919187, 0.5649621212121215),
#    (True, False, 0.9523809523809526, 0.9333333333333335),
#    (False, False, 0.8444444444444444, 0.13333333333333333),
#    (True, False, 0.8455042225534023, 0.5254339440694311),
#    (False, False, 0.653846153846154, 0.4649122807017544),
#    (True, False, 0.9878787878787879, 0.6713972431077694),
#    (True, True, 0.9661172161172161, 0.896825396825397),
#    (False, False, 0.8874458874458873, 0.3529411764705882)],
#   2: [(True, False, 0.9393939393939394, 0.7916666666666666),
#    (True, True, 0.9898989898989901, 0.8897058823529412),
#    (True, True, 0.9629629629629629, 1.0),
#    (True, False, 0.9968102073365231, 0.19919530627334622),
#    (False, False, 0.9197802197802198, 0.39391534391534394),
#    (False, False, 0.5909941176470592, 0.6651449275362331),
#    (True, True, 0.9230158730158733, 1.0),
#    (False, False, 0.7636363636363638, 0.8771929824561404),
#    (False, False, 0.9001044932079414, 0.5342811050615046),
#    (False, False, 0.7232142857142857, 0.3979591836734695),
#    (True, True, 0.9502164502164502, 0.9166666666666667),
#    (False, False, 0.9090909090909091, 0.8999999999999999),
#    (True, True, 0.8736842105263161, 0.5335180055401662),
#    (True, False, 0.9393939393939394, 0.7916666666666666),
#    (True, True, 0.9898989898989901, 0.8897058823529412),
#    (True, True, 0.9629629629629629, 1.0),
#    (True, False, 0.9968102073365231, 0.19919530627334622),
#    (False, False, 0.9183673469387756, 0.44444444444444453),
#    (False, False, 0.5873320981936085, 0.6650833048042921),
#    (True, True, 0.9230158730158733, 1.0),
#    (False, False, 0.7636363636363638, 0.8771929824561404),
#    (False, False, 0.9027168234064786, 0.5351885460778385),
#    (False, False, 0.7232142857142857, 0.3979591836734695),
#    (True, True, 0.974025974025974, 0.9166666666666667),
#    (False, False, 0.9090909090909091, 0.8999999999999999),
#    (True, True, 0.8599206349206351, 0.5355263157894739),
#    (True, False, 0.9393939393939394, 0.7916666666666666),
#    (True, True, 0.9898989898989901, 0.8897058823529412),
#    (True, True, 0.9629629629629629, 1.0),
#    (True, False, 0.9968102073365231, 0.19919530627334622),
#    (False, False, 0.9197802197802198, 0.39391534391534394),
#    (False, False, 0.5881713554987216, 0.66507704645701),
#    (True, True, 0.9230158730158733, 1.0),
#    (False, False, 0.768831168831169, 0.8822055137844612),
#    (False, False, 0.9027168234064786, 0.5351885460778385),
#    (False, False, 0.7232142857142857, 0.3979591836734695),
#    (True, True, 0.974025974025974, 0.9166666666666667),
#    (False, False, 0.9090909090909091, 0.8999999999999999),
#    (True, True, 0.8736842105263161, 0.5335180055401662),
#    (True, False, 0.9393939393939394, 0.7916666666666666),
#    (True, True, 0.9898989898989901, 0.8897058823529412),
#    (True, True, 0.9629629629629629, 1.0),
#    (True, False, 0.9968102073365231, 0.19919530627334622),
#    (False, False, 0.9183673469387756, 0.44444444444444453),
#    (False, False, 0.5909941176470592, 0.6651449275362331),
#    (True, True, 0.9230158730158733, 1.0),
#    (False, False, 0.768831168831169, 0.8822055137844612),
#    (False, False, 0.9027168234064786, 0.5351885460778385),
#    (False, False, 0.7244791666666667, 0.38988095238095244),
#    (True, True, 0.9696969696969697, 0.9027777777777778),
#    (False, False, 0.9090909090909091, 0.8999999999999999),
#    (True, True, 0.8736842105263161, 0.5335180055401662),
#    (False, False, 0.9090909090909091, 0.7279411764705883),
#    (True, True, 0.9898989898989901, 0.8897058823529412),
#    (True, True, 0.9629629629629629, 1.0),
#    (True, False, 0.9968102073365231, 0.19919530627334622),
#    (False, False, 0.9183673469387756, 0.44444444444444453),
#    (False, False, 0.5909941176470592, 0.6651449275362331),
#    (True, True, 0.9230158730158733, 1.0),
#    (False, False, 0.7595959595959596, 0.8271604938271605),
#    (False, False, 0.9027168234064786, 0.5351885460778385),
#    (False, False, 0.7232142857142857, 0.3979591836734695),
#    (True, True, 0.9696969696969697, 0.9027777777777778),
#    (False, False, 0.9090909090909091, 0.8999999999999999),
#    (True, True, 0.859809523809524, 0.5351578947368423)]}}

# %%
cluster_num_df
# Out:
#       seed site mig_type  clusters  sites  tree_num  cluster_bins  \
# 0        0   m5       mS        19      5         0             0
# 1        0   m5       mS        19      5         1             0
# 2        7   m5       mS        14      5         0             0
# 3        7   m5       mS        14      5         1             0
# 4        4   m5       mS        12      5         0             0
# ...    ...  ...      ...       ...    ...       ...           ...
# 1642   157   m8        R        29     11        43             2
# 1643   157   m8        R        29     11        44             2
# 1644   157   m8        R        29     11        45             2
# 1645   157   m8        R        29     11        46             2
# 1646   157   m8        R        29     11        47             2
#
#                                   prob_size  prob_size_bins
# 0                           381,469,726.562               0
# 1                           381,469,726.562               0
# 2                               122,070.312               0
# 3                               122,070.312               0
# 4                                 4,882.812               0
# ...                                     ...             ...
# 1642 14,420,993,610,649,923,169,026,048.000               2
# 1643 14,420,993,610,649,923,169,026,048.000               2
# 1644 14,420,993,610,649,923,169,026,048.000               2
# 1645 14,420,993,610,649,923,169,026,048.000               2
# 1646 14,420,993,610,649,923,169,026,048.000               2
#
# [1647 rows x 9 columns]

# %% [markdown]
# ### Load machina results for comparison #TODO: use multiple runs for MACHINA

# %%
mach_node_size_to_ground_truth_slns = {}
mach_num_sites_to_ground_truth_slns = {}
mach_prob_size_bin_to_ground_truth_slns = {}

machina_m5_df, machina_m8_df = eutil.load_machina_results(os.path.join(REPO_DIR, 'test/machina_simulated_data'))
col_mapping = {"FscoreT": "migrating clones F1 score", "FscoreMultiG": "migration graph F1 score", "pattern": "seeding pattern", "seed":"seed"}
machina_m5_df = machina_m5_df.rename(columns=col_mapping)
machina_m8_df = machina_m8_df.rename(columns=col_mapping)
for site, df in zip(['m5', 'm8'],[machina_m5_df, machina_m8_df]):
    for i, row in df.iterrows():
        pattern = row['seeding pattern'].replace("p", "")
        subset_df = cluster_num_df[(cluster_num_df['seed']==int(row['seed']))&(cluster_num_df['site']==site)&(cluster_num_df['mig_type']==pattern)]
        num_nodes = subset_df.iloc[0]['clusters']
        rng = subset_df['cluster_bins'].unique().item()
        num_sites = subset_df.iloc[0]['sites']
        if rng not in mach_node_size_to_ground_truth_slns:
            mach_node_size_to_ground_truth_slns[rng] = []
        if num_sites not in mach_num_sites_to_ground_truth_slns:
            mach_num_sites_to_ground_truth_slns[num_sites] = []
            
        prob_size_bin = subset_df['prob_size_bins'].unique().item()
        if prob_size_bin not in mach_prob_size_bin_to_ground_truth_slns:
            mach_prob_size_bin_to_ground_truth_slns[prob_size_bin] = []
        
            
        ground_truth_clones_found = False
        ground_truth_mig_graph_found = False
        if float(row['migrating clones F1 score']) >= CUTOFF:
            ground_truth_clones_found = True
        if float(row['migration graph F1 score']) >= CUTOFF:
            ground_truth_mig_graph_found = True
        info = (ground_truth_clones_found, ground_truth_mig_graph_found, row['migrating clones F1 score'], row['migration graph F1 score'])
        mach_node_size_to_ground_truth_slns[rng].append(info)
        mach_num_sites_to_ground_truth_slns[num_sites].append(info)
        mach_prob_size_bin_to_ground_truth_slns[prob_size_bin].append(info)
mach_node_size_to_ground_truth_slns
# Out:
# {0: [(False, False, 0.666666666667, 0.5),
#   (False, False, 0.666666666667, 0.5),
#   (False, False, 0.75, 0.5),
#   (False, False, 0.75, 0.5),
#   (False, False, 0.75, 0.5),
#   (False, False, 0.75, 0.5),
#   (False, False, 0.75, 0.5),
#   (False, False, 0.75, 0.5),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (True, False, 1.0, 0.727272727273),
#   (False, False, 0.5, 0.727272727273),
#   (False, False, 0.571428571429, 0.727272727273),
#   (False, False, 0.444444444444, 0.727272727273),
#   (False, False, 0.571428571429, 0.727272727273),
#   (False, False, 0.571428571429, 0.727272727273),
#   (False, False, 0.5, 0.727272727273),
#   (False, False, 0.444444444444, 0.727272727273),
#   (False, False, 0.5, 0.727272727273),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (False, False, 0.8, 0.666666666667),
#   (False, False, 0.888888888889, 0.666666666667),
#   (False, False, 0.8, 0.666666666667),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.615384615385),
#   (True, False, 1.0, 0.615384615385),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75),
#   (True, False, 1.0, 0.75),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.8, 0.75),
#   (False, False, 0.8, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (False, False, 0.8, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (False, False, 0.8, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.909090909091),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.75, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.545454545455, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.666666666667, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.6, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.6, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.75, 0.333333333333),
#   (False, False, 0.75, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (False, False, 0.888888888889, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (False, False, 0.75, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (False, False, 0.6, 0.333333333333),
#   (False, False, 0.8, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.235294117647),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (True, False, 1.0, 0.117647058824),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.8, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.888888888889, 0.571428571429),
#   (False, False, 0.8, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.888888888889, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.888888888889, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.666666666667, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.888888888889, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.666666666667, 0.142857142857),
#   (False, False, 0.888888888889, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.6, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.888888888889, 0.571428571429),
#   (False, False, 0.888888888889, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.888888888889, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.75, 0.142857142857),
#   (False, False, 0.5, 0.545454545455),
#   (False, False, 0.75, 0.571428571429),
#   (False, False, 0.666666666667, 0.571428571429),
#   (False, False, 0.75, 0.571428571429),
#   (False, False, 0.75, 0.571428571429),
#   (False, False, 0.75, 0.769230769231),
#   (False, False, 0.75, 0.769230769231),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.888888888889, 0.428571428571),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.833333333333),
#   (False, False, 0.857142857143, 0.833333333333),
#   (False, False, 0.857142857143, 0.833333333333),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.888888888889, 0.2),
#   (False, False, 0.888888888889, 0.2),
#   (False, False, 0.888888888889, 0.2),
#   (False, False, 0.888888888889, 0.2),
#   (False, False, 0.857142857143, 0.8),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (False, False, 0.75, 0.833333333333),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (True, False, 1.0, 0.6),
#   (False, False, 0.666666666667, 0.8),
#   (False, False, 0.75, 0.8),
#   (False, False, 0.75, 0.8),
#   (False, False, 0.666666666667, 0.8),
#   (False, False, 0.8, 0.888888888889),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.333333333333),
#   (True, False, 1.0, 0.833333333333),
#   (True, False, 1.0, 0.833333333333),
#   (False, False, 0.857142857143, 0.8),
#   (False, False, 0.75, 0.8),
#   (True, False, 1.0, 0.888888888889),
#   (True, False, 1.0, 0.888888888889),
#   (False, False, 0.571428571429, 0.909090909091),
#   (False, False, 0.571428571429, 0.909090909091),
#   (False, False, 0.571428571429, 0.909090909091),
#   (False, False, 0.571428571429, 0.909090909091),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.888888888889),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.666666666667),
#   (False, False, 0.923076923077, 0.666666666667),
#   (True, False, 1.0, 0.823529411765),
#   (True, False, 1.0, 0.823529411765),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.625),
#   (True, False, 1.0, 0.25),
#   (True, False, 1.0, 0.75),
#   (False, False, 0.8, 0.777777777778),
#   (False, False, 0.8, 0.777777777778),
#   (False, False, 0.857142857143, 0.947368421053),
#   (False, False, 0.857142857143, 0.947368421053),
#   (False, False, 0.857142857143, 0.947368421053),
#   (False, False, 0.857142857143, 0.947368421053),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.666666666667)],
#  1: [(False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.666666666667, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.615384615385, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.857142857143, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.615384615385, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.857142857143, 0.8),
#   (False, False, 0.857142857143, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.533333333333, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.8, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.615384615385, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.615384615385, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.769230769231, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (False, False, 0.923076923077, 0.8),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.8, 0.823529411765),
#   (True, False, 1.0, 0.823529411765),
#   (True, False, 1.0, 0.823529411765),
#   (True, False, 1.0, 0.823529411765),
#   (False, False, 0.727272727273, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.727272727273, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.727272727273, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.727272727273, 0.380952380952),
#   (False, False, 0.8, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.909090909091, 0.380952380952),
#   (False, False, 0.888888888889, 0.857142857143),
#   (False, False, 0.533333333333, 0.9),
#   (False, False, 0.714285714286, 0.8),
#   (False, False, 0.8, 0.9),
#   (False, False, 0.857142857143, 0.333333333333),
#   (False, False, 0.857142857143, 0.333333333333),
#   (False, False, 0.857142857143, 0.333333333333),
#   (False, False, 0.857142857143, 0.222222222222),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.625),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.625),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.625),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.666666666667, 0.714285714286),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, False, 0.666666666667, 0.857142857143),
#   (False, True, 0.666666666667, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.909090909091, 0.375),
#   (False, False, 0.727272727273, 0.375),
#   (False, False, 0.909090909091, 0.375),
#   (False, False, 0.909090909091, 0.375),
#   (True, False, 1.0, 0.526315789474),
#   (False, False, 0.909090909091, 0.736842105263),
#   (False, False, 0.909090909091, 0.736842105263),
#   (False, False, 0.909090909091, 0.631578947368),
#   (True, False, 1.0, 0.526315789474),
#   (True, False, 1.0, 0.736842105263),
#   (False, False, 0.909090909091, 0.526315789474),
#   (True, False, 1.0, 0.631578947368),
#   (False, False, 0.923076923077, 0.444444444444),
#   (True, False, 1.0, 0.444444444444),
#   (False, False, 0.857142857143, 0.444444444444),
#   (False, False, 0.923076923077, 0.444444444444),
#   (False, False, 0.714285714286, 0.444444444444),
#   (True, False, 1.0, 0.444444444444),
#   (False, True, 0.666666666667, 1.0),
#   (False, True, 0.615384615385, 1.0),
#   (False, False, 0.666666666667, 0.666666666667),
#   (False, False, 0.666666666667, 0.888888888889),
#   (False, False, 0.666666666667, 0.666666666667),
#   (False, True, 0.666666666667, 1.0),
#   (False, False, 0.666666666667, 0.888888888889),
#   (False, True, 0.615384615385, 1.0),
#   (False, True, 0.666666666667, 1.0),
#   (False, True, 0.666666666667, 1.0),
#   (False, True, 0.615384615385, 1.0),
#   (False, True, 0.666666666667, 1.0),
#   (False, False, 0.666666666667, 0.777777777778),
#   (False, True, 0.666666666667, 1.0),
#   (False, False, 0.666666666667, 0.888888888889),
#   (False, False, 0.666666666667, 0.888888888889),
#   (True, False, 1.0, 0.933333333333),
#   (True, False, 1.0, 0.933333333333),
#   (True, False, 1.0, 0.933333333333),
#   (True, False, 1.0, 0.933333333333),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.857142857143, 0.761904761905),
#   (False, False, 0.857142857143, 0.571428571429),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.47619047619),
#   (False, False, 0.933333333333, 0.857142857143),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.47619047619),
#   (False, False, 0.857142857143, 0.857142857143),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.933333333333, 0.571428571429),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.47619047619),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.857142857143, 0.857142857143),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.8, 0.666666666667),
#   (False, False, 0.933333333333, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.285714285714),
#   (False, False, 0.857142857143, 0.571428571429),
#   (False, False, 0.933333333333, 0.571428571429),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.933333333333, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.857142857143, 0.47619047619),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.933333333333, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.571428571429),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.933333333333, 0.857142857143),
#   (True, False, 1.0, 0.47619047619),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.933333333333, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.857142857143, 0.761904761905),
#   (False, False, 0.857142857143, 0.380952380952),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.8, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.857142857143, 0.571428571429),
#   (True, False, 1.0, 0.47619047619),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.933333333333, 0.761904761905),
#   (False, False, 0.933333333333, 0.857142857143),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.857142857143, 0.666666666667),
#   (False, False, 0.857142857143, 0.761904761905),
#   (False, False, 0.933333333333, 0.761904761905),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.857142857143, 0.380952380952),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.857142857143, 0.857142857143),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.47619047619),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.761904761905),
#   (False, False, 0.933333333333, 0.761904761905),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.285714285714),
#   (False, False, 0.857142857143, 0.761904761905),
#   (True, False, 1.0, 0.761904761905),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.380952380952),
#   (False, False, 0.857142857143, 0.571428571429),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.933333333333, 0.857142857143),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.666666666667),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.857142857143),
#   (True, False, 1.0, 0.571428571429),
#   (False, False, 0.857142857143, 0.857142857143),
#   (True, False, 1.0, 0.857142857143),
#   (True, False, 1.0, 0.380952380952),
#   (True, False, 1.0, 0.857142857143),
#   (False, False, 0.933333333333, 0.761904761905),
#   (False, False, 0.857142857143, 0.571428571429),
#   (False, False, 0.8, 0.5),
#   (False, True, 0.8, 1.0),
#   (False, True, 0.545454545455, 1.0),
#   (False, True, 0.727272727273, 1.0),
#   (True, False, 1.0, 0.5),
#   (True, False, 1.0, 0.5),
#   (False, False, 0.909090909091, 0.5),
#   (False, True, 0.8, 1.0),
#   (True, False, 1.0, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.8, 0.5),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.5),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.5),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.5),
#   (False, True, 0.8, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.8, 0.5),
#   (False, False, 0.909090909091, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, True, 0.909090909091, 1.0),
#   (False, True, 0.727272727273, 1.0),
#   (False, True, 0.8, 1.0),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.8, 0.5),
#   (False, True, 0.727272727273, 1.0),
#   (False, True, 0.8, 1.0),
#   (False, True, 0.8, 1.0),
#   (False, False, 0.8, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, True, 0.8, 1.0),
#   (False, True, 0.545454545455, 1.0),
#   (False, False, 0.727272727273, 0.5),
#   (False, True, 0.909090909091, 1.0),
#   (False, True, 0.545454545455, 1.0),
#   (False, False, 0.8, 0.5),
#   (True, True, 1.0, 1.0),
#   (True, False, 1.0, 0.5),
#   (False, True, 0.8, 1.0),
#   (False, False, 0.8, 0.5),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.727272727273, 1.0),
#   (False, False, 0.8, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.727272727273, 1.0),
#   (True, False, 1.0, 0.5),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.8, 1.0),
#   (False, False, 0.8, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.8, 0.5),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.888888888889, 0.533333333333),
#   (False, False, 0.888888888889, 0.4),
#   (True, False, 1.0, 0.666666666667),
#   (False, False, 0.888888888889, 0.133333333333)],
#  2: [(True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.909090909091, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.8, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.909090909091, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.8, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.909090909091, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.909090909091, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.8, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (False, False, 0.8, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.230769230769),
#   (True, False, 1.0, 0.352941176471),
#   (True, False, 1.0, 0.588235294118),
#   (True, False, 1.0, 0.588235294118),
#   (True, False, 1.0, 0.846153846154),
#   (True, False, 1.0, 0.846153846154),
#   (True, False, 1.0, 0.846153846154),
#   (False, False, 0.923076923077, 0.846153846154),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, False, 1.0, 0.875),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.888888888889, 1.0),
#   (False, False, 0.727272727273, 0.526315789474),
#   (False, False, 0.727272727273, 0.526315789474),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.727272727273, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.727272727273, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (True, False, 1.0, 0.555555555556),
#   (False, False, 0.909090909091, 0.555555555556),
#   (False, False, 0.727272727273, 0.416666666667),
#   (False, False, 0.909090909091, 0.416666666667),
#   (False, False, 0.666666666667, 0.416666666667),
#   (False, False, 0.909090909091, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.727272727273, 0.583333333333),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.666666666667, 0.416666666667),
#   (False, False, 0.727272727273, 0.416666666667),
#   (False, False, 0.909090909091, 0.583333333333),
#   (False, False, 0.909090909091, 0.416666666667),
#   (False, False, 0.727272727273, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.833333333333, 0.5),
#   (False, False, 0.727272727273, 0.416666666667),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.909090909091, 0.583333333333),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.666666666667, 0.416666666667),
#   (False, False, 0.727272727273, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.909090909091, 0.416666666667),
#   (False, False, 0.833333333333, 0.416666666667),
#   (False, False, 0.909090909091, 0.416666666667),
#   (False, False, 0.666666666667, 0.416666666667),
#   (False, False, 0.727272727273, 0.5),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.75, 0.526315789474),
#   (False, False, 0.625, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.875, 0.526315789474),
#   (False, False, 0.588235294118, 0.380952380952),
#   (False, False, 0.625, 0.380952380952),
#   (False, False, 0.823529411765, 0.521739130435),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.25, 0.521739130435),
#   (False, False, 0.235294117647, 0.608695652174),
#   (False, False, 0.375, 0.521739130435),
#   (False, False, 0.235294117647, 0.521739130435),
#   (False, False, 0.75, 0.608695652174),
#   (False, False, 0.235294117647, 0.608695652174),
#   (False, False, 0.235294117647, 0.608695652174),
#   (False, False, 0.75, 0.608695652174),
#   (False, False, 0.235294117647, 0.608695652174),
#   (False, False, 0.875, 0.695652173913),
#   (False, False, 0.75, 0.695652173913),
#   (False, False, 0.375, 0.695652173913),
#   (False, False, 0.823529411765, 0.608695652174),
#   (False, False, 0.875, 0.521739130435),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.666666666667, 0.695652173913),
#   (False, False, 0.823529411765, 0.608695652174),
#   (False, False, 0.333333333333, 0.608695652174),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.666666666667, 0.608695652174),
#   (False, False, 0.823529411765, 0.608695652174),
#   (False, False, 0.352941176471, 0.521739130435),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.875, 0.695652173913),
#   (False, False, 0.75, 0.521739130435),
#   (False, False, 0.235294117647, 0.695652173913),
#   (False, False, 0.235294117647, 0.521739130435),
#   (False, False, 0.666666666667, 0.608695652174),
#   (False, False, 0.75, 0.608695652174),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.875, 0.695652173913),
#   (False, False, 0.75, 0.695652173913),
#   (False, False, 0.875, 0.695652173913),
#   (False, False, 0.333333333333, 0.608695652174),
#   (False, False, 0.875, 0.608695652174),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.666666666667, 0.608695652174),
#   (False, False, 0.875, 0.608695652174),
#   (False, False, 0.823529411765, 0.695652173913),
#   (False, False, 0.352941176471, 0.608695652174),
#   (False, False, 0.823529411765, 0.608695652174),
#   (False, False, 0.352941176471, 0.608695652174),
#   (False, False, 0.352941176471, 0.695652173913),
#   (False, False, 0.875, 0.695652173913),
#   (False, True, 0.888888888889, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.727272727273, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.8, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.888888888889, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, True, 0.888888888889, 1.0),
#   (True, True, 1.0, 1.0),
#   (True, True, 1.0, 1.0),
#   (False, False, 0.909090909091, 0.941176470588),
#   (False, False, 0.909090909091, 0.941176470588),
#   (False, False, 0.909090909091, 0.941176470588),
#   (False, False, 0.909090909091, 0.941176470588)]}

# %%
def get_merged_results_df(met_dict, mach_dict, x, methods):
    data = []
    for bs in met_dict:
        for key in met_dict[bs]:
            gt_list = met_dict[bs][key]
            percent_true_clones = sum(1 for item in gt_list if item[0]) / len(gt_list) * 100
            percent_true_mig_graph = sum(1 for item in gt_list if item[1]) / len(gt_list) * 100
            avg_clones_f1 = sum(item[2] for item in gt_list) / len(gt_list) * 100
            avg_mig_graph_f1 = sum(item[3] for item in gt_list) / len(gt_list) * 100
            data.append([f"Metient-{bs}", key, avg_clones_f1, avg_mig_graph_f1, percent_true_clones, percent_true_mig_graph])
    
    for key in mach_dict:
        gt_list = mach_dict[key]
        percent_true_clones = sum(1 for item in gt_list if item[0]) / len(gt_list) * 100
        percent_true_mig_graph = sum(1 for item in gt_list if item[1]) / len(gt_list) * 100
        avg_clones_f1 = sum(item[2] for item in gt_list) / len(gt_list) * 100
        avg_mig_graph_f1 = sum(item[3] for item in gt_list) / len(gt_list) * 100
        data.append(["MACHINA", key, avg_clones_f1, avg_mig_graph_f1, percent_true_clones, percent_true_mig_graph])
    results = pd.DataFrame(data, columns=["Method", x, "Migrating clones F1-score", "Migration graph F1-score", "% time that migrating clone ground truth found", "% time that migration graph ground truth found"])
    return results

methods = ["Metient-64", "Metient-256", "Metient-1024",]

results1 = get_merged_results_df(bs_to_num_nodes_to_ground_truth_slns, mach_node_size_to_ground_truth_slns, "Number of tree nodes", methods)
results2 = get_merged_results_df(bs_to_num_sites_to_ground_truth_slns, mach_num_sites_to_ground_truth_slns, "Number of anatomical sites", methods)
results3 = get_merged_results_df(bs_to_prob_size_bin_to_ground_truth_slns, mach_prob_size_bin_to_ground_truth_slns, "Size of search space binned", methods)
# results4 = get_merged_results_df(bs_to_prob_size_to_ground_truth_slns, mach_prob_size_to_ground_truth_slns, "Size of Search Space", methods)

results1
# Out:
#           Method  Number of tree nodes  Migrating clones F1-score  \
# 0     Metient-64                     0                     93.627
# 1     Metient-64                     1                     91.622
# 2     Metient-64                     2                     89.752
# 3    Metient-256                     0                     92.507
# 4    Metient-256                     1                     91.062
# 5    Metient-256                     2                     88.479
# 6   Metient-1024                     0                     91.177
# 7   Metient-1024                     1                     89.915
# 8   Metient-1024                     2                     88.833
# 9        MACHINA                     0                     90.419
# 10       MACHINA                     1                     88.689
# 11       MACHINA                     2                     84.658
#
#     Migration graph F1-score  % time that migrating clone ground truth found  \
# 0                     76.743                                          76.087
# 1                     71.812                                          80.000
# 2                     63.580                                          35.714
# 3                     76.760                                          70.000
# 4                     73.256                                          75.000
# 5                     66.533                                          42.857
# 6                     76.550                                          65.652
# 7                     71.259                                          70.000
# 8                     68.952                                          55.714
# 9                     58.344                                          52.754
# 10                    70.657                                          44.675
# 11                    50.726                                          43.933
#
#     % time that migration graph ground truth found
# 0                                           50.000
# 1                                           42.000
# 2                                           21.429
# 3                                           41.304
# 4                                           60.000
# 5                                           28.571
# 6                                           28.261
# 7                                           50.000
# 8                                           35.714
# 9                                            7.536
# 10                                          16.104
# 11                                           7.531

# %% [markdown]
# ### Make plots for performance as a function of tree size, # anatomical sites, and size of search space

# %%
import seaborn as sns
import matplotlib.pyplot as plt
colors = sns.color_palette("crest")
colors = colors[:len(methods)]
colors.append((0.99609375, 0.56640625, 0.37109375))
print(colors)
sns.set_palette(sns.color_palette(colors))

ys = ["Migrating clones F1-score", "Migration graph F1-score", "% time that migrating clone ground truth found", "% time that migration graph ground truth found"]
y_labels = ["Migrating clones F1-score", "Migration graph F1-score", "Ground truth migrating\n clones found (%)", "Ground truth migration\n graph found (%)"]
out_names = ["Migrating clones F1-score", "Migration graph F1-score", "Ground truth migrating clones found", "Ground truth migration graph found"]

def get_tree_node_bins():
    bin_numbers = sorted(list(cluster_num_df['cluster_bins'].unique()))
    bin_ranges = []
    for bin_num in bin_numbers:
        bin_min = cluster_num_df[cluster_num_df['cluster_bins']==bin_num]['clusters'].min()
        bin_max = cluster_num_df[cluster_num_df['cluster_bins']==bin_num]['clusters'].max()
        size = len(cluster_num_df[cluster_num_df['cluster_bins']==bin_num])
        bin_ranges.append(f"{bin_min}-{bin_max}")
        print(bin_num, bin_min, bin_max, size)
    return bin_numbers, bin_ranges

def get_prob_size_bins():
    bin_numbers = sorted(list(cluster_num_df['prob_size_bins'].unique()))
    bin_ranges = []
    for bin_num in bin_numbers:
        bin_min = cluster_num_df[cluster_num_df['prob_size_bins']==bin_num]['prob_size'].min()*denom
        bin_minf = "{:.1e}".format(bin_min)
        bin_max = cluster_num_df[cluster_num_df['prob_size_bins']==bin_num]['prob_size'].max()*denom
        bin_maxf = "{:.1e}".format(bin_max)
        size = len(cluster_num_df[cluster_num_df['prob_size_bins']==bin_num])
        bin_ranges.append(f"{bin_minf}-{bin_maxf}")
        print(bin_num, bin_minf, bin_maxf, size)
    return bin_numbers, bin_ranges

for x, df in zip(["Number of tree nodes", "Number of anatomical sites", "Size of search space binned"], [results1, results2, results3]):
    for i,y in enumerate(ys):
        with sns.plotting_context("notebook", font_scale=1.6):
            g = sns.lineplot(
                data=df, x=x, y=y, linewidth=2.5,
                hue="Method", legend=False,  
            )
            if x == "Number of tree nodes":
                bin_numbers, bin_ranges = get_tree_node_bins()
                plt.xticks(ticks=bin_numbers,labels=bin_ranges)
            if x == "Size of search space binned":
                bin_numbers, bin_ranges = get_prob_size_bins()
                plt.xticks(ticks=bin_numbers,labels=bin_ranges)
                plt.xticks(rotation=45)
            if x == "Size of search space":
                plt.xscale('log')
            
            if y == "% time that migration graph ground truth found":
                plt.ylim(0, 50)
            elif y == "Migrating clones F1-score":
                plt.ylim(80, 100)
            else:
                plt.ylim(0, 100)
                
            legend = g.legend(prop={'size': 8})  # Set the desired font size here
            g.spines['top'].set_visible(False)
            g.spines['right'].set_visible(False)
            
            plt.ylabel(y_labels[i])
            out_name = ("_").join(out_names[i].split(" ") + x.split(" "))

            plt.savefig(os.path.join(REPO_DIR, "test/output_plots", f"{out_name}_10runs_lossthres{LOSS_THRES}_{PARAMS}_{DATE}.png"), dpi=600, bbox_inches="tight", pad_inches=0.3) 

            plt.show()
# Out:
# 12:47:14 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# [(0.48942421, 0.72854938, 0.56751036), (0.34892097, 0.64828676, 0.56513633), (0.24929311, 0.56486397, 0.5586654), (0.99609375, 0.56640625, 0.37109375)]
# 0 7 19 567
# 1 20 24 542
# 2 25 29 538
# 12:47:15 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 7 19 567
# 1 20 24 542
# 2 25 29 538
# 12:47:16 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 7 19 567
# 1 20 24 542
# 2 25 29 538
# 12:47:17 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 7 19 567
# 1 20 24 542
# 2 25 29 538
# 12:47:18 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 12:47:19 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 12:47:20 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 12:47:21 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 12:47:22 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 1.6e+04 1.8e+16 567
# 1 1.3e+17 8.9e+21 548
# 2 3.8e+22 1.4e+29 532
# 12:47:24 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 1.6e+04 1.8e+16 567
# 1 1.3e+17 8.9e+21 548
# 2 3.8e+22 1.4e+29 532
# 12:47:25 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 1.6e+04 1.8e+16 567
# 1 1.3e+17 8.9e+21 548
# 2 3.8e+22 1.4e+29 532
# 12:47:27 WARNING
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# 0 1.6e+04 1.8e+16 567
# 1 1.3e+17 8.9e+21 548
# 2 3.8e+22 1.4e+29 532
